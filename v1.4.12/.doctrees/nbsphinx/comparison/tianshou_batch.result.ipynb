# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fe39cf22940>
# ├── 'a' --> tensor([[ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313]])
# └── 'x' --> <FastTreeValue 0x7fe39cf228b0>
#     └── 'c' --> tensor([[-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675]])

# %%
t.a
# Out:
# tensor([[ 1.2092,  0.7298,  0.1790],
#         [-0.7701,  1.3919, -0.1313]])

# %%
# %timeit t.a
# Out:
# 74.2 ns ± 0.149 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fe39cf22940>
# ├── 'a' --> tensor([[-0.2590,  1.0531,  0.9089],
# │                   [-0.7960, -1.9613, -0.4437]])
# └── 'x' --> <FastTreeValue 0x7fe39cf228b0>
#     └── 'c' --> tensor([[-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675]])

# %%
# %timeit t.a = new_value
# Out:
# 75.5 ns ± 0.155 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313]]),
#     x: Batch(
#            c: tensor([[-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.2092,  0.7298,  0.1790],
#         [-0.7701,  1.3919, -0.1313]])

# %%
# %timeit b.a
# Out:
# 66.2 ns ± 0.124 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.0684, -1.3879, -0.2608],
#                [-0.9117,  1.4592, -0.0309]]),
#     x: Batch(
#            c: tensor([[-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 546 ns ± 2.32 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 882 ns ± 1.45 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 29.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 151 µs ± 1.27 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 153 µs ± 1.03 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fe2ae5868b0>
# ├── 'a' --> tensor([[[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]],
# │
# │                   [[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]],
# │
# │                   [[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]],
# │
# │                   [[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]],
# │
# │                   [[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]],
# │
# │                   [[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]],
# │
# │                   [[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]],
# │
# │                   [[ 1.2092,  0.7298,  0.1790],
# │                    [-0.7701,  1.3919, -0.1313]]])
# └── 'x' --> <FastTreeValue 0x7fe2c8a7dd00>
#     └── 'c' --> tensor([[[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                         [[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                         [[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                         [[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                         [[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                         [[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                         [[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                         [[-0.6659,  0.5828, -0.3355,  1.3561],
#                          [ 0.5608, -0.0599,  1.7662, -1.4576],
#                          [-0.1522,  2.0440, -0.4743,  0.8675]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.3 µs ± 59.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fe2ae586550>
# ├── 'a' --> tensor([[ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313],
# │                   [ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313],
# │                   [ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313],
# │                   [ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313],
# │                   [ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313],
# │                   [ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313],
# │                   [ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313],
# │                   [ 1.2092,  0.7298,  0.1790],
# │                   [-0.7701,  1.3919, -0.1313]])
# └── 'x' --> <FastTreeValue 0x7fe39cf22c40>
#     └── 'c' --> tensor([[-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675],
#                         [-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675],
#                         [-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675],
#                         [-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675],
#                         [-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675],
#                         [-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675],
#                         [-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675],
#                         [-0.6659,  0.5828, -0.3355,  1.3561],
#                         [ 0.5608, -0.0599,  1.7662, -1.4576],
#                         [-0.1522,  2.0440, -0.4743,  0.8675]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.4 µs ± 129 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.3 µs ± 57.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]],
#
#                [[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]],
#
#                [[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]],
#
#                [[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]],
#
#                [[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]],
#
#                [[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]],
#
#                [[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]],
#
#                [[ 1.2092,  0.7298,  0.1790],
#                 [-0.7701,  1.3919, -0.1313]]]),
#     x: Batch(
#            c: tensor([[[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                       [[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                       [[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                       [[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                       [[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                       [[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                       [[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]],
#
#                       [[-0.6659,  0.5828, -0.3355,  1.3561],
#                        [ 0.5608, -0.0599,  1.7662, -1.4576],
#                        [-0.1522,  2.0440, -0.4743,  0.8675]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.6 µs ± 356 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313],
#                [ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313],
#                [ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313],
#                [ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313],
#                [ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313],
#                [ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313],
#                [ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313],
#                [ 1.2092,  0.7298,  0.1790],
#                [-0.7701,  1.3919, -0.1313]]),
#     x: Batch(
#            c: tensor([[-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675],
#                       [-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675],
#                       [-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675],
#                       [-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675],
#                       [-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675],
#                       [-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675],
#                       [-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675],
#                       [-0.6659,  0.5828, -0.3355,  1.3561],
#                       [ 0.5608, -0.0599,  1.7662, -1.4576],
#                       [-0.1522,  2.0440, -0.4743,  0.8675]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 144 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 387 µs ± 6.02 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
