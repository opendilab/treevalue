# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5f50524a00>
# ├── 'a' --> tensor([[ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519]])
# └── 'x' --> <FastTreeValue 0x7f5f50524bb0>
#     └── 'c' --> tensor([[ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435]])

# %%
t.a
# Out:
# tensor([[ 0.0611, -2.2357, -0.2635],
#         [ 2.2987,  1.9464, -0.9519]])

# %%
# %timeit t.a
# Out:
# 83.2 ns ± 1.07 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5f50524a00>
# ├── 'a' --> tensor([[-0.2966, -0.2014,  0.0176],
# │                   [-0.3897,  1.0773,  0.5717]])
# └── 'x' --> <FastTreeValue 0x7f5f50524bb0>
#     └── 'c' --> tensor([[ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435]])

# %%
# %timeit t.a = new_value
# Out:
# 98.9 ns ± 1.19 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519]]),
#     x: Batch(
#            c: tensor([[ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0611, -2.2357, -0.2635],
#         [ 2.2987,  1.9464, -0.9519]])

# %%
# %timeit b.a
# Out:
# 75.6 ns ± 1.78 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.1592,  0.4027,  0.7936],
#                [-0.8773,  0.0622,  1.9457]]),
#     x: Batch(
#            c: tensor([[ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 670 ns ± 13.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.07 µs ± 12.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.3 µs ± 120 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 296 µs ± 14.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 302 µs ± 6.67 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5f481e07f0>
# ├── 'a' --> tensor([[[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]],
# │
# │                   [[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]],
# │
# │                   [[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]],
# │
# │                   [[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]],
# │
# │                   [[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]],
# │
# │                   [[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]],
# │
# │                   [[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]],
# │
# │                   [[ 0.0611, -2.2357, -0.2635],
# │                    [ 2.2987,  1.9464, -0.9519]]])
# └── 'x' --> <FastTreeValue 0x7f5f481e0be0>
#     └── 'c' --> tensor([[[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                         [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                         [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                         [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                         [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                         [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                         [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                         [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                          [ 0.0363,  1.1858,  2.5663, -1.4157],
#                          [ 0.5782, -0.7824,  1.4679,  0.5435]]])

# %%
# %timeit t_stack(trees)
# Out:
# 50.9 µs ± 752 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5e5fbf6f10>
# ├── 'a' --> tensor([[ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519],
# │                   [ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519],
# │                   [ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519],
# │                   [ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519],
# │                   [ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519],
# │                   [ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519],
# │                   [ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519],
# │                   [ 0.0611, -2.2357, -0.2635],
# │                   [ 2.2987,  1.9464, -0.9519]])
# └── 'x' --> <FastTreeValue 0x7f5e5fbf6fa0>
#     └── 'c' --> tensor([[ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435],
#                         [ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435],
#                         [ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435],
#                         [ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435],
#                         [ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435],
#                         [ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435],
#                         [ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435],
#                         [ 3.7958, -1.5951, -0.1527, -1.0054],
#                         [ 0.0363,  1.1858,  2.5663, -1.4157],
#                         [ 0.5782, -0.7824,  1.4679,  0.5435]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.2 µs ± 814 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 99.2 µs ± 1.08 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]],
#
#                [[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]],
#
#                [[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]],
#
#                [[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]],
#
#                [[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]],
#
#                [[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]],
#
#                [[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]],
#
#                [[ 0.0611, -2.2357, -0.2635],
#                 [ 2.2987,  1.9464, -0.9519]]]),
#     x: Batch(
#            c: tensor([[[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                       [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                       [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                       [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                       [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                       [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                       [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]],
#
#                       [[ 3.7958, -1.5951, -0.1527, -1.0054],
#                        [ 0.0363,  1.1858,  2.5663, -1.4157],
#                        [ 0.5782, -0.7824,  1.4679,  0.5435]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 166 µs ± 3.12 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519],
#                [ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519],
#                [ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519],
#                [ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519],
#                [ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519],
#                [ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519],
#                [ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519],
#                [ 0.0611, -2.2357, -0.2635],
#                [ 2.2987,  1.9464, -0.9519]]),
#     x: Batch(
#            c: tensor([[ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435],
#                       [ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435],
#                       [ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435],
#                       [ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435],
#                       [ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435],
#                       [ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435],
#                       [ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435],
#                       [ 3.7958, -1.5951, -0.1527, -1.0054],
#                       [ 0.0363,  1.1858,  2.5663, -1.4157],
#                       [ 0.5782, -0.7824,  1.4679,  0.5435]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 202 µs ± 3.51 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 785 µs ± 39.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
