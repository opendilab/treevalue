# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f3717a048e0>
# ├── 'a' --> tensor([[-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066]])
# └── 'x' --> <FastTreeValue 0x7f370d23a970>
#     └── 'c' --> tensor([[ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998]])

# %%
t.a
# Out:
# tensor([[-0.8283,  0.2278, -1.8077],
#         [ 0.1389,  1.0039,  0.2066]])

# %%
# %timeit t.a
# Out:
# 62.6 ns ± 0.0638 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f3717a048e0>
# ├── 'a' --> tensor([[-0.3710, -0.7582, -0.8741],
# │                   [-0.1402,  0.5530, -0.2904]])
# └── 'x' --> <FastTreeValue 0x7f370d23a970>
#     └── 'c' --> tensor([[ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998]])

# %%
# %timeit t.a = new_value
# Out:
# 62.4 ns ± 0.0321 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066]]),
#     x: Batch(
#            c: tensor([[ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.8283,  0.2278, -1.8077],
#         [ 0.1389,  1.0039,  0.2066]])

# %%
# %timeit b.a
# Out:
# 57.6 ns ± 0.0899 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.4606, -0.6758,  0.8550],
#                [ 0.6078, -1.1570,  0.5706]]),
#     x: Batch(
#            c: tensor([[ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 496 ns ± 0.0976 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.52 µs ± 57.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 61.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 8.15 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 718 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f37ec3dd070>
# ├── 'a' --> tensor([[[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]],
# │
# │                   [[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]],
# │
# │                   [[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]],
# │
# │                   [[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]],
# │
# │                   [[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]],
# │
# │                   [[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]],
# │
# │                   [[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]],
# │
# │                   [[-0.8283,  0.2278, -1.8077],
# │                    [ 0.1389,  1.0039,  0.2066]]])
# └── 'x' --> <FastTreeValue 0x7f36feab0fa0>
#     └── 'c' --> tensor([[[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                         [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                         [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                         [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                         [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                         [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                         [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                         [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                          [-1.1793, -0.7833,  0.7888,  0.2202],
#                          [-0.6862,  0.0133,  0.5610,  0.4998]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.6 µs ± 129 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f36fea51430>
# ├── 'a' --> tensor([[-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066],
# │                   [-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066],
# │                   [-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066],
# │                   [-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066],
# │                   [-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066],
# │                   [-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066],
# │                   [-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066],
# │                   [-0.8283,  0.2278, -1.8077],
# │                   [ 0.1389,  1.0039,  0.2066]])
# └── 'x' --> <FastTreeValue 0x7f36fea510d0>
#     └── 'c' --> tensor([[ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998],
#                         [ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998],
#                         [ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998],
#                         [ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998],
#                         [ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998],
#                         [ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998],
#                         [ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998],
#                         [ 1.5220,  1.1155,  0.9141,  1.2550],
#                         [-1.1793, -0.7833,  0.7888,  0.2202],
#                         [-0.6862,  0.0133,  0.5610,  0.4998]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.7 µs ± 50.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 70.3 µs ± 142 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                       [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                       [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                       [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                       [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                       [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                       [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]],
#
#                       [[ 1.5220,  1.1155,  0.9141,  1.2550],
#                        [-1.1793, -0.7833,  0.7888,  0.2202],
#                        [-0.6862,  0.0133,  0.5610,  0.4998]]]),
#        ),
#     a: tensor([[[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]],
#
#                [[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]],
#
#                [[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]],
#
#                [[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]],
#
#                [[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]],
#
#                [[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]],
#
#                [[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]],
#
#                [[-0.8283,  0.2278, -1.8077],
#                 [ 0.1389,  1.0039,  0.2066]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.4 µs ± 250 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998],
#                       [ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998],
#                       [ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998],
#                       [ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998],
#                       [ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998],
#                       [ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998],
#                       [ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998],
#                       [ 1.5220,  1.1155,  0.9141,  1.2550],
#                       [-1.1793, -0.7833,  0.7888,  0.2202],
#                       [-0.6862,  0.0133,  0.5610,  0.4998]]),
#        ),
#     a: tensor([[-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066],
#                [-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066],
#                [-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066],
#                [-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066],
#                [-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066],
#                [-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066],
#                [-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066],
#                [-0.8283,  0.2278, -1.8077],
#                [ 0.1389,  1.0039,  0.2066]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 529 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 368 µs ± 4.58 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
