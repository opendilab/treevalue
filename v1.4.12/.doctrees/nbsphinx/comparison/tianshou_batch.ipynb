# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fba06b47eb0>
# ├── 'a' --> tensor([[-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939]])
# └── 'x' --> <FastTreeValue 0x7fba06b47d30>
#     └── 'c' --> tensor([[-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853]])

# %%
t.a
# Out:
# tensor([[-0.9037,  2.6069,  0.8644],
#         [-0.0202,  0.2338,  0.5939]])

# %%
# %timeit t.a
# Out:
# 71 ns ± 0.0961 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fba06b47eb0>
# ├── 'a' --> tensor([[ 0.5469,  1.2589, -0.5805],
# │                   [ 0.8191, -0.0592,  1.4940]])
# └── 'x' --> <FastTreeValue 0x7fba06b47d30>
#     └── 'c' --> tensor([[-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853]])

# %%
# %timeit t.a = new_value
# Out:
# 71.8 ns ± 0.05 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939]]),
#     x: Batch(
#            c: tensor([[-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.9037,  2.6069,  0.8644],
#         [-0.0202,  0.2338,  0.5939]])

# %%
# %timeit b.a
# Out:
# 66.1 ns ± 0.0793 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.6502, -1.8896,  0.2761],
#                [ 1.3980, -0.0751,  0.6540]]),
#     x: Batch(
#            c: tensor([[-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 543 ns ± 0.203 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.06 µs ± 68.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 63.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 149 µs ± 1.74 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 149 µs ± 790 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fb917149550>
# ├── 'a' --> tensor([[[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]],
# │
# │                   [[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]],
# │
# │                   [[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]],
# │
# │                   [[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]],
# │
# │                   [[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]],
# │
# │                   [[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]],
# │
# │                   [[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]],
# │
# │                   [[-0.9037,  2.6069,  0.8644],
# │                    [-0.0202,  0.2338,  0.5939]]])
# └── 'x' --> <FastTreeValue 0x7fb917149df0>
#     └── 'c' --> tensor([[[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                         [[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                         [[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                         [[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                         [[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                         [[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                         [[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                         [[-0.2066,  0.2935, -0.5059,  1.8472],
#                          [-0.9459, -0.3755, -1.6203, -0.7609],
#                          [ 0.3784,  0.6495,  0.7426,  2.0853]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.9 µs ± 38.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fb917149490>
# ├── 'a' --> tensor([[-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939],
# │                   [-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939],
# │                   [-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939],
# │                   [-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939],
# │                   [-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939],
# │                   [-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939],
# │                   [-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939],
# │                   [-0.9037,  2.6069,  0.8644],
# │                   [-0.0202,  0.2338,  0.5939]])
# └── 'x' --> <FastTreeValue 0x7fb917149d90>
#     └── 'c' --> tensor([[-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853],
#                         [-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853],
#                         [-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853],
#                         [-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853],
#                         [-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853],
#                         [-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853],
#                         [-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853],
#                         [-0.2066,  0.2935, -0.5059,  1.8472],
#                         [-0.9459, -0.3755, -1.6203, -0.7609],
#                         [ 0.3784,  0.6495,  0.7426,  2.0853]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 75.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.3 µs ± 210 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                       [[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                       [[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                       [[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                       [[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                       [[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                       [[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]],
#
#                       [[-0.2066,  0.2935, -0.5059,  1.8472],
#                        [-0.9459, -0.3755, -1.6203, -0.7609],
#                        [ 0.3784,  0.6495,  0.7426,  2.0853]]]),
#        ),
#     a: tensor([[[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]],
#
#                [[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]],
#
#                [[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]],
#
#                [[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]],
#
#                [[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]],
#
#                [[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]],
#
#                [[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]],
#
#                [[-0.9037,  2.6069,  0.8644],
#                 [-0.0202,  0.2338,  0.5939]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.9 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853],
#                       [-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853],
#                       [-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853],
#                       [-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853],
#                       [-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853],
#                       [-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853],
#                       [-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853],
#                       [-0.2066,  0.2935, -0.5059,  1.8472],
#                       [-0.9459, -0.3755, -1.6203, -0.7609],
#                       [ 0.3784,  0.6495,  0.7426,  2.0853]]),
#        ),
#     a: tensor([[-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939],
#                [-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939],
#                [-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939],
#                [-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939],
#                [-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939],
#                [-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939],
#                [-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939],
#                [-0.9037,  2.6069,  0.8644],
#                [-0.0202,  0.2338,  0.5939]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 387 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 376 µs ± 8.61 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
