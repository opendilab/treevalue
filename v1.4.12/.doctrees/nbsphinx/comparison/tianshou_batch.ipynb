# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f0d54624a30>
# ├── 'a' --> tensor([[ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968]])
# └── 'x' --> <FastTreeValue 0x7f0d54624820>
#     └── 'c' --> tensor([[-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187]])

# %%
t.a
# Out:
# tensor([[ 0.8338,  0.6833, -0.6602],
#         [-0.2986, -1.6275, -0.6968]])

# %%
# %timeit t.a
# Out:
# 94.4 ns ± 0.162 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f0d54624a30>
# ├── 'a' --> tensor([[ 0.3872,  0.5999,  0.0477],
# │                   [ 0.2599, -1.1853,  0.1348]])
# └── 'x' --> <FastTreeValue 0x7f0d54624820>
#     └── 'c' --> tensor([[-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187]])

# %%
# %timeit t.a = new_value
# Out:
# 95.6 ns ± 1.39 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968]]),
#     x: Batch(
#            c: tensor([[-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8338,  0.6833, -0.6602],
#         [-0.2986, -1.6275, -0.6968]])

# %%
# %timeit b.a
# Out:
# 87.1 ns ± 2.27 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.1708,  0.6405, -1.0662],
#                [-0.1377, -1.0548,  0.1775]]),
#     x: Batch(
#            c: tensor([[-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 659 ns ± 0.221 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 10.6 µs ± 75.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.4 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 176 µs ± 2.12 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 177 µs ± 2.9 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f0d54688e20>
# ├── 'a' --> tensor([[[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]],
# │
# │                   [[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]],
# │
# │                   [[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]],
# │
# │                   [[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]],
# │
# │                   [[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]],
# │
# │                   [[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]],
# │
# │                   [[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]],
# │
# │                   [[ 0.8338,  0.6833, -0.6602],
# │                    [-0.2986, -1.6275, -0.6968]]])
# └── 'x' --> <FastTreeValue 0x7f0c642b36a0>
#     └── 'c' --> tensor([[[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                         [[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                         [[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                         [[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                         [[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                         [[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                         [[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                         [[-0.3486, -1.2356, -0.5044,  1.0485],
#                          [-1.0779, -0.6645,  0.3592, -0.2348],
#                          [ 1.3214,  0.3568, -1.1100, -0.0187]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39 µs ± 842 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f0c63c49a90>
# ├── 'a' --> tensor([[ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968],
# │                   [ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968],
# │                   [ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968],
# │                   [ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968],
# │                   [ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968],
# │                   [ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968],
# │                   [ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968],
# │                   [ 0.8338,  0.6833, -0.6602],
# │                   [-0.2986, -1.6275, -0.6968]])
# └── 'x' --> <FastTreeValue 0x7f0c63c49d30>
#     └── 'c' --> tensor([[-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187],
#                         [-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187],
#                         [-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187],
#                         [-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187],
#                         [-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187],
#                         [-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187],
#                         [-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187],
#                         [-0.3486, -1.2356, -0.5044,  1.0485],
#                         [-1.0779, -0.6645,  0.3592, -0.2348],
#                         [ 1.3214,  0.3568, -1.1100, -0.0187]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.8 µs ± 526 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.3 µs ± 377 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                       [[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                       [[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                       [[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                       [[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                       [[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                       [[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]],
#
#                       [[-0.3486, -1.2356, -0.5044,  1.0485],
#                        [-1.0779, -0.6645,  0.3592, -0.2348],
#                        [ 1.3214,  0.3568, -1.1100, -0.0187]]]),
#        ),
#     a: tensor([[[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]],
#
#                [[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]],
#
#                [[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]],
#
#                [[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]],
#
#                [[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]],
#
#                [[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]],
#
#                [[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]],
#
#                [[ 0.8338,  0.6833, -0.6602],
#                 [-0.2986, -1.6275, -0.6968]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.4 µs ± 520 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187],
#                       [-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187],
#                       [-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187],
#                       [-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187],
#                       [-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187],
#                       [-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187],
#                       [-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187],
#                       [-0.3486, -1.2356, -0.5044,  1.0485],
#                       [-1.0779, -0.6645,  0.3592, -0.2348],
#                       [ 1.3214,  0.3568, -1.1100, -0.0187]]),
#        ),
#     a: tensor([[ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968],
#                [ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968],
#                [ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968],
#                [ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968],
#                [ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968],
#                [ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968],
#                [ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968],
#                [ 0.8338,  0.6833, -0.6602],
#                [-0.2986, -1.6275, -0.6968]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 181 µs ± 995 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 448 µs ± 28.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
