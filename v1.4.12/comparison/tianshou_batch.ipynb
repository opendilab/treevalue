# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f890c25eaf0>
# ├── 'a' --> tensor([[ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881]])
# └── 'x' --> <FastTreeValue 0x7f890c25e970>
#     └── 'c' --> tensor([[-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427]])

# %%
t.a
# Out:
# tensor([[ 0.2438, -0.4234,  0.8772],
#         [ 1.3609,  0.7174,  0.0881]])

# %%
# %timeit t.a
# Out:
# 87.5 ns ± 0.337 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f890c25eaf0>
# ├── 'a' --> tensor([[ 0.9933, -0.4904, -1.4718],
# │                   [ 0.1819,  0.3785,  0.2789]])
# └── 'x' --> <FastTreeValue 0x7f890c25e970>
#     └── 'c' --> tensor([[-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427]])

# %%
# %timeit t.a = new_value
# Out:
# 92.9 ns ± 0.625 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881]]),
#     x: Batch(
#            c: tensor([[-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.2438, -0.4234,  0.8772],
#         [ 1.3609,  0.7174,  0.0881]])

# %%
# %timeit b.a
# Out:
# 78.4 ns ± 0.481 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.1555, -0.3171,  1.3021],
#                [ 1.4973, -0.0630,  0.0254]]),
#     x: Batch(
#            c: tensor([[-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 644 ns ± 2.56 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.42 µs ± 73.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.1 µs ± 43.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 171 µs ± 1.43 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 172 µs ± 1.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f890c2c8c10>
# ├── 'a' --> tensor([[[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]],
# │
# │                   [[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]],
# │
# │                   [[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]],
# │
# │                   [[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]],
# │
# │                   [[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]],
# │
# │                   [[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]],
# │
# │                   [[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]],
# │
# │                   [[ 0.2438, -0.4234,  0.8772],
# │                    [ 1.3609,  0.7174,  0.0881]]])
# └── 'x' --> <FastTreeValue 0x7f881b9c11f0>
#     └── 'c' --> tensor([[[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                         [[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                         [[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                         [[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                         [[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                         [[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                         [[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                         [[-0.9574, -0.8693, -0.5406, -1.2562],
#                          [-1.1474, -1.2029, -0.6476, -0.0194],
#                          [-1.4660,  1.1781,  0.9368,  0.2427]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39.2 µs ± 473 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f881b885b50>
# ├── 'a' --> tensor([[ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881],
# │                   [ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881],
# │                   [ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881],
# │                   [ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881],
# │                   [ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881],
# │                   [ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881],
# │                   [ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881],
# │                   [ 0.2438, -0.4234,  0.8772],
# │                   [ 1.3609,  0.7174,  0.0881]])
# └── 'x' --> <FastTreeValue 0x7f881b885220>
#     └── 'c' --> tensor([[-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427],
#                         [-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427],
#                         [-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427],
#                         [-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427],
#                         [-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427],
#                         [-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427],
#                         [-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427],
#                         [-0.9574, -0.8693, -0.5406, -1.2562],
#                         [-1.1474, -1.2029, -0.6476, -0.0194],
#                         [-1.4660,  1.1781,  0.9368,  0.2427]])

# %%
# %timeit t_cat(trees)
# Out:
# 37 µs ± 401 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 73.8 µs ± 761 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]],
#
#                [[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]],
#
#                [[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]],
#
#                [[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]],
#
#                [[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]],
#
#                [[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]],
#
#                [[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]],
#
#                [[ 0.2438, -0.4234,  0.8772],
#                 [ 1.3609,  0.7174,  0.0881]]]),
#     x: Batch(
#            c: tensor([[[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                       [[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                       [[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                       [[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                       [[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                       [[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                       [[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]],
#
#                       [[-0.9574, -0.8693, -0.5406, -1.2562],
#                        [-1.1474, -1.2029, -0.6476, -0.0194],
#                        [-1.4660,  1.1781,  0.9368,  0.2427]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 96.1 µs ± 406 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881],
#                [ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881],
#                [ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881],
#                [ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881],
#                [ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881],
#                [ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881],
#                [ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881],
#                [ 0.2438, -0.4234,  0.8772],
#                [ 1.3609,  0.7174,  0.0881]]),
#     x: Batch(
#            c: tensor([[-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427],
#                       [-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427],
#                       [-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427],
#                       [-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427],
#                       [-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427],
#                       [-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427],
#                       [-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427],
#                       [-0.9574, -0.8693, -0.5406, -1.2562],
#                       [-1.1474, -1.2029, -0.6476, -0.0194],
#                       [-1.4660,  1.1781,  0.9368,  0.2427]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 176 µs ± 1.68 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 437 µs ± 7.24 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
