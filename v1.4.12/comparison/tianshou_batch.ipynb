# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f63fcc1d040>
# ├── 'a' --> tensor([[ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396]])
# └── 'x' --> <FastTreeValue 0x7f632707cf70>
#     └── 'c' --> tensor([[-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480]])

# %%
t.a
# Out:
# tensor([[ 0.0141,  1.1598, -1.0627],
#         [-0.9826, -0.0600,  1.2396]])

# %%
# %timeit t.a
# Out:
# 71.4 ns ± 0.134 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f63fcc1d040>
# ├── 'a' --> tensor([[-0.5974, -1.9868,  0.7022],
# │                   [-0.0437, -0.5210, -1.7022]])
# └── 'x' --> <FastTreeValue 0x7f632707cf70>
#     └── 'c' --> tensor([[-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480]])

# %%
# %timeit t.a = new_value
# Out:
# 73.7 ns ± 0.105 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396]]),
#     x: Batch(
#            c: tensor([[-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0141,  1.1598, -1.0627],
#         [-0.9826, -0.0600,  1.2396]])

# %%
# %timeit b.a
# Out:
# 67.6 ns ± 0.15 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.5128, -0.3781,  1.0051],
#                [-0.3906,  0.6903,  0.5467]]),
#     x: Batch(
#            c: tensor([[-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 548 ns ± 0.119 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.19 µs ± 42.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 41 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 146 µs ± 1 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 149 µs ± 812 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f6328602e50>
# ├── 'a' --> tensor([[[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]],
# │
# │                   [[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]],
# │
# │                   [[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]],
# │
# │                   [[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]],
# │
# │                   [[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]],
# │
# │                   [[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]],
# │
# │                   [[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]],
# │
# │                   [[ 0.0141,  1.1598, -1.0627],
# │                    [-0.9826, -0.0600,  1.2396]]])
# └── 'x' --> <FastTreeValue 0x7f638114e550>
#     └── 'c' --> tensor([[[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                         [[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                         [[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                         [[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                         [[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                         [[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                         [[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                         [[-0.7259, -0.3689, -1.5339, -0.8075],
#                          [ 0.1636,  0.6309,  0.0527,  0.2789],
#                          [ 0.8149, -0.9148, -0.0497, -0.1480]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.4 µs ± 107 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f630e2876d0>
# ├── 'a' --> tensor([[ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396],
# │                   [ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396],
# │                   [ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396],
# │                   [ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396],
# │                   [ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396],
# │                   [ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396],
# │                   [ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396],
# │                   [ 0.0141,  1.1598, -1.0627],
# │                   [-0.9826, -0.0600,  1.2396]])
# └── 'x' --> <FastTreeValue 0x7f630e2fc1f0>
#     └── 'c' --> tensor([[-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480],
#                         [-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480],
#                         [-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480],
#                         [-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480],
#                         [-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480],
#                         [-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480],
#                         [-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480],
#                         [-0.7259, -0.3689, -1.5339, -0.8075],
#                         [ 0.1636,  0.6309,  0.0527,  0.2789],
#                         [ 0.8149, -0.9148, -0.0497, -0.1480]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.3 µs ± 78.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.1 µs ± 47.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]],
#
#                [[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]],
#
#                [[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]],
#
#                [[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]],
#
#                [[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]],
#
#                [[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]],
#
#                [[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]],
#
#                [[ 0.0141,  1.1598, -1.0627],
#                 [-0.9826, -0.0600,  1.2396]]]),
#     x: Batch(
#            c: tensor([[[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                       [[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                       [[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                       [[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                       [[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                       [[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                       [[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]],
#
#                       [[-0.7259, -0.3689, -1.5339, -0.8075],
#                        [ 0.1636,  0.6309,  0.0527,  0.2789],
#                        [ 0.8149, -0.9148, -0.0497, -0.1480]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.1 µs ± 386 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396],
#                [ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396],
#                [ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396],
#                [ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396],
#                [ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396],
#                [ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396],
#                [ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396],
#                [ 0.0141,  1.1598, -1.0627],
#                [-0.9826, -0.0600,  1.2396]]),
#     x: Batch(
#            c: tensor([[-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480],
#                       [-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480],
#                       [-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480],
#                       [-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480],
#                       [-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480],
#                       [-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480],
#                       [-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480],
#                       [-0.7259, -0.3689, -1.5339, -0.8075],
#                       [ 0.1636,  0.6309,  0.0527,  0.2789],
#                       [ 0.8149, -0.9148, -0.0497, -0.1480]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 153 µs ± 549 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 373 µs ± 7.79 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
