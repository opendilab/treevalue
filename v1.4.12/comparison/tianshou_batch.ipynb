# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f7b3c4444f0>
# ├── 'a' --> tensor([[ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471]])
# └── 'x' --> <FastTreeValue 0x7f7b3c4445e0>
#     └── 'c' --> tensor([[ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574]])

# %%
t.a
# Out:
# tensor([[ 1.4219,  1.8507, -1.2282],
#         [ 0.1126,  0.6305, -0.1471]])

# %%
# %timeit t.a
# Out:
# 78.2 ns ± 0.105 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f7b3c4444f0>
# ├── 'a' --> tensor([[-1.7611, -1.9471,  0.8805],
# │                   [ 0.7295, -0.4215,  0.0854]])
# └── 'x' --> <FastTreeValue 0x7f7b3c4445e0>
#     └── 'c' --> tensor([[ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574]])

# %%
# %timeit t.a = new_value
# Out:
# 80.9 ns ± 0.0344 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471]]),
#     x: Batch(
#            c: tensor([[ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.4219,  1.8507, -1.2282],
#         [ 0.1126,  0.6305, -0.1471]])

# %%
# %timeit b.a
# Out:
# 68.1 ns ± 0.0481 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.6370,  0.1549, -1.2329],
#                [-0.8843,  0.5155, -1.5583]]),
#     x: Batch(
#            c: tensor([[ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 560 ns ± 0.215 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 896 ns ± 0.657 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 24.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 147 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 147 µs ± 741 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f7a5fcd4b20>
# ├── 'a' --> tensor([[[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]],
# │
# │                   [[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]],
# │
# │                   [[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]],
# │
# │                   [[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]],
# │
# │                   [[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]],
# │
# │                   [[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]],
# │
# │                   [[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]],
# │
# │                   [[ 1.4219,  1.8507, -1.2282],
# │                    [ 0.1126,  0.6305, -0.1471]]])
# └── 'x' --> <FastTreeValue 0x7f7b404d3c40>
#     └── 'c' --> tensor([[[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                         [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                         [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                         [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                         [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                         [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                         [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                         [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                          [-0.1568, -1.2547, -0.7306,  0.4815],
#                          [ 0.0295,  1.2811, -1.0532,  0.1574]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34 µs ± 54.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f7b404ba880>
# ├── 'a' --> tensor([[ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471],
# │                   [ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471],
# │                   [ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471],
# │                   [ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471],
# │                   [ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471],
# │                   [ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471],
# │                   [ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471],
# │                   [ 1.4219,  1.8507, -1.2282],
# │                   [ 0.1126,  0.6305, -0.1471]])
# └── 'x' --> <FastTreeValue 0x7f7b4047e0a0>
#     └── 'c' --> tensor([[ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574],
#                         [ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574],
#                         [ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574],
#                         [ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574],
#                         [ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574],
#                         [ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574],
#                         [ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574],
#                         [ 1.6851, -0.6352,  1.9308, -1.1236],
#                         [-0.1568, -1.2547, -0.7306,  0.4815],
#                         [ 0.0295,  1.2811, -1.0532,  0.1574]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.1 µs ± 128 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.1 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                       [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                       [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                       [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                       [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                       [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                       [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]],
#
#                       [[ 1.6851, -0.6352,  1.9308, -1.1236],
#                        [-0.1568, -1.2547, -0.7306,  0.4815],
#                        [ 0.0295,  1.2811, -1.0532,  0.1574]]]),
#        ),
#     a: tensor([[[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]],
#
#                [[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]],
#
#                [[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]],
#
#                [[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]],
#
#                [[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]],
#
#                [[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]],
#
#                [[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]],
#
#                [[ 1.4219,  1.8507, -1.2282],
#                 [ 0.1126,  0.6305, -0.1471]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.4 µs ± 304 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574],
#                       [ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574],
#                       [ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574],
#                       [ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574],
#                       [ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574],
#                       [ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574],
#                       [ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574],
#                       [ 1.6851, -0.6352,  1.9308, -1.1236],
#                       [-0.1568, -1.2547, -0.7306,  0.4815],
#                       [ 0.0295,  1.2811, -1.0532,  0.1574]]),
#        ),
#     a: tensor([[ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471],
#                [ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471],
#                [ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471],
#                [ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471],
#                [ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471],
#                [ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471],
#                [ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471],
#                [ 1.4219,  1.8507, -1.2282],
#                [ 0.1126,  0.6305, -0.1471]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 306 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 352 µs ± 4.87 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
