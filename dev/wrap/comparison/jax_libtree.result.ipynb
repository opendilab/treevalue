# %% [markdown]
# # Comparison Between TreeValue and Jax LibTree

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [jax-libtree](https://jax.readthedocs.io/en/latest/pytrees.html) library, which is developed by Google.

# %%
_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}

# %% [markdown]
# ## Mapping Operation

# %% [markdown]
# ### TreeValue's Mapping

# %%
from treevalue import mapping, FastTreeValue

t = FastTreeValue(_TREE_DATA_1)
mapping(t, lambda x: x ** 2)
# Out:
# <FastTreeValue 0x7fa60835a8b0>
# ├── 'a' --> 1
# ├── 'b' --> 4
# └── 'x' --> <FastTreeValue 0x7fa6083bacd0>
#     ├── 'c' --> 9
#     └── 'd' --> 16

# %%
# %timeit mapping(t, lambda x: x ** 2)
# Out:
# 3.8 µs ± 48.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
mapping(t, lambda x, p: (x ** 2, p))
# Out:
# <FastTreeValue 0x7fa60835ac10>
# ├── 'a' --> (1, ('a',))
# ├── 'b' --> (4, ('b',))
# └── 'x' --> <FastTreeValue 0x7fa60835a3d0>
#     ├── 'c' --> (9, ('x', 'c'))
#     └── 'd' --> (16, ('x', 'd'))

# %%
# %timeit mapping(t, lambda x, p: (x ** 2, p))
# Out:
# 3.91 µs ± 53 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### pytree's tree_map

# %%
from jax.tree_util import tree_map

tree_map(lambda x: x ** 2, _TREE_DATA_1)
# Out:
# {'a': 1, 'b': 4, 'x': {'c': 9, 'd': 16}}

# %%
# %timeit tree_map(lambda x: x ** 2, _TREE_DATA_1)
# Out:
# 6.88 µs ± 69.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Flatten and Unflatten Operation

# %% [markdown]
# ### TreeValue's Performance

# %%
from treevalue import flatten, flatten_keys, flatten_values

t_flatted = flatten(t)
t_flatted
# Out:
# [(('a',), 1), (('b',), 2), (('x', 'c'), 3), (('x', 'd'), 4)]

# %%
# %timeit flatten(t)
# Out:
# 902 ns ± 18.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from treevalue import flatten_keys

flatten_keys(t)
# Out:
# [('a',), ('b',), ('x', 'c'), ('x', 'd')]

# %%
# %timeit flatten_keys(t)
# Out:
# 839 ns ± 16.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from treevalue import flatten_values

flatten_values(t)
# Out:
# [1, 2, 3, 4]

# %%
# %timeit flatten_values(t)
# Out:
# 598 ns ± 7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from treevalue import unflatten

unflatten(t_flatted)
# Out:
# <TreeValue 0x7fa600fbf490>
# ├── 'a' --> 1
# ├── 'b' --> 2
# └── 'x' --> <TreeValue 0x7fa600fbff10>
#     ├── 'c' --> 3
#     └── 'd' --> 4

# %%
# %timeit unflatten(t_flatted)
# Out:
# 1.03 µs ± 17.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### pytree's Performance

# %%
from jax.tree_util import tree_flatten

leaves, treedef = tree_flatten(_TREE_DATA_1)
print('Leaves:', leaves)
print('Treedef:', treedef)
# Out:
# Leaves: [1, 2, 3, 4]
# Treedef: PyTreeDef({'a': *, 'b': *, 'x': {'c': *, 'd': *}})

# %%
# %timeit tree_flatten(_TREE_DATA_1)
# Out:
# 2.35 µs ± 68.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
from jax.tree_util import tree_unflatten

tree_unflatten(treedef, leaves)
# Out:
# {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}

# %%
# %timeit tree_unflatten(treedef, leaves)
# Out:
# 1.07 µs ± 10.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## All Operation

# %% [markdown]
# ### TreeValue's Performance

# %%
all(flatten_values(t))
# Out:
# True

# %%
# %timeit all(flatten_values(t))
# Out:
# 734 ns ± 14.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### pytree.tree_all's performance

# %%
from jax.tree_util import tree_all

# %%
tree_all(_TREE_DATA_1)
# Out:
# True

# %%
# %timeit tree_all(_TREE_DATA_1)
# Out:
# 2.67 µs ± 84.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Reduce Operation

# %% [markdown]
# ### TreeValue's Reduce

# %%
from functools import reduce

def _flatten_reduce(tree):
    values = flatten_values(tree)
    return reduce(lambda x, y: x + y, values)

_flatten_reduce(t)
# Out:
# 10

# %%
# %timeit _flatten_reduce(t)
# Out:
# 1.39 µs ± 14 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
def _flatten_reduce_with_init(tree):
    values = flatten_values(tree)
    return reduce(lambda x, y: x + y, values, 0)

_flatten_reduce_with_init(t)
# Out:
# 10

# %%
# %timeit _flatten_reduce_with_init(t)
# Out:
# 1.55 µs ± 20.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### pytree.tree_reduce

# %%
from jax.tree_util import tree_reduce

tree_reduce(lambda x, y: x + y, _TREE_DATA_1)
# Out:
# 10

# %%
# %timeit tree_reduce(lambda x, y: x + y, _TREE_DATA_1)
# Out:
# 3.37 µs ± 33.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
tree_reduce(lambda x, y: x + y, _TREE_DATA_1, 0)
# Out:
# 10

# %%
# %timeit tree_reduce(lambda x, y: x + y, _TREE_DATA_1, 0)
# Out:
# 3.53 µs ± 46.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Structure Transpose

# %% [markdown]
# ### Subside and Rise in TreeValue

# %%
from treevalue import subside

value = {
    'a': FastTreeValue({'a': 1, 'b': {'x': 2, 'y': 3}}),
    'b': FastTreeValue({'a': 10, 'b': {'x': 20, 'y': 30}}),
    'c': {
        'x': FastTreeValue({'a': 100, 'b': {'x': 200, 'y': 300}}),
        'y': FastTreeValue({'a': 400, 'b': {'x': 500, 'y': 600}}),
    },
}
subside(value)
# Out:
# <FastTreeValue 0x7fa5e0c31c10>
# ├── 'a' --> {'a': 1, 'b': 10, 'c': {'x': 100, 'y': 400}}
# └── 'b' --> <FastTreeValue 0x7fa5e0c3e2e0>
#     ├── 'x' --> {'a': 2, 'b': 20, 'c': {'x': 200, 'y': 500}}
#     └── 'y' --> {'a': 3, 'b': 30, 'c': {'x': 300, 'y': 600}}

# %%
# %timeit subside(value)
# Out:
# 18.1 µs ± 201 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
from treevalue import raw, rise

value = FastTreeValue({
    'a': raw({'a': 1, 'b': {'x': 2, 'y': 3}}),
    'b': raw({'a': 10, 'b': {'x': 20, 'y': 30}}),
    'c': {
        'x': raw({'a': 100, 'b': {'x': 200, 'y': 300}}),
        'y': raw({'a': 400, 'b': {'x': 500, 'y': 600}}),
    },
})
rise(value)
# Out:
# {'b': {'x': <FastTreeValue 0x7fa5e0c3e8b0>
#   ├── 'a' --> 2
#   ├── 'b' --> 20
#   └── 'c' --> <FastTreeValue 0x7fa5e0c3e850>
#       ├── 'x' --> 200
#       └── 'y' --> 500,
#   'y': <FastTreeValue 0x7fa5e0c3e520>
#   ├── 'a' --> 3
#   ├── 'b' --> 30
#   └── 'c' --> <FastTreeValue 0x7fa5e0c3ef10>
#       ├── 'x' --> 300
#       └── 'y' --> 600},
#  'a': <FastTreeValue 0x7fa5e0c31fa0>
#  ├── 'a' --> 1
#  ├── 'b' --> 10
#  └── 'c' --> <FastTreeValue 0x7fa608361cd0>
#      ├── 'x' --> 100
#      └── 'y' --> 400}

# %%
# %timeit rise(value)
# Out:
# 18.7 µs ± 237 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
vt = {'a': None, 'b': {'x': None, 'y': None}}
rise(value, template=vt)
# Out:
# {'a': <FastTreeValue 0x7fa5e0c3e4c0>
#  ├── 'a' --> 1
#  ├── 'b' --> 10
#  └── 'c' --> <FastTreeValue 0x7fa5e0c3e610>
#      ├── 'x' --> 100
#      └── 'y' --> 400,
#  'b': {'x': <FastTreeValue 0x7fa5e0c3ebb0>
#   ├── 'a' --> 2
#   ├── 'b' --> 20
#   └── 'c' --> <FastTreeValue 0x7fa5e0c3eac0>
#       ├── 'x' --> 200
#       └── 'y' --> 500,
#   'y': <FastTreeValue 0x7fa5e0c3ebe0>
#   ├── 'a' --> 3
#   ├── 'b' --> 30
#   └── 'c' --> <FastTreeValue 0x7fa5e0c3e880>
#       ├── 'x' --> 300
#       └── 'y' --> 600}}

# %%
# %timeit rise(value, template=vt)
# Out:
# 14.9 µs ± 167 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### pytree.tree_transpose

# %%
from jax.tree_util import tree_structure, tree_transpose

sto = tree_structure({'a': 1, 'b': 2, 'c': {'x': 3, 'y': 4}})
sti = tree_structure({'a': 1, 'b': {'x': 2, 'y': 3}})

value = (
    {'a': 1, 'b': {'x': 2, 'y': 3}},
    {
        'a': {'a': 10, 'b': {'x': 20, 'y': 30}},
        'b': [
            {'a': 100, 'b': {'x': 200, 'y': 300}},
            {'a': 400, 'b': {'x': 500, 'y': 600}},
        ],
    }
)
tree_transpose(sto, sti, value)
# Out:
# {'a': {'a': 1, 'b': 10, 'c': {'x': 100, 'y': 400}},
#  'b': {'x': {'a': 2, 'b': 20, 'c': {'x': 200, 'y': 500}},
#   'y': {'a': 3, 'b': 30, 'c': {'x': 300, 'y': 600}}}}

# %%
# %timeit tree_transpose(sto, sti, value)
# Out:
# 17.7 µs ± 218 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
