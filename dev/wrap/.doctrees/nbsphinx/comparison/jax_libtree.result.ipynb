# %% [markdown]
# # Comparison Between TreeValue and Jax LibTree

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [jax-libtree](https://jax.readthedocs.io/en/latest/pytrees.html) library, which is developed by Google.

# %%
_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}

# %% [markdown]
# ## Mapping Operation

# %% [markdown]
# ### TreeValue's Mapping

# %%
from treevalue import mapping, FastTreeValue

t = FastTreeValue(_TREE_DATA_1)
mapping(t, lambda x: x ** 2)
# Out:
# <FastTreeValue 0x7f6d8a5b0b50>
# ├── 'a' --> 1
# ├── 'b' --> 4
# └── 'x' --> <FastTreeValue 0x7f6d88547190>
#     ├── 'c' --> 9
#     └── 'd' --> 16

# %%
# %timeit mapping(t, lambda x: x ** 2)
# Out:
# 3.62 µs ± 24.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
mapping(t, lambda x, p: (x ** 2, p))
# Out:
# <FastTreeValue 0x7f6d8815ceb0>
# ├── 'a' --> (1, ('a',))
# ├── 'b' --> (4, ('b',))
# └── 'x' --> <FastTreeValue 0x7f6d8815ca90>
#     ├── 'c' --> (9, ('x', 'c'))
#     └── 'd' --> (16, ('x', 'd'))

# %%
# %timeit mapping(t, lambda x, p: (x ** 2, p))
# Out:
# 3.78 µs ± 44.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### pytree's tree_map

# %%
from jax.tree_util import tree_map

tree_map(lambda x: x ** 2, _TREE_DATA_1)
# Out:
# {'a': 1, 'b': 4, 'x': {'c': 9, 'd': 16}}

# %%
# %timeit tree_map(lambda x: x ** 2, _TREE_DATA_1)
# Out:
# 6.62 µs ± 26.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Flatten and Unflatten Operation

# %% [markdown]
# ### TreeValue's Performance

# %%
from treevalue import flatten, flatten_keys, flatten_values

t_flatted = flatten(t)
t_flatted
# Out:
# [(('a',), 1), (('b',), 2), (('x', 'c'), 3), (('x', 'd'), 4)]

# %%
# %timeit flatten(t)
# Out:
# 834 ns ± 3.79 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from treevalue import flatten_keys

flatten_keys(t)
# Out:
# [('a',), ('b',), ('x', 'c'), ('x', 'd')]

# %%
# %timeit flatten_keys(t)
# Out:
# 759 ns ± 7.91 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from treevalue import flatten_values

flatten_values(t)
# Out:
# [1, 2, 3, 4]

# %%
# %timeit flatten_values(t)
# Out:
# 557 ns ± 5.45 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
from treevalue import unflatten

unflatten(t_flatted)
# Out:
# <TreeValue 0x7f6d5c37de20>
# ├── 'a' --> 1
# ├── 'b' --> 2
# └── 'x' --> <TreeValue 0x7f6d5c37dfd0>
#     ├── 'c' --> 3
#     └── 'd' --> 4

# %%
# %timeit unflatten(t_flatted)
# Out:
# 960 ns ± 7.13 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### pytree's Performance

# %%
from jax.tree_util import tree_flatten

leaves, treedef = tree_flatten(_TREE_DATA_1)
print('Leaves:', leaves)
print('Treedef:', treedef)
# Out:
# Leaves: [1, 2, 3, 4]
# Treedef: PyTreeDef({'a': *, 'b': *, 'x': {'c': *, 'd': *}})

# %%
# %timeit tree_flatten(_TREE_DATA_1)
# Out:
# 2.21 µs ± 17 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
from jax.tree_util import tree_unflatten

tree_unflatten(treedef, leaves)
# Out:
# {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}

# %%
# %timeit tree_unflatten(treedef, leaves)
# Out:
# 1.01 µs ± 4.99 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## All Operation

# %% [markdown]
# ### TreeValue's Performance

# %%
all(flatten_values(t))
# Out:
# True

# %%
# %timeit all(flatten_values(t))
# Out:
# 685 ns ± 8.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### pytree.tree_all's performance

# %%
from jax.tree_util import tree_all

# %%
tree_all(_TREE_DATA_1)
# Out:
# True

# %%
# %timeit tree_all(_TREE_DATA_1)
# Out:
# 2.44 µs ± 31.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Reduce Operation

# %% [markdown]
# ### TreeValue's Reduce

# %%
from functools import reduce

def _flatten_reduce(tree):
    values = flatten_values(tree)
    return reduce(lambda x, y: x + y, values)

_flatten_reduce(t)
# Out:
# 10

# %%
# %timeit _flatten_reduce(t)
# Out:
# 1.28 µs ± 9.67 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
def _flatten_reduce_with_init(tree):
    values = flatten_values(tree)
    return reduce(lambda x, y: x + y, values, 0)

_flatten_reduce_with_init(t)
# Out:
# 10

# %%
# %timeit _flatten_reduce_with_init(t)
# Out:
# 1.39 µs ± 22 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### pytree.tree_reduce

# %%
from jax.tree_util import tree_reduce

tree_reduce(lambda x, y: x + y, _TREE_DATA_1)
# Out:
# 10

# %%
# %timeit tree_reduce(lambda x, y: x + y, _TREE_DATA_1)
# Out:
# 3.11 µs ± 35.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
tree_reduce(lambda x, y: x + y, _TREE_DATA_1, 0)
# Out:
# 10

# %%
# %timeit tree_reduce(lambda x, y: x + y, _TREE_DATA_1, 0)
# Out:
# 3.35 µs ± 45 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Structure Transpose

# %% [markdown]
# ### Subside and Rise in TreeValue

# %%
from treevalue import subside

value = {
    'a': FastTreeValue({'a': 1, 'b': {'x': 2, 'y': 3}}),
    'b': FastTreeValue({'a': 10, 'b': {'x': 20, 'y': 30}}),
    'c': {
        'x': FastTreeValue({'a': 100, 'b': {'x': 200, 'y': 300}}),
        'y': FastTreeValue({'a': 400, 'b': {'x': 500, 'y': 600}}),
    },
}
subside(value)
# Out:
# <FastTreeValue 0x7f6d5c393cd0>
# ├── 'a' --> {'a': 1, 'b': 10, 'c': {'x': 100, 'y': 400}}
# └── 'b' --> <FastTreeValue 0x7f6d5c393c40>
#     ├── 'x' --> {'a': 2, 'b': 20, 'c': {'x': 200, 'y': 500}}
#     └── 'y' --> {'a': 3, 'b': 30, 'c': {'x': 300, 'y': 600}}

# %%
# %timeit subside(value)
# Out:
# 15.8 µs ± 58.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
from treevalue import raw, rise

value = FastTreeValue({
    'a': raw({'a': 1, 'b': {'x': 2, 'y': 3}}),
    'b': raw({'a': 10, 'b': {'x': 20, 'y': 30}}),
    'c': {
        'x': raw({'a': 100, 'b': {'x': 200, 'y': 300}}),
        'y': raw({'a': 400, 'b': {'x': 500, 'y': 600}}),
    },
})
rise(value)
# Out:
# {'a': <FastTreeValue 0x7f6d5c393c10>
#  ├── 'a' --> 1
#  ├── 'b' --> 10
#  └── 'c' --> <FastTreeValue 0x7f6d5c393be0>
#      ├── 'x' --> 100
#      └── 'y' --> 400,
#  'b': {'x': <FastTreeValue 0x7f6d5c393d30>
#   ├── 'a' --> 2
#   ├── 'b' --> 20
#   └── 'c' --> <FastTreeValue 0x7f6d5c393ca0>
#       ├── 'x' --> 200
#       └── 'y' --> 500,
#   'y': <FastTreeValue 0x7f6d5c393100>
#   ├── 'a' --> 3
#   ├── 'b' --> 30
#   └── 'c' --> <FastTreeValue 0x7f6d5c393b50>
#       ├── 'x' --> 300
#       └── 'y' --> 600}}

# %%
# %timeit rise(value)
# Out:
# 17.9 µs ± 154 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
vt = {'a': None, 'b': {'x': None, 'y': None}}
rise(value, template=vt)
# Out:
# {'a': <FastTreeValue 0x7f6d5c393040>
#  ├── 'a' --> 1
#  ├── 'b' --> 10
#  └── 'c' --> <FastTreeValue 0x7f6d5c393490>
#      ├── 'x' --> 100
#      └── 'y' --> 400,
#  'b': {'x': <FastTreeValue 0x7f6d5c3938e0>
#   ├── 'a' --> 2
#   ├── 'b' --> 20
#   └── 'c' --> <FastTreeValue 0x7f6d5c3939a0>
#       ├── 'x' --> 200
#       └── 'y' --> 500,
#   'y': <FastTreeValue 0x7f6d5c393880>
#   ├── 'a' --> 3
#   ├── 'b' --> 30
#   └── 'c' --> <FastTreeValue 0x7f6d5c393af0>
#       ├── 'x' --> 300
#       └── 'y' --> 600}}

# %%
# %timeit rise(value, template=vt)
# Out:
# 14.1 µs ± 91.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### pytree.tree_transpose

# %%
from jax.tree_util import tree_structure, tree_transpose

sto = tree_structure({'a': 1, 'b': 2, 'c': {'x': 3, 'y': 4}})
sti = tree_structure({'a': 1, 'b': {'x': 2, 'y': 3}})

value = (
    {'a': 1, 'b': {'x': 2, 'y': 3}},
    {
        'a': {'a': 10, 'b': {'x': 20, 'y': 30}},
        'b': [
            {'a': 100, 'b': {'x': 200, 'y': 300}},
            {'a': 400, 'b': {'x': 500, 'y': 600}},
        ],
    }
)
tree_transpose(sto, sti, value)
# Out:
# {'a': {'a': 1, 'b': 10, 'c': {'x': 100, 'y': 400}},
#  'b': {'x': {'a': 2, 'b': 20, 'c': {'x': 200, 'y': 500}},
#   'y': {'a': 3, 'b': 30, 'c': {'x': 300, 'y': 600}}}}

# %%
# %timeit tree_transpose(sto, sti, value)
# Out:
# 16.2 µs ± 43.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
