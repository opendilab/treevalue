# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc974c59fd0>
# ├── 'a' --> tensor([[ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153]])
# └── 'x' --> <FastTreeValue 0x7fc94ca8e430>
#     └── 'c' --> tensor([[-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776]])

# %%
t.a
# Out:
# tensor([[ 0.0522, -0.0157, -0.1317],
#         [-0.4610, -1.2370, -1.7153]])

# %%
# %timeit t.a
# Out:
# 78.6 ns ± 0.542 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc974c59fd0>
# ├── 'a' --> tensor([[ 1.9241,  1.1255, -0.2326],
# │                   [ 0.3587, -1.4965,  0.0254]])
# └── 'x' --> <FastTreeValue 0x7fc94ca8e430>
#     └── 'c' --> tensor([[-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776]])

# %%
# %timeit t.a = new_value
# Out:
# 81.6 ns ± 1.32 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153]]),
#     x: Batch(
#            c: tensor([[-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0522, -0.0157, -0.1317],
#         [-0.4610, -1.2370, -1.7153]])

# %%
# %timeit b.a
# Out:
# 69.2 ns ± 0.719 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.4694, -0.0227,  0.1812],
#                [ 1.2555, -1.9739, -0.6698]]),
#     x: Batch(
#            c: tensor([[-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 655 ns ± 11.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.79 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.8 µs ± 227 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 307 µs ± 9.73 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 298 µs ± 11 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc94ce21df0>
# ├── 'a' --> tensor([[[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]],
# │
# │                   [[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]],
# │
# │                   [[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]],
# │
# │                   [[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]],
# │
# │                   [[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]],
# │
# │                   [[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]],
# │
# │                   [[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]],
# │
# │                   [[ 0.0522, -0.0157, -0.1317],
# │                    [-0.4610, -1.2370, -1.7153]]])
# └── 'x' --> <FastTreeValue 0x7fc94ce21730>
#     └── 'c' --> tensor([[[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                         [[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                         [[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                         [[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                         [[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                         [[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                         [[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                         [[-0.2553, -1.0417,  0.2767, -1.0073],
#                          [ 0.3681, -0.7595, -0.8831, -0.6640],
#                          [ 0.1328,  1.4826, -2.2080, -0.7776]]])

# %%
# %timeit t_stack(trees)
# Out:
# 49.5 µs ± 1.22 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc88524a820>
# ├── 'a' --> tensor([[ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153],
# │                   [ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153],
# │                   [ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153],
# │                   [ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153],
# │                   [ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153],
# │                   [ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153],
# │                   [ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153],
# │                   [ 0.0522, -0.0157, -0.1317],
# │                   [-0.4610, -1.2370, -1.7153]])
# └── 'x' --> <FastTreeValue 0x7fc88524abb0>
#     └── 'c' --> tensor([[-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776],
#                         [-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776],
#                         [-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776],
#                         [-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776],
#                         [-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776],
#                         [-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776],
#                         [-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776],
#                         [-0.2553, -1.0417,  0.2767, -1.0073],
#                         [ 0.3681, -0.7595, -0.8831, -0.6640],
#                         [ 0.1328,  1.4826, -2.2080, -0.7776]])

# %%
# %timeit t_cat(trees)
# Out:
# 44.7 µs ± 714 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 98.5 µs ± 1.65 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                       [[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                       [[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                       [[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                       [[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                       [[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                       [[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]],
#
#                       [[-0.2553, -1.0417,  0.2767, -1.0073],
#                        [ 0.3681, -0.7595, -0.8831, -0.6640],
#                        [ 0.1328,  1.4826, -2.2080, -0.7776]]]),
#        ),
#     a: tensor([[[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]],
#
#                [[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]],
#
#                [[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]],
#
#                [[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]],
#
#                [[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]],
#
#                [[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]],
#
#                [[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]],
#
#                [[ 0.0522, -0.0157, -0.1317],
#                 [-0.4610, -1.2370, -1.7153]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 114 µs ± 2.31 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776],
#                       [-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776],
#                       [-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776],
#                       [-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776],
#                       [-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776],
#                       [-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776],
#                       [-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776],
#                       [-0.2553, -1.0417,  0.2767, -1.0073],
#                       [ 0.3681, -0.7595, -0.8831, -0.6640],
#                       [ 0.1328,  1.4826, -2.2080, -0.7776]]),
#        ),
#     a: tensor([[ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153],
#                [ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153],
#                [ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153],
#                [ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153],
#                [ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153],
#                [ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153],
#                [ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153],
#                [ 0.0522, -0.0157, -0.1317],
#                [-0.4610, -1.2370, -1.7153]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 215 µs ± 10.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 708 µs ± 40 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
