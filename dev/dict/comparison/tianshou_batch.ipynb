# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f6fe079e040>
# ├── 'a' --> tensor([[ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499]])
# └── 'x' --> <FastTreeValue 0x7f6f0ac62d60>
#     └── 'c' --> tensor([[-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416]])

# %%
t.a
# Out:
# tensor([[ 0.0043,  1.3538, -2.2997],
#         [ 0.7239,  0.0445,  0.0499]])

# %%
# %timeit t.a
# Out:
# 73.2 ns ± 0.0932 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f6fe079e040>
# ├── 'a' --> tensor([[-0.7468, -0.5883, -0.3615],
# │                   [-0.4215,  0.9438, -1.7563]])
# └── 'x' --> <FastTreeValue 0x7f6f0ac62d60>
#     └── 'c' --> tensor([[-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416]])

# %%
# %timeit t.a = new_value
# Out:
# 75.1 ns ± 0.0746 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499]]),
#     x: Batch(
#            c: tensor([[-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0043,  1.3538, -2.2997],
#         [ 0.7239,  0.0445,  0.0499]])

# %%
# %timeit b.a
# Out:
# 66.1 ns ± 0.124 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.5956,  1.7479, -0.5378],
#                [-0.5204, -0.1663, -0.6190]]),
#     x: Batch(
#            c: tensor([[-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 555 ns ± 8.55 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.8 µs ± 33.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 12.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 886 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 150 µs ± 1.49 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f6efc741f40>
# ├── 'a' --> tensor([[[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]],
# │
# │                   [[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]],
# │
# │                   [[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]],
# │
# │                   [[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]],
# │
# │                   [[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]],
# │
# │                   [[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]],
# │
# │                   [[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]],
# │
# │                   [[ 0.0043,  1.3538, -2.2997],
# │                    [ 0.7239,  0.0445,  0.0499]]])
# └── 'x' --> <FastTreeValue 0x7f6fe183b040>
#     └── 'c' --> tensor([[[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                         [[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                         [[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                         [[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                         [[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                         [[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                         [[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                         [[-1.5380,  0.5829, -0.1146, -0.5737],
#                          [ 0.0345, -0.4563, -0.0584,  0.5742],
#                          [ 0.2247,  0.8422,  0.5182,  0.0416]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.6 µs ± 104 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f6f0ae2e430>
# ├── 'a' --> tensor([[ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499],
# │                   [ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499],
# │                   [ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499],
# │                   [ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499],
# │                   [ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499],
# │                   [ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499],
# │                   [ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499],
# │                   [ 0.0043,  1.3538, -2.2997],
# │                   [ 0.7239,  0.0445,  0.0499]])
# └── 'x' --> <FastTreeValue 0x7f6fd027fee0>
#     └── 'c' --> tensor([[-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416],
#                         [-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416],
#                         [-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416],
#                         [-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416],
#                         [-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416],
#                         [-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416],
#                         [-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416],
#                         [-1.5380,  0.5829, -0.1146, -0.5737],
#                         [ 0.0345, -0.4563, -0.0584,  0.5742],
#                         [ 0.2247,  0.8422,  0.5182,  0.0416]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.2 µs ± 59.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.8 µs ± 76.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]],
#
#                [[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]],
#
#                [[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]],
#
#                [[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]],
#
#                [[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]],
#
#                [[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]],
#
#                [[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]],
#
#                [[ 0.0043,  1.3538, -2.2997],
#                 [ 0.7239,  0.0445,  0.0499]]]),
#     x: Batch(
#            c: tensor([[[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                       [[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                       [[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                       [[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                       [[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                       [[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                       [[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]],
#
#                       [[-1.5380,  0.5829, -0.1146, -0.5737],
#                        [ 0.0345, -0.4563, -0.0584,  0.5742],
#                        [ 0.2247,  0.8422,  0.5182,  0.0416]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.9 µs ± 457 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499],
#                [ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499],
#                [ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499],
#                [ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499],
#                [ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499],
#                [ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499],
#                [ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499],
#                [ 0.0043,  1.3538, -2.2997],
#                [ 0.7239,  0.0445,  0.0499]]),
#     x: Batch(
#            c: tensor([[-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416],
#                       [-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416],
#                       [-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416],
#                       [-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416],
#                       [-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416],
#                       [-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416],
#                       [-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416],
#                       [-1.5380,  0.5829, -0.1146, -0.5737],
#                       [ 0.0345, -0.4563, -0.0584,  0.5742],
#                       [ 0.2247,  0.8422,  0.5182,  0.0416]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 605 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 377 µs ± 7.02 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
