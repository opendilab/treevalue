# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fa5f0e62a30>
# ├── 'a' --> tensor([[-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782]])
# └── 'x' --> <FastTreeValue 0x7fa5f0e62400>
#     └── 'c' --> tensor([[ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014]])

# %%
t.a
# Out:
# tensor([[-2.6488, -0.2722,  0.6863],
#         [-2.5120, -0.3922, -0.6782]])

# %%
# %timeit t.a
# Out:
# 63.3 ns ± 0.023 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fa5f0e62a30>
# ├── 'a' --> tensor([[ 0.6666,  1.2526,  0.7370],
# │                   [-0.9672,  1.7682,  1.5606]])
# └── 'x' --> <FastTreeValue 0x7fa5f0e62400>
#     └── 'c' --> tensor([[ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014]])

# %%
# %timeit t.a = new_value
# Out:
# 59.8 ns ± 0.0266 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782]]),
#     x: Batch(
#            c: tensor([[ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-2.6488, -0.2722,  0.6863],
#         [-2.5120, -0.3922, -0.6782]])

# %%
# %timeit b.a
# Out:
# 55.5 ns ± 0.0526 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.9167,  0.0279,  0.9618],
#                [-0.6118,  1.5782, -1.8847]]),
#     x: Batch(
#            c: tensor([[ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 500 ns ± 0.278 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.47 µs ± 63.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 114 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 140 µs ± 1.33 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 1.44 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fa5024848e0>
# ├── 'a' --> tensor([[[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]],
# │
# │                   [[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]],
# │
# │                   [[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]],
# │
# │                   [[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]],
# │
# │                   [[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]],
# │
# │                   [[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]],
# │
# │                   [[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]],
# │
# │                   [[-2.6488, -0.2722,  0.6863],
# │                    [-2.5120, -0.3922, -0.6782]]])
# └── 'x' --> <FastTreeValue 0x7fa502484100>
#     └── 'c' --> tensor([[[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                         [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                         [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                         [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                         [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                         [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                         [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                         [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                          [-1.3863, -0.1359,  0.6525, -1.0745],
#                          [ 0.6381,  0.8554, -1.8883,  1.4014]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 52.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fa502484460>
# ├── 'a' --> tensor([[-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782],
# │                   [-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782],
# │                   [-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782],
# │                   [-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782],
# │                   [-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782],
# │                   [-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782],
# │                   [-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782],
# │                   [-2.6488, -0.2722,  0.6863],
# │                   [-2.5120, -0.3922, -0.6782]])
# └── 'x' --> <FastTreeValue 0x7fa502484ac0>
#     └── 'c' --> tensor([[ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014],
#                         [ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014],
#                         [ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014],
#                         [ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014],
#                         [ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014],
#                         [ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014],
#                         [ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014],
#                         [ 0.2750, -0.8859, -0.2506, -0.9743],
#                         [-1.3863, -0.1359,  0.6525, -1.0745],
#                         [ 0.6381,  0.8554, -1.8883,  1.4014]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.8 µs ± 64.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69 µs ± 57.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]],
#
#                [[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]],
#
#                [[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]],
#
#                [[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]],
#
#                [[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]],
#
#                [[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]],
#
#                [[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]],
#
#                [[-2.6488, -0.2722,  0.6863],
#                 [-2.5120, -0.3922, -0.6782]]]),
#     x: Batch(
#            c: tensor([[[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                       [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                       [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                       [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                       [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                       [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                       [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]],
#
#                       [[ 0.2750, -0.8859, -0.2506, -0.9743],
#                        [-1.3863, -0.1359,  0.6525, -1.0745],
#                        [ 0.6381,  0.8554, -1.8883,  1.4014]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.6 µs ± 280 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782],
#                [-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782],
#                [-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782],
#                [-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782],
#                [-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782],
#                [-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782],
#                [-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782],
#                [-2.6488, -0.2722,  0.6863],
#                [-2.5120, -0.3922, -0.6782]]),
#     x: Batch(
#            c: tensor([[ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014],
#                       [ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014],
#                       [ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014],
#                       [ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014],
#                       [ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014],
#                       [ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014],
#                       [ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014],
#                       [ 0.2750, -0.8859, -0.2506, -0.9743],
#                       [-1.3863, -0.1359,  0.6525, -1.0745],
#                       [ 0.6381,  0.8554, -1.8883,  1.4014]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 440 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 360 µs ± 5.74 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
