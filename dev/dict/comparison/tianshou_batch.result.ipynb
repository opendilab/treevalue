# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f48b8aa4070>
# ├── 'a' --> tensor([[-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953]])
# └── 'x' --> <FastTreeValue 0x7f47d8938940>
#     └── 'c' --> tensor([[ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276]])

# %%
t.a
# Out:
# tensor([[-0.2738,  1.6350,  0.4599],
#         [-1.7590, -1.1099,  0.2953]])

# %%
# %timeit t.a
# Out:
# 71.2 ns ± 0.067 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f48b8aa4070>
# ├── 'a' --> tensor([[ 0.4257, -1.5751, -0.5548],
# │                   [-1.2071, -0.7294, -0.2599]])
# └── 'x' --> <FastTreeValue 0x7f47d8938940>
#     └── 'c' --> tensor([[ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276]])

# %%
# %timeit t.a = new_value
# Out:
# 72.4 ns ± 0.043 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953]]),
#     x: Batch(
#            c: tensor([[ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2738,  1.6350,  0.4599],
#         [-1.7590, -1.1099,  0.2953]])

# %%
# %timeit b.a
# Out:
# 66.3 ns ± 0.122 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.2767, -0.6800,  0.5210],
#                [ 0.9172,  1.4863,  1.5701]]),
#     x: Batch(
#            c: tensor([[ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 544 ns ± 6.86 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.19 µs ± 28.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 8.24 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 150 µs ± 757 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 151 µs ± 695 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f47ca1893a0>
# ├── 'a' --> tensor([[[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]],
# │
# │                   [[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]],
# │
# │                   [[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]],
# │
# │                   [[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]],
# │
# │                   [[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]],
# │
# │                   [[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]],
# │
# │                   [[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]],
# │
# │                   [[-0.2738,  1.6350,  0.4599],
# │                    [-1.7590, -1.1099,  0.2953]]])
# └── 'x' --> <FastTreeValue 0x7f47ca189910>
#     └── 'c' --> tensor([[[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                         [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                         [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                         [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                         [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                         [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                         [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                         [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                          [ 2.0742, -0.5746, -0.5820,  2.0918],
#                          [-0.4403,  0.4911, -0.1391,  0.7276]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f47ca1897c0>
# ├── 'a' --> tensor([[-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953],
# │                   [-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953],
# │                   [-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953],
# │                   [-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953],
# │                   [-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953],
# │                   [-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953],
# │                   [-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953],
# │                   [-0.2738,  1.6350,  0.4599],
# │                   [-1.7590, -1.1099,  0.2953]])
# └── 'x' --> <FastTreeValue 0x7f47ca189370>
#     └── 'c' --> tensor([[ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276],
#                         [ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276],
#                         [ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276],
#                         [ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276],
#                         [ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276],
#                         [ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276],
#                         [ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276],
#                         [ 0.1461,  1.8473, -1.2116,  0.9187],
#                         [ 2.0742, -0.5746, -0.5820,  2.0918],
#                         [-0.4403,  0.4911, -0.1391,  0.7276]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.9 µs ± 94.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.7 µs ± 40.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]],
#
#                [[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]],
#
#                [[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]],
#
#                [[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]],
#
#                [[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]],
#
#                [[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]],
#
#                [[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]],
#
#                [[-0.2738,  1.6350,  0.4599],
#                 [-1.7590, -1.1099,  0.2953]]]),
#     x: Batch(
#            c: tensor([[[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                       [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                       [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                       [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                       [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                       [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                       [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]],
#
#                       [[ 0.1461,  1.8473, -1.2116,  0.9187],
#                        [ 2.0742, -0.5746, -0.5820,  2.0918],
#                        [-0.4403,  0.4911, -0.1391,  0.7276]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.4 µs ± 146 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953],
#                [-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953],
#                [-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953],
#                [-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953],
#                [-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953],
#                [-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953],
#                [-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953],
#                [-0.2738,  1.6350,  0.4599],
#                [-1.7590, -1.1099,  0.2953]]),
#     x: Batch(
#            c: tensor([[ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276],
#                       [ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276],
#                       [ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276],
#                       [ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276],
#                       [ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276],
#                       [ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276],
#                       [ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276],
#                       [ 0.1461,  1.8473, -1.2116,  0.9187],
#                       [ 2.0742, -0.5746, -0.5820,  2.0918],
#                       [-0.4403,  0.4911, -0.1391,  0.7276]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 365 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 390 µs ± 7.96 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
