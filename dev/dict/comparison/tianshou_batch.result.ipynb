# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fe728a18df0>
# ├── 'a' --> tensor([[ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128]])
# └── 'x' --> <FastTreeValue 0x7fe652004970>
#     └── 'c' --> tensor([[-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915]])

# %%
t.a
# Out:
# tensor([[ 1.9459, -1.8369, -1.0851],
#         [-1.4107,  1.5242, -0.1128]])

# %%
# %timeit t.a
# Out:
# 76 ns ± 0.0668 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fe728a18df0>
# ├── 'a' --> tensor([[ 1.4665,  0.9393, -1.3746],
# │                   [ 0.0375,  0.4435, -0.9833]])
# └── 'x' --> <FastTreeValue 0x7fe652004970>
#     └── 'c' --> tensor([[-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915]])

# %%
# %timeit t.a = new_value
# Out:
# 77.4 ns ± 0.062 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128]]),
#     x: Batch(
#            c: tensor([[-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.9459, -1.8369, -1.0851],
#         [-1.4107,  1.5242, -0.1128]])

# %%
# %timeit b.a
# Out:
# 66.5 ns ± 0.127 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.8023, -0.0839,  0.7759],
#                [-0.6652, -0.6095,  0.1459]]),
#     x: Batch(
#            c: tensor([[-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 559 ns ± 6.89 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.27 µs ± 50.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 32.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 149 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 149 µs ± 839 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fe63904bd30>
# ├── 'a' --> tensor([[[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]],
# │
# │                   [[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]],
# │
# │                   [[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]],
# │
# │                   [[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]],
# │
# │                   [[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]],
# │
# │                   [[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]],
# │
# │                   [[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]],
# │
# │                   [[ 1.9459, -1.8369, -1.0851],
# │                    [-1.4107,  1.5242, -0.1128]]])
# └── 'x' --> <FastTreeValue 0x7fe63904bf40>
#     └── 'c' --> tensor([[[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                         [[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                         [[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                         [[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                         [[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                         [[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                         [[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                         [[-1.1636, -0.4599,  1.2409,  0.4226],
#                          [ 0.1725, -0.8157, -1.6050,  0.7418],
#                          [ 0.7564,  1.1299,  0.5795,  0.3915]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.3 µs ± 87.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fe700e20430>
# ├── 'a' --> tensor([[ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128],
# │                   [ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128],
# │                   [ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128],
# │                   [ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128],
# │                   [ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128],
# │                   [ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128],
# │                   [ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128],
# │                   [ 1.9459, -1.8369, -1.0851],
# │                   [-1.4107,  1.5242, -0.1128]])
# └── 'x' --> <FastTreeValue 0x7fe63904b520>
#     └── 'c' --> tensor([[-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915],
#                         [-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915],
#                         [-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915],
#                         [-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915],
#                         [-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915],
#                         [-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915],
#                         [-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915],
#                         [-1.1636, -0.4599,  1.2409,  0.4226],
#                         [ 0.1725, -0.8157, -1.6050,  0.7418],
#                         [ 0.7564,  1.1299,  0.5795,  0.3915]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.2 µs ± 197 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66 µs ± 64.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]],
#
#                [[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]],
#
#                [[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]],
#
#                [[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]],
#
#                [[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]],
#
#                [[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]],
#
#                [[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]],
#
#                [[ 1.9459, -1.8369, -1.0851],
#                 [-1.4107,  1.5242, -0.1128]]]),
#     x: Batch(
#            c: tensor([[[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                       [[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                       [[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                       [[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                       [[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                       [[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                       [[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]],
#
#                       [[-1.1636, -0.4599,  1.2409,  0.4226],
#                        [ 0.1725, -0.8157, -1.6050,  0.7418],
#                        [ 0.7564,  1.1299,  0.5795,  0.3915]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.7 µs ± 365 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128],
#                [ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128],
#                [ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128],
#                [ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128],
#                [ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128],
#                [ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128],
#                [ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128],
#                [ 1.9459, -1.8369, -1.0851],
#                [-1.4107,  1.5242, -0.1128]]),
#     x: Batch(
#            c: tensor([[-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915],
#                       [-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915],
#                       [-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915],
#                       [-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915],
#                       [-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915],
#                       [-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915],
#                       [-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915],
#                       [-1.1636, -0.4599,  1.2409,  0.4226],
#                       [ 0.1725, -0.8157, -1.6050,  0.7418],
#                       [ 0.7564,  1.1299,  0.5795,  0.3915]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 592 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 383 µs ± 7.92 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
