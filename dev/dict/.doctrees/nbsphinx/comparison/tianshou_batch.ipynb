# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f818c608dc0>
# ├── 'a' --> tensor([[-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813]])
# └── 'x' --> <FastTreeValue 0x7f818c608c40>
#     └── 'c' --> tensor([[ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305]])

# %%
t.a
# Out:
# tensor([[-0.7377, -0.3770,  0.7842],
#         [ 0.2994, -1.1025, -0.6813]])

# %%
# %timeit t.a
# Out:
# 85 ns ± 0.139 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f818c608dc0>
# ├── 'a' --> tensor([[-1.7484, -0.8213,  1.9526],
# │                   [-1.3517, -0.1136,  0.3558]])
# └── 'x' --> <FastTreeValue 0x7f818c608c40>
#     └── 'c' --> tensor([[ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305]])

# %%
# %timeit t.a = new_value
# Out:
# 86.3 ns ± 0.091 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813]]),
#     x: Batch(
#            c: tensor([[ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7377, -0.3770,  0.7842],
#         [ 0.2994, -1.1025, -0.6813]])

# %%
# %timeit b.a
# Out:
# 79.3 ns ± 0.122 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0705, -0.1699, -0.8956],
#                [ 0.1082, -0.6779, -0.6997]]),
#     x: Batch(
#            c: tensor([[ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 657 ns ± 1.21 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.57 µs ± 49 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.5 µs ± 48.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 174 µs ± 2.46 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 174 µs ± 2.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f809bbc62e0>
# ├── 'a' --> tensor([[[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]],
# │
# │                   [[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]],
# │
# │                   [[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]],
# │
# │                   [[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]],
# │
# │                   [[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]],
# │
# │                   [[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]],
# │
# │                   [[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]],
# │
# │                   [[-0.7377, -0.3770,  0.7842],
# │                    [ 0.2994, -1.1025, -0.6813]]])
# └── 'x' --> <FastTreeValue 0x7f809bbc61c0>
#     └── 'c' --> tensor([[[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                         [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                         [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                         [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                         [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                         [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                         [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                         [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                          [ 0.1709, -2.0276,  1.2477,  0.1992],
#                          [ 0.1970, -2.3409,  1.4917, -0.1305]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40.1 µs ± 91.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f81842209d0>
# ├── 'a' --> tensor([[-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813],
# │                   [-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813],
# │                   [-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813],
# │                   [-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813],
# │                   [-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813],
# │                   [-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813],
# │                   [-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813],
# │                   [-0.7377, -0.3770,  0.7842],
# │                   [ 0.2994, -1.1025, -0.6813]])
# └── 'x' --> <FastTreeValue 0x7f809bbc6fd0>
#     └── 'c' --> tensor([[ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305],
#                         [ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305],
#                         [ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305],
#                         [ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305],
#                         [ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305],
#                         [ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305],
#                         [ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305],
#                         [ 2.4235,  0.9897, -0.4798, -0.4392],
#                         [ 0.1709, -2.0276,  1.2477,  0.1992],
#                         [ 0.1970, -2.3409,  1.4917, -0.1305]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.7 µs ± 73.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.4 µs ± 241 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]],
#
#                [[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]],
#
#                [[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]],
#
#                [[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]],
#
#                [[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]],
#
#                [[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]],
#
#                [[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]],
#
#                [[-0.7377, -0.3770,  0.7842],
#                 [ 0.2994, -1.1025, -0.6813]]]),
#     x: Batch(
#            c: tensor([[[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                       [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                       [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                       [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                       [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                       [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                       [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]],
#
#                       [[ 2.4235,  0.9897, -0.4798, -0.4392],
#                        [ 0.1709, -2.0276,  1.2477,  0.1992],
#                        [ 0.1970, -2.3409,  1.4917, -0.1305]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 99.3 µs ± 438 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813],
#                [-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813],
#                [-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813],
#                [-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813],
#                [-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813],
#                [-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813],
#                [-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813],
#                [-0.7377, -0.3770,  0.7842],
#                [ 0.2994, -1.1025, -0.6813]]),
#     x: Batch(
#            c: tensor([[ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305],
#                       [ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305],
#                       [ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305],
#                       [ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305],
#                       [ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305],
#                       [ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305],
#                       [ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305],
#                       [ 2.4235,  0.9897, -0.4798, -0.4392],
#                       [ 0.1709, -2.0276,  1.2477,  0.1992],
#                       [ 0.1970, -2.3409,  1.4917, -0.1305]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 420 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 462 µs ± 38.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
