# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f44b8857910>
# ├── 'a' --> tensor([[-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741]])
# └── 'x' --> <FastTreeValue 0x7f44b8857e20>
#     └── 'c' --> tensor([[-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800]])

# %%
t.a
# Out:
# tensor([[-1.8531, -0.7744, -0.0497],
#         [ 0.3334, -0.8480,  0.5741]])

# %%
# %timeit t.a
# Out:
# 90 ns ± 0.647 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f44b8857910>
# ├── 'a' --> tensor([[-0.5338,  0.4993,  0.1881],
# │                   [-0.2122, -0.2902, -0.2259]])
# └── 'x' --> <FastTreeValue 0x7f44b8857e20>
#     └── 'c' --> tensor([[-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800]])

# %%
# %timeit t.a = new_value
# Out:
# 90.9 ns ± 0.555 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741]]),
#     x: Batch(
#            c: tensor([[-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.8531, -0.7744, -0.0497],
#         [ 0.3334, -0.8480,  0.5741]])

# %%
# %timeit b.a
# Out:
# 83 ns ± 0.0843 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.4925,  0.9625, -0.2140],
#                [-0.7304,  0.7991, -0.2943]]),
#     x: Batch(
#            c: tensor([[-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 659 ns ± 0.227 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 10.3 µs ± 24 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.6 µs ± 24.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 174 µs ± 1.84 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 175 µs ± 1.12 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f44a827df70>
# ├── 'a' --> tensor([[[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]],
# │
# │                   [[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]],
# │
# │                   [[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]],
# │
# │                   [[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]],
# │
# │                   [[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]],
# │
# │                   [[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]],
# │
# │                   [[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]],
# │
# │                   [[-1.8531, -0.7744, -0.0497],
# │                    [ 0.3334, -0.8480,  0.5741]]])
# └── 'x' --> <FastTreeValue 0x7f43e2ce2d90>
#     └── 'c' --> tensor([[[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                         [[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                         [[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                         [[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                         [[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                         [[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                         [[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                         [[-1.0946,  2.0465, -0.4956, -0.1252],
#                          [-1.5796, -0.1107, -0.5907, -0.0343],
#                          [-0.3235, -1.0367,  0.3143, -0.3800]]])

# %%
# %timeit t_stack(trees)
# Out:
# 43.2 µs ± 3.57 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f43c9ebd1c0>
# ├── 'a' --> tensor([[-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741],
# │                   [-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741],
# │                   [-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741],
# │                   [-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741],
# │                   [-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741],
# │                   [-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741],
# │                   [-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741],
# │                   [-1.8531, -0.7744, -0.0497],
# │                   [ 0.3334, -0.8480,  0.5741]])
# └── 'x' --> <FastTreeValue 0x7f44b885cf40>
#     └── 'c' --> tensor([[-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800],
#                         [-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800],
#                         [-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800],
#                         [-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800],
#                         [-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800],
#                         [-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800],
#                         [-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800],
#                         [-1.0946,  2.0465, -0.4956, -0.1252],
#                         [-1.5796, -0.1107, -0.5907, -0.0343],
#                         [-0.3235, -1.0367,  0.3143, -0.3800]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.3 µs ± 69.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.4 µs ± 1.49 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]],
#
#                [[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]],
#
#                [[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]],
#
#                [[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]],
#
#                [[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]],
#
#                [[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]],
#
#                [[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]],
#
#                [[-1.8531, -0.7744, -0.0497],
#                 [ 0.3334, -0.8480,  0.5741]]]),
#     x: Batch(
#            c: tensor([[[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                       [[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                       [[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                       [[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                       [[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                       [[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                       [[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]],
#
#                       [[-1.0946,  2.0465, -0.4956, -0.1252],
#                        [-1.5796, -0.1107, -0.5907, -0.0343],
#                        [-0.3235, -1.0367,  0.3143, -0.3800]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.7 µs ± 101 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741],
#                [-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741],
#                [-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741],
#                [-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741],
#                [-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741],
#                [-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741],
#                [-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741],
#                [-1.8531, -0.7744, -0.0497],
#                [ 0.3334, -0.8480,  0.5741]]),
#     x: Batch(
#            c: tensor([[-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800],
#                       [-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800],
#                       [-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800],
#                       [-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800],
#                       [-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800],
#                       [-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800],
#                       [-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800],
#                       [-1.0946,  2.0465, -0.4956, -0.1252],
#                       [-1.5796, -0.1107, -0.5907, -0.0343],
#                       [-0.3235, -1.0367,  0.3143, -0.3800]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 182 µs ± 1.29 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 449 µs ± 5.27 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
