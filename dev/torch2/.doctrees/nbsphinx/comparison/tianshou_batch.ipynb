# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fac443cc5b0>
# ├── 'a' --> tensor([[-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492]])
# └── 'x' --> <FastTreeValue 0x7fac443cc9a0>
#     └── 'c' --> tensor([[ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472]])

# %%
t.a
# Out:
# tensor([[-0.6016,  0.9815,  0.9926],
#         [-0.4111,  0.3340,  0.3492]])

# %%
# %timeit t.a
# Out:
# 62.7 ns ± 0.0146 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fac443cc5b0>
# ├── 'a' --> tensor([[ 2.1928,  0.0257,  0.6955],
# │                   [ 0.0369, -1.8115, -0.5373]])
# └── 'x' --> <FastTreeValue 0x7fac443cc9a0>
#     └── 'c' --> tensor([[ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472]])

# %%
# %timeit t.a = new_value
# Out:
# 59.6 ns ± 0.0371 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492]]),
#     x: Batch(
#            c: tensor([[ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.6016,  0.9815,  0.9926],
#         [-0.4111,  0.3340,  0.3492]])

# %%
# %timeit b.a
# Out:
# 57.4 ns ± 0.079 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 7.8495e-01, -1.3105e+00, -1.8830e+00],
#                [-3.5640e-04, -7.5900e-01,  1.8305e+00]]),
#     x: Batch(
#            c: tensor([[ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 499 ns ± 0.105 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 841 ns ± 16.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 26.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 579 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 772 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fac47450f10>
# ├── 'a' --> tensor([[[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]],
# │
# │                   [[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]],
# │
# │                   [[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]],
# │
# │                   [[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]],
# │
# │                   [[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]],
# │
# │                   [[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]],
# │
# │                   [[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]],
# │
# │                   [[-0.6016,  0.9815,  0.9926],
# │                    [-0.4111,  0.3340,  0.3492]]])
# └── 'x' --> <FastTreeValue 0x7fac443ccfd0>
#     └── 'c' --> tensor([[[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                         [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                         [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                         [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                         [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                         [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                         [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                         [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                          [-0.1133, -0.1181, -1.4450,  0.4955],
#                          [-0.4649, -0.5415, -1.8148, -0.0472]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.1 µs ± 111 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fab7f60be50>
# ├── 'a' --> tensor([[-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492],
# │                   [-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492],
# │                   [-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492],
# │                   [-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492],
# │                   [-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492],
# │                   [-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492],
# │                   [-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492],
# │                   [-0.6016,  0.9815,  0.9926],
# │                   [-0.4111,  0.3340,  0.3492]])
# └── 'x' --> <FastTreeValue 0x7fab7f60bf40>
#     └── 'c' --> tensor([[ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472],
#                         [ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472],
#                         [ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472],
#                         [ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472],
#                         [ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472],
#                         [ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472],
#                         [ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472],
#                         [ 1.2327,  0.7807,  0.6855, -0.3949],
#                         [-0.1133, -0.1181, -1.4450,  0.4955],
#                         [-0.4649, -0.5415, -1.8148, -0.0472]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.1 µs ± 82.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.2 µs ± 86.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                       [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                       [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                       [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                       [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                       [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                       [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]],
#
#                       [[ 1.2327,  0.7807,  0.6855, -0.3949],
#                        [-0.1133, -0.1181, -1.4450,  0.4955],
#                        [-0.4649, -0.5415, -1.8148, -0.0472]]]),
#        ),
#     a: tensor([[[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]],
#
#                [[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]],
#
#                [[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]],
#
#                [[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]],
#
#                [[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]],
#
#                [[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]],
#
#                [[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]],
#
#                [[-0.6016,  0.9815,  0.9926],
#                 [-0.4111,  0.3340,  0.3492]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.4 µs ± 188 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472],
#                       [ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472],
#                       [ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472],
#                       [ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472],
#                       [ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472],
#                       [ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472],
#                       [ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472],
#                       [ 1.2327,  0.7807,  0.6855, -0.3949],
#                       [-0.1133, -0.1181, -1.4450,  0.4955],
#                       [-0.4649, -0.5415, -1.8148, -0.0472]]),
#        ),
#     a: tensor([[-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492],
#                [-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492],
#                [-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492],
#                [-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492],
#                [-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492],
#                [-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492],
#                [-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492],
#                [-0.6016,  0.9815,  0.9926],
#                [-0.4111,  0.3340,  0.3492]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 324 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 329 µs ± 2.33 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
