# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc330486730>
# ├── 'a' --> tensor([[-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719]])
# └── 'x' --> <FastTreeValue 0x7fc330486250>
#     └── 'c' --> tensor([[-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416]])

# %%
t.a
# Out:
# tensor([[-0.1920,  1.1182,  1.0492],
#         [-1.1373, -0.3620,  0.6719]])

# %%
# %timeit t.a
# Out:
# 61.3 ns ± 0.0831 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc330486730>
# ├── 'a' --> tensor([[-0.0588,  0.8138,  0.8349],
# │                   [-2.5333, -2.4904, -0.7365]])
# └── 'x' --> <FastTreeValue 0x7fc330486250>
#     └── 'c' --> tensor([[-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416]])

# %%
# %timeit t.a = new_value
# Out:
# 60 ns ± 0.0504 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719]]),
#     x: Batch(
#            c: tensor([[-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.1920,  1.1182,  1.0492],
#         [-1.1373, -0.3620,  0.6719]])

# %%
# %timeit b.a
# Out:
# 54.7 ns ± 0.157 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0830, -0.5100,  0.5889],
#                [-0.1680,  0.1359,  1.1009]]),
#     x: Batch(
#            c: tensor([[-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 485 ns ± 0.0903 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 854 ns ± 0.217 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.6 µs ± 33.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 138 µs ± 319 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 479 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc3324fa7f0>
# ├── 'a' --> tensor([[[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]],
# │
# │                   [[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]],
# │
# │                   [[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]],
# │
# │                   [[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]],
# │
# │                   [[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]],
# │
# │                   [[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]],
# │
# │                   [[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]],
# │
# │                   [[-0.1920,  1.1182,  1.0492],
# │                    [-1.1373, -0.3620,  0.6719]]])
# └── 'x' --> <FastTreeValue 0x7fc32837d730>
#     └── 'c' --> tensor([[[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                         [[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                         [[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                         [[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                         [[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                         [[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                         [[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                         [[-0.3052, -0.2575, -0.3152, -0.1231],
#                          [ 0.5036, -0.6174, -2.4092,  0.4670],
#                          [-1.4807, -0.1869, -1.3977,  0.1416]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 58.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc3304865b0>
# ├── 'a' --> tensor([[-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719],
# │                   [-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719],
# │                   [-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719],
# │                   [-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719],
# │                   [-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719],
# │                   [-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719],
# │                   [-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719],
# │                   [-0.1920,  1.1182,  1.0492],
# │                   [-1.1373, -0.3620,  0.6719]])
# └── 'x' --> <FastTreeValue 0x7fc33048ae80>
#     └── 'c' --> tensor([[-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416],
#                         [-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416],
#                         [-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416],
#                         [-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416],
#                         [-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416],
#                         [-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416],
#                         [-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416],
#                         [-0.3052, -0.2575, -0.3152, -0.1231],
#                         [ 0.5036, -0.6174, -2.4092,  0.4670],
#                         [-1.4807, -0.1869, -1.3977,  0.1416]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.9 µs ± 46 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.7 µs ± 53.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]],
#
#                [[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]],
#
#                [[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]],
#
#                [[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]],
#
#                [[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]],
#
#                [[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]],
#
#                [[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]],
#
#                [[-0.1920,  1.1182,  1.0492],
#                 [-1.1373, -0.3620,  0.6719]]]),
#     x: Batch(
#            c: tensor([[[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                       [[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                       [[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                       [[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                       [[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                       [[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                       [[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]],
#
#                       [[-0.3052, -0.2575, -0.3152, -0.1231],
#                        [ 0.5036, -0.6174, -2.4092,  0.4670],
#                        [-1.4807, -0.1869, -1.3977,  0.1416]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.9 µs ± 275 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719],
#                [-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719],
#                [-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719],
#                [-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719],
#                [-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719],
#                [-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719],
#                [-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719],
#                [-0.1920,  1.1182,  1.0492],
#                [-1.1373, -0.3620,  0.6719]]),
#     x: Batch(
#            c: tensor([[-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416],
#                       [-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416],
#                       [-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416],
#                       [-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416],
#                       [-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416],
#                       [-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416],
#                       [-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416],
#                       [-0.3052, -0.2575, -0.3152, -0.1231],
#                       [ 0.5036, -0.6174, -2.4092,  0.4670],
#                       [-1.4807, -0.1869, -1.3977,  0.1416]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 151 µs ± 530 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 338 µs ± 3.78 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
