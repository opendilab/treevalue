# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f414c4b1670>
# ├── 'a' --> tensor([[-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318]])
# └── 'x' --> <FastTreeValue 0x7f414c4b1550>
#     └── 'c' --> tensor([[-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495]])

# %%
t.a
# Out:
# tensor([[-0.8977,  0.0131, -0.8787],
#         [ 0.9129, -0.0824, -0.1318]])

# %%
# %timeit t.a
# Out:
# 64.1 ns ± 0.029 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f414c4b1670>
# ├── 'a' --> tensor([[ 0.3082,  0.5118,  0.0096],
# │                   [-0.0061, -0.7572,  1.7539]])
# └── 'x' --> <FastTreeValue 0x7f414c4b1550>
#     └── 'c' --> tensor([[-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495]])

# %%
# %timeit t.a = new_value
# Out:
# 67.5 ns ± 0.0196 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318]]),
#     x: Batch(
#            c: tensor([[-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.8977,  0.0131, -0.8787],
#         [ 0.9129, -0.0824, -0.1318]])

# %%
# %timeit b.a
# Out:
# 59.1 ns ± 0.0626 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.2312, -0.6125, -0.6261],
#                [-2.2129, -0.8274,  0.0226]]),
#     x: Batch(
#            c: tensor([[-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 497 ns ± 0.163 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 807 ns ± 0.442 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.8 µs ± 15.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 369 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 723 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f406d1d9f40>
# ├── 'a' --> tensor([[[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]],
# │
# │                   [[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]],
# │
# │                   [[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]],
# │
# │                   [[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]],
# │
# │                   [[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]],
# │
# │                   [[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]],
# │
# │                   [[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]],
# │
# │                   [[-0.8977,  0.0131, -0.8787],
# │                    [ 0.9129, -0.0824, -0.1318]]])
# └── 'x' --> <FastTreeValue 0x7f40868d4af0>
#     └── 'c' --> tensor([[[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                         [[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                         [[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                         [[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                         [[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                         [[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                         [[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                         [[-0.7376, -0.1877,  0.3227,  0.7780],
#                          [-0.3749,  1.9145,  0.9747,  0.2147],
#                          [ 1.0233,  0.6959, -1.4289,  1.1495]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.1 µs ± 70.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f406e234fd0>
# ├── 'a' --> tensor([[-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318],
# │                   [-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318],
# │                   [-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318],
# │                   [-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318],
# │                   [-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318],
# │                   [-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318],
# │                   [-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318],
# │                   [-0.8977,  0.0131, -0.8787],
# │                   [ 0.9129, -0.0824, -0.1318]])
# └── 'x' --> <FastTreeValue 0x7f406e234b50>
#     └── 'c' --> tensor([[-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495],
#                         [-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495],
#                         [-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495],
#                         [-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495],
#                         [-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495],
#                         [-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495],
#                         [-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495],
#                         [-0.7376, -0.1877,  0.3227,  0.7780],
#                         [-0.3749,  1.9145,  0.9747,  0.2147],
#                         [ 1.0233,  0.6959, -1.4289,  1.1495]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 87.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.2 µs ± 240 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]],
#
#                [[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]],
#
#                [[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]],
#
#                [[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]],
#
#                [[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]],
#
#                [[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]],
#
#                [[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]],
#
#                [[-0.8977,  0.0131, -0.8787],
#                 [ 0.9129, -0.0824, -0.1318]]]),
#     x: Batch(
#            c: tensor([[[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                       [[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                       [[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                       [[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                       [[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                       [[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                       [[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]],
#
#                       [[-0.7376, -0.1877,  0.3227,  0.7780],
#                        [-0.3749,  1.9145,  0.9747,  0.2147],
#                        [ 1.0233,  0.6959, -1.4289,  1.1495]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.3 µs ± 359 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318],
#                [-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318],
#                [-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318],
#                [-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318],
#                [-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318],
#                [-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318],
#                [-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318],
#                [-0.8977,  0.0131, -0.8787],
#                [ 0.9129, -0.0824, -0.1318]]),
#     x: Batch(
#            c: tensor([[-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495],
#                       [-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495],
#                       [-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495],
#                       [-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495],
#                       [-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495],
#                       [-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495],
#                       [-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495],
#                       [-0.7376, -0.1877,  0.3227,  0.7780],
#                       [-0.3749,  1.9145,  0.9747,  0.2147],
#                       [ 1.0233,  0.6959, -1.4289,  1.1495]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 148 µs ± 846 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 348 µs ± 1.63 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
