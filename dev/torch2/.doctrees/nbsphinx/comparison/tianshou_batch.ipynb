# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f827c36df10>
# ├── 'a' --> tensor([[ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929]])
# └── 'x' --> <FastTreeValue 0x7f827c36dbe0>
#     └── 'c' --> tensor([[ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166]])

# %%
t.a
# Out:
# tensor([[ 0.7262,  0.0373, -0.0703],
#         [-1.6730, -1.4953, -1.4929]])

# %%
# %timeit t.a
# Out:
# 85.1 ns ± 0.0965 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f827c36df10>
# ├── 'a' --> tensor([[-0.9181,  0.1394, -1.5484],
# │                   [-1.7777, -1.0688,  0.4304]])
# └── 'x' --> <FastTreeValue 0x7f827c36dbe0>
#     └── 'c' --> tensor([[ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166]])

# %%
# %timeit t.a = new_value
# Out:
# 90.5 ns ± 0.0998 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929]]),
#     x: Batch(
#            c: tensor([[ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.7262,  0.0373, -0.0703],
#         [-1.6730, -1.4953, -1.4929]])

# %%
# %timeit b.a
# Out:
# 79.4 ns ± 0.193 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.2756, -1.5969,  1.5682],
#                [-1.3650,  0.4980,  0.8738]]),
#     x: Batch(
#            c: tensor([[ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 655 ns ± 0.195 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.62 µs ± 33.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.5 µs ± 23.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 172 µs ± 1.23 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 176 µs ± 1.03 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f818e9d1970>
# ├── 'a' --> tensor([[[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]],
# │
# │                   [[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]],
# │
# │                   [[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]],
# │
# │                   [[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]],
# │
# │                   [[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]],
# │
# │                   [[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]],
# │
# │                   [[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]],
# │
# │                   [[ 0.7262,  0.0373, -0.0703],
# │                    [-1.6730, -1.4953, -1.4929]]])
# └── 'x' --> <FastTreeValue 0x7f826c221640>
#     └── 'c' --> tensor([[[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                         [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                         [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                         [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                         [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                         [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                         [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                         [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                          [ 0.4430, -0.5978,  0.5312,  0.8725],
#                          [ 1.2529,  1.0994,  0.4839, -1.0166]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39.7 µs ± 59.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f818e9d15b0>
# ├── 'a' --> tensor([[ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929],
# │                   [ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929],
# │                   [ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929],
# │                   [ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929],
# │                   [ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929],
# │                   [ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929],
# │                   [ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929],
# │                   [ 0.7262,  0.0373, -0.0703],
# │                   [-1.6730, -1.4953, -1.4929]])
# └── 'x' --> <FastTreeValue 0x7f818e9d1250>
#     └── 'c' --> tensor([[ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166],
#                         [ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166],
#                         [ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166],
#                         [ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166],
#                         [ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166],
#                         [ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166],
#                         [ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166],
#                         [ 0.8560,  1.3166, -0.3154, -0.9722],
#                         [ 0.4430, -0.5978,  0.5312,  0.8725],
#                         [ 1.2529,  1.0994,  0.4839, -1.0166]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.4 µs ± 232 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.6 µs ± 138 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]],
#
#                [[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]],
#
#                [[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]],
#
#                [[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]],
#
#                [[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]],
#
#                [[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]],
#
#                [[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]],
#
#                [[ 0.7262,  0.0373, -0.0703],
#                 [-1.6730, -1.4953, -1.4929]]]),
#     x: Batch(
#            c: tensor([[[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                       [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                       [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                       [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                       [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                       [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                       [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]],
#
#                       [[ 0.8560,  1.3166, -0.3154, -0.9722],
#                        [ 0.4430, -0.5978,  0.5312,  0.8725],
#                        [ 1.2529,  1.0994,  0.4839, -1.0166]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 100 µs ± 1.03 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929],
#                [ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929],
#                [ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929],
#                [ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929],
#                [ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929],
#                [ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929],
#                [ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929],
#                [ 0.7262,  0.0373, -0.0703],
#                [-1.6730, -1.4953, -1.4929]]),
#     x: Batch(
#            c: tensor([[ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166],
#                       [ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166],
#                       [ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166],
#                       [ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166],
#                       [ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166],
#                       [ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166],
#                       [ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166],
#                       [ 0.8560,  1.3166, -0.3154, -0.9722],
#                       [ 0.4430, -0.5978,  0.5312,  0.8725],
#                       [ 1.2529,  1.0994,  0.4839, -1.0166]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 378 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 445 µs ± 11.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
