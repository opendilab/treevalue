# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f4ab80443a0>
# ├── 'a' --> tensor([[ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803]])
# └── 'x' --> <FastTreeValue 0x7f4abc0b9460>
#     └── 'c' --> tensor([[ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324]])

# %%
t.a
# Out:
# tensor([[ 0.1626,  0.5121, -0.6113],
#         [-0.2942,  1.0031, -0.3803]])

# %%
# %timeit t.a
# Out:
# 72.2 ns ± 0.0807 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f4ab80443a0>
# ├── 'a' --> tensor([[ 1.1703, -0.3790,  0.2003],
# │                   [ 1.7773,  0.1364, -0.6830]])
# └── 'x' --> <FastTreeValue 0x7f4abc0b9460>
#     └── 'c' --> tensor([[ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324]])

# %%
# %timeit t.a = new_value
# Out:
# 76.7 ns ± 0.0793 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803]]),
#     x: Batch(
#            c: tensor([[ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.1626,  0.5121, -0.6113],
#         [-0.2942,  1.0031, -0.3803]])

# %%
# %timeit b.a
# Out:
# 68.1 ns ± 0.0638 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.6118, -0.7510,  0.2234],
#                [ 2.7555, -2.9749, -1.3034]]),
#     x: Batch(
#            c: tensor([[ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 551 ns ± 0.11 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 865 ns ± 0.181 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.5 µs ± 30.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 146 µs ± 1.76 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 565 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f49db8d5be0>
# ├── 'a' --> tensor([[[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]],
# │
# │                   [[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]],
# │
# │                   [[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]],
# │
# │                   [[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]],
# │
# │                   [[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]],
# │
# │                   [[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]],
# │
# │                   [[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]],
# │
# │                   [[ 0.1626,  0.5121, -0.6113],
# │                    [-0.2942,  1.0031, -0.3803]]])
# └── 'x' --> <FastTreeValue 0x7f49db8c41f0>
#     └── 'c' --> tensor([[[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                         [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                         [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                         [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                         [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                         [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                         [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                         [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                          [-0.4686, -0.3194,  0.3679,  0.2709],
#                          [-0.7984,  0.4929,  0.5220,  0.1324]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.9 µs ± 64.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f49db8d5670>
# ├── 'a' --> tensor([[ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803],
# │                   [ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803],
# │                   [ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803],
# │                   [ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803],
# │                   [ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803],
# │                   [ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803],
# │                   [ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803],
# │                   [ 0.1626,  0.5121, -0.6113],
# │                   [-0.2942,  1.0031, -0.3803]])
# └── 'x' --> <FastTreeValue 0x7f49db8d56d0>
#     └── 'c' --> tensor([[ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324],
#                         [ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324],
#                         [ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324],
#                         [ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324],
#                         [ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324],
#                         [ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324],
#                         [ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324],
#                         [ 0.2876, -1.1108, -0.5279,  0.3563],
#                         [-0.4686, -0.3194,  0.3679,  0.2709],
#                         [-0.7984,  0.4929,  0.5220,  0.1324]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.3 µs ± 50.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.4 µs ± 185 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]],
#
#                [[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]],
#
#                [[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]],
#
#                [[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]],
#
#                [[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]],
#
#                [[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]],
#
#                [[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]],
#
#                [[ 0.1626,  0.5121, -0.6113],
#                 [-0.2942,  1.0031, -0.3803]]]),
#     x: Batch(
#            c: tensor([[[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                       [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                       [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                       [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                       [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                       [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                       [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]],
#
#                       [[ 0.2876, -1.1108, -0.5279,  0.3563],
#                        [-0.4686, -0.3194,  0.3679,  0.2709],
#                        [-0.7984,  0.4929,  0.5220,  0.1324]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.2 µs ± 351 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803],
#                [ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803],
#                [ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803],
#                [ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803],
#                [ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803],
#                [ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803],
#                [ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803],
#                [ 0.1626,  0.5121, -0.6113],
#                [-0.2942,  1.0031, -0.3803]]),
#     x: Batch(
#            c: tensor([[ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324],
#                       [ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324],
#                       [ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324],
#                       [ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324],
#                       [ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324],
#                       [ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324],
#                       [ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324],
#                       [ 0.2876, -1.1108, -0.5279,  0.3563],
#                       [-0.4686, -0.3194,  0.3679,  0.2709],
#                       [-0.7984,  0.4929,  0.5220,  0.1324]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 152 µs ± 321 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 358 µs ± 4.25 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
