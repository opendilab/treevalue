# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc12ce7d910>
# ├── 'a' --> tensor([[ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162]])
# └── 'x' --> <FastTreeValue 0x7fc12ce7d3d0>
#     └── 'c' --> tensor([[-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738]])

# %%
t.a
# Out:
# tensor([[ 1.5627,  1.4918, -0.0779],
#         [-2.0535, -0.5853,  1.2162]])

# %%
# %timeit t.a
# Out:
# 72.3 ns ± 0.101 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc12ce7d910>
# ├── 'a' --> tensor([[ 0.0330, -0.2860,  0.8733],
# │                   [ 0.0168, -1.9001,  0.6771]])
# └── 'x' --> <FastTreeValue 0x7fc12ce7d3d0>
#     └── 'c' --> tensor([[-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738]])

# %%
# %timeit t.a = new_value
# Out:
# 78.8 ns ± 0.107 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162]]),
#     x: Batch(
#            c: tensor([[-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.5627,  1.4918, -0.0779],
#         [-2.0535, -0.5853,  1.2162]])

# %%
# %timeit b.a
# Out:
# 64.6 ns ± 0.0653 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.7022,  0.7873, -0.2217],
#                [ 1.0499, -0.2130,  0.0558]]),
#     x: Batch(
#            c: tensor([[-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 551 ns ± 0.134 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 892 ns ± 3.38 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 14.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 1.65 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 1.15 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc05e6196d0>
# ├── 'a' --> tensor([[[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]],
# │
# │                   [[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]],
# │
# │                   [[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]],
# │
# │                   [[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]],
# │
# │                   [[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]],
# │
# │                   [[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]],
# │
# │                   [[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]],
# │
# │                   [[ 1.5627,  1.4918, -0.0779],
# │                    [-2.0535, -0.5853,  1.2162]]])
# └── 'x' --> <FastTreeValue 0x7fc0506e9910>
#     └── 'c' --> tensor([[[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                         [[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                         [[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                         [[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                         [[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                         [[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                         [[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                         [[-0.0525, -1.4619, -0.2272, -0.8942],
#                          [ 0.5319,  0.0530,  1.3304,  0.7940],
#                          [-0.0831, -0.5761, -1.1629, -1.5738]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.8 µs ± 102 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc0506e9df0>
# ├── 'a' --> tensor([[ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162],
# │                   [ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162],
# │                   [ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162],
# │                   [ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162],
# │                   [ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162],
# │                   [ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162],
# │                   [ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162],
# │                   [ 1.5627,  1.4918, -0.0779],
# │                   [-2.0535, -0.5853,  1.2162]])
# └── 'x' --> <FastTreeValue 0x7fc04f68df40>
#     └── 'c' --> tensor([[-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738],
#                         [-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738],
#                         [-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738],
#                         [-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738],
#                         [-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738],
#                         [-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738],
#                         [-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738],
#                         [-0.0525, -1.4619, -0.2272, -0.8942],
#                         [ 0.5319,  0.0530,  1.3304,  0.7940],
#                         [-0.0831, -0.5761, -1.1629, -1.5738]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.2 µs ± 77.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69.3 µs ± 58.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]],
#
#                [[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]],
#
#                [[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]],
#
#                [[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]],
#
#                [[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]],
#
#                [[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]],
#
#                [[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]],
#
#                [[ 1.5627,  1.4918, -0.0779],
#                 [-2.0535, -0.5853,  1.2162]]]),
#     x: Batch(
#            c: tensor([[[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                       [[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                       [[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                       [[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                       [[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                       [[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                       [[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]],
#
#                       [[-0.0525, -1.4619, -0.2272, -0.8942],
#                        [ 0.5319,  0.0530,  1.3304,  0.7940],
#                        [-0.0831, -0.5761, -1.1629, -1.5738]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.1 µs ± 142 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162],
#                [ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162],
#                [ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162],
#                [ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162],
#                [ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162],
#                [ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162],
#                [ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162],
#                [ 1.5627,  1.4918, -0.0779],
#                [-2.0535, -0.5853,  1.2162]]),
#     x: Batch(
#            c: tensor([[-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738],
#                       [-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738],
#                       [-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738],
#                       [-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738],
#                       [-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738],
#                       [-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738],
#                       [-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738],
#                       [-0.0525, -1.4619, -0.2272, -0.8942],
#                       [ 0.5319,  0.0530,  1.3304,  0.7940],
#                       [-0.0831, -0.5761, -1.1629, -1.5738]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 263 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 355 µs ± 6.64 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
