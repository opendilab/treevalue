# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7ff47024d1f0>
# ├── 'a' --> tensor([[-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454]])
# └── 'x' --> <FastTreeValue 0x7ff4722fc880>
#     └── 'c' --> tensor([[ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822]])

# %%
t.a
# Out:
# tensor([[-0.8476, -1.3226, -0.6391],
#         [ 0.7403, -0.4802,  2.2454]])

# %%
# %timeit t.a
# Out:
# 86.5 ns ± 0.0663 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7ff47024d1f0>
# ├── 'a' --> tensor([[-0.6547,  1.1971,  1.9562],
# │                   [-0.1625, -1.2734, -1.3091]])
# └── 'x' --> <FastTreeValue 0x7ff4722fc880>
#     └── 'c' --> tensor([[ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822]])

# %%
# %timeit t.a = new_value
# Out:
# 99.8 ns ± 0.18 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454]]),
#     x: Batch(
#            c: tensor([[ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.8476, -1.3226, -0.6391],
#         [ 0.7403, -0.4802,  2.2454]])

# %%
# %timeit b.a
# Out:
# 81.7 ns ± 0.0596 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.9765,  0.3312,  1.1723],
#                [-0.8556,  0.5341,  1.1020]]),
#     x: Batch(
#            c: tensor([[ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 654 ns ± 0.362 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.06 µs ± 0.51 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.5 µs ± 8.12 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 170 µs ± 757 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 173 µs ± 9.03 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7ff39c2108e0>
# ├── 'a' --> tensor([[[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]],
# │
# │                   [[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]],
# │
# │                   [[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]],
# │
# │                   [[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]],
# │
# │                   [[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]],
# │
# │                   [[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]],
# │
# │                   [[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]],
# │
# │                   [[-0.8476, -1.3226, -0.6391],
# │                    [ 0.7403, -0.4802,  2.2454]]])
# └── 'x' --> <FastTreeValue 0x7ff39c1c6f40>
#     └── 'c' --> tensor([[[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                         [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                         [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                         [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                         [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                         [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                         [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                         [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                          [-0.3896, -0.3951,  0.5513,  1.9206],
#                          [ 0.8652,  0.4957, -2.4270, -0.3822]]])

# %%
# %timeit t_stack(trees)
# Out:
# 38.5 µs ± 105 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7ff39fa37370>
# ├── 'a' --> tensor([[-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454],
# │                   [-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454],
# │                   [-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454],
# │                   [-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454],
# │                   [-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454],
# │                   [-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454],
# │                   [-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454],
# │                   [-0.8476, -1.3226, -0.6391],
# │                   [ 0.7403, -0.4802,  2.2454]])
# └── 'x' --> <FastTreeValue 0x7ff39fa37040>
#     └── 'c' --> tensor([[ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822],
#                         [ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822],
#                         [ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822],
#                         [ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822],
#                         [ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822],
#                         [ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822],
#                         [ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822],
#                         [ 1.0198,  0.0809, -2.0205,  0.3086],
#                         [-0.3896, -0.3951,  0.5513,  1.9206],
#                         [ 0.8652,  0.4957, -2.4270, -0.3822]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.4 µs ± 86.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.6 µs ± 56.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                       [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                       [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                       [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                       [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                       [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                       [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]],
#
#                       [[ 1.0198,  0.0809, -2.0205,  0.3086],
#                        [-0.3896, -0.3951,  0.5513,  1.9206],
#                        [ 0.8652,  0.4957, -2.4270, -0.3822]]]),
#        ),
#     a: tensor([[[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]],
#
#                [[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]],
#
#                [[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]],
#
#                [[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]],
#
#                [[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]],
#
#                [[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]],
#
#                [[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]],
#
#                [[-0.8476, -1.3226, -0.6391],
#                 [ 0.7403, -0.4802,  2.2454]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98 µs ± 264 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822],
#                       [ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822],
#                       [ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822],
#                       [ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822],
#                       [ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822],
#                       [ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822],
#                       [ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822],
#                       [ 1.0198,  0.0809, -2.0205,  0.3086],
#                       [-0.3896, -0.3951,  0.5513,  1.9206],
#                       [ 0.8652,  0.4957, -2.4270, -0.3822]]),
#        ),
#     a: tensor([[-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454],
#                [-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454],
#                [-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454],
#                [-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454],
#                [-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454],
#                [-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454],
#                [-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454],
#                [-0.8476, -1.3226, -0.6391],
#                [ 0.7403, -0.4802,  2.2454]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 142 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 419 µs ± 10.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
