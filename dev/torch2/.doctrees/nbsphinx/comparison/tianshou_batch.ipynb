# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f36adfb9a60>
# ├── 'a' --> tensor([[ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254]])
# └── 'x' --> <FastTreeValue 0x7f36adfb98e0>
#     └── 'c' --> tensor([[ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782]])

# %%
t.a
# Out:
# tensor([[ 0.8170,  1.1757,  0.3356],
#         [-0.1715,  1.0560, -0.6254]])

# %%
# %timeit t.a
# Out:
# 85.1 ns ± 1.28 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f36adfb9a60>
# ├── 'a' --> tensor([[-0.2614, -0.7581,  0.9789],
# │                   [ 0.0755, -1.0712, -0.2743]])
# └── 'x' --> <FastTreeValue 0x7f36adfb98e0>
#     └── 'c' --> tensor([[ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782]])

# %%
# %timeit t.a = new_value
# Out:
# 89.6 ns ± 1.29 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254]]),
#     x: Batch(
#            c: tensor([[ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8170,  1.1757,  0.3356],
#         [-0.1715,  1.0560, -0.6254]])

# %%
# %timeit b.a
# Out:
# 75.6 ns ± 0.872 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5427,  0.1110,  1.3199],
#                [-0.3277, -0.6848, -1.4752]]),
#     x: Batch(
#            c: tensor([[ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 655 ns ± 11.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.03 µs ± 5.77 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.7 µs ± 38.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 167 µs ± 1.25 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 166 µs ± 1.34 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f35db709df0>
# ├── 'a' --> tensor([[[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]],
# │
# │                   [[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]],
# │
# │                   [[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]],
# │
# │                   [[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]],
# │
# │                   [[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]],
# │
# │                   [[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]],
# │
# │                   [[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]],
# │
# │                   [[ 0.8170,  1.1757,  0.3356],
# │                    [-0.1715,  1.0560, -0.6254]]])
# └── 'x' --> <FastTreeValue 0x7f35db709640>
#     └── 'c' --> tensor([[[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                         [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                         [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                         [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                         [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                         [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                         [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                         [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                          [ 0.9495,  0.2337,  1.1621, -1.7552],
#                          [-0.2324, -2.0748,  0.7776,  1.5782]]])

# %%
# %timeit t_stack(trees)
# Out:
# 38 µs ± 625 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f35cd811f10>
# ├── 'a' --> tensor([[ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254],
# │                   [ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254],
# │                   [ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254],
# │                   [ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254],
# │                   [ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254],
# │                   [ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254],
# │                   [ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254],
# │                   [ 0.8170,  1.1757,  0.3356],
# │                   [-0.1715,  1.0560, -0.6254]])
# └── 'x' --> <FastTreeValue 0x7f35cd81e070>
#     └── 'c' --> tensor([[ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782],
#                         [ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782],
#                         [ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782],
#                         [ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782],
#                         [ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782],
#                         [ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782],
#                         [ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782],
#                         [ 1.1127,  0.5536,  1.5148, -0.4806],
#                         [ 0.9495,  0.2337,  1.1621, -1.7552],
#                         [-0.2324, -2.0748,  0.7776,  1.5782]])

# %%
# %timeit t_cat(trees)
# Out:
# 35.9 µs ± 253 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.1 µs ± 529 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]],
#
#                [[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]],
#
#                [[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]],
#
#                [[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]],
#
#                [[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]],
#
#                [[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]],
#
#                [[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]],
#
#                [[ 0.8170,  1.1757,  0.3356],
#                 [-0.1715,  1.0560, -0.6254]]]),
#     x: Batch(
#            c: tensor([[[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                       [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                       [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                       [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                       [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                       [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                       [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]],
#
#                       [[ 1.1127,  0.5536,  1.5148, -0.4806],
#                        [ 0.9495,  0.2337,  1.1621, -1.7552],
#                        [-0.2324, -2.0748,  0.7776,  1.5782]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 96 µs ± 1.35 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254],
#                [ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254],
#                [ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254],
#                [ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254],
#                [ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254],
#                [ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254],
#                [ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254],
#                [ 0.8170,  1.1757,  0.3356],
#                [-0.1715,  1.0560, -0.6254]]),
#     x: Batch(
#            c: tensor([[ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782],
#                       [ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782],
#                       [ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782],
#                       [ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782],
#                       [ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782],
#                       [ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782],
#                       [ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782],
#                       [ 1.1127,  0.5536,  1.5148, -0.4806],
#                       [ 0.9495,  0.2337,  1.1621, -1.7552],
#                       [-0.2324, -2.0748,  0.7776,  1.5782]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 177 µs ± 2.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 411 µs ± 7.12 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
