# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5e879bcfa0>
# ├── 'a' --> tensor([[-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070]])
# └── 'x' --> <FastTreeValue 0x7f5e879bc640>
#     └── 'c' --> tensor([[-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558]])

# %%
t.a
# Out:
# tensor([[-0.2617,  2.5389, -0.5266],
#         [ 1.2851, -0.9590,  0.6070]])

# %%
# %timeit t.a
# Out:
# 63.6 ns ± 0.0453 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5e879bcfa0>
# ├── 'a' --> tensor([[ 0.6113,  0.6519,  0.6188],
# │                   [-0.1214,  0.5228,  0.3564]])
# └── 'x' --> <FastTreeValue 0x7f5e879bc640>
#     └── 'c' --> tensor([[-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558]])

# %%
# %timeit t.a = new_value
# Out:
# 67.5 ns ± 0.0273 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070]]),
#     x: Batch(
#            c: tensor([[-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2617,  2.5389, -0.5266],
#         [ 1.2851, -0.9590,  0.6070]])

# %%
# %timeit b.a
# Out:
# 58.5 ns ± 0.148 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.3375, -0.1594, -1.1328],
#                [ 1.4928, -0.1354, -0.8326]]),
#     x: Batch(
#            c: tensor([[-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 504 ns ± 0.0892 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 831 ns ± 2.82 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 24.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 143 µs ± 1.21 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 652 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5da7702e50>
# ├── 'a' --> tensor([[[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]],
# │
# │                   [[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]],
# │
# │                   [[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]],
# │
# │                   [[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]],
# │
# │                   [[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]],
# │
# │                   [[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]],
# │
# │                   [[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]],
# │
# │                   [[-0.2617,  2.5389, -0.5266],
# │                    [ 1.2851, -0.9590,  0.6070]]])
# └── 'x' --> <FastTreeValue 0x7f5da7702eb0>
#     └── 'c' --> tensor([[[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                         [[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                         [[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                         [[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                         [[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                         [[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                         [[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                         [[-2.1596,  0.9592, -1.3297,  1.5933],
#                          [-0.4809, -0.7240,  0.0857, -0.3419],
#                          [ 1.2186, -0.6041, -0.1928, -0.5558]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.3 µs ± 83.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5da7702d00>
# ├── 'a' --> tensor([[-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070],
# │                   [-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070],
# │                   [-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070],
# │                   [-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070],
# │                   [-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070],
# │                   [-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070],
# │                   [-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070],
# │                   [-0.2617,  2.5389, -0.5266],
# │                   [ 1.2851, -0.9590,  0.6070]])
# └── 'x' --> <FastTreeValue 0x7f5e84919b50>
#     └── 'c' --> tensor([[-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558],
#                         [-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558],
#                         [-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558],
#                         [-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558],
#                         [-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558],
#                         [-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558],
#                         [-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558],
#                         [-2.1596,  0.9592, -1.3297,  1.5933],
#                         [-0.4809, -0.7240,  0.0857, -0.3419],
#                         [ 1.2186, -0.6041, -0.1928, -0.5558]])

# %%
# %timeit t_cat(trees)
# Out:
# 31 µs ± 87.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.2 µs ± 44.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                       [[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                       [[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                       [[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                       [[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                       [[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                       [[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]],
#
#                       [[-2.1596,  0.9592, -1.3297,  1.5933],
#                        [-0.4809, -0.7240,  0.0857, -0.3419],
#                        [ 1.2186, -0.6041, -0.1928, -0.5558]]]),
#        ),
#     a: tensor([[[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]],
#
#                [[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]],
#
#                [[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]],
#
#                [[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]],
#
#                [[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]],
#
#                [[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]],
#
#                [[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]],
#
#                [[-0.2617,  2.5389, -0.5266],
#                 [ 1.2851, -0.9590,  0.6070]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.7 µs ± 324 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558],
#                       [-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558],
#                       [-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558],
#                       [-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558],
#                       [-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558],
#                       [-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558],
#                       [-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558],
#                       [-2.1596,  0.9592, -1.3297,  1.5933],
#                       [-0.4809, -0.7240,  0.0857, -0.3419],
#                       [ 1.2186, -0.6041, -0.1928, -0.5558]]),
#        ),
#     a: tensor([[-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070],
#                [-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070],
#                [-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070],
#                [-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070],
#                [-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070],
#                [-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070],
#                [-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070],
#                [-0.2617,  2.5389, -0.5266],
#                [ 1.2851, -0.9590,  0.6070]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 147 µs ± 305 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 341 µs ± 2.88 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
