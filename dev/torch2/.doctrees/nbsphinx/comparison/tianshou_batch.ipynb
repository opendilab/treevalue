# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9eb4d7f1f0>
# ├── 'a' --> tensor([[ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438]])
# └── 'x' --> <FastTreeValue 0x7f9eb4d7f430>
#     └── 'c' --> tensor([[-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041]])

# %%
t.a
# Out:
# tensor([[ 1.4685, -0.7805,  0.7140],
#         [ 0.4753, -1.3087,  0.6438]])

# %%
# %timeit t.a
# Out:
# 76.9 ns ± 0.324 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9eb4d7f1f0>
# ├── 'a' --> tensor([[-0.3753, -0.4850, -0.2365],
# │                   [ 1.1986, -0.0518,  1.5543]])
# └── 'x' --> <FastTreeValue 0x7f9eb4d7f430>
#     └── 'c' --> tensor([[-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041]])

# %%
# %timeit t.a = new_value
# Out:
# 81.8 ns ± 0.405 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438]]),
#     x: Batch(
#            c: tensor([[-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.4685, -0.7805,  0.7140],
#         [ 0.4753, -1.3087,  0.6438]])

# %%
# %timeit b.a
# Out:
# 74.2 ns ± 1.18 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.4241,  0.8546, -0.0906],
#                [-0.0332,  0.1496,  1.8135]]),
#     x: Batch(
#            c: tensor([[-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 672 ns ± 4.01 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.08 µs ± 12.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 14.5 µs ± 226 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 301 µs ± 25.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 276 µs ± 20.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f9dd6663af0>
# ├── 'a' --> tensor([[[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]],
# │
# │                   [[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]],
# │
# │                   [[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]],
# │
# │                   [[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]],
# │
# │                   [[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]],
# │
# │                   [[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]],
# │
# │                   [[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]],
# │
# │                   [[ 1.4685, -0.7805,  0.7140],
# │                    [ 0.4753, -1.3087,  0.6438]]])
# └── 'x' --> <FastTreeValue 0x7f9de4538c10>
#     └── 'c' --> tensor([[[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                         [[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                         [[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                         [[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                         [[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                         [[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                         [[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                         [[-0.3359, -0.1675,  0.1654,  0.5244],
#                          [ 2.1446,  1.2281,  1.7986, -0.3110],
#                          [ 0.2926, -0.2445,  0.4536,  0.7041]]])

# %%
# %timeit t_stack(trees)
# Out:
# 50.8 µs ± 1.97 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9dd6663f10>
# ├── 'a' --> tensor([[ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438],
# │                   [ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438],
# │                   [ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438],
# │                   [ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438],
# │                   [ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438],
# │                   [ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438],
# │                   [ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438],
# │                   [ 1.4685, -0.7805,  0.7140],
# │                   [ 0.4753, -1.3087,  0.6438]])
# └── 'x' --> <FastTreeValue 0x7f9def14ad00>
#     └── 'c' --> tensor([[-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041],
#                         [-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041],
#                         [-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041],
#                         [-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041],
#                         [-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041],
#                         [-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041],
#                         [-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041],
#                         [-0.3359, -0.1675,  0.1654,  0.5244],
#                         [ 2.1446,  1.2281,  1.7986, -0.3110],
#                         [ 0.2926, -0.2445,  0.4536,  0.7041]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.1 µs ± 624 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 108 µs ± 4.64 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                       [[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                       [[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                       [[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                       [[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                       [[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                       [[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]],
#
#                       [[-0.3359, -0.1675,  0.1654,  0.5244],
#                        [ 2.1446,  1.2281,  1.7986, -0.3110],
#                        [ 0.2926, -0.2445,  0.4536,  0.7041]]]),
#        ),
#     a: tensor([[[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]],
#
#                [[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]],
#
#                [[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]],
#
#                [[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]],
#
#                [[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]],
#
#                [[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]],
#
#                [[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]],
#
#                [[ 1.4685, -0.7805,  0.7140],
#                 [ 0.4753, -1.3087,  0.6438]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 113 µs ± 1.53 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041],
#                       [-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041],
#                       [-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041],
#                       [-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041],
#                       [-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041],
#                       [-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041],
#                       [-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041],
#                       [-0.3359, -0.1675,  0.1654,  0.5244],
#                       [ 2.1446,  1.2281,  1.7986, -0.3110],
#                       [ 0.2926, -0.2445,  0.4536,  0.7041]]),
#        ),
#     a: tensor([[ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438],
#                [ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438],
#                [ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438],
#                [ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438],
#                [ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438],
#                [ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438],
#                [ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438],
#                [ 1.4685, -0.7805,  0.7140],
#                [ 0.4753, -1.3087,  0.6438]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 205 µs ± 2.37 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 631 µs ± 35.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
