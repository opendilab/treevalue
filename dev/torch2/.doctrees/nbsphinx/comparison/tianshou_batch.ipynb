# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fef788f4af0>
# ├── 'a' --> tensor([[ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229]])
# └── 'x' --> <FastTreeValue 0x7fef788f46d0>
#     └── 'c' --> tensor([[-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214]])

# %%
t.a
# Out:
# tensor([[ 0.0855,  0.3297, -0.0380],
#         [ 1.1371, -0.3756,  0.2229]])

# %%
# %timeit t.a
# Out:
# 58.5 ns ± 0.0523 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fef788f4af0>
# ├── 'a' --> tensor([[-1.1043,  0.1827,  0.9644],
# │                   [-0.4905,  0.5340, -0.3681]])
# └── 'x' --> <FastTreeValue 0x7fef788f46d0>
#     └── 'c' --> tensor([[-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214]])

# %%
# %timeit t.a = new_value
# Out:
# 64.4 ns ± 0.0418 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229]]),
#     x: Batch(
#            c: tensor([[-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0855,  0.3297, -0.0380],
#         [ 1.1371, -0.3756,  0.2229]])

# %%
# %timeit b.a
# Out:
# 55 ns ± 0.0225 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5090, -0.2819, -1.2301],
#                [-0.6650,  0.7208, -2.7928]]),
#     x: Batch(
#            c: tensor([[-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 487 ns ± 0.119 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 835 ns ± 1.01 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.6 µs ± 13.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 141 µs ± 1.26 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 482 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fee9d6b80a0>
# ├── 'a' --> tensor([[[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]],
# │
# │                   [[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]],
# │
# │                   [[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]],
# │
# │                   [[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]],
# │
# │                   [[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]],
# │
# │                   [[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]],
# │
# │                   [[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]],
# │
# │                   [[ 0.0855,  0.3297, -0.0380],
# │                    [ 1.1371, -0.3756,  0.2229]]])
# └── 'x' --> <FastTreeValue 0x7feeb5cec790>
#     └── 'c' --> tensor([[[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                         [[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                         [[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                         [[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                         [[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                         [[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                         [[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                         [[-0.6127,  2.1521,  0.9649, -1.4185],
#                          [-0.8129, -0.1999, -0.3427,  0.1240],
#                          [-1.5041,  1.7421, -1.2780,  0.4214]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.4 µs ± 29.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fee9d7212e0>
# ├── 'a' --> tensor([[ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229],
# │                   [ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229],
# │                   [ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229],
# │                   [ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229],
# │                   [ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229],
# │                   [ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229],
# │                   [ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229],
# │                   [ 0.0855,  0.3297, -0.0380],
# │                   [ 1.1371, -0.3756,  0.2229]])
# └── 'x' --> <FastTreeValue 0x7fef7d97b580>
#     └── 'c' --> tensor([[-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214],
#                         [-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214],
#                         [-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214],
#                         [-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214],
#                         [-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214],
#                         [-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214],
#                         [-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214],
#                         [-0.6127,  2.1521,  0.9649, -1.4185],
#                         [-0.8129, -0.1999, -0.3427,  0.1240],
#                         [-1.5041,  1.7421, -1.2780,  0.4214]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.1 µs ± 90.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 70.2 µs ± 50.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]],
#
#                [[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]],
#
#                [[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]],
#
#                [[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]],
#
#                [[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]],
#
#                [[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]],
#
#                [[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]],
#
#                [[ 0.0855,  0.3297, -0.0380],
#                 [ 1.1371, -0.3756,  0.2229]]]),
#     x: Batch(
#            c: tensor([[[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                       [[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                       [[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                       [[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                       [[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                       [[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                       [[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]],
#
#                       [[-0.6127,  2.1521,  0.9649, -1.4185],
#                        [-0.8129, -0.1999, -0.3427,  0.1240],
#                        [-1.5041,  1.7421, -1.2780,  0.4214]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.1 µs ± 143 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229],
#                [ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229],
#                [ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229],
#                [ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229],
#                [ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229],
#                [ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229],
#                [ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229],
#                [ 0.0855,  0.3297, -0.0380],
#                [ 1.1371, -0.3756,  0.2229]]),
#     x: Batch(
#            c: tensor([[-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214],
#                       [-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214],
#                       [-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214],
#                       [-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214],
#                       [-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214],
#                       [-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214],
#                       [-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214],
#                       [-0.6127,  2.1521,  0.9649, -1.4185],
#                       [-0.8129, -0.1999, -0.3427,  0.1240],
#                       [-1.5041,  1.7421, -1.2780,  0.4214]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 305 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 324 µs ± 912 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
