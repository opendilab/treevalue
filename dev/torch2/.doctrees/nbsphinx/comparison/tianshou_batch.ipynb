# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f51f5fc5940>
# ├── 'a' --> tensor([[-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101]])
# └── 'x' --> <FastTreeValue 0x7f51eb7f9970>
#     └── 'c' --> tensor([[ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113]])

# %%
t.a
# Out:
# tensor([[-1.7316,  0.4835, -0.2075],
#         [-1.0097,  0.6632,  0.1101]])

# %%
# %timeit t.a
# Out:
# 71.3 ns ± 0.0825 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f51f5fc5940>
# ├── 'a' --> tensor([[ 0.7046, -0.4135,  0.8018],
# │                   [-1.1267, -0.3398,  0.1517]])
# └── 'x' --> <FastTreeValue 0x7f51eb7f9970>
#     └── 'c' --> tensor([[ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113]])

# %%
# %timeit t.a = new_value
# Out:
# 76 ns ± 0.131 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101]]),
#     x: Batch(
#            c: tensor([[ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.7316,  0.4835, -0.2075],
#         [-1.0097,  0.6632,  0.1101]])

# %%
# %timeit b.a
# Out:
# 66.4 ns ± 0.102 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.1206,  0.4801, -1.1960],
#                [-0.7062, -1.5203,  1.4350]]),
#     x: Batch(
#            c: tensor([[ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 538 ns ± 2.03 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.3 µs ± 35.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 31.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 590 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 149 µs ± 817 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f51dd009580>
# ├── 'a' --> tensor([[[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]],
# │
# │                   [[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]],
# │
# │                   [[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]],
# │
# │                   [[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]],
# │
# │                   [[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]],
# │
# │                   [[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]],
# │
# │                   [[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]],
# │
# │                   [[-1.7316,  0.4835, -0.2075],
# │                    [-1.0097,  0.6632,  0.1101]]])
# └── 'x' --> <FastTreeValue 0x7f51f5e66f70>
#     └── 'c' --> tensor([[[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                         [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                         [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                         [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                         [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                         [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                         [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                         [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                          [ 0.5440,  0.2187,  1.5820,  1.2726],
#                          [-0.3954,  0.8514, -0.3118,  0.1113]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34 µs ± 58.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f51dd009dc0>
# ├── 'a' --> tensor([[-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101],
# │                   [-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101],
# │                   [-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101],
# │                   [-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101],
# │                   [-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101],
# │                   [-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101],
# │                   [-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101],
# │                   [-1.7316,  0.4835, -0.2075],
# │                   [-1.0097,  0.6632,  0.1101]])
# └── 'x' --> <FastTreeValue 0x7f51dd009670>
#     └── 'c' --> tensor([[ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113],
#                         [ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113],
#                         [ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113],
#                         [ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113],
#                         [ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113],
#                         [ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113],
#                         [ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113],
#                         [ 1.7764,  1.1561,  0.6759,  0.3507],
#                         [ 0.5440,  0.2187,  1.5820,  1.2726],
#                         [-0.3954,  0.8514, -0.3118,  0.1113]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.7 µs ± 87.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.7 µs ± 175 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]],
#
#                [[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]],
#
#                [[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]],
#
#                [[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]],
#
#                [[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]],
#
#                [[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]],
#
#                [[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]],
#
#                [[-1.7316,  0.4835, -0.2075],
#                 [-1.0097,  0.6632,  0.1101]]]),
#     x: Batch(
#            c: tensor([[[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                       [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                       [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                       [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                       [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                       [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                       [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]],
#
#                       [[ 1.7764,  1.1561,  0.6759,  0.3507],
#                        [ 0.5440,  0.2187,  1.5820,  1.2726],
#                        [-0.3954,  0.8514, -0.3118,  0.1113]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.9 µs ± 201 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101],
#                [-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101],
#                [-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101],
#                [-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101],
#                [-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101],
#                [-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101],
#                [-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101],
#                [-1.7316,  0.4835, -0.2075],
#                [-1.0097,  0.6632,  0.1101]]),
#     x: Batch(
#            c: tensor([[ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113],
#                       [ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113],
#                       [ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113],
#                       [ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113],
#                       [ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113],
#                       [ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113],
#                       [ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113],
#                       [ 1.7764,  1.1561,  0.6759,  0.3507],
#                       [ 0.5440,  0.2187,  1.5820,  1.2726],
#                       [-0.3954,  0.8514, -0.3118,  0.1113]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 153 µs ± 354 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 392 µs ± 6.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
