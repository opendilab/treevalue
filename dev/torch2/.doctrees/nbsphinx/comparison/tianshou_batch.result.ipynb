# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fad54b2fd30>
# ├── 'a' --> tensor([[-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216]])
# └── 'x' --> <FastTreeValue 0x7fad54b18f70>
#     └── 'c' --> tensor([[-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558]])

# %%
t.a
# Out:
# tensor([[-0.9775,  0.0346, -0.0436],
#         [ 3.7298,  0.3625, -0.9216]])

# %%
# %timeit t.a
# Out:
# 88.9 ns ± 0.863 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fad54b2fd30>
# ├── 'a' --> tensor([[ 1.2804,  0.4149,  0.6383],
# │                   [ 1.0709, -0.2988,  0.5086]])
# └── 'x' --> <FastTreeValue 0x7fad54b18f70>
#     └── 'c' --> tensor([[-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558]])

# %%
# %timeit t.a = new_value
# Out:
# 89.1 ns ± 0.0984 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216]]),
#     x: Batch(
#            c: tensor([[-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.9775,  0.0346, -0.0436],
#         [ 3.7298,  0.3625, -0.9216]])

# %%
# %timeit b.a
# Out:
# 79.1 ns ± 0.0309 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.3308, -0.9389, -0.3673],
#                [ 0.6713, -0.6321, -0.1130]]),
#     x: Batch(
#            c: tensor([[-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 651 ns ± 0.412 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.06 µs ± 6.84 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.5 µs ± 21.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 181 µs ± 9.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 175 µs ± 2.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fad54b2feb0>
# ├── 'a' --> tensor([[[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]],
# │
# │                   [[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]],
# │
# │                   [[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]],
# │
# │                   [[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]],
# │
# │                   [[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]],
# │
# │                   [[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]],
# │
# │                   [[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]],
# │
# │                   [[-0.9775,  0.0346, -0.0436],
# │                    [ 3.7298,  0.3625, -0.9216]]])
# └── 'x' --> <FastTreeValue 0x7fad54b2fa30>
#     └── 'c' --> tensor([[[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                         [[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                         [[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                         [[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                         [[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                         [[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                         [[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                         [[-1.2301, -0.5216, -1.9301, -0.3958],
#                          [-0.4421, -1.6709,  0.3986, -0.9130],
#                          [-0.9227,  0.8326,  1.8706, -0.4558]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40.8 µs ± 63.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fad2ce06d90>
# ├── 'a' --> tensor([[-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216],
# │                   [-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216],
# │                   [-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216],
# │                   [-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216],
# │                   [-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216],
# │                   [-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216],
# │                   [-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216],
# │                   [-0.9775,  0.0346, -0.0436],
# │                   [ 3.7298,  0.3625, -0.9216]])
# └── 'x' --> <FastTreeValue 0x7fad2ce06c40>
#     └── 'c' --> tensor([[-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558],
#                         [-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558],
#                         [-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558],
#                         [-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558],
#                         [-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558],
#                         [-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558],
#                         [-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558],
#                         [-1.2301, -0.5216, -1.9301, -0.3958],
#                         [-0.4421, -1.6709,  0.3986, -0.9130],
#                         [-0.9227,  0.8326,  1.8706, -0.4558]])

# %%
# %timeit t_cat(trees)
# Out:
# 38.1 µs ± 88.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 77.7 µs ± 233 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]],
#
#                [[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]],
#
#                [[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]],
#
#                [[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]],
#
#                [[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]],
#
#                [[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]],
#
#                [[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]],
#
#                [[-0.9775,  0.0346, -0.0436],
#                 [ 3.7298,  0.3625, -0.9216]]]),
#     x: Batch(
#            c: tensor([[[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                       [[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                       [[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                       [[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                       [[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                       [[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                       [[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]],
#
#                       [[-1.2301, -0.5216, -1.9301, -0.3958],
#                        [-0.4421, -1.6709,  0.3986, -0.9130],
#                        [-0.9227,  0.8326,  1.8706, -0.4558]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 123 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216],
#                [-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216],
#                [-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216],
#                [-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216],
#                [-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216],
#                [-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216],
#                [-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216],
#                [-0.9775,  0.0346, -0.0436],
#                [ 3.7298,  0.3625, -0.9216]]),
#     x: Batch(
#            c: tensor([[-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558],
#                       [-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558],
#                       [-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558],
#                       [-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558],
#                       [-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558],
#                       [-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558],
#                       [-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558],
#                       [-1.2301, -0.5216, -1.9301, -0.3958],
#                       [-0.4421, -1.6709,  0.3986, -0.9130],
#                       [-0.9227,  0.8326,  1.8706, -0.4558]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 188 µs ± 4.89 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 452 µs ± 16 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
