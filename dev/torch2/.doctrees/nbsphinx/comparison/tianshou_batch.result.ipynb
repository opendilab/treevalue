# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f47a0818970>
# ├── 'a' --> tensor([[-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607]])
# └── 'x' --> <FastTreeValue 0x7f47a08189a0>
#     └── 'c' --> tensor([[-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571]])

# %%
t.a
# Out:
# tensor([[-1.4894, -2.6380, -0.2639],
#         [-0.5566,  1.4219, -0.6607]])

# %%
# %timeit t.a
# Out:
# 72.7 ns ± 0.0743 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f47a0818970>
# ├── 'a' --> tensor([[-1.1689,  1.4255, -1.4255],
# │                   [-0.6674,  0.4293, -1.3692]])
# └── 'x' --> <FastTreeValue 0x7f47a08189a0>
#     └── 'c' --> tensor([[-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571]])

# %%
# %timeit t.a = new_value
# Out:
# 76.7 ns ± 0.143 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607]]),
#     x: Batch(
#            c: tensor([[-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.4894, -2.6380, -0.2639],
#         [-0.5566,  1.4219, -0.6607]])

# %%
# %timeit b.a
# Out:
# 66.6 ns ± 0.154 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.1842, -0.8593,  0.1915],
#                [ 1.4433, -0.8856, -2.3322]]),
#     x: Batch(
#            c: tensor([[-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 548 ns ± 4.37 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 863 ns ± 0.888 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11 µs ± 15.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 149 µs ± 1.27 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 148 µs ± 620 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f47982058e0>
# ├── 'a' --> tensor([[[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]],
# │
# │                   [[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]],
# │
# │                   [[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]],
# │
# │                   [[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]],
# │
# │                   [[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]],
# │
# │                   [[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]],
# │
# │                   [[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]],
# │
# │                   [[-1.4894, -2.6380, -0.2639],
# │                    [-0.5566,  1.4219, -0.6607]]])
# └── 'x' --> <FastTreeValue 0x7f47a0818f10>
#     └── 'c' --> tensor([[[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                         [[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                         [[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                         [[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                         [[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                         [[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                         [[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                         [[-0.2960, -0.3109, -1.1941,  0.8071],
#                          [-1.6044, -1.8590,  0.1142, -0.0411],
#                          [ 0.3544,  0.8769,  0.2876,  0.0571]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.6 µs ± 72.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f46b0e49cd0>
# ├── 'a' --> tensor([[-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607],
# │                   [-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607],
# │                   [-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607],
# │                   [-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607],
# │                   [-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607],
# │                   [-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607],
# │                   [-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607],
# │                   [-1.4894, -2.6380, -0.2639],
# │                   [-0.5566,  1.4219, -0.6607]])
# └── 'x' --> <FastTreeValue 0x7f46b0e49940>
#     └── 'c' --> tensor([[-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571],
#                         [-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571],
#                         [-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571],
#                         [-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571],
#                         [-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571],
#                         [-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571],
#                         [-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571],
#                         [-0.2960, -0.3109, -1.1941,  0.8071],
#                         [-1.6044, -1.8590,  0.1142, -0.0411],
#                         [ 0.3544,  0.8769,  0.2876,  0.0571]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.6 µs ± 99.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.5 µs ± 45.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                       [[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                       [[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                       [[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                       [[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                       [[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                       [[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]],
#
#                       [[-0.2960, -0.3109, -1.1941,  0.8071],
#                        [-1.6044, -1.8590,  0.1142, -0.0411],
#                        [ 0.3544,  0.8769,  0.2876,  0.0571]]]),
#        ),
#     a: tensor([[[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]],
#
#                [[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]],
#
#                [[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]],
#
#                [[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]],
#
#                [[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]],
#
#                [[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]],
#
#                [[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]],
#
#                [[-1.4894, -2.6380, -0.2639],
#                 [-0.5566,  1.4219, -0.6607]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.3 µs ± 529 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571],
#                       [-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571],
#                       [-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571],
#                       [-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571],
#                       [-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571],
#                       [-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571],
#                       [-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571],
#                       [-0.2960, -0.3109, -1.1941,  0.8071],
#                       [-1.6044, -1.8590,  0.1142, -0.0411],
#                       [ 0.3544,  0.8769,  0.2876,  0.0571]]),
#        ),
#     a: tensor([[-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607],
#                [-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607],
#                [-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607],
#                [-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607],
#                [-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607],
#                [-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607],
#                [-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607],
#                [-1.4894, -2.6380, -0.2639],
#                [-0.5566,  1.4219, -0.6607]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 156 µs ± 454 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 378 µs ± 4.84 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
