# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc750f8fca0>
# ├── 'a' --> tensor([[-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761]])
# └── 'x' --> <FastTreeValue 0x7fc750f8ff70>
#     └── 'c' --> tensor([[-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770]])

# %%
t.a
# Out:
# tensor([[-0.6191,  0.6892, -1.3474],
#         [ 0.3736,  0.6936,  1.0761]])

# %%
# %timeit t.a
# Out:
# 62.7 ns ± 0.114 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc750f8fca0>
# ├── 'a' --> tensor([[-1.3275,  1.2840, -0.0940],
# │                   [ 1.1255,  1.3214, -1.2815]])
# └── 'x' --> <FastTreeValue 0x7fc750f8ff70>
#     └── 'c' --> tensor([[-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770]])

# %%
# %timeit t.a = new_value
# Out:
# 67.1 ns ± 0.026 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761]]),
#     x: Batch(
#            c: tensor([[-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.6191,  0.6892, -1.3474],
#         [ 0.3736,  0.6936,  1.0761]])

# %%
# %timeit b.a
# Out:
# 59.1 ns ± 0.0496 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.9766, -0.0813, -0.9950],
#                [-0.9491, -0.3585, -0.3685]]),
#     x: Batch(
#            c: tensor([[-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 494 ns ± 0.112 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 800 ns ± 1.33 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 25 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 146 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 270 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc7501ac1c0>
# ├── 'a' --> tensor([[[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]],
# │
# │                   [[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]],
# │
# │                   [[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]],
# │
# │                   [[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]],
# │
# │                   [[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]],
# │
# │                   [[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]],
# │
# │                   [[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]],
# │
# │                   [[-0.6191,  0.6892, -1.3474],
# │                    [ 0.3736,  0.6936,  1.0761]]])
# └── 'x' --> <FastTreeValue 0x7fc7501acf10>
#     └── 'c' --> tensor([[[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                         [[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                         [[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                         [[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                         [[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                         [[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                         [[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                         [[-1.4015, -1.3890,  1.1026, -1.2699],
#                          [-1.8539, -1.1099,  0.1461,  0.7665],
#                          [-1.6162,  1.7175,  1.8187,  0.1770]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 60.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc7501acee0>
# ├── 'a' --> tensor([[-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761],
# │                   [-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761],
# │                   [-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761],
# │                   [-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761],
# │                   [-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761],
# │                   [-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761],
# │                   [-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761],
# │                   [-0.6191,  0.6892, -1.3474],
# │                   [ 0.3736,  0.6936,  1.0761]])
# └── 'x' --> <FastTreeValue 0x7fc7501acf70>
#     └── 'c' --> tensor([[-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770],
#                         [-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770],
#                         [-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770],
#                         [-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770],
#                         [-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770],
#                         [-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770],
#                         [-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770],
#                         [-1.4015, -1.3890,  1.1026, -1.2699],
#                         [-1.8539, -1.1099,  0.1461,  0.7665],
#                         [-1.6162,  1.7175,  1.8187,  0.1770]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.7 µs ± 71.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.8 µs ± 178 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                       [[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                       [[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                       [[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                       [[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                       [[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                       [[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]],
#
#                       [[-1.4015, -1.3890,  1.1026, -1.2699],
#                        [-1.8539, -1.1099,  0.1461,  0.7665],
#                        [-1.6162,  1.7175,  1.8187,  0.1770]]]),
#        ),
#     a: tensor([[[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]],
#
#                [[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]],
#
#                [[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]],
#
#                [[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]],
#
#                [[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]],
#
#                [[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]],
#
#                [[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]],
#
#                [[-0.6191,  0.6892, -1.3474],
#                 [ 0.3736,  0.6936,  1.0761]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.3 µs ± 317 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770],
#                       [-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770],
#                       [-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770],
#                       [-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770],
#                       [-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770],
#                       [-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770],
#                       [-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770],
#                       [-1.4015, -1.3890,  1.1026, -1.2699],
#                       [-1.8539, -1.1099,  0.1461,  0.7665],
#                       [-1.6162,  1.7175,  1.8187,  0.1770]]),
#        ),
#     a: tensor([[-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761],
#                [-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761],
#                [-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761],
#                [-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761],
#                [-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761],
#                [-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761],
#                [-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761],
#                [-0.6191,  0.6892, -1.3474],
#                [ 0.3736,  0.6936,  1.0761]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 148 µs ± 371 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 341 µs ± 2.03 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
