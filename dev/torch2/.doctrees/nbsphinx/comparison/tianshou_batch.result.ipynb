# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f37127cfd60>
# ├── 'a' --> tensor([[-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028]])
# └── 'x' --> <FastTreeValue 0x7f37d80c5220>
#     └── 'c' --> tensor([[ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274]])

# %%
t.a
# Out:
# tensor([[-1.5547, -0.2221, -1.7155],
#         [ 0.3045,  0.5863,  0.0028]])

# %%
# %timeit t.a
# Out:
# 65.8 ns ± 0.0526 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f37127cfd60>
# ├── 'a' --> tensor([[-1.1324,  0.7803,  0.5772],
# │                   [ 0.7672, -1.3970,  2.4098]])
# └── 'x' --> <FastTreeValue 0x7f37d80c5220>
#     └── 'c' --> tensor([[ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274]])

# %%
# %timeit t.a = new_value
# Out:
# 67.2 ns ± 0.0501 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028]]),
#     x: Batch(
#            c: tensor([[ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.5547, -0.2221, -1.7155],
#         [ 0.3045,  0.5863,  0.0028]])

# %%
# %timeit b.a
# Out:
# 55.3 ns ± 0.0315 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.7620, -0.8447, -0.2386],
#                [-0.4165, -0.2352,  0.9483]]),
#     x: Batch(
#            c: tensor([[ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 495 ns ± 0.166 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 838 ns ± 0.24 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.5 µs ± 21 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 137 µs ± 590 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 502 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f3707897fa0>
# ├── 'a' --> tensor([[[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]],
# │
# │                   [[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]],
# │
# │                   [[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]],
# │
# │                   [[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]],
# │
# │                   [[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]],
# │
# │                   [[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]],
# │
# │                   [[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]],
# │
# │                   [[-1.5547, -0.2221, -1.7155],
# │                    [ 0.3045,  0.5863,  0.0028]]])
# └── 'x' --> <FastTreeValue 0x7f37d810af40>
#     └── 'c' --> tensor([[[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                         [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                         [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                         [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                         [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                         [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                         [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                         [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                          [-0.0625, -1.0079, -0.2888, -0.9188],
#                          [-1.1079, -0.7518,  0.7300,  0.2274]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 39.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f3707897220>
# ├── 'a' --> tensor([[-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028],
# │                   [-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028],
# │                   [-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028],
# │                   [-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028],
# │                   [-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028],
# │                   [-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028],
# │                   [-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028],
# │                   [-1.5547, -0.2221, -1.7155],
# │                   [ 0.3045,  0.5863,  0.0028]])
# └── 'x' --> <FastTreeValue 0x7f3707897520>
#     └── 'c' --> tensor([[ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274],
#                         [ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274],
#                         [ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274],
#                         [ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274],
#                         [ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274],
#                         [ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274],
#                         [ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274],
#                         [ 0.4814, -1.8759,  0.0393,  0.0875],
#                         [-0.0625, -1.0079, -0.2888, -0.9188],
#                         [-1.1079, -0.7518,  0.7300,  0.2274]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.4 µs ± 43.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 70.3 µs ± 190 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]],
#
#                [[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]],
#
#                [[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]],
#
#                [[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]],
#
#                [[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]],
#
#                [[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]],
#
#                [[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]],
#
#                [[-1.5547, -0.2221, -1.7155],
#                 [ 0.3045,  0.5863,  0.0028]]]),
#     x: Batch(
#            c: tensor([[[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                       [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                       [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                       [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                       [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                       [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                       [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]],
#
#                       [[ 0.4814, -1.8759,  0.0393,  0.0875],
#                        [-0.0625, -1.0079, -0.2888, -0.9188],
#                        [-1.1079, -0.7518,  0.7300,  0.2274]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 81.3 µs ± 433 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028],
#                [-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028],
#                [-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028],
#                [-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028],
#                [-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028],
#                [-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028],
#                [-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028],
#                [-1.5547, -0.2221, -1.7155],
#                [ 0.3045,  0.5863,  0.0028]]),
#     x: Batch(
#            c: tensor([[ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274],
#                       [ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274],
#                       [ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274],
#                       [ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274],
#                       [ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274],
#                       [ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274],
#                       [ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274],
#                       [ 0.4814, -1.8759,  0.0393,  0.0875],
#                       [-0.0625, -1.0079, -0.2888, -0.9188],
#                       [-1.1079, -0.7518,  0.7300,  0.2274]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 151 µs ± 409 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 331 µs ± 4.47 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
