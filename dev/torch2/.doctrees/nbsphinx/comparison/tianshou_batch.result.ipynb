# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f1694c3cf70>
# ├── 'a' --> tensor([[-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252]])
# └── 'x' --> <FastTreeValue 0x7f1694c3c730>
#     └── 'c' --> tensor([[-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008]])

# %%
t.a
# Out:
# tensor([[-0.1640,  1.1697,  1.5848],
#         [ 1.3457,  0.3506,  2.0252]])

# %%
# %timeit t.a
# Out:
# 85.3 ns ± 0.489 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f1694c3cf70>
# ├── 'a' --> tensor([[ 0.3833, -1.1527,  1.5508],
# │                   [-0.5764,  0.3720, -0.8296]])
# └── 'x' --> <FastTreeValue 0x7f1694c3c730>
#     └── 'c' --> tensor([[-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008]])

# %%
# %timeit t.a = new_value
# Out:
# 87.5 ns ± 0.815 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252]]),
#     x: Batch(
#            c: tensor([[-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.1640,  1.1697,  1.5848],
#         [ 1.3457,  0.3506,  2.0252]])

# %%
# %timeit b.a
# Out:
# 76 ns ± 0.761 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.4282, -1.8866, -1.0304],
#                [-0.0312,  2.5880,  1.0533]]),
#     x: Batch(
#            c: tensor([[-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 638 ns ± 3.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.05 µs ± 3.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.3 µs ± 88.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 168 µs ± 1.27 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 170 µs ± 749 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f1690b59610>
# ├── 'a' --> tensor([[[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]],
# │
# │                   [[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]],
# │
# │                   [[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]],
# │
# │                   [[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]],
# │
# │                   [[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]],
# │
# │                   [[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]],
# │
# │                   [[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]],
# │
# │                   [[-0.1640,  1.1697,  1.5848],
# │                    [ 1.3457,  0.3506,  2.0252]]])
# └── 'x' --> <FastTreeValue 0x7f1690bc1730>
#     └── 'c' --> tensor([[[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                         [[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                         [[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                         [[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                         [[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                         [[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                         [[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                         [[-1.5679, -1.3937,  0.2608,  0.3595],
#                          [-0.5586,  0.5793, -0.4585,  0.5239],
#                          [ 0.4650,  0.3729, -1.2006,  0.2008]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39 µs ± 299 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f15c233fbe0>
# ├── 'a' --> tensor([[-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252],
# │                   [-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252],
# │                   [-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252],
# │                   [-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252],
# │                   [-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252],
# │                   [-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252],
# │                   [-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252],
# │                   [-0.1640,  1.1697,  1.5848],
# │                   [ 1.3457,  0.3506,  2.0252]])
# └── 'x' --> <FastTreeValue 0x7f15b4452220>
#     └── 'c' --> tensor([[-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008],
#                         [-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008],
#                         [-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008],
#                         [-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008],
#                         [-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008],
#                         [-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008],
#                         [-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008],
#                         [-1.5679, -1.3937,  0.2608,  0.3595],
#                         [-0.5586,  0.5793, -0.4585,  0.5239],
#                         [ 0.4650,  0.3729, -1.2006,  0.2008]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.7 µs ± 202 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 80.6 µs ± 218 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]],
#
#                [[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]],
#
#                [[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]],
#
#                [[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]],
#
#                [[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]],
#
#                [[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]],
#
#                [[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]],
#
#                [[-0.1640,  1.1697,  1.5848],
#                 [ 1.3457,  0.3506,  2.0252]]]),
#     x: Batch(
#            c: tensor([[[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                       [[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                       [[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                       [[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                       [[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                       [[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                       [[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]],
#
#                       [[-1.5679, -1.3937,  0.2608,  0.3595],
#                        [-0.5586,  0.5793, -0.4585,  0.5239],
#                        [ 0.4650,  0.3729, -1.2006,  0.2008]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 99 µs ± 481 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252],
#                [-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252],
#                [-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252],
#                [-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252],
#                [-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252],
#                [-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252],
#                [-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252],
#                [-0.1640,  1.1697,  1.5848],
#                [ 1.3457,  0.3506,  2.0252]]),
#     x: Batch(
#            c: tensor([[-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008],
#                       [-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008],
#                       [-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008],
#                       [-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008],
#                       [-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008],
#                       [-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008],
#                       [-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008],
#                       [-1.5679, -1.3937,  0.2608,  0.3595],
#                       [-0.5586,  0.5793, -0.4585,  0.5239],
#                       [ 0.4650,  0.3729, -1.2006,  0.2008]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 176 µs ± 1.29 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 419 µs ± 9.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
