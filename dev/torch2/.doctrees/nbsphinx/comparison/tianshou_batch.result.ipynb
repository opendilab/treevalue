# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb0bec17070>
# ├── 'a' --> tensor([[ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521]])
# └── 'x' --> <FastTreeValue 0x7fb0bec176a0>
#     └── 'c' --> tensor([[-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698]])

# %%
t.a
# Out:
# tensor([[ 0.5885, -2.2060, -0.4170],
#         [ 2.0740,  0.4835,  1.2521]])

# %%
# %timeit t.a
# Out:
# 66.4 ns ± 0.0244 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb0bec17070>
# ├── 'a' --> tensor([[-1.1532,  0.6708, -0.2721],
# │                   [ 1.7102,  0.9635,  1.4948]])
# └── 'x' --> <FastTreeValue 0x7fb0bec176a0>
#     └── 'c' --> tensor([[-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698]])

# %%
# %timeit t.a = new_value
# Out:
# 61.7 ns ± 0.022 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521]]),
#     x: Batch(
#            c: tensor([[-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.5885, -2.2060, -0.4170],
#         [ 2.0740,  0.4835,  1.2521]])

# %%
# %timeit b.a
# Out:
# 61.1 ns ± 0.174 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.7793,  0.3228,  0.7211],
#                [ 1.3484, -0.3816, -1.1030]]),
#     x: Batch(
#            c: tensor([[-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 503 ns ± 0.121 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 864 ns ± 12.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.6 µs ± 25.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 139 µs ± 473 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 1.79 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fb0bcbfcee0>
# ├── 'a' --> tensor([[[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]],
# │
# │                   [[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]],
# │
# │                   [[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]],
# │
# │                   [[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]],
# │
# │                   [[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]],
# │
# │                   [[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]],
# │
# │                   [[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]],
# │
# │                   [[ 0.5885, -2.2060, -0.4170],
# │                    [ 2.0740,  0.4835,  1.2521]]])
# └── 'x' --> <FastTreeValue 0x7fb0bcbfc340>
#     └── 'c' --> tensor([[[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                         [[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                         [[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                         [[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                         [[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                         [[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                         [[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                         [[-0.9643, -0.7704,  0.2707,  1.1519],
#                          [-0.0313, -0.2963, -0.9693,  0.6116],
#                          [-0.0296, -0.5681, -0.4845, -0.3698]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.3 µs ± 128 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fb0bec17670>
# ├── 'a' --> tensor([[ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521],
# │                   [ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521],
# │                   [ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521],
# │                   [ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521],
# │                   [ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521],
# │                   [ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521],
# │                   [ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521],
# │                   [ 0.5885, -2.2060, -0.4170],
# │                   [ 2.0740,  0.4835,  1.2521]])
# └── 'x' --> <FastTreeValue 0x7fb0bcb99310>
#     └── 'c' --> tensor([[-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698],
#                         [-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698],
#                         [-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698],
#                         [-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698],
#                         [-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698],
#                         [-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698],
#                         [-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698],
#                         [-0.9643, -0.7704,  0.2707,  1.1519],
#                         [-0.0313, -0.2963, -0.9693,  0.6116],
#                         [-0.0296, -0.5681, -0.4845, -0.3698]])

# %%
# %timeit t_cat(trees)
# Out:
# 31 µs ± 85.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 70.9 µs ± 250 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]],
#
#                [[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]],
#
#                [[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]],
#
#                [[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]],
#
#                [[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]],
#
#                [[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]],
#
#                [[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]],
#
#                [[ 0.5885, -2.2060, -0.4170],
#                 [ 2.0740,  0.4835,  1.2521]]]),
#     x: Batch(
#            c: tensor([[[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                       [[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                       [[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                       [[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                       [[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                       [[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                       [[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]],
#
#                       [[-0.9643, -0.7704,  0.2707,  1.1519],
#                        [-0.0313, -0.2963, -0.9693,  0.6116],
#                        [-0.0296, -0.5681, -0.4845, -0.3698]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 81.1 µs ± 321 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521],
#                [ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521],
#                [ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521],
#                [ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521],
#                [ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521],
#                [ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521],
#                [ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521],
#                [ 0.5885, -2.2060, -0.4170],
#                [ 2.0740,  0.4835,  1.2521]]),
#     x: Batch(
#            c: tensor([[-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698],
#                       [-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698],
#                       [-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698],
#                       [-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698],
#                       [-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698],
#                       [-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698],
#                       [-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698],
#                       [-0.9643, -0.7704,  0.2707,  1.1519],
#                       [-0.0313, -0.2963, -0.9693,  0.6116],
#                       [-0.0296, -0.5681, -0.4845, -0.3698]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 151 µs ± 383 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 335 µs ± 4.39 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
