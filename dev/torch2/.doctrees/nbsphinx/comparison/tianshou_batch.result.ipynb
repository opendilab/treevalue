# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f30e8c5bf40>
# ├── 'a' --> tensor([[-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795]])
# └── 'x' --> <FastTreeValue 0x7f30e8c5b0a0>
#     └── 'c' --> tensor([[ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784]])

# %%
t.a
# Out:
# tensor([[-0.7488,  0.6705,  0.9781],
#         [-2.4526, -1.4005,  0.1795]])

# %%
# %timeit t.a
# Out:
# 87.8 ns ± 2.21 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f30e8c5bf40>
# ├── 'a' --> tensor([[ 2.0265, -0.0690, -1.0914],
# │                   [ 0.2043,  0.2741, -0.0453]])
# └── 'x' --> <FastTreeValue 0x7f30e8c5b0a0>
#     └── 'c' --> tensor([[ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784]])

# %%
# %timeit t.a = new_value
# Out:
# 95.9 ns ± 2.82 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795]]),
#     x: Batch(
#            c: tensor([[ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7488,  0.6705,  0.9781],
#         [-2.4526, -1.4005,  0.1795]])

# %%
# %timeit b.a
# Out:
# 79 ns ± 0.0967 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0909, -0.2242,  0.1963],
#                [-0.5828, -1.6469,  0.2615]]),
#     x: Batch(
#            c: tensor([[ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 659 ns ± 0.203 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.05 µs ± 0.608 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.8 µs ± 370 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 192 µs ± 5.83 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 191 µs ± 8.72 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f30e8c61cd0>
# ├── 'a' --> tensor([[[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]],
# │
# │                   [[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]],
# │
# │                   [[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]],
# │
# │                   [[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]],
# │
# │                   [[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]],
# │
# │                   [[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]],
# │
# │                   [[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]],
# │
# │                   [[-0.7488,  0.6705,  0.9781],
# │                    [-2.4526, -1.4005,  0.1795]]])
# └── 'x' --> <FastTreeValue 0x7f30e8c1e0a0>
#     └── 'c' --> tensor([[[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                         [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                         [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                         [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                         [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                         [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                         [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                         [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                          [ 0.7341,  0.3369, -0.4298, -0.4832],
#                          [ 0.6246,  0.0242,  0.0550,  0.5784]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40 µs ± 152 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f2ffb28b8b0>
# ├── 'a' --> tensor([[-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795],
# │                   [-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795],
# │                   [-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795],
# │                   [-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795],
# │                   [-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795],
# │                   [-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795],
# │                   [-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795],
# │                   [-0.7488,  0.6705,  0.9781],
# │                   [-2.4526, -1.4005,  0.1795]])
# └── 'x' --> <FastTreeValue 0x7f2ffb28ba60>
#     └── 'c' --> tensor([[ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784],
#                         [ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784],
#                         [ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784],
#                         [ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784],
#                         [ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784],
#                         [ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784],
#                         [ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784],
#                         [ 0.3749,  1.2225,  1.2986,  0.2510],
#                         [ 0.7341,  0.3369, -0.4298, -0.4832],
#                         [ 0.6246,  0.0242,  0.0550,  0.5784]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.4 µs ± 131 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.8 µs ± 353 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]],
#
#                [[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]],
#
#                [[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]],
#
#                [[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]],
#
#                [[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]],
#
#                [[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]],
#
#                [[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]],
#
#                [[-0.7488,  0.6705,  0.9781],
#                 [-2.4526, -1.4005,  0.1795]]]),
#     x: Batch(
#            c: tensor([[[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                       [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                       [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                       [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                       [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                       [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                       [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]],
#
#                       [[ 0.3749,  1.2225,  1.2986,  0.2510],
#                        [ 0.7341,  0.3369, -0.4298, -0.4832],
#                        [ 0.6246,  0.0242,  0.0550,  0.5784]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.5 µs ± 103 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795],
#                [-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795],
#                [-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795],
#                [-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795],
#                [-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795],
#                [-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795],
#                [-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795],
#                [-0.7488,  0.6705,  0.9781],
#                [-2.4526, -1.4005,  0.1795]]),
#     x: Batch(
#            c: tensor([[ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784],
#                       [ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784],
#                       [ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784],
#                       [ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784],
#                       [ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784],
#                       [ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784],
#                       [ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784],
#                       [ 0.3749,  1.2225,  1.2986,  0.2510],
#                       [ 0.7341,  0.3369, -0.4298, -0.4832],
#                       [ 0.6246,  0.0242,  0.0550,  0.5784]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 222 µs ± 2.91 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 456 µs ± 9.99 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
