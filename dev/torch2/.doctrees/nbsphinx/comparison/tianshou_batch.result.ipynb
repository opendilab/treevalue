# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7ff410144490>
# ├── 'a' --> tensor([[ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574]])
# └── 'x' --> <FastTreeValue 0x7ff410144370>
#     └── 'c' --> tensor([[ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773]])

# %%
t.a
# Out:
# tensor([[ 0.3159,  1.1228, -1.4962],
#         [-1.9136, -0.9791, -1.4574]])

# %%
# %timeit t.a
# Out:
# 80.6 ns ± 0.084 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7ff410144490>
# ├── 'a' --> tensor([[ 0.8587, -0.3478, -0.3849],
# │                   [ 0.1728, -0.8111,  0.1617]])
# └── 'x' --> <FastTreeValue 0x7ff410144370>
#     └── 'c' --> tensor([[ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773]])

# %%
# %timeit t.a = new_value
# Out:
# 82.8 ns ± 0.115 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574]]),
#     x: Batch(
#            c: tensor([[ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.3159,  1.1228, -1.4962],
#         [-1.9136, -0.9791, -1.4574]])

# %%
# %timeit b.a
# Out:
# 64.9 ns ± 0.124 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.9994,  1.0240, -0.9541],
#                [ 0.7392,  1.1110, -0.1753]]),
#     x: Batch(
#            c: tensor([[ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 541 ns ± 0.0961 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 864 ns ± 0.795 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 25.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 143 µs ± 1.14 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 1.35 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7ff3329fd940>
# ├── 'a' --> tensor([[[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]],
# │
# │                   [[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]],
# │
# │                   [[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]],
# │
# │                   [[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]],
# │
# │                   [[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]],
# │
# │                   [[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]],
# │
# │                   [[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]],
# │
# │                   [[ 0.3159,  1.1228, -1.4962],
# │                    [-1.9136, -0.9791, -1.4574]]])
# └── 'x' --> <FastTreeValue 0x7ff3329fd730>
#     └── 'c' --> tensor([[[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                         [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                         [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                         [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                         [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                         [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                         [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                         [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                          [-0.3261,  1.7645,  2.2829,  0.6873],
#                          [ 0.2249, -1.0704, -0.9356,  0.3773]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.6 µs ± 63.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7ff340974e20>
# ├── 'a' --> tensor([[ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574],
# │                   [ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574],
# │                   [ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574],
# │                   [ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574],
# │                   [ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574],
# │                   [ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574],
# │                   [ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574],
# │                   [ 0.3159,  1.1228, -1.4962],
# │                   [-1.9136, -0.9791, -1.4574]])
# └── 'x' --> <FastTreeValue 0x7ff340974700>
#     └── 'c' --> tensor([[ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773],
#                         [ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773],
#                         [ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773],
#                         [ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773],
#                         [ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773],
#                         [ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773],
#                         [ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773],
#                         [ 1.0834, -1.4758, -1.3318,  0.4107],
#                         [-0.3261,  1.7645,  2.2829,  0.6873],
#                         [ 0.2249, -1.0704, -0.9356,  0.3773]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.6 µs ± 87.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69 µs ± 187 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]],
#
#                [[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]],
#
#                [[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]],
#
#                [[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]],
#
#                [[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]],
#
#                [[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]],
#
#                [[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]],
#
#                [[ 0.3159,  1.1228, -1.4962],
#                 [-1.9136, -0.9791, -1.4574]]]),
#     x: Batch(
#            c: tensor([[[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                       [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                       [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                       [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                       [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                       [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                       [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]],
#
#                       [[ 1.0834, -1.4758, -1.3318,  0.4107],
#                        [-0.3261,  1.7645,  2.2829,  0.6873],
#                        [ 0.2249, -1.0704, -0.9356,  0.3773]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.9 µs ± 165 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574],
#                [ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574],
#                [ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574],
#                [ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574],
#                [ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574],
#                [ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574],
#                [ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574],
#                [ 0.3159,  1.1228, -1.4962],
#                [-1.9136, -0.9791, -1.4574]]),
#     x: Batch(
#            c: tensor([[ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773],
#                       [ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773],
#                       [ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773],
#                       [ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773],
#                       [ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773],
#                       [ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773],
#                       [ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773],
#                       [ 1.0834, -1.4758, -1.3318,  0.4107],
#                       [-0.3261,  1.7645,  2.2829,  0.6873],
#                       [ 0.2249, -1.0704, -0.9356,  0.3773]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 153 µs ± 161 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 351 µs ± 8.29 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
