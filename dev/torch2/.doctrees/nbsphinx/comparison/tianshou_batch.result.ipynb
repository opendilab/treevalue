# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb4484eaf10>
# ├── 'a' --> tensor([[ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015]])
# └── 'x' --> <FastTreeValue 0x7fb4484eaac0>
#     └── 'c' --> tensor([[ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579]])

# %%
t.a
# Out:
# tensor([[ 1.1131,  1.1122, -0.2219],
#         [-1.6591, -1.0246, -0.6015]])

# %%
# %timeit t.a
# Out:
# 81.6 ns ± 10.7 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb4484eaf10>
# ├── 'a' --> tensor([[ 1.4427,  1.2259, -0.2473],
# │                   [ 0.7555, -0.5454, -1.6474]])
# └── 'x' --> <FastTreeValue 0x7fb4484eaac0>
#     └── 'c' --> tensor([[ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579]])

# %%
# %timeit t.a = new_value
# Out:
# 69.6 ns ± 0.0557 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015]]),
#     x: Batch(
#            c: tensor([[ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.1131,  1.1122, -0.2219],
#         [-1.6591, -1.0246, -0.6015]])

# %%
# %timeit b.a
# Out:
# 61.2 ns ± 0.0266 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.1510, -0.0371,  0.8267],
#                [-0.0320, -1.5123,  0.8291]]),
#     x: Batch(
#            c: tensor([[ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 493 ns ± 0.377 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 828 ns ± 1.61 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 19.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 613 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 292 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fb4484ea520>
# ├── 'a' --> tensor([[[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]],
# │
# │                   [[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]],
# │
# │                   [[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]],
# │
# │                   [[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]],
# │
# │                   [[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]],
# │
# │                   [[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]],
# │
# │                   [[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]],
# │
# │                   [[ 1.1131,  1.1122, -0.2219],
# │                    [-1.6591, -1.0246, -0.6015]]])
# └── 'x' --> <FastTreeValue 0x7fb4484eae20>
#     └── 'c' --> tensor([[[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                         [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                         [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                         [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                         [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                         [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                         [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                         [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                          [-0.1923,  0.0829, -0.1074,  1.5412],
#                          [ 0.7631,  1.2276, -0.7471,  0.6579]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.5 µs ± 100 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fb36a2a9fd0>
# ├── 'a' --> tensor([[ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015],
# │                   [ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015],
# │                   [ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015],
# │                   [ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015],
# │                   [ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015],
# │                   [ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015],
# │                   [ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015],
# │                   [ 1.1131,  1.1122, -0.2219],
# │                   [-1.6591, -1.0246, -0.6015]])
# └── 'x' --> <FastTreeValue 0x7fb36a2a9be0>
#     └── 'c' --> tensor([[ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579],
#                         [ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579],
#                         [ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579],
#                         [ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579],
#                         [ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579],
#                         [ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579],
#                         [ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579],
#                         [ 0.9482, -1.1076,  0.6493, -1.8150],
#                         [-0.1923,  0.0829, -0.1074,  1.5412],
#                         [ 0.7631,  1.2276, -0.7471,  0.6579]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.6 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67 µs ± 92.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                       [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                       [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                       [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                       [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                       [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                       [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]],
#
#                       [[ 0.9482, -1.1076,  0.6493, -1.8150],
#                        [-0.1923,  0.0829, -0.1074,  1.5412],
#                        [ 0.7631,  1.2276, -0.7471,  0.6579]]]),
#        ),
#     a: tensor([[[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]],
#
#                [[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]],
#
#                [[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]],
#
#                [[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]],
#
#                [[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]],
#
#                [[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]],
#
#                [[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]],
#
#                [[ 1.1131,  1.1122, -0.2219],
#                 [-1.6591, -1.0246, -0.6015]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 77.9 µs ± 253 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579],
#                       [ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579],
#                       [ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579],
#                       [ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579],
#                       [ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579],
#                       [ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579],
#                       [ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579],
#                       [ 0.9482, -1.1076,  0.6493, -1.8150],
#                       [-0.1923,  0.0829, -0.1074,  1.5412],
#                       [ 0.7631,  1.2276, -0.7471,  0.6579]]),
#        ),
#     a: tensor([[ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015],
#                [ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015],
#                [ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015],
#                [ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015],
#                [ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015],
#                [ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015],
#                [ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015],
#                [ 1.1131,  1.1122, -0.2219],
#                [-1.6591, -1.0246, -0.6015]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 5.57 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 346 µs ± 3.26 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
