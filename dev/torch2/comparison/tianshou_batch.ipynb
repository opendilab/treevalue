# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fd2244fd3d0>
# ├── 'a' --> tensor([[ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247]])
# └── 'x' --> <FastTreeValue 0x7fd2245036d0>
#     └── 'c' --> tensor([[ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338]])

# %%
t.a
# Out:
# tensor([[ 0.6225,  0.3363, -1.0452],
#         [-0.8101, -0.8647,  1.6247]])

# %%
# %timeit t.a
# Out:
# 78.3 ns ± 0.0553 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fd2244fd3d0>
# ├── 'a' --> tensor([[ 0.5701,  1.7879,  0.2346],
# │                   [ 0.0513, -0.8563,  0.7967]])
# └── 'x' --> <FastTreeValue 0x7fd2245036d0>
#     └── 'c' --> tensor([[ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338]])

# %%
# %timeit t.a = new_value
# Out:
# 78.7 ns ± 0.0526 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247]]),
#     x: Batch(
#            c: tensor([[ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.6225,  0.3363, -1.0452],
#         [-0.8101, -0.8647,  1.6247]])

# %%
# %timeit b.a
# Out:
# 64.8 ns ± 0.108 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.6639,  0.9443, -1.4167],
#                [ 0.7966, -1.0074,  0.7439]]),
#     x: Batch(
#            c: tensor([[ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 544 ns ± 0.162 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 872 ns ± 0.251 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.6 µs ± 27.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 147 µs ± 964 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 147 µs ± 562 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fd147dacaf0>
# ├── 'a' --> tensor([[[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]],
# │
# │                   [[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]],
# │
# │                   [[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]],
# │
# │                   [[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]],
# │
# │                   [[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]],
# │
# │                   [[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]],
# │
# │                   [[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]],
# │
# │                   [[ 0.6225,  0.3363, -1.0452],
# │                    [-0.8101, -0.8647,  1.6247]]])
# └── 'x' --> <FastTreeValue 0x7fd147dacdf0>
#     └── 'c' --> tensor([[[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                         [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                         [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                         [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                         [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                         [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                         [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                         [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                          [-1.2759, -1.2809,  1.9177, -0.7543],
#                          [-1.1236, -0.6468, -1.1193, -2.1338]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.6 µs ± 45.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fd147dacb50>
# ├── 'a' --> tensor([[ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247],
# │                   [ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247],
# │                   [ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247],
# │                   [ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247],
# │                   [ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247],
# │                   [ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247],
# │                   [ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247],
# │                   [ 0.6225,  0.3363, -1.0452],
# │                   [-0.8101, -0.8647,  1.6247]])
# └── 'x' --> <FastTreeValue 0x7fd147dacee0>
#     └── 'c' --> tensor([[ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338],
#                         [ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338],
#                         [ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338],
#                         [ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338],
#                         [ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338],
#                         [ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338],
#                         [ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338],
#                         [ 0.3835, -0.0167,  0.2437,  0.8316],
#                         [-1.2759, -1.2809,  1.9177, -0.7543],
#                         [-1.1236, -0.6468, -1.1193, -2.1338]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.3 µs ± 101 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.4 µs ± 99.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                       [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                       [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                       [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                       [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                       [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                       [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]],
#
#                       [[ 0.3835, -0.0167,  0.2437,  0.8316],
#                        [-1.2759, -1.2809,  1.9177, -0.7543],
#                        [-1.1236, -0.6468, -1.1193, -2.1338]]]),
#        ),
#     a: tensor([[[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]],
#
#                [[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]],
#
#                [[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]],
#
#                [[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]],
#
#                [[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]],
#
#                [[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]],
#
#                [[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]],
#
#                [[ 0.6225,  0.3363, -1.0452],
#                 [-0.8101, -0.8647,  1.6247]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.5 µs ± 108 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338],
#                       [ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338],
#                       [ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338],
#                       [ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338],
#                       [ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338],
#                       [ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338],
#                       [ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338],
#                       [ 0.3835, -0.0167,  0.2437,  0.8316],
#                       [-1.2759, -1.2809,  1.9177, -0.7543],
#                       [-1.1236, -0.6468, -1.1193, -2.1338]]),
#        ),
#     a: tensor([[ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247],
#                [ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247],
#                [ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247],
#                [ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247],
#                [ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247],
#                [ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247],
#                [ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247],
#                [ 0.6225,  0.3363, -1.0452],
#                [-0.8101, -0.8647,  1.6247]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 156 µs ± 420 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 361 µs ± 8.65 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
