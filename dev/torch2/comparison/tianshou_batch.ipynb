# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fa9049afd90>
# ├── 'a' --> tensor([[ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884]])
# └── 'x' --> <FastTreeValue 0x7fa824798e80>
#     └── 'c' --> tensor([[-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846]])

# %%
t.a
# Out:
# tensor([[ 0.7479,  0.0652, -0.9307],
#         [-1.2340,  0.5033, -0.6884]])

# %%
# %timeit t.a
# Out:
# 67.4 ns ± 0.0463 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fa9049afd90>
# ├── 'a' --> tensor([[ 1.7645,  1.4834, -0.9284],
# │                   [ 2.3196,  0.8810,  0.4542]])
# └── 'x' --> <FastTreeValue 0x7fa824798e80>
#     └── 'c' --> tensor([[-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846]])

# %%
# %timeit t.a = new_value
# Out:
# 67.3 ns ± 0.0291 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884]]),
#     x: Batch(
#            c: tensor([[-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.7479,  0.0652, -0.9307],
#         [-1.2340,  0.5033, -0.6884]])

# %%
# %timeit b.a
# Out:
# 55.2 ns ± 0.0668 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.3060, -0.4555, -1.5449],
#                [-1.1439,  0.5292,  1.0490]]),
#     x: Batch(
#            c: tensor([[-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 496 ns ± 0.496 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.7 µs ± 73.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 79.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 1.12 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 480 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fa816004580>
# ├── 'a' --> tensor([[[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]],
# │
# │                   [[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]],
# │
# │                   [[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]],
# │
# │                   [[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]],
# │
# │                   [[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]],
# │
# │                   [[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]],
# │
# │                   [[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]],
# │
# │                   [[ 0.7479,  0.0652, -0.9307],
# │                    [-1.2340,  0.5033, -0.6884]]])
# └── 'x' --> <FastTreeValue 0x7fa816004970>
#     └── 'c' --> tensor([[[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                         [[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                         [[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                         [[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                         [[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                         [[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                         [[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                         [[-0.8345, -0.1233, -1.2033,  0.0068],
#                          [ 0.7675, -0.9437,  0.2869,  0.6666],
#                          [-0.1358,  1.3730,  0.5140,  0.8846]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 75 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fa816004940>
# ├── 'a' --> tensor([[ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884],
# │                   [ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884],
# │                   [ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884],
# │                   [ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884],
# │                   [ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884],
# │                   [ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884],
# │                   [ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884],
# │                   [ 0.7479,  0.0652, -0.9307],
# │                   [-1.2340,  0.5033, -0.6884]])
# └── 'x' --> <FastTreeValue 0x7fa816004190>
#     └── 'c' --> tensor([[-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846],
#                         [-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846],
#                         [-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846],
#                         [-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846],
#                         [-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846],
#                         [-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846],
#                         [-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846],
#                         [-0.8345, -0.1233, -1.2033,  0.0068],
#                         [ 0.7675, -0.9437,  0.2869,  0.6666],
#                         [-0.1358,  1.3730,  0.5140,  0.8846]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.6 µs ± 69.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.6 µs ± 76.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]],
#
#                [[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]],
#
#                [[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]],
#
#                [[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]],
#
#                [[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]],
#
#                [[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]],
#
#                [[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]],
#
#                [[ 0.7479,  0.0652, -0.9307],
#                 [-1.2340,  0.5033, -0.6884]]]),
#     x: Batch(
#            c: tensor([[[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                       [[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                       [[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                       [[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                       [[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                       [[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                       [[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]],
#
#                       [[-0.8345, -0.1233, -1.2033,  0.0068],
#                        [ 0.7675, -0.9437,  0.2869,  0.6666],
#                        [-0.1358,  1.3730,  0.5140,  0.8846]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.4 µs ± 207 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884],
#                [ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884],
#                [ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884],
#                [ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884],
#                [ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884],
#                [ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884],
#                [ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884],
#                [ 0.7479,  0.0652, -0.9307],
#                [-1.2340,  0.5033, -0.6884]]),
#     x: Batch(
#            c: tensor([[-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846],
#                       [-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846],
#                       [-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846],
#                       [-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846],
#                       [-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846],
#                       [-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846],
#                       [-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846],
#                       [-0.8345, -0.1233, -1.2033,  0.0068],
#                       [ 0.7675, -0.9437,  0.2869,  0.6666],
#                       [-0.1358,  1.3730,  0.5140,  0.8846]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 406 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 359 µs ± 4.96 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
