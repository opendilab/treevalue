# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f4548db5ee0>
# ├── 'a' --> tensor([[-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418]])
# └── 'x' --> <FastTreeValue 0x7f454ce3bf70>
#     └── 'c' --> tensor([[-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193]])

# %%
t.a
# Out:
# tensor([[-0.6386,  0.1856,  0.1126],
#         [-0.1413, -0.7507,  0.1418]])

# %%
# %timeit t.a
# Out:
# 72.9 ns ± 1.15 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f4548db5ee0>
# ├── 'a' --> tensor([[-0.4367, -1.4653,  0.0853],
# │                   [-0.0869,  0.1648,  0.3241]])
# └── 'x' --> <FastTreeValue 0x7f454ce3bf70>
#     └── 'c' --> tensor([[-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193]])

# %%
# %timeit t.a = new_value
# Out:
# 69.3 ns ± 0.103 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418]]),
#     x: Batch(
#            c: tensor([[-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.6386,  0.1856,  0.1126],
#         [-0.1413, -0.7507,  0.1418]])

# %%
# %timeit b.a
# Out:
# 58.1 ns ± 0.0529 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.0541,  0.7717,  0.8621],
#                [ 1.7028, -0.3152,  1.3729]]),
#     x: Batch(
#            c: tensor([[-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 492 ns ± 0.18 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 850 ns ± 3.22 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 7.46 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 141 µs ± 196 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 539 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f446cb5bd90>
# ├── 'a' --> tensor([[[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]],
# │
# │                   [[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]],
# │
# │                   [[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]],
# │
# │                   [[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]],
# │
# │                   [[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]],
# │
# │                   [[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]],
# │
# │                   [[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]],
# │
# │                   [[-0.6386,  0.1856,  0.1126],
# │                    [-0.1413, -0.7507,  0.1418]]])
# └── 'x' --> <FastTreeValue 0x7f446cb5bfd0>
#     └── 'c' --> tensor([[[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                         [[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                         [[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                         [[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                         [[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                         [[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                         [[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                         [[-0.9884, -1.1227,  0.1754,  0.3160],
#                          [ 0.3378, -0.5735,  0.3262, -0.0127],
#                          [-0.3083,  0.6812,  1.1009, -0.1193]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.9 µs ± 60 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f454ce41760>
# ├── 'a' --> tensor([[-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418],
# │                   [-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418],
# │                   [-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418],
# │                   [-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418],
# │                   [-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418],
# │                   [-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418],
# │                   [-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418],
# │                   [-0.6386,  0.1856,  0.1126],
# │                   [-0.1413, -0.7507,  0.1418]])
# └── 'x' --> <FastTreeValue 0x7f446cbd10d0>
#     └── 'c' --> tensor([[-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193],
#                         [-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193],
#                         [-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193],
#                         [-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193],
#                         [-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193],
#                         [-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193],
#                         [-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193],
#                         [-0.9884, -1.1227,  0.1754,  0.3160],
#                         [ 0.3378, -0.5735,  0.3262, -0.0127],
#                         [-0.3083,  0.6812,  1.1009, -0.1193]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.5 µs ± 147 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.9 µs ± 66.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]],
#
#                [[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]],
#
#                [[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]],
#
#                [[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]],
#
#                [[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]],
#
#                [[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]],
#
#                [[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]],
#
#                [[-0.6386,  0.1856,  0.1126],
#                 [-0.1413, -0.7507,  0.1418]]]),
#     x: Batch(
#            c: tensor([[[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                       [[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                       [[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                       [[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                       [[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                       [[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                       [[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]],
#
#                       [[-0.9884, -1.1227,  0.1754,  0.3160],
#                        [ 0.3378, -0.5735,  0.3262, -0.0127],
#                        [-0.3083,  0.6812,  1.1009, -0.1193]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.5 µs ± 683 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418],
#                [-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418],
#                [-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418],
#                [-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418],
#                [-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418],
#                [-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418],
#                [-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418],
#                [-0.6386,  0.1856,  0.1126],
#                [-0.1413, -0.7507,  0.1418]]),
#     x: Batch(
#            c: tensor([[-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193],
#                       [-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193],
#                       [-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193],
#                       [-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193],
#                       [-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193],
#                       [-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193],
#                       [-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193],
#                       [-0.9884, -1.1227,  0.1754,  0.3160],
#                       [ 0.3378, -0.5735,  0.3262, -0.0127],
#                       [-0.3083,  0.6812,  1.1009, -0.1193]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 146 µs ± 201 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 344 µs ± 599 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
