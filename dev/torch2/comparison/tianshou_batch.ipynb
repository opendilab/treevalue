# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb07070b2b0>
# ├── 'a' --> tensor([[2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040]])
# └── 'x' --> <FastTreeValue 0x7fb0737d3b80>
#     └── 'c' --> tensor([[ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656]])

# %%
t.a
# Out:
# tensor([[2.1915, 1.2644, 0.8141],
#         [0.6544, 0.2236, 0.3040]])

# %%
# %timeit t.a
# Out:
# 84.8 ns ± 0.78 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb07070b2b0>
# ├── 'a' --> tensor([[-0.6078,  0.0215, -0.4158],
# │                   [ 2.1663,  0.0223,  0.5269]])
# └── 'x' --> <FastTreeValue 0x7fb0737d3b80>
#     └── 'c' --> tensor([[ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656]])

# %%
# %timeit t.a = new_value
# Out:
# 87 ns ± 0.737 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040]]),
#     x: Batch(
#            c: tensor([[ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[2.1915, 1.2644, 0.8141],
#         [0.6544, 0.2236, 0.3040]])

# %%
# %timeit b.a
# Out:
# 76.6 ns ± 0.588 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[1.6988, 1.4747, 1.1969],
#                [0.2489, 0.4749, 0.0252]]),
#     x: Batch(
#            c: tensor([[ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 635 ns ± 3.62 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.08 µs ± 3.44 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.2 µs ± 83.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 166 µs ± 921 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 169 µs ± 789 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7faf92f93c70>
# ├── 'a' --> tensor([[[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]],
# │
# │                   [[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]],
# │
# │                   [[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]],
# │
# │                   [[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]],
# │
# │                   [[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]],
# │
# │                   [[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]],
# │
# │                   [[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]],
# │
# │                   [[2.1915, 1.2644, 0.8141],
# │                    [0.6544, 0.2236, 0.3040]]])
# └── 'x' --> <FastTreeValue 0x7fb070746190>
#     └── 'c' --> tensor([[[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                         [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                         [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                         [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                         [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                         [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                         [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                         [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                          [ 1.2687, -0.7220, -0.9366, -1.6589],
#                          [-0.1135,  0.0688, -1.5505, -1.3656]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39.5 µs ± 114 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7faf92f93fa0>
# ├── 'a' --> tensor([[2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040],
# │                   [2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040],
# │                   [2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040],
# │                   [2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040],
# │                   [2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040],
# │                   [2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040],
# │                   [2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040],
# │                   [2.1915, 1.2644, 0.8141],
# │                   [0.6544, 0.2236, 0.3040]])
# └── 'x' --> <FastTreeValue 0x7faf92f93d00>
#     └── 'c' --> tensor([[ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656],
#                         [ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656],
#                         [ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656],
#                         [ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656],
#                         [ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656],
#                         [ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656],
#                         [ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656],
#                         [ 1.8534,  0.9357,  0.6213, -0.5516],
#                         [ 1.2687, -0.7220, -0.9366, -1.6589],
#                         [-0.1135,  0.0688, -1.5505, -1.3656]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.6 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 77 µs ± 169 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]],
#
#                [[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]],
#
#                [[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]],
#
#                [[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]],
#
#                [[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]],
#
#                [[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]],
#
#                [[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]],
#
#                [[2.1915, 1.2644, 0.8141],
#                 [0.6544, 0.2236, 0.3040]]]),
#     x: Batch(
#            c: tensor([[[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                       [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                       [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                       [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                       [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                       [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                       [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]],
#
#                       [[ 1.8534,  0.9357,  0.6213, -0.5516],
#                        [ 1.2687, -0.7220, -0.9366, -1.6589],
#                        [-0.1135,  0.0688, -1.5505, -1.3656]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 97.9 µs ± 502 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040],
#                [2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040],
#                [2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040],
#                [2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040],
#                [2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040],
#                [2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040],
#                [2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040],
#                [2.1915, 1.2644, 0.8141],
#                [0.6544, 0.2236, 0.3040]]),
#     x: Batch(
#            c: tensor([[ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656],
#                       [ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656],
#                       [ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656],
#                       [ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656],
#                       [ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656],
#                       [ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656],
#                       [ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656],
#                       [ 1.8534,  0.9357,  0.6213, -0.5516],
#                       [ 1.2687, -0.7220, -0.9366, -1.6589],
#                       [-0.1135,  0.0688, -1.5505, -1.3656]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 1.19 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 402 µs ± 5.44 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
