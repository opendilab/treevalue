# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7feec4b63dc0>
# ├── 'a' --> tensor([[ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782]])
# └── 'x' --> <FastTreeValue 0x7feec4b63d00>
#     └── 'c' --> tensor([[-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966]])

# %%
t.a
# Out:
# tensor([[ 0.9446, -0.4071, -0.3669],
#         [ 0.9137, -0.4697,  0.5782]])

# %%
# %timeit t.a
# Out:
# 62.6 ns ± 0.0736 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7feec4b63dc0>
# ├── 'a' --> tensor([[ 0.0474, -0.1462,  2.1159],
# │                   [-1.4518,  0.5708, -0.4180]])
# └── 'x' --> <FastTreeValue 0x7feec4b63d00>
#     └── 'c' --> tensor([[-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966]])

# %%
# %timeit t.a = new_value
# Out:
# 74.1 ns ± 0.0369 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782]]),
#     x: Batch(
#            c: tensor([[-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.9446, -0.4071, -0.3669],
#         [ 0.9137, -0.4697,  0.5782]])

# %%
# %timeit b.a
# Out:
# 58.7 ns ± 0.0717 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.1365, -0.3671,  0.3133],
#                [ 0.0090, -1.1760,  0.5194]]),
#     x: Batch(
#            c: tensor([[-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 501 ns ± 0.32 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 818 ns ± 0.182 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 39.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 348 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 631 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fede837b220>
# ├── 'a' --> tensor([[[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]],
# │
# │                   [[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]],
# │
# │                   [[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]],
# │
# │                   [[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]],
# │
# │                   [[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]],
# │
# │                   [[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]],
# │
# │                   [[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]],
# │
# │                   [[ 0.9446, -0.4071, -0.3669],
# │                    [ 0.9137, -0.4697,  0.5782]]])
# └── 'x' --> <FastTreeValue 0x7fede83a6f40>
#     └── 'c' --> tensor([[[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                         [[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                         [[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                         [[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                         [[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                         [[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                         [[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                         [[-0.6988,  1.1835,  0.2286, -0.1101],
#                          [ 2.0027, -0.2518,  0.8135, -0.6154],
#                          [ 1.7244, -1.7903,  1.0367,  0.1966]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.9 µs ± 84.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7feea03e1c70>
# ├── 'a' --> tensor([[ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782],
# │                   [ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782],
# │                   [ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782],
# │                   [ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782],
# │                   [ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782],
# │                   [ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782],
# │                   [ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782],
# │                   [ 0.9446, -0.4071, -0.3669],
# │                   [ 0.9137, -0.4697,  0.5782]])
# └── 'x' --> <FastTreeValue 0x7feea03e1ac0>
#     └── 'c' --> tensor([[-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966],
#                         [-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966],
#                         [-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966],
#                         [-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966],
#                         [-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966],
#                         [-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966],
#                         [-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966],
#                         [-0.6988,  1.1835,  0.2286, -0.1101],
#                         [ 2.0027, -0.2518,  0.8135, -0.6154],
#                         [ 1.7244, -1.7903,  1.0367,  0.1966]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.3 µs ± 882 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.3 µs ± 114 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                       [[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                       [[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                       [[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                       [[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                       [[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                       [[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]],
#
#                       [[-0.6988,  1.1835,  0.2286, -0.1101],
#                        [ 2.0027, -0.2518,  0.8135, -0.6154],
#                        [ 1.7244, -1.7903,  1.0367,  0.1966]]]),
#        ),
#     a: tensor([[[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]],
#
#                [[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]],
#
#                [[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]],
#
#                [[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]],
#
#                [[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]],
#
#                [[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]],
#
#                [[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]],
#
#                [[ 0.9446, -0.4071, -0.3669],
#                 [ 0.9137, -0.4697,  0.5782]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.7 µs ± 165 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966],
#                       [-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966],
#                       [-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966],
#                       [-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966],
#                       [-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966],
#                       [-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966],
#                       [-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966],
#                       [-0.6988,  1.1835,  0.2286, -0.1101],
#                       [ 2.0027, -0.2518,  0.8135, -0.6154],
#                       [ 1.7244, -1.7903,  1.0367,  0.1966]]),
#        ),
#     a: tensor([[ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782],
#                [ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782],
#                [ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782],
#                [ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782],
#                [ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782],
#                [ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782],
#                [ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782],
#                [ 0.9446, -0.4071, -0.3669],
#                [ 0.9137, -0.4697,  0.5782]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 350 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 345 µs ± 8.41 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
