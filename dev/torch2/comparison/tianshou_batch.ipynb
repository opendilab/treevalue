# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc76d8d3d60>
# ├── 'a' --> tensor([[ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546]])
# └── 'x' --> <FastTreeValue 0x7fc83024b220>
#     └── 'c' --> tensor([[ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793]])

# %%
t.a
# Out:
# tensor([[ 1.7890, -0.1268,  0.5476],
#         [-0.5410, -0.2762, -0.9546]])

# %%
# %timeit t.a
# Out:
# 64.9 ns ± 0.0877 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc76d8d3d60>
# ├── 'a' --> tensor([[-0.7922,  0.4709,  1.6075],
# │                   [ 1.9749, -0.7771, -2.4367]])
# └── 'x' --> <FastTreeValue 0x7fc83024b220>
#     └── 'c' --> tensor([[ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793]])

# %%
# %timeit t.a = new_value
# Out:
# 65.5 ns ± 0.0164 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546]]),
#     x: Batch(
#            c: tensor([[ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.7890, -0.1268,  0.5476],
#         [-0.5410, -0.2762, -0.9546]])

# %%
# %timeit b.a
# Out:
# 60.5 ns ± 0.0254 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.6634,  0.4300,  0.3105],
#                [-0.2365,  0.0534,  0.6709]]),
#     x: Batch(
#            c: tensor([[ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 485 ns ± 0.191 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 837 ns ± 0.516 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 22.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 141 µs ± 705 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 658 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc762a00d60>
# ├── 'a' --> tensor([[[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]],
# │
# │                   [[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]],
# │
# │                   [[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]],
# │
# │                   [[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]],
# │
# │                   [[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]],
# │
# │                   [[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]],
# │
# │                   [[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]],
# │
# │                   [[ 1.7890, -0.1268,  0.5476],
# │                    [-0.5410, -0.2762, -0.9546]]])
# └── 'x' --> <FastTreeValue 0x7fc762a002e0>
#     └── 'c' --> tensor([[[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                         [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                         [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                         [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                         [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                         [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                         [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                         [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                          [ 1.1628, -1.4132, -0.8097,  0.9399],
#                          [ 0.6051,  0.0925,  1.4735,  0.9793]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.9 µs ± 99.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc753a7af40>
# ├── 'a' --> tensor([[ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546],
# │                   [ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546],
# │                   [ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546],
# │                   [ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546],
# │                   [ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546],
# │                   [ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546],
# │                   [ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546],
# │                   [ 1.7890, -0.1268,  0.5476],
# │                   [-0.5410, -0.2762, -0.9546]])
# └── 'x' --> <FastTreeValue 0x7fc8352986a0>
#     └── 'c' --> tensor([[ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793],
#                         [ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793],
#                         [ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793],
#                         [ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793],
#                         [ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793],
#                         [ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793],
#                         [ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793],
#                         [ 0.6921, -0.0869, -0.1949,  0.9351],
#                         [ 1.1628, -1.4132, -0.8097,  0.9399],
#                         [ 0.6051,  0.0925,  1.4735,  0.9793]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.2 µs ± 94 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69.2 µs ± 51.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                       [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                       [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                       [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                       [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                       [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                       [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]],
#
#                       [[ 0.6921, -0.0869, -0.1949,  0.9351],
#                        [ 1.1628, -1.4132, -0.8097,  0.9399],
#                        [ 0.6051,  0.0925,  1.4735,  0.9793]]]),
#        ),
#     a: tensor([[[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]],
#
#                [[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]],
#
#                [[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]],
#
#                [[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]],
#
#                [[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]],
#
#                [[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]],
#
#                [[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]],
#
#                [[ 1.7890, -0.1268,  0.5476],
#                 [-0.5410, -0.2762, -0.9546]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.3 µs ± 134 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793],
#                       [ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793],
#                       [ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793],
#                       [ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793],
#                       [ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793],
#                       [ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793],
#                       [ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793],
#                       [ 0.6921, -0.0869, -0.1949,  0.9351],
#                       [ 1.1628, -1.4132, -0.8097,  0.9399],
#                       [ 0.6051,  0.0925,  1.4735,  0.9793]]),
#        ),
#     a: tensor([[ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546],
#                [ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546],
#                [ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546],
#                [ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546],
#                [ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546],
#                [ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546],
#                [ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546],
#                [ 1.7890, -0.1268,  0.5476],
#                [-0.5410, -0.2762, -0.9546]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 148 µs ± 340 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 327 µs ± 5.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
