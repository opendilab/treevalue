# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7faffc8be220>
# ├── 'a' --> tensor([[-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298]])
# └── 'x' --> <FastTreeValue 0x7faffc8be1f0>
#     └── 'c' --> tensor([[ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163]])

# %%
t.a
# Out:
# tensor([[-1.0900, -0.1929, -0.2139],
#         [-1.0328, -1.6476,  0.8298]])

# %%
# %timeit t.a
# Out:
# 72.3 ns ± 0.043 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7faffc8be220>
# ├── 'a' --> tensor([[-0.4168, -0.1542,  0.7321],
# │                   [ 0.0556,  0.0100, -0.1392]])
# └── 'x' --> <FastTreeValue 0x7faffc8be1f0>
#     └── 'c' --> tensor([[ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163]])

# %%
# %timeit t.a = new_value
# Out:
# 74.6 ns ± 0.0854 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298]]),
#     x: Batch(
#            c: tensor([[ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.0900, -0.1929, -0.2139],
#         [-1.0328, -1.6476,  0.8298]])

# %%
# %timeit b.a
# Out:
# 65.1 ns ± 0.151 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.5057,  0.7455, -0.0074],
#                [-0.4327, -1.0147,  1.0615]]),
#     x: Batch(
#            c: tensor([[ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 590 ns ± 1.43 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 888 ns ± 1.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 18 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 534 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 639 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7faf1f115af0>
# ├── 'a' --> tensor([[[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]],
# │
# │                   [[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]],
# │
# │                   [[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]],
# │
# │                   [[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]],
# │
# │                   [[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]],
# │
# │                   [[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]],
# │
# │                   [[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]],
# │
# │                   [[-1.0900, -0.1929, -0.2139],
# │                    [-1.0328, -1.6476,  0.8298]]])
# └── 'x' --> <FastTreeValue 0x7faf1f115820>
#     └── 'c' --> tensor([[[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                         [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                         [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                         [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                         [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                         [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                         [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                         [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                          [ 0.6205, -0.5185, -0.2456,  0.6006],
#                          [-2.4326,  0.4205,  0.5620,  0.6163]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 108 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7faffc85b2b0>
# ├── 'a' --> tensor([[-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298],
# │                   [-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298],
# │                   [-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298],
# │                   [-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298],
# │                   [-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298],
# │                   [-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298],
# │                   [-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298],
# │                   [-1.0900, -0.1929, -0.2139],
# │                   [-1.0328, -1.6476,  0.8298]])
# └── 'x' --> <FastTreeValue 0x7faf2d038130>
#     └── 'c' --> tensor([[ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163],
#                         [ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163],
#                         [ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163],
#                         [ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163],
#                         [ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163],
#                         [ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163],
#                         [ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163],
#                         [ 0.2163,  0.7096,  1.7358,  2.1248],
#                         [ 0.6205, -0.5185, -0.2456,  0.6006],
#                         [-2.4326,  0.4205,  0.5620,  0.6163]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.2 µs ± 38.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.8 µs ± 74.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                       [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                       [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                       [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                       [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                       [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                       [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]],
#
#                       [[ 0.2163,  0.7096,  1.7358,  2.1248],
#                        [ 0.6205, -0.5185, -0.2456,  0.6006],
#                        [-2.4326,  0.4205,  0.5620,  0.6163]]]),
#        ),
#     a: tensor([[[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]],
#
#                [[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]],
#
#                [[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]],
#
#                [[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]],
#
#                [[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]],
#
#                [[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]],
#
#                [[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]],
#
#                [[-1.0900, -0.1929, -0.2139],
#                 [-1.0328, -1.6476,  0.8298]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.3 µs ± 286 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163],
#                       [ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163],
#                       [ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163],
#                       [ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163],
#                       [ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163],
#                       [ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163],
#                       [ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163],
#                       [ 0.2163,  0.7096,  1.7358,  2.1248],
#                       [ 0.6205, -0.5185, -0.2456,  0.6006],
#                       [-2.4326,  0.4205,  0.5620,  0.6163]]),
#        ),
#     a: tensor([[-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298],
#                [-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298],
#                [-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298],
#                [-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298],
#                [-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298],
#                [-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298],
#                [-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298],
#                [-1.0900, -0.1929, -0.2139],
#                [-1.0328, -1.6476,  0.8298]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 395 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 354 µs ± 6.43 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
