# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7ffa9c860340>
# ├── 'a' --> tensor([[ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090]])
# └── 'x' --> <FastTreeValue 0x7ffa9c860760>
#     └── 'c' --> tensor([[-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957]])

# %%
t.a
# Out:
# tensor([[ 0.9563,  1.8178, -0.4905],
#         [ 0.4871,  0.7970,  0.9090]])

# %%
# %timeit t.a
# Out:
# 62 ns ± 0.0466 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7ffa9c860340>
# ├── 'a' --> tensor([[-0.7459,  0.7975,  0.2866],
# │                   [-0.4265, -1.5380,  0.6617]])
# └── 'x' --> <FastTreeValue 0x7ffa9c860760>
#     └── 'c' --> tensor([[-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957]])

# %%
# %timeit t.a = new_value
# Out:
# 61.5 ns ± 0.0719 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090]]),
#     x: Batch(
#            c: tensor([[-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.9563,  1.8178, -0.4905],
#         [ 0.4871,  0.7970,  0.9090]])

# %%
# %timeit b.a
# Out:
# 51.7 ns ± 0.0542 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.7029, -0.4905, -1.3638],
#                [-0.2643,  0.3155, -1.1789]]),
#     x: Batch(
#            c: tensor([[-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 483 ns ± 0.117 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 819 ns ± 0.11 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.5 µs ± 17.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 136 µs ± 305 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 138 µs ± 716 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7ffa9c8ca580>
# ├── 'a' --> tensor([[[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]],
# │
# │                   [[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]],
# │
# │                   [[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]],
# │
# │                   [[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]],
# │
# │                   [[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]],
# │
# │                   [[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]],
# │
# │                   [[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]],
# │
# │                   [[ 0.9563,  1.8178, -0.4905],
# │                    [ 0.4871,  0.7970,  0.9090]]])
# └── 'x' --> <FastTreeValue 0x7ff9cc2e5640>
#     └── 'c' --> tensor([[[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                         [[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                         [[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                         [[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                         [[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                         [[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                         [[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                         [[-0.3445, -1.6679, -1.3621,  0.3653],
#                          [-1.1897,  0.0660, -0.8127,  1.3351],
#                          [ 2.1993,  0.8522,  0.6013,  1.4957]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 67.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7ff9cc34f850>
# ├── 'a' --> tensor([[ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090],
# │                   [ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090],
# │                   [ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090],
# │                   [ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090],
# │                   [ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090],
# │                   [ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090],
# │                   [ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090],
# │                   [ 0.9563,  1.8178, -0.4905],
# │                   [ 0.4871,  0.7970,  0.9090]])
# └── 'x' --> <FastTreeValue 0x7ffa9c8cae50>
#     └── 'c' --> tensor([[-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957],
#                         [-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957],
#                         [-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957],
#                         [-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957],
#                         [-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957],
#                         [-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957],
#                         [-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957],
#                         [-0.3445, -1.6679, -1.3621,  0.3653],
#                         [-1.1897,  0.0660, -0.8127,  1.3351],
#                         [ 2.1993,  0.8522,  0.6013,  1.4957]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.4 µs ± 103 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.2 µs ± 75 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                       [[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                       [[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                       [[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                       [[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                       [[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                       [[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]],
#
#                       [[-0.3445, -1.6679, -1.3621,  0.3653],
#                        [-1.1897,  0.0660, -0.8127,  1.3351],
#                        [ 2.1993,  0.8522,  0.6013,  1.4957]]]),
#        ),
#     a: tensor([[[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]],
#
#                [[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]],
#
#                [[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]],
#
#                [[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]],
#
#                [[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]],
#
#                [[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]],
#
#                [[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]],
#
#                [[ 0.9563,  1.8178, -0.4905],
#                 [ 0.4871,  0.7970,  0.9090]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.4 µs ± 154 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957],
#                       [-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957],
#                       [-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957],
#                       [-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957],
#                       [-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957],
#                       [-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957],
#                       [-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957],
#                       [-0.3445, -1.6679, -1.3621,  0.3653],
#                       [-1.1897,  0.0660, -0.8127,  1.3351],
#                       [ 2.1993,  0.8522,  0.6013,  1.4957]]),
#        ),
#     a: tensor([[ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090],
#                [ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090],
#                [ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090],
#                [ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090],
#                [ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090],
#                [ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090],
#                [ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090],
#                [ 0.9563,  1.8178, -0.4905],
#                [ 0.4871,  0.7970,  0.9090]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 144 µs ± 589 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 309 µs ± 1.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
