# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7febe0a3c1c0>
# ├── 'a' --> tensor([[ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603]])
# └── 'x' --> <FastTreeValue 0x7febe0a3c700>
#     └── 'c' --> tensor([[-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236]])

# %%
t.a
# Out:
# tensor([[ 1.5751,  0.3837, -0.5880],
#         [-0.3307, -0.9506,  1.6603]])

# %%
# %timeit t.a
# Out:
# 63.5 ns ± 0.0243 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7febe0a3c1c0>
# ├── 'a' --> tensor([[-0.4015, -0.2833, -0.3239],
# │                   [ 0.2750, -1.0327, -0.7102]])
# └── 'x' --> <FastTreeValue 0x7febe0a3c700>
#     └── 'c' --> tensor([[-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236]])

# %%
# %timeit t.a = new_value
# Out:
# 68.4 ns ± 0.0605 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603]]),
#     x: Batch(
#            c: tensor([[-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.5751,  0.3837, -0.5880],
#         [-0.3307, -0.9506,  1.6603]])

# %%
# %timeit b.a
# Out:
# 57.4 ns ± 0.0662 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0656, -0.2528,  1.0085],
#                [ 0.5007, -0.3231, -0.1128]]),
#     x: Batch(
#            c: tensor([[-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 505 ns ± 1.01 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 816 ns ± 0.221 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 55 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 146 µs ± 410 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 941 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7feb00786ca0>
# ├── 'a' --> tensor([[[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]],
# │
# │                   [[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]],
# │
# │                   [[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]],
# │
# │                   [[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]],
# │
# │                   [[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]],
# │
# │                   [[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]],
# │
# │                   [[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]],
# │
# │                   [[ 1.5751,  0.3837, -0.5880],
# │                    [-0.3307, -0.9506,  1.6603]]])
# └── 'x' --> <FastTreeValue 0x7feb00786a30>
#     └── 'c' --> tensor([[[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                         [[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                         [[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                         [[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                         [[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                         [[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                         [[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                         [[-0.4795, -1.2767, -0.2460, -0.3276],
#                          [-1.0794,  0.3653,  0.0993, -0.5115],
#                          [ 0.1301, -0.5826,  1.0079,  0.6236]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.8 µs ± 75.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7feb00786fd0>
# ├── 'a' --> tensor([[ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603],
# │                   [ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603],
# │                   [ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603],
# │                   [ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603],
# │                   [ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603],
# │                   [ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603],
# │                   [ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603],
# │                   [ 1.5751,  0.3837, -0.5880],
# │                   [-0.3307, -0.9506,  1.6603]])
# └── 'x' --> <FastTreeValue 0x7feb00786e80>
#     └── 'c' --> tensor([[-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236],
#                         [-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236],
#                         [-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236],
#                         [-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236],
#                         [-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236],
#                         [-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236],
#                         [-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236],
#                         [-0.4795, -1.2767, -0.2460, -0.3276],
#                         [-1.0794,  0.3653,  0.0993, -0.5115],
#                         [ 0.1301, -0.5826,  1.0079,  0.6236]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.4 µs ± 119 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.4 µs ± 40.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]],
#
#                [[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]],
#
#                [[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]],
#
#                [[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]],
#
#                [[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]],
#
#                [[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]],
#
#                [[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]],
#
#                [[ 1.5751,  0.3837, -0.5880],
#                 [-0.3307, -0.9506,  1.6603]]]),
#     x: Batch(
#            c: tensor([[[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                       [[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                       [[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                       [[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                       [[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                       [[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                       [[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]],
#
#                       [[-0.4795, -1.2767, -0.2460, -0.3276],
#                        [-1.0794,  0.3653,  0.0993, -0.5115],
#                        [ 0.1301, -0.5826,  1.0079,  0.6236]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.6 µs ± 566 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603],
#                [ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603],
#                [ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603],
#                [ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603],
#                [ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603],
#                [ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603],
#                [ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603],
#                [ 1.5751,  0.3837, -0.5880],
#                [-0.3307, -0.9506,  1.6603]]),
#     x: Batch(
#            c: tensor([[-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236],
#                       [-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236],
#                       [-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236],
#                       [-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236],
#                       [-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236],
#                       [-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236],
#                       [-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236],
#                       [-0.4795, -1.2767, -0.2460, -0.3276],
#                       [-1.0794,  0.3653,  0.0993, -0.5115],
#                       [ 0.1301, -0.5826,  1.0079,  0.6236]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 147 µs ± 520 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 346 µs ± 2.83 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
