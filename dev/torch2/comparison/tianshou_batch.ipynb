# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f2ce0c5ba00>
# ├── 'a' --> tensor([[ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414]])
# └── 'x' --> <FastTreeValue 0x7f2ce0c56910>
#     └── 'c' --> tensor([[ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567]])

# %%
t.a
# Out:
# tensor([[ 0.8670, -0.2158, -0.8619],
#         [-0.3524, -0.5447, -0.2414]])

# %%
# %timeit t.a
# Out:
# 88 ns ± 0.101 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f2ce0c5ba00>
# ├── 'a' --> tensor([[-0.3349, -0.4775, -0.3657],
# │                   [ 0.1564,  0.7610,  0.2951]])
# └── 'x' --> <FastTreeValue 0x7f2ce0c56910>
#     └── 'c' --> tensor([[ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567]])

# %%
# %timeit t.a = new_value
# Out:
# 89.3 ns ± 0.777 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414]]),
#     x: Batch(
#            c: tensor([[ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8670, -0.2158, -0.8619],
#         [-0.3524, -0.5447, -0.2414]])

# %%
# %timeit b.a
# Out:
# 79.7 ns ± 0.113 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.5989,  0.0585, -0.4514],
#                [-0.3141,  1.0550,  0.3155]]),
#     x: Batch(
#            c: tensor([[ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 651 ns ± 0.124 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.55 µs ± 36.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.6 µs ± 105 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 183 µs ± 3.94 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 189 µs ± 3.65 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f2bf32c10d0>
# ├── 'a' --> tensor([[[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]],
# │
# │                   [[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]],
# │
# │                   [[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]],
# │
# │                   [[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]],
# │
# │                   [[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]],
# │
# │                   [[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]],
# │
# │                   [[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]],
# │
# │                   [[ 0.8670, -0.2158, -0.8619],
# │                    [-0.3524, -0.5447, -0.2414]]])
# └── 'x' --> <FastTreeValue 0x7f2bf32c1580>
#     └── 'c' --> tensor([[[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                         [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                         [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                         [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                         [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                         [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                         [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                         [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                          [-0.6832,  0.6484,  0.3764, -1.4005],
#                          [ 0.2423,  0.9683, -1.2639, -1.1567]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39.8 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f2bf32c1550>
# ├── 'a' --> tensor([[ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414],
# │                   [ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414],
# │                   [ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414],
# │                   [ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414],
# │                   [ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414],
# │                   [ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414],
# │                   [ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414],
# │                   [ 0.8670, -0.2158, -0.8619],
# │                   [-0.3524, -0.5447, -0.2414]])
# └── 'x' --> <FastTreeValue 0x7f2bf33adfd0>
#     └── 'c' --> tensor([[ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567],
#                         [ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567],
#                         [ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567],
#                         [ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567],
#                         [ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567],
#                         [ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567],
#                         [ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567],
#                         [ 0.0906, -1.1847, -1.2265, -1.2461],
#                         [-0.6832,  0.6484,  0.3764, -1.4005],
#                         [ 0.2423,  0.9683, -1.2639, -1.1567]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.7 µs ± 84.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.4 µs ± 131 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]],
#
#                [[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]],
#
#                [[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]],
#
#                [[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]],
#
#                [[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]],
#
#                [[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]],
#
#                [[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]],
#
#                [[ 0.8670, -0.2158, -0.8619],
#                 [-0.3524, -0.5447, -0.2414]]]),
#     x: Batch(
#            c: tensor([[[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                       [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                       [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                       [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                       [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                       [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                       [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]],
#
#                       [[ 0.0906, -1.1847, -1.2265, -1.2461],
#                        [-0.6832,  0.6484,  0.3764, -1.4005],
#                        [ 0.2423,  0.9683, -1.2639, -1.1567]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 99 µs ± 98.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414],
#                [ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414],
#                [ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414],
#                [ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414],
#                [ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414],
#                [ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414],
#                [ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414],
#                [ 0.8670, -0.2158, -0.8619],
#                [-0.3524, -0.5447, -0.2414]]),
#     x: Batch(
#            c: tensor([[ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567],
#                       [ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567],
#                       [ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567],
#                       [ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567],
#                       [ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567],
#                       [ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567],
#                       [ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567],
#                       [ 0.0906, -1.1847, -1.2265, -1.2461],
#                       [-0.6832,  0.6484,  0.3764, -1.4005],
#                       [ 0.2423,  0.9683, -1.2639, -1.1567]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 182 µs ± 507 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 479 µs ± 17.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
