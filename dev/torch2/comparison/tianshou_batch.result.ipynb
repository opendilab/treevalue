# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7efc35afac40>
# ├── 'a' --> tensor([[ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776]])
# └── 'x' --> <FastTreeValue 0x7efc35afa640>
#     └── 'c' --> tensor([[-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372]])

# %%
t.a
# Out:
# tensor([[ 0.0662,  0.0981,  0.3015],
#         [ 0.8572, -0.4162, -0.4776]])

# %%
# %timeit t.a
# Out:
# 72.3 ns ± 0.0641 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7efc35afac40>
# ├── 'a' --> tensor([[ 1.2722, -1.0403, -1.4239],
# │                   [-1.1405, -0.3999,  1.1993]])
# └── 'x' --> <FastTreeValue 0x7efc35afa640>
#     └── 'c' --> tensor([[-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372]])

# %%
# %timeit t.a = new_value
# Out:
# 81.1 ns ± 0.125 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776]]),
#     x: Batch(
#            c: tensor([[-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0662,  0.0981,  0.3015],
#         [ 0.8572, -0.4162, -0.4776]])

# %%
# %timeit b.a
# Out:
# 64.8 ns ± 0.123 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.6538,  0.7171, -0.5190],
#                [-0.9430, -1.3249, -0.7045]]),
#     x: Batch(
#            c: tensor([[-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 545 ns ± 0.998 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 905 ns ± 1.95 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 13.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 147 µs ± 504 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 148 µs ± 1.14 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7efb6321bb50>
# ├── 'a' --> tensor([[[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]],
# │
# │                   [[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]],
# │
# │                   [[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]],
# │
# │                   [[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]],
# │
# │                   [[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]],
# │
# │                   [[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]],
# │
# │                   [[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]],
# │
# │                   [[ 0.0662,  0.0981,  0.3015],
# │                    [ 0.8572, -0.4162, -0.4776]]])
# └── 'x' --> <FastTreeValue 0x7efb6321bdf0>
#     └── 'c' --> tensor([[[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                         [[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                         [[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                         [[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                         [[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                         [[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                         [[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                         [[-1.1918, -1.3994,  0.5052,  0.5855],
#                          [-0.7244,  1.9855, -1.4021, -0.8909],
#                          [-2.9120,  2.3852,  2.3147, -0.6372]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.2 µs ± 144 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7efb6321b520>
# ├── 'a' --> tensor([[ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776],
# │                   [ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776],
# │                   [ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776],
# │                   [ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776],
# │                   [ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776],
# │                   [ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776],
# │                   [ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776],
# │                   [ 0.0662,  0.0981,  0.3015],
# │                   [ 0.8572, -0.4162, -0.4776]])
# └── 'x' --> <FastTreeValue 0x7efb6321bcd0>
#     └── 'c' --> tensor([[-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372],
#                         [-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372],
#                         [-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372],
#                         [-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372],
#                         [-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372],
#                         [-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372],
#                         [-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372],
#                         [-1.1918, -1.3994,  0.5052,  0.5855],
#                         [-0.7244,  1.9855, -1.4021, -0.8909],
#                         [-2.9120,  2.3852,  2.3147, -0.6372]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.5 µs ± 87.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.9 µs ± 55.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                       [[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                       [[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                       [[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                       [[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                       [[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                       [[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]],
#
#                       [[-1.1918, -1.3994,  0.5052,  0.5855],
#                        [-0.7244,  1.9855, -1.4021, -0.8909],
#                        [-2.9120,  2.3852,  2.3147, -0.6372]]]),
#        ),
#     a: tensor([[[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]],
#
#                [[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]],
#
#                [[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]],
#
#                [[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]],
#
#                [[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]],
#
#                [[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]],
#
#                [[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]],
#
#                [[ 0.0662,  0.0981,  0.3015],
#                 [ 0.8572, -0.4162, -0.4776]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.3 µs ± 159 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372],
#                       [-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372],
#                       [-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372],
#                       [-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372],
#                       [-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372],
#                       [-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372],
#                       [-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372],
#                       [-1.1918, -1.3994,  0.5052,  0.5855],
#                       [-0.7244,  1.9855, -1.4021, -0.8909],
#                       [-2.9120,  2.3852,  2.3147, -0.6372]]),
#        ),
#     a: tensor([[ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776],
#                [ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776],
#                [ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776],
#                [ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776],
#                [ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776],
#                [ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776],
#                [ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776],
#                [ 0.0662,  0.0981,  0.3015],
#                [ 0.8572, -0.4162, -0.4776]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 355 µs ± 6.82 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
