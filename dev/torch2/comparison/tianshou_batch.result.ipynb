# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f6a707768e0>
# ├── 'a' --> tensor([[-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963]])
# └── 'x' --> <FastTreeValue 0x7f6a70776670>
#     └── 'c' --> tensor([[-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546]])

# %%
t.a
# Out:
# tensor([[-0.5816,  0.5630, -0.5242],
#         [ 1.6059, -0.2925, -0.1963]])

# %%
# %timeit t.a
# Out:
# 63.4 ns ± 0.046 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f6a707768e0>
# ├── 'a' --> tensor([[ 0.3411, -0.3892,  1.2612],
# │                   [ 1.2251,  0.0916,  0.3346]])
# └── 'x' --> <FastTreeValue 0x7f6a70776670>
#     └── 'c' --> tensor([[-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546]])

# %%
# %timeit t.a = new_value
# Out:
# 62.5 ns ± 0.03 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963]]),
#     x: Batch(
#            c: tensor([[-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.5816,  0.5630, -0.5242],
#         [ 1.6059, -0.2925, -0.1963]])

# %%
# %timeit b.a
# Out:
# 53.2 ns ± 0.0372 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.2533, -1.3885,  1.7361],
#                [ 0.1221, -0.5895,  1.4109]]),
#     x: Batch(
#            c: tensor([[-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 488 ns ± 0.142 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 840 ns ± 0.161 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 34.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 138 µs ± 505 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 1.37 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f6a70796760>
# ├── 'a' --> tensor([[[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]],
# │
# │                   [[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]],
# │
# │                   [[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]],
# │
# │                   [[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]],
# │
# │                   [[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]],
# │
# │                   [[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]],
# │
# │                   [[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]],
# │
# │                   [[-0.5816,  0.5630, -0.5242],
# │                    [ 1.6059, -0.2925, -0.1963]]])
# └── 'x' --> <FastTreeValue 0x7f6a7383c340>
#     └── 'c' --> tensor([[[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                         [[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                         [[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                         [[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                         [[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                         [[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                         [[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                         [[-0.2760,  0.5532,  1.3272,  0.5901],
#                          [-0.4445,  1.8648, -0.3889,  0.3419],
#                          [-0.5646, -0.3248, -1.1125, -1.4546]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.4 µs ± 74.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f69a145c6a0>
# ├── 'a' --> tensor([[-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963],
# │                   [-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963],
# │                   [-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963],
# │                   [-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963],
# │                   [-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963],
# │                   [-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963],
# │                   [-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963],
# │                   [-0.5816,  0.5630, -0.5242],
# │                   [ 1.6059, -0.2925, -0.1963]])
# └── 'x' --> <FastTreeValue 0x7f6992539f40>
#     └── 'c' --> tensor([[-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546],
#                         [-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546],
#                         [-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546],
#                         [-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546],
#                         [-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546],
#                         [-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546],
#                         [-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546],
#                         [-0.2760,  0.5532,  1.3272,  0.5901],
#                         [-0.4445,  1.8648, -0.3889,  0.3419],
#                         [-0.5646, -0.3248, -1.1125, -1.4546]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.3 µs ± 137 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69.2 µs ± 50.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]],
#
#                [[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]],
#
#                [[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]],
#
#                [[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]],
#
#                [[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]],
#
#                [[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]],
#
#                [[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]],
#
#                [[-0.5816,  0.5630, -0.5242],
#                 [ 1.6059, -0.2925, -0.1963]]]),
#     x: Batch(
#            c: tensor([[[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                       [[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                       [[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                       [[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                       [[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                       [[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                       [[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]],
#
#                       [[-0.2760,  0.5532,  1.3272,  0.5901],
#                        [-0.4445,  1.8648, -0.3889,  0.3419],
#                        [-0.5646, -0.3248, -1.1125, -1.4546]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.6 µs ± 172 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963],
#                [-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963],
#                [-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963],
#                [-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963],
#                [-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963],
#                [-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963],
#                [-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963],
#                [-0.5816,  0.5630, -0.5242],
#                [ 1.6059, -0.2925, -0.1963]]),
#     x: Batch(
#            c: tensor([[-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546],
#                       [-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546],
#                       [-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546],
#                       [-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546],
#                       [-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546],
#                       [-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546],
#                       [-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546],
#                       [-0.2760,  0.5532,  1.3272,  0.5901],
#                       [-0.4445,  1.8648, -0.3889,  0.3419],
#                       [-0.5646, -0.3248, -1.1125, -1.4546]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 148 µs ± 871 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 328 µs ± 3.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
