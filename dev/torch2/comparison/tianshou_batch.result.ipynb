# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f67e4c974c0>
# ├── 'a' --> tensor([[ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315]])
# └── 'x' --> <FastTreeValue 0x7f67e4c97a00>
#     └── 'c' --> tensor([[-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237]])

# %%
t.a
# Out:
# tensor([[ 0.6691, -1.0045, -0.1830],
#         [-0.1910,  0.1853,  0.0315]])

# %%
# %timeit t.a
# Out:
# 58.8 ns ± 0.134 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f67e4c974c0>
# ├── 'a' --> tensor([[-0.3524, -0.5226, -0.4886],
# │                   [-1.4714,  0.1412, -0.6529]])
# └── 'x' --> <FastTreeValue 0x7f67e4c97a00>
#     └── 'c' --> tensor([[-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237]])

# %%
# %timeit t.a = new_value
# Out:
# 58.5 ns ± 0.0195 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315]]),
#     x: Batch(
#            c: tensor([[-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.6691, -1.0045, -0.1830],
#         [-0.1910,  0.1853,  0.0315]])

# %%
# %timeit b.a
# Out:
# 60.1 ns ± 0.0381 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.8054, -0.7701, -0.3384],
#                [-0.5791, -2.5441,  0.1528]]),
#     x: Batch(
#            c: tensor([[-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 482 ns ± 0.119 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 824 ns ± 0.408 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 71 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 138 µs ± 308 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 1.08 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f67e412c340>
# ├── 'a' --> tensor([[[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]],
# │
# │                   [[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]],
# │
# │                   [[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]],
# │
# │                   [[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]],
# │
# │                   [[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]],
# │
# │                   [[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]],
# │
# │                   [[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]],
# │
# │                   [[ 0.6691, -1.0045, -0.1830],
# │                    [-0.1910,  0.1853,  0.0315]]])
# └── 'x' --> <FastTreeValue 0x7f67e8d70fd0>
#     └── 'c' --> tensor([[[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                         [[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                         [[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                         [[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                         [[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                         [[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                         [[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                         [[-1.8850,  0.0473,  1.1043, -2.0420],
#                          [ 1.5174, -0.6499,  0.4003, -0.7802],
#                          [-0.1374, -3.3185,  0.0251, -0.6237]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.1 µs ± 57.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f67e4115fa0>
# ├── 'a' --> tensor([[ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315],
# │                   [ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315],
# │                   [ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315],
# │                   [ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315],
# │                   [ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315],
# │                   [ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315],
# │                   [ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315],
# │                   [ 0.6691, -1.0045, -0.1830],
# │                   [-0.1910,  0.1853,  0.0315]])
# └── 'x' --> <FastTreeValue 0x7f67e8d91700>
#     └── 'c' --> tensor([[-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237],
#                         [-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237],
#                         [-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237],
#                         [-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237],
#                         [-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237],
#                         [-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237],
#                         [-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237],
#                         [-1.8850,  0.0473,  1.1043, -2.0420],
#                         [ 1.5174, -0.6499,  0.4003, -0.7802],
#                         [-0.1374, -3.3185,  0.0251, -0.6237]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.6 µs ± 54.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68 µs ± 177 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]],
#
#                [[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]],
#
#                [[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]],
#
#                [[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]],
#
#                [[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]],
#
#                [[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]],
#
#                [[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]],
#
#                [[ 0.6691, -1.0045, -0.1830],
#                 [-0.1910,  0.1853,  0.0315]]]),
#     x: Batch(
#            c: tensor([[[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                       [[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                       [[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                       [[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                       [[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                       [[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                       [[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]],
#
#                       [[-1.8850,  0.0473,  1.1043, -2.0420],
#                        [ 1.5174, -0.6499,  0.4003, -0.7802],
#                        [-0.1374, -3.3185,  0.0251, -0.6237]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.6 µs ± 198 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315],
#                [ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315],
#                [ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315],
#                [ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315],
#                [ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315],
#                [ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315],
#                [ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315],
#                [ 0.6691, -1.0045, -0.1830],
#                [-0.1910,  0.1853,  0.0315]]),
#     x: Batch(
#            c: tensor([[-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237],
#                       [-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237],
#                       [-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237],
#                       [-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237],
#                       [-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237],
#                       [-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237],
#                       [-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237],
#                       [-1.8850,  0.0473,  1.1043, -2.0420],
#                       [ 1.5174, -0.6499,  0.4003, -0.7802],
#                       [-0.1374, -3.3185,  0.0251, -0.6237]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 147 µs ± 487 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 321 µs ± 767 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
