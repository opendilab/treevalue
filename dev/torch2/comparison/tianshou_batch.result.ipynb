# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9810b7a850>
# ├── 'a' --> tensor([[-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688]])
# └── 'x' --> <FastTreeValue 0x7f9810b7acd0>
#     └── 'c' --> tensor([[ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144]])

# %%
t.a
# Out:
# tensor([[-1.5065, -0.5771, -0.6598],
#         [ 2.1073,  0.8880,  0.9688]])

# %%
# %timeit t.a
# Out:
# 74.7 ns ± 0.633 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9810b7a850>
# ├── 'a' --> tensor([[ 1.6263, -0.4006, -1.1962],
# │                   [-1.8330,  0.7886,  1.3045]])
# └── 'x' --> <FastTreeValue 0x7f9810b7acd0>
#     └── 'c' --> tensor([[ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144]])

# %%
# %timeit t.a = new_value
# Out:
# 80.9 ns ± 0.803 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688]]),
#     x: Batch(
#            c: tensor([[ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.5065, -0.5771, -0.6598],
#         [ 2.1073,  0.8880,  0.9688]])

# %%
# %timeit b.a
# Out:
# 72.1 ns ± 0.716 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5007,  0.2539,  0.1619],
#                [-0.4841,  0.7960, -2.2455]]),
#     x: Batch(
#            c: tensor([[ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 660 ns ± 6.91 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.08 µs ± 13.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.6 µs ± 74.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 298 µs ± 11.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 288 µs ± 23.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f97303b8b50>
# ├── 'a' --> tensor([[[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]],
# │
# │                   [[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]],
# │
# │                   [[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]],
# │
# │                   [[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]],
# │
# │                   [[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]],
# │
# │                   [[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]],
# │
# │                   [[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]],
# │
# │                   [[-1.5065, -0.5771, -0.6598],
# │                    [ 2.1073,  0.8880,  0.9688]]])
# └── 'x' --> <FastTreeValue 0x7f97303b8850>
#     └── 'c' --> tensor([[[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                         [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                         [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                         [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                         [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                         [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                         [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                         [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                          [-1.2720,  0.8320,  1.1796, -1.0801],
#                          [-0.0775,  0.6350, -1.3387,  0.6144]]])

# %%
# %timeit t_stack(trees)
# Out:
# 51.7 µs ± 715 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f97f4f8d910>
# ├── 'a' --> tensor([[-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688],
# │                   [-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688],
# │                   [-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688],
# │                   [-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688],
# │                   [-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688],
# │                   [-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688],
# │                   [-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688],
# │                   [-1.5065, -0.5771, -0.6598],
# │                   [ 2.1073,  0.8880,  0.9688]])
# └── 'x' --> <FastTreeValue 0x7f9730427be0>
#     └── 'c' --> tensor([[ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144],
#                         [ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144],
#                         [ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144],
#                         [ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144],
#                         [ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144],
#                         [ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144],
#                         [ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144],
#                         [ 0.5635,  0.2857, -0.0485, -0.4858],
#                         [-1.2720,  0.8320,  1.1796, -1.0801],
#                         [-0.0775,  0.6350, -1.3387,  0.6144]])

# %%
# %timeit t_cat(trees)
# Out:
# 48 µs ± 475 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 105 µs ± 5.19 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]],
#
#                [[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]],
#
#                [[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]],
#
#                [[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]],
#
#                [[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]],
#
#                [[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]],
#
#                [[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]],
#
#                [[-1.5065, -0.5771, -0.6598],
#                 [ 2.1073,  0.8880,  0.9688]]]),
#     x: Batch(
#            c: tensor([[[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                       [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                       [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                       [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                       [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                       [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                       [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]],
#
#                       [[ 0.5635,  0.2857, -0.0485, -0.4858],
#                        [-1.2720,  0.8320,  1.1796, -1.0801],
#                        [-0.0775,  0.6350, -1.3387,  0.6144]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 117 µs ± 1.37 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688],
#                [-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688],
#                [-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688],
#                [-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688],
#                [-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688],
#                [-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688],
#                [-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688],
#                [-1.5065, -0.5771, -0.6598],
#                [ 2.1073,  0.8880,  0.9688]]),
#     x: Batch(
#            c: tensor([[ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144],
#                       [ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144],
#                       [ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144],
#                       [ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144],
#                       [ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144],
#                       [ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144],
#                       [ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144],
#                       [ 0.5635,  0.2857, -0.0485, -0.4858],
#                       [-1.2720,  0.8320,  1.1796, -1.0801],
#                       [-0.0775,  0.6350, -1.3387,  0.6144]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 214 µs ± 9.68 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 707 µs ± 68.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
