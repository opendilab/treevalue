# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f7f3c8574c0>
# ├── 'a' --> tensor([[-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966]])
# └── 'x' --> <FastTreeValue 0x7f7f3c85cf70>
#     └── 'c' --> tensor([[-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553]])

# %%
t.a
# Out:
# tensor([[-1.3633, -0.5977,  0.3174],
#         [-2.1012,  1.7514,  0.0966]])

# %%
# %timeit t.a
# Out:
# 85.4 ns ± 1.16 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f7f3c8574c0>
# ├── 'a' --> tensor([[ 0.0537, -0.2210, -0.4122],
# │                   [ 1.5040,  0.1855, -0.8900]])
# └── 'x' --> <FastTreeValue 0x7f7f3c85cf70>
#     └── 'c' --> tensor([[-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553]])

# %%
# %timeit t.a = new_value
# Out:
# 86.5 ns ± 0.67 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966]]),
#     x: Batch(
#            c: tensor([[-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.3633, -0.5977,  0.3174],
#         [-2.1012,  1.7514,  0.0966]])

# %%
# %timeit b.a
# Out:
# 79.1 ns ± 0.303 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0744, -1.2023, -2.6260],
#                [-0.6970,  0.4966,  0.9394]]),
#     x: Batch(
#            c: tensor([[-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 645 ns ± 6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.03 µs ± 14.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.4 µs ± 153 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 174 µs ± 1.56 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 175 µs ± 796 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f7f2c220940>
# ├── 'a' --> tensor([[[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]],
# │
# │                   [[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]],
# │
# │                   [[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]],
# │
# │                   [[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]],
# │
# │                   [[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]],
# │
# │                   [[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]],
# │
# │                   [[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]],
# │
# │                   [[-1.3633, -0.5977,  0.3174],
# │                    [-2.1012,  1.7514,  0.0966]]])
# └── 'x' --> <FastTreeValue 0x7f7f2c220a30>
#     └── 'c' --> tensor([[[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                         [[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                         [[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                         [[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                         [[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                         [[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                         [[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                         [[-0.5801, -0.9188, -1.1656,  1.1108],
#                          [-0.6354,  1.0920,  2.5867,  0.9958],
#                          [ 0.3869,  0.3669,  0.9483,  2.5553]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39.2 µs ± 303 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f7f3c86e7c0>
# ├── 'a' --> tensor([[-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966],
# │                   [-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966],
# │                   [-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966],
# │                   [-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966],
# │                   [-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966],
# │                   [-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966],
# │                   [-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966],
# │                   [-1.3633, -0.5977,  0.3174],
# │                   [-2.1012,  1.7514,  0.0966]])
# └── 'x' --> <FastTreeValue 0x7f7e4e006520>
#     └── 'c' --> tensor([[-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553],
#                         [-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553],
#                         [-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553],
#                         [-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553],
#                         [-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553],
#                         [-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553],
#                         [-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553],
#                         [-0.5801, -0.9188, -1.1656,  1.1108],
#                         [-0.6354,  1.0920,  2.5867,  0.9958],
#                         [ 0.3869,  0.3669,  0.9483,  2.5553]])

# %%
# %timeit t_cat(trees)
# Out:
# 37 µs ± 274 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.4 µs ± 356 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                       [[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                       [[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                       [[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                       [[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                       [[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                       [[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]],
#
#                       [[-0.5801, -0.9188, -1.1656,  1.1108],
#                        [-0.6354,  1.0920,  2.5867,  0.9958],
#                        [ 0.3869,  0.3669,  0.9483,  2.5553]]]),
#        ),
#     a: tensor([[[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]],
#
#                [[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]],
#
#                [[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]],
#
#                [[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]],
#
#                [[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]],
#
#                [[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]],
#
#                [[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]],
#
#                [[-1.3633, -0.5977,  0.3174],
#                 [-2.1012,  1.7514,  0.0966]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.3 µs ± 4.14 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553],
#                       [-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553],
#                       [-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553],
#                       [-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553],
#                       [-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553],
#                       [-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553],
#                       [-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553],
#                       [-0.5801, -0.9188, -1.1656,  1.1108],
#                       [-0.6354,  1.0920,  2.5867,  0.9958],
#                       [ 0.3869,  0.3669,  0.9483,  2.5553]]),
#        ),
#     a: tensor([[-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966],
#                [-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966],
#                [-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966],
#                [-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966],
#                [-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966],
#                [-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966],
#                [-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966],
#                [-1.3633, -0.5977,  0.3174],
#                [-2.1012,  1.7514,  0.0966]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 175 µs ± 2.37 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 435 µs ± 9.65 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
