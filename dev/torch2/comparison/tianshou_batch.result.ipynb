# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f326839ca60>
# ├── 'a' --> tensor([[-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489]])
# └── 'x' --> <FastTreeValue 0x7f326839cb50>
#     └── 'c' --> tensor([[ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582]])

# %%
t.a
# Out:
# tensor([[-0.3720, -1.3095,  0.1672],
#         [-0.2647,  0.2256, -0.8489]])

# %%
# %timeit t.a
# Out:
# 80.2 ns ± 0.925 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f326839ca60>
# ├── 'a' --> tensor([[ 0.9456,  0.2356, -1.1089],
# │                   [-0.0457,  0.1304, -0.0726]])
# └── 'x' --> <FastTreeValue 0x7f326839cb50>
#     └── 'c' --> tensor([[ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582]])

# %%
# %timeit t.a = new_value
# Out:
# 82.3 ns ± 0.718 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489]]),
#     x: Batch(
#            c: tensor([[ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.3720, -1.3095,  0.1672],
#         [-0.2647,  0.2256, -0.8489]])

# %%
# %timeit b.a
# Out:
# 74 ns ± 1.6 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.2364, -1.7310, -1.1337],
#                [-0.4583, -1.0448,  3.1767]]),
#     x: Batch(
#            c: tensor([[ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 645 ns ± 7.34 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.06 µs ± 9.39 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.4 µs ± 153 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 302 µs ± 11.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 283 µs ± 16.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f32582068e0>
# ├── 'a' --> tensor([[[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]],
# │
# │                   [[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]],
# │
# │                   [[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]],
# │
# │                   [[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]],
# │
# │                   [[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]],
# │
# │                   [[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]],
# │
# │                   [[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]],
# │
# │                   [[-0.3720, -1.3095,  0.1672],
# │                    [-0.2647,  0.2256, -0.8489]]])
# └── 'x' --> <FastTreeValue 0x7f325821f760>
#     └── 'c' --> tensor([[[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                         [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                         [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                         [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                         [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                         [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                         [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                         [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                          [ 0.4865, -0.4991, -0.7561, -0.2473],
#                          [ 1.1127, -1.6282, -0.6215,  0.2582]]])

# %%
# %timeit t_stack(trees)
# Out:
# 48.8 µs ± 931 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f325821f400>
# ├── 'a' --> tensor([[-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489],
# │                   [-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489],
# │                   [-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489],
# │                   [-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489],
# │                   [-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489],
# │                   [-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489],
# │                   [-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489],
# │                   [-0.3720, -1.3095,  0.1672],
# │                   [-0.2647,  0.2256, -0.8489]])
# └── 'x' --> <FastTreeValue 0x7f31842fcf40>
#     └── 'c' --> tensor([[ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582],
#                         [ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582],
#                         [ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582],
#                         [ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582],
#                         [ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582],
#                         [ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582],
#                         [ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582],
#                         [ 1.0389, -2.1403,  0.8142, -2.1349],
#                         [ 0.4865, -0.4991, -0.7561, -0.2473],
#                         [ 1.1127, -1.6282, -0.6215,  0.2582]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.5 µs ± 830 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 98 µs ± 1.71 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                       [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                       [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                       [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                       [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                       [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                       [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]],
#
#                       [[ 1.0389, -2.1403,  0.8142, -2.1349],
#                        [ 0.4865, -0.4991, -0.7561, -0.2473],
#                        [ 1.1127, -1.6282, -0.6215,  0.2582]]]),
#        ),
#     a: tensor([[[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]],
#
#                [[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]],
#
#                [[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]],
#
#                [[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]],
#
#                [[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]],
#
#                [[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]],
#
#                [[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]],
#
#                [[-0.3720, -1.3095,  0.1672],
#                 [-0.2647,  0.2256, -0.8489]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 109 µs ± 1.96 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582],
#                       [ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582],
#                       [ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582],
#                       [ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582],
#                       [ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582],
#                       [ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582],
#                       [ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582],
#                       [ 1.0389, -2.1403,  0.8142, -2.1349],
#                       [ 0.4865, -0.4991, -0.7561, -0.2473],
#                       [ 1.1127, -1.6282, -0.6215,  0.2582]]),
#        ),
#     a: tensor([[-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489],
#                [-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489],
#                [-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489],
#                [-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489],
#                [-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489],
#                [-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489],
#                [-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489],
#                [-0.3720, -1.3095,  0.1672],
#                [-0.2647,  0.2256, -0.8489]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 197 µs ± 3.34 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 693 µs ± 19.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
