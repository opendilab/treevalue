# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f488832e640>
# ├── 'a' --> tensor([[ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635]])
# └── 'x' --> <FastTreeValue 0x7f488832e550>
#     └── 'c' --> tensor([[ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249]])

# %%
t.a
# Out:
# tensor([[ 0.3436,  0.3474, -0.3751],
#         [-0.7782,  0.6897, -1.2635]])

# %%
# %timeit t.a
# Out:
# 66.4 ns ± 0.0616 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f488832e640>
# ├── 'a' --> tensor([[ 1.2068, -2.0836,  0.4823],
# │                   [-0.7330, -0.1558, -0.5751]])
# └── 'x' --> <FastTreeValue 0x7f488832e550>
#     └── 'c' --> tensor([[ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249]])

# %%
# %timeit t.a = new_value
# Out:
# 72.2 ns ± 0.0272 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635]]),
#     x: Batch(
#            c: tensor([[ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.3436,  0.3474, -0.3751],
#         [-0.7782,  0.6897, -1.2635]])

# %%
# %timeit b.a
# Out:
# 59.7 ns ± 0.0734 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.6674,  0.4885, -0.7187],
#                [-0.9042, -0.4714, -0.1615]]),
#     x: Batch(
#            c: tensor([[ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 501 ns ± 0.0485 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 805 ns ± 1.38 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.6 µs ± 28.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 92.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 1.6 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f47b7f32d60>
# ├── 'a' --> tensor([[[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]],
# │
# │                   [[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]],
# │
# │                   [[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]],
# │
# │                   [[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]],
# │
# │                   [[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]],
# │
# │                   [[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]],
# │
# │                   [[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]],
# │
# │                   [[ 0.3436,  0.3474, -0.3751],
# │                    [-0.7782,  0.6897, -1.2635]]])
# └── 'x' --> <FastTreeValue 0x7f488a3ba8b0>
#     └── 'c' --> tensor([[[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                         [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                         [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                         [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                         [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                         [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                         [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                         [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                          [-0.5285, -1.7380, -0.6498, -0.1908],
#                          [-1.9855, -0.6454, -0.8093,  0.0249]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.1 µs ± 74.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f47b4cc6e80>
# ├── 'a' --> tensor([[ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635],
# │                   [ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635],
# │                   [ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635],
# │                   [ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635],
# │                   [ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635],
# │                   [ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635],
# │                   [ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635],
# │                   [ 0.3436,  0.3474, -0.3751],
# │                   [-0.7782,  0.6897, -1.2635]])
# └── 'x' --> <FastTreeValue 0x7f488832e610>
#     └── 'c' --> tensor([[ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249],
#                         [ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249],
#                         [ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249],
#                         [ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249],
#                         [ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249],
#                         [ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249],
#                         [ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249],
#                         [ 1.4561,  0.2848,  1.9875,  0.9648],
#                         [-0.5285, -1.7380, -0.6498, -0.1908],
#                         [-1.9855, -0.6454, -0.8093,  0.0249]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.9 µs ± 44.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.9 µs ± 95.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]],
#
#                [[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]],
#
#                [[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]],
#
#                [[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]],
#
#                [[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]],
#
#                [[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]],
#
#                [[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]],
#
#                [[ 0.3436,  0.3474, -0.3751],
#                 [-0.7782,  0.6897, -1.2635]]]),
#     x: Batch(
#            c: tensor([[[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                       [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                       [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                       [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                       [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                       [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                       [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]],
#
#                       [[ 1.4561,  0.2848,  1.9875,  0.9648],
#                        [-0.5285, -1.7380, -0.6498, -0.1908],
#                        [-1.9855, -0.6454, -0.8093,  0.0249]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.8 µs ± 249 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635],
#                [ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635],
#                [ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635],
#                [ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635],
#                [ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635],
#                [ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635],
#                [ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635],
#                [ 0.3436,  0.3474, -0.3751],
#                [-0.7782,  0.6897, -1.2635]]),
#     x: Batch(
#            c: tensor([[ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249],
#                       [ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249],
#                       [ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249],
#                       [ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249],
#                       [ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249],
#                       [ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249],
#                       [ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249],
#                       [ 1.4561,  0.2848,  1.9875,  0.9648],
#                       [-0.5285, -1.7380, -0.6498, -0.1908],
#                       [-1.9855, -0.6454, -0.8093,  0.0249]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 147 µs ± 484 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 353 µs ± 1.01 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
