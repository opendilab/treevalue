# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f37931ba4f0>
# ├── 'a' --> tensor([[ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143]])
# └── 'x' --> <FastTreeValue 0x7f37931ba8b0>
#     └── 'c' --> tensor([[ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965]])

# %%
t.a
# Out:
# tensor([[ 0.5207,  0.9903, -0.0286],
#         [ 0.1572,  0.0552, -0.1143]])

# %%
# %timeit t.a
# Out:
# 63.5 ns ± 0.0446 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f37931ba4f0>
# ├── 'a' --> tensor([[-0.8517, -2.6035, -0.2394],
# │                   [ 0.1071,  0.3104,  0.9798]])
# └── 'x' --> <FastTreeValue 0x7f37931ba8b0>
#     └── 'c' --> tensor([[ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965]])

# %%
# %timeit t.a = new_value
# Out:
# 67.7 ns ± 0.0268 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143]]),
#     x: Batch(
#            c: tensor([[ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.5207,  0.9903, -0.0286],
#         [ 0.1572,  0.0552, -0.1143]])

# %%
# %timeit b.a
# Out:
# 57.8 ns ± 0.139 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.5935,  1.4714, -2.0933],
#                [-1.0286, -0.4709, -1.4690]]),
#     x: Batch(
#            c: tensor([[ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 488 ns ± 0.158 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 807 ns ± 0.487 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.8 µs ± 37.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 754 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 395 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f36b2f542b0>
# ├── 'a' --> tensor([[[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]],
# │
# │                   [[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]],
# │
# │                   [[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]],
# │
# │                   [[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]],
# │
# │                   [[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]],
# │
# │                   [[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]],
# │
# │                   [[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]],
# │
# │                   [[ 0.5207,  0.9903, -0.0286],
# │                    [ 0.1572,  0.0552, -0.1143]]])
# └── 'x' --> <FastTreeValue 0x7f3790132730>
#     └── 'c' --> tensor([[[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                         [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                         [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                         [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                         [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                         [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                         [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                         [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                          [-0.8558,  0.3015,  0.1348, -0.2047],
#                          [ 0.3528, -1.6464, -0.1157, -1.2965]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 90.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f36b2edfb80>
# ├── 'a' --> tensor([[ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143],
# │                   [ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143],
# │                   [ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143],
# │                   [ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143],
# │                   [ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143],
# │                   [ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143],
# │                   [ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143],
# │                   [ 0.5207,  0.9903, -0.0286],
# │                   [ 0.1572,  0.0552, -0.1143]])
# └── 'x' --> <FastTreeValue 0x7f36b2f54370>
#     └── 'c' --> tensor([[ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965],
#                         [ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965],
#                         [ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965],
#                         [ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965],
#                         [ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965],
#                         [ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965],
#                         [ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965],
#                         [ 0.7389,  0.0462, -1.0893, -0.3732],
#                         [-0.8558,  0.3015,  0.1348, -0.2047],
#                         [ 0.3528, -1.6464, -0.1157, -1.2965]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.4 µs ± 85.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.5 µs ± 30.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]],
#
#                [[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]],
#
#                [[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]],
#
#                [[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]],
#
#                [[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]],
#
#                [[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]],
#
#                [[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]],
#
#                [[ 0.5207,  0.9903, -0.0286],
#                 [ 0.1572,  0.0552, -0.1143]]]),
#     x: Batch(
#            c: tensor([[[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                       [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                       [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                       [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                       [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                       [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                       [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]],
#
#                       [[ 0.7389,  0.0462, -1.0893, -0.3732],
#                        [-0.8558,  0.3015,  0.1348, -0.2047],
#                        [ 0.3528, -1.6464, -0.1157, -1.2965]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.7 µs ± 307 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143],
#                [ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143],
#                [ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143],
#                [ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143],
#                [ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143],
#                [ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143],
#                [ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143],
#                [ 0.5207,  0.9903, -0.0286],
#                [ 0.1572,  0.0552, -0.1143]]),
#     x: Batch(
#            c: tensor([[ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965],
#                       [ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965],
#                       [ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965],
#                       [ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965],
#                       [ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965],
#                       [ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965],
#                       [ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965],
#                       [ 0.7389,  0.0462, -1.0893, -0.3732],
#                       [-0.8558,  0.3015,  0.1348, -0.2047],
#                       [ 0.3528, -1.6464, -0.1157, -1.2965]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 245 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 342 µs ± 976 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
