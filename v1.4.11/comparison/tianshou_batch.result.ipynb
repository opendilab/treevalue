# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f974af3c580>
# ├── 'a' --> tensor([[-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043]])
# └── 'x' --> <FastTreeValue 0x7f974af3cb80>
#     └── 'c' --> tensor([[ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641]])

# %%
t.a
# Out:
# tensor([[-2.0821,  0.6166,  0.0465],
#         [ 0.9415,  0.2899, -0.9043]])

# %%
# %timeit t.a
# Out:
# 84.5 ns ± 0.371 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f974af3c580>
# ├── 'a' --> tensor([[ 1.7324e-01, -8.1793e-02, -1.3082e+00],
# │                   [ 1.9981e-04,  5.3647e-01, -9.1474e-01]])
# └── 'x' --> <FastTreeValue 0x7f974af3cb80>
#     └── 'c' --> tensor([[ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641]])

# %%
# %timeit t.a = new_value
# Out:
# 86.8 ns ± 0.436 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043]]),
#     x: Batch(
#            c: tensor([[ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-2.0821,  0.6166,  0.0465],
#         [ 0.9415,  0.2899, -0.9043]])

# %%
# %timeit b.a
# Out:
# 79.3 ns ± 0.684 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 2.2043,  1.0952, -0.5842],
#                [-1.0210, -0.1186,  0.4703]]),
#     x: Batch(
#            c: tensor([[ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 633 ns ± 3.03 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.07 µs ± 3.84 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.4 µs ± 61 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 173 µs ± 9.36 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 169 µs ± 1.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f9748e58700>
# ├── 'a' --> tensor([[[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]],
# │
# │                   [[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]],
# │
# │                   [[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]],
# │
# │                   [[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]],
# │
# │                   [[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]],
# │
# │                   [[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]],
# │
# │                   [[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]],
# │
# │                   [[-2.0821,  0.6166,  0.0465],
# │                    [ 0.9415,  0.2899, -0.9043]]])
# └── 'x' --> <FastTreeValue 0x7f966a739070>
#     └── 'c' --> tensor([[[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                         [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                         [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                         [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                         [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                         [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                         [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                         [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                          [-0.4146, -0.2923, -0.6008,  1.1693],
#                          [-0.7586, -0.4101,  0.8154, -2.1641]]])

# %%
# %timeit t_stack(trees)
# Out:
# 38.1 µs ± 683 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9678657190>
# ├── 'a' --> tensor([[-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043],
# │                   [-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043],
# │                   [-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043],
# │                   [-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043],
# │                   [-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043],
# │                   [-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043],
# │                   [-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043],
# │                   [-2.0821,  0.6166,  0.0465],
# │                   [ 0.9415,  0.2899, -0.9043]])
# └── 'x' --> <FastTreeValue 0x7f9678657250>
#     └── 'c' --> tensor([[ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641],
#                         [ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641],
#                         [ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641],
#                         [ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641],
#                         [ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641],
#                         [ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641],
#                         [ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641],
#                         [ 0.6669, -0.3421,  0.5862, -0.5694],
#                         [-0.4146, -0.2923, -0.6008,  1.1693],
#                         [-0.7586, -0.4101,  0.8154, -2.1641]])

# %%
# %timeit t_cat(trees)
# Out:
# 35.6 µs ± 255 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 77.5 µs ± 264 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                       [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                       [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                       [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                       [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                       [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                       [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]],
#
#                       [[ 0.6669, -0.3421,  0.5862, -0.5694],
#                        [-0.4146, -0.2923, -0.6008,  1.1693],
#                        [-0.7586, -0.4101,  0.8154, -2.1641]]]),
#        ),
#     a: tensor([[[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]],
#
#                [[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]],
#
#                [[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]],
#
#                [[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]],
#
#                [[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]],
#
#                [[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]],
#
#                [[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]],
#
#                [[-2.0821,  0.6166,  0.0465],
#                 [ 0.9415,  0.2899, -0.9043]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 95.8 µs ± 489 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641],
#                       [ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641],
#                       [ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641],
#                       [ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641],
#                       [ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641],
#                       [ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641],
#                       [ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641],
#                       [ 0.6669, -0.3421,  0.5862, -0.5694],
#                       [-0.4146, -0.2923, -0.6008,  1.1693],
#                       [-0.7586, -0.4101,  0.8154, -2.1641]]),
#        ),
#     a: tensor([[-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043],
#                [-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043],
#                [-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043],
#                [-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043],
#                [-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043],
#                [-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043],
#                [-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043],
#                [-2.0821,  0.6166,  0.0465],
#                [ 0.9415,  0.2899, -0.9043]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 178 µs ± 1.61 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 409 µs ± 8.66 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
