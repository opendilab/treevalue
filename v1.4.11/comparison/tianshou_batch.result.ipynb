# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f2dc442ef40>
# ├── 'a' --> tensor([[-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132]])
# └── 'x' --> <FastTreeValue 0x7f2dc4417760>
#     └── 'c' --> tensor([[ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191]])

# %%
t.a
# Out:
# tensor([[-0.1898,  0.7525,  0.7387],
#         [-0.0858,  1.1577,  0.5132]])

# %%
# %timeit t.a
# Out:
# 79.3 ns ± 0.884 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f2dc442ef40>
# ├── 'a' --> tensor([[-1.2512,  0.0057, -0.0241],
# │                   [-0.4855,  1.4604,  0.0072]])
# └── 'x' --> <FastTreeValue 0x7f2dc4417760>
#     └── 'c' --> tensor([[ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191]])

# %%
# %timeit t.a = new_value
# Out:
# 82.9 ns ± 1.43 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132]]),
#     x: Batch(
#            c: tensor([[ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.1898,  0.7525,  0.7387],
#         [-0.0858,  1.1577,  0.5132]])

# %%
# %timeit b.a
# Out:
# 71.6 ns ± 1.79 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.4915, -0.6378, -1.1160],
#                [ 0.0064, -1.4703,  0.2748]]),
#     x: Batch(
#            c: tensor([[ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 656 ns ± 7.91 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.12 µs ± 29.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.9 µs ± 288 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 299 µs ± 17.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 302 µs ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f2ce035cac0>
# ├── 'a' --> tensor([[[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]],
# │
# │                   [[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]],
# │
# │                   [[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]],
# │
# │                   [[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]],
# │
# │                   [[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]],
# │
# │                   [[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]],
# │
# │                   [[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]],
# │
# │                   [[-0.1898,  0.7525,  0.7387],
# │                    [-0.0858,  1.1577,  0.5132]]])
# └── 'x' --> <FastTreeValue 0x7f2ce035c790>
#     └── 'c' --> tensor([[[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                         [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                         [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                         [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                         [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                         [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                         [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                         [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                          [ 0.5288,  0.7707,  1.7395, -0.8524],
#                          [-0.2966, -1.0923,  0.8858,  2.7191]]])

# %%
# %timeit t_stack(trees)
# Out:
# 49.2 µs ± 811 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f2db42e6700>
# ├── 'a' --> tensor([[-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132],
# │                   [-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132],
# │                   [-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132],
# │                   [-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132],
# │                   [-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132],
# │                   [-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132],
# │                   [-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132],
# │                   [-0.1898,  0.7525,  0.7387],
# │                   [-0.0858,  1.1577,  0.5132]])
# └── 'x' --> <FastTreeValue 0x7f2cee8a5d30>
#     └── 'c' --> tensor([[ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191],
#                         [ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191],
#                         [ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191],
#                         [ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191],
#                         [ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191],
#                         [ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191],
#                         [ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191],
#                         [ 0.1804,  0.3561, -1.8147,  0.1109],
#                         [ 0.5288,  0.7707,  1.7395, -0.8524],
#                         [-0.2966, -1.0923,  0.8858,  2.7191]])

# %%
# %timeit t_cat(trees)
# Out:
# 46.9 µs ± 598 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 96.5 µs ± 2.16 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                       [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                       [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                       [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                       [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                       [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                       [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]],
#
#                       [[ 0.1804,  0.3561, -1.8147,  0.1109],
#                        [ 0.5288,  0.7707,  1.7395, -0.8524],
#                        [-0.2966, -1.0923,  0.8858,  2.7191]]]),
#        ),
#     a: tensor([[[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]],
#
#                [[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]],
#
#                [[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]],
#
#                [[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]],
#
#                [[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]],
#
#                [[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]],
#
#                [[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]],
#
#                [[-0.1898,  0.7525,  0.7387],
#                 [-0.0858,  1.1577,  0.5132]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 108 µs ± 2.58 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191],
#                       [ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191],
#                       [ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191],
#                       [ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191],
#                       [ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191],
#                       [ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191],
#                       [ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191],
#                       [ 0.1804,  0.3561, -1.8147,  0.1109],
#                       [ 0.5288,  0.7707,  1.7395, -0.8524],
#                       [-0.2966, -1.0923,  0.8858,  2.7191]]),
#        ),
#     a: tensor([[-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132],
#                [-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132],
#                [-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132],
#                [-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132],
#                [-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132],
#                [-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132],
#                [-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132],
#                [-0.1898,  0.7525,  0.7387],
#                [-0.0858,  1.1577,  0.5132]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 199 µs ± 4.01 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 711 µs ± 9.05 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
