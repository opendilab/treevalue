# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7ff2be652f10>
# ├── 'a' --> tensor([[-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722]])
# └── 'x' --> <FastTreeValue 0x7ff2be652ee0>
#     └── 'c' --> tensor([[ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497]])

# %%
t.a
# Out:
# tensor([[-0.0422,  1.6476, -2.7643],
#         [ 0.8294, -0.9079,  0.7722]])

# %%
# %timeit t.a
# Out:
# 64.1 ns ± 0.0521 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7ff2be652f10>
# ├── 'a' --> tensor([[ 0.0276, -0.5685,  0.0323],
# │                   [ 0.2390,  0.2582, -1.3510]])
# └── 'x' --> <FastTreeValue 0x7ff2be652ee0>
#     └── 'c' --> tensor([[ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497]])

# %%
# %timeit t.a = new_value
# Out:
# 65.6 ns ± 0.0671 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722]]),
#     x: Batch(
#            c: tensor([[ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.0422,  1.6476, -2.7643],
#         [ 0.8294, -0.9079,  0.7722]])

# %%
# %timeit b.a
# Out:
# 54 ns ± 0.0756 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.3838,  1.2676,  0.9103],
#                [-0.8147, -0.4604, -0.3901]]),
#     x: Batch(
#            c: tensor([[ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 490 ns ± 0.152 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 939 ns ± 7.22 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 30.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 138 µs ± 601 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 808 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7ff1e85a8e80>
# ├── 'a' --> tensor([[[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]],
# │
# │                   [[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]],
# │
# │                   [[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]],
# │
# │                   [[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]],
# │
# │                   [[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]],
# │
# │                   [[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]],
# │
# │                   [[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]],
# │
# │                   [[-0.0422,  1.6476, -2.7643],
# │                    [ 0.8294, -0.9079,  0.7722]]])
# └── 'x' --> <FastTreeValue 0x7ff1e8537eb0>
#     └── 'c' --> tensor([[[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                         [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                         [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                         [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                         [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                         [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                         [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                         [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                          [-0.7303,  0.8299,  0.9678,  0.6963],
#                          [ 0.8874,  1.3236, -1.2660,  0.2497]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.4 µs ± 56.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7ff1e8537d60>
# ├── 'a' --> tensor([[-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722],
# │                   [-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722],
# │                   [-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722],
# │                   [-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722],
# │                   [-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722],
# │                   [-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722],
# │                   [-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722],
# │                   [-0.0422,  1.6476, -2.7643],
# │                   [ 0.8294, -0.9079,  0.7722]])
# └── 'x' --> <FastTreeValue 0x7ff1e85278e0>
#     └── 'c' --> tensor([[ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497],
#                         [ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497],
#                         [ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497],
#                         [ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497],
#                         [ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497],
#                         [ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497],
#                         [ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497],
#                         [ 1.1535, -0.4194,  1.4867, -0.1452],
#                         [-0.7303,  0.8299,  0.9678,  0.6963],
#                         [ 0.8874,  1.3236, -1.2660,  0.2497]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.5 µs ± 91.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68 µs ± 106 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                       [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                       [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                       [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                       [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                       [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                       [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]],
#
#                       [[ 1.1535, -0.4194,  1.4867, -0.1452],
#                        [-0.7303,  0.8299,  0.9678,  0.6963],
#                        [ 0.8874,  1.3236, -1.2660,  0.2497]]]),
#        ),
#     a: tensor([[[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]],
#
#                [[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]],
#
#                [[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]],
#
#                [[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]],
#
#                [[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]],
#
#                [[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]],
#
#                [[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]],
#
#                [[-0.0422,  1.6476, -2.7643],
#                 [ 0.8294, -0.9079,  0.7722]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.6 µs ± 197 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497],
#                       [ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497],
#                       [ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497],
#                       [ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497],
#                       [ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497],
#                       [ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497],
#                       [ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497],
#                       [ 1.1535, -0.4194,  1.4867, -0.1452],
#                       [-0.7303,  0.8299,  0.9678,  0.6963],
#                       [ 0.8874,  1.3236, -1.2660,  0.2497]]),
#        ),
#     a: tensor([[-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722],
#                [-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722],
#                [-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722],
#                [-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722],
#                [-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722],
#                [-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722],
#                [-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722],
#                [-0.0422,  1.6476, -2.7643],
#                [ 0.8294, -0.9079,  0.7722]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 152 µs ± 689 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 324 µs ± 5.02 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
