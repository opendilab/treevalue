# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f4b28ea2190>
# ├── 'a' --> tensor([[-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555]])
# └── 'x' --> <FastTreeValue 0x7f4b28ea2310>
#     └── 'c' --> tensor([[-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990]])

# %%
t.a
# Out:
# tensor([[-0.4677,  0.8849, -1.1732],
#         [-1.8452, -0.5266,  0.5555]])

# %%
# %timeit t.a
# Out:
# 74 ns ± 0.0758 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f4b28ea2190>
# ├── 'a' --> tensor([[-1.2278, -1.7902,  0.3944],
# │                   [ 0.3631, -0.8527,  0.9721]])
# └── 'x' --> <FastTreeValue 0x7f4b28ea2310>
#     └── 'c' --> tensor([[-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990]])

# %%
# %timeit t.a = new_value
# Out:
# 84.2 ns ± 0.11 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555]]),
#     x: Batch(
#            c: tensor([[-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.4677,  0.8849, -1.1732],
#         [-1.8452, -0.5266,  0.5555]])

# %%
# %timeit b.a
# Out:
# 69.4 ns ± 0.11 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.7298, -2.1685,  0.2495],
#                [-1.0627, -0.9213,  0.5212]]),
#     x: Batch(
#            c: tensor([[-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 552 ns ± 0.287 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 868 ns ± 0.426 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 23.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 151 µs ± 1.6 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 151 µs ± 785 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f4a5352f280>
# ├── 'a' --> tensor([[[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]],
# │
# │                   [[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]],
# │
# │                   [[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]],
# │
# │                   [[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]],
# │
# │                   [[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]],
# │
# │                   [[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]],
# │
# │                   [[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]],
# │
# │                   [[-0.4677,  0.8849, -1.1732],
# │                    [-1.8452, -0.5266,  0.5555]]])
# └── 'x' --> <FastTreeValue 0x7f4a3a4c89a0>
#     └── 'c' --> tensor([[[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                         [[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                         [[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                         [[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                         [[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                         [[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                         [[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                         [[-1.4528,  1.7307, -1.0123,  0.1347],
#                          [ 2.0197, -0.2076,  0.2868, -0.0520],
#                          [-2.0351,  0.1312,  1.0611,  0.0990]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34 µs ± 59.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f4a54ae8700>
# ├── 'a' --> tensor([[-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555],
# │                   [-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555],
# │                   [-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555],
# │                   [-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555],
# │                   [-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555],
# │                   [-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555],
# │                   [-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555],
# │                   [-0.4677,  0.8849, -1.1732],
# │                   [-1.8452, -0.5266,  0.5555]])
# └── 'x' --> <FastTreeValue 0x7f4a3a4c8640>
#     └── 'c' --> tensor([[-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990],
#                         [-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990],
#                         [-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990],
#                         [-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990],
#                         [-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990],
#                         [-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990],
#                         [-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990],
#                         [-1.4528,  1.7307, -1.0123,  0.1347],
#                         [ 2.0197, -0.2076,  0.2868, -0.0520],
#                         [-2.0351,  0.1312,  1.0611,  0.0990]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.3 µs ± 154 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.2 µs ± 528 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                       [[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                       [[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                       [[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                       [[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                       [[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                       [[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]],
#
#                       [[-1.4528,  1.7307, -1.0123,  0.1347],
#                        [ 2.0197, -0.2076,  0.2868, -0.0520],
#                        [-2.0351,  0.1312,  1.0611,  0.0990]]]),
#        ),
#     a: tensor([[[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]],
#
#                [[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]],
#
#                [[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]],
#
#                [[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]],
#
#                [[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]],
#
#                [[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]],
#
#                [[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]],
#
#                [[-0.4677,  0.8849, -1.1732],
#                 [-1.8452, -0.5266,  0.5555]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.1 µs ± 111 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990],
#                       [-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990],
#                       [-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990],
#                       [-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990],
#                       [-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990],
#                       [-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990],
#                       [-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990],
#                       [-1.4528,  1.7307, -1.0123,  0.1347],
#                       [ 2.0197, -0.2076,  0.2868, -0.0520],
#                       [-2.0351,  0.1312,  1.0611,  0.0990]]),
#        ),
#     a: tensor([[-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555],
#                [-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555],
#                [-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555],
#                [-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555],
#                [-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555],
#                [-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555],
#                [-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555],
#                [-0.4677,  0.8849, -1.1732],
#                [-1.8452, -0.5266,  0.5555]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 152 µs ± 480 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 388 µs ± 5.38 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
