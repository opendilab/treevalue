# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f335871ad30>
# ├── 'a' --> tensor([[ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403]])
# └── 'x' --> <FastTreeValue 0x7f335c7992e0>
#     └── 'c' --> tensor([[ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505]])

# %%
t.a
# Out:
# tensor([[ 0.6973,  0.4712, -1.2325],
#         [ 0.3257,  0.0572,  0.7403]])

# %%
# %timeit t.a
# Out:
# 72.3 ns ± 0.186 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f335871ad30>
# ├── 'a' --> tensor([[-0.3970, -1.3227,  0.0646],
# │                   [-0.3337,  1.3449,  1.1665]])
# └── 'x' --> <FastTreeValue 0x7f335c7992e0>
#     └── 'c' --> tensor([[ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505]])

# %%
# %timeit t.a = new_value
# Out:
# 78.7 ns ± 0.113 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403]]),
#     x: Batch(
#            c: tensor([[ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.6973,  0.4712, -1.2325],
#         [ 0.3257,  0.0572,  0.7403]])

# %%
# %timeit b.a
# Out:
# 64.5 ns ± 0.0669 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.0677,  0.0058, -1.2365],
#                [-0.1573, -0.2174, -1.2825]]),
#     x: Batch(
#            c: tensor([[ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 536 ns ± 0.118 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 894 ns ± 6.39 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 15.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 146 µs ± 1.23 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 771 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f327c019f10>
# ├── 'a' --> tensor([[[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]],
# │
# │                   [[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]],
# │
# │                   [[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]],
# │
# │                   [[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]],
# │
# │                   [[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]],
# │
# │                   [[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]],
# │
# │                   [[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]],
# │
# │                   [[ 0.6973,  0.4712, -1.2325],
# │                    [ 0.3257,  0.0572,  0.7403]]])
# └── 'x' --> <FastTreeValue 0x7f3289ef2fa0>
#     └── 'c' --> tensor([[[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                         [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                         [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                         [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                         [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                         [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                         [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                         [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                          [-0.7256,  1.7507, -1.0747, -0.0734],
#                          [-0.6802, -2.0995,  1.3586,  0.8505]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.4 µs ± 56.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f327c019ee0>
# ├── 'a' --> tensor([[ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403],
# │                   [ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403],
# │                   [ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403],
# │                   [ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403],
# │                   [ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403],
# │                   [ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403],
# │                   [ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403],
# │                   [ 0.6973,  0.4712, -1.2325],
# │                   [ 0.3257,  0.0572,  0.7403]])
# └── 'x' --> <FastTreeValue 0x7f327c019cd0>
#     └── 'c' --> tensor([[ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505],
#                         [ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505],
#                         [ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505],
#                         [ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505],
#                         [ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505],
#                         [ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505],
#                         [ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505],
#                         [ 0.0334,  1.4573,  0.2453, -0.3956],
#                         [-0.7256,  1.7507, -1.0747, -0.0734],
#                         [-0.6802, -2.0995,  1.3586,  0.8505]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.7 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68 µs ± 66.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]],
#
#                [[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]],
#
#                [[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]],
#
#                [[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]],
#
#                [[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]],
#
#                [[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]],
#
#                [[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]],
#
#                [[ 0.6973,  0.4712, -1.2325],
#                 [ 0.3257,  0.0572,  0.7403]]]),
#     x: Batch(
#            c: tensor([[[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                       [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                       [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                       [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                       [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                       [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                       [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]],
#
#                       [[ 0.0334,  1.4573,  0.2453, -0.3956],
#                        [-0.7256,  1.7507, -1.0747, -0.0734],
#                        [-0.6802, -2.0995,  1.3586,  0.8505]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.1 µs ± 206 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403],
#                [ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403],
#                [ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403],
#                [ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403],
#                [ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403],
#                [ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403],
#                [ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403],
#                [ 0.6973,  0.4712, -1.2325],
#                [ 0.3257,  0.0572,  0.7403]]),
#     x: Batch(
#            c: tensor([[ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505],
#                       [ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505],
#                       [ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505],
#                       [ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505],
#                       [ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505],
#                       [ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505],
#                       [ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505],
#                       [ 0.0334,  1.4573,  0.2453, -0.3956],
#                       [-0.7256,  1.7507, -1.0747, -0.0734],
#                       [-0.6802, -2.0995,  1.3586,  0.8505]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 554 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 350 µs ± 4.76 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
