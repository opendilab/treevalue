# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9640eaf550>
# ├── 'a' --> tensor([[-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539]])
# └── 'x' --> <FastTreeValue 0x7f9640eafee0>
#     └── 'c' --> tensor([[ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348]])

# %%
t.a
# Out:
# tensor([[-0.0755, -0.4396, -1.0937],
#         [ 0.8359,  0.4757, -1.8539]])

# %%
# %timeit t.a
# Out:
# 89 ns ± 0.119 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9640eaf550>
# ├── 'a' --> tensor([[ 0.3332,  0.9883, -1.8449],
# │                   [ 1.7334, -0.6453,  0.2635]])
# └── 'x' --> <FastTreeValue 0x7f9640eafee0>
#     └── 'c' --> tensor([[ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348]])

# %%
# %timeit t.a = new_value
# Out:
# 124 ns ± 0.272 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539]]),
#     x: Batch(
#            c: tensor([[ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.0755, -0.4396, -1.0937],
#         [ 0.8359,  0.4757, -1.8539]])

# %%
# %timeit b.a
# Out:
# 85.6 ns ± 0.153 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.1327, -1.6894,  0.2746],
#                [-0.4350, -0.3207,  1.0992]]),
#     x: Batch(
#            c: tensor([[ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 677 ns ± 9.09 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.06 µs ± 6.82 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.8 µs ± 27.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 191 µs ± 9.21 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 188 µs ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f95524cc5e0>
# ├── 'a' --> tensor([[[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]],
# │
# │                   [[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]],
# │
# │                   [[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]],
# │
# │                   [[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]],
# │
# │                   [[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]],
# │
# │                   [[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]],
# │
# │                   [[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]],
# │
# │                   [[-0.0755, -0.4396, -1.0937],
# │                    [ 0.8359,  0.4757, -1.8539]]])
# └── 'x' --> <FastTreeValue 0x7f95524cc460>
#     └── 'c' --> tensor([[[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                         [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                         [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                         [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                         [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                         [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                         [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                         [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                          [ 0.3108, -1.7223,  0.1992,  0.2214],
#                          [-0.1097, -0.5203, -1.9645,  1.2348]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40 µs ± 140 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9552532eb0>
# ├── 'a' --> tensor([[-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539],
# │                   [-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539],
# │                   [-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539],
# │                   [-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539],
# │                   [-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539],
# │                   [-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539],
# │                   [-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539],
# │                   [-0.0755, -0.4396, -1.0937],
# │                   [ 0.8359,  0.4757, -1.8539]])
# └── 'x' --> <FastTreeValue 0x7f9560cbbb80>
#     └── 'c' --> tensor([[ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348],
#                         [ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348],
#                         [ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348],
#                         [ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348],
#                         [ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348],
#                         [ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348],
#                         [ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348],
#                         [ 0.4082, -0.4410, -0.7892,  0.1079],
#                         [ 0.3108, -1.7223,  0.1992,  0.2214],
#                         [-0.1097, -0.5203, -1.9645,  1.2348]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.6 µs ± 211 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76 µs ± 117 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                       [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                       [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                       [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                       [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                       [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                       [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]],
#
#                       [[ 0.4082, -0.4410, -0.7892,  0.1079],
#                        [ 0.3108, -1.7223,  0.1992,  0.2214],
#                        [-0.1097, -0.5203, -1.9645,  1.2348]]]),
#        ),
#     a: tensor([[[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]],
#
#                [[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]],
#
#                [[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]],
#
#                [[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]],
#
#                [[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]],
#
#                [[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]],
#
#                [[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]],
#
#                [[-0.0755, -0.4396, -1.0937],
#                 [ 0.8359,  0.4757, -1.8539]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 99.6 µs ± 1.51 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348],
#                       [ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348],
#                       [ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348],
#                       [ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348],
#                       [ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348],
#                       [ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348],
#                       [ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348],
#                       [ 0.4082, -0.4410, -0.7892,  0.1079],
#                       [ 0.3108, -1.7223,  0.1992,  0.2214],
#                       [-0.1097, -0.5203, -1.9645,  1.2348]]),
#        ),
#     a: tensor([[-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539],
#                [-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539],
#                [-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539],
#                [-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539],
#                [-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539],
#                [-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539],
#                [-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539],
#                [-0.0755, -0.4396, -1.0937],
#                [ 0.8359,  0.4757, -1.8539]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 206 µs ± 5 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 471 µs ± 17.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
