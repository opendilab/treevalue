# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fe7aac13c10>
# ├── 'a' --> tensor([[-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489]])
# └── 'x' --> <FastTreeValue 0x7fe7aac13b80>
#     └── 'c' --> tensor([[-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485]])

# %%
t.a
# Out:
# tensor([[-0.5073, -1.0989, -0.8014],
#         [-0.7302, -0.5589,  0.4489]])

# %%
# %timeit t.a
# Out:
# 59.4 ns ± 0.0489 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fe7aac13c10>
# ├── 'a' --> tensor([[-0.5634,  0.8194,  1.0967],
# │                   [-1.1093,  0.0743, -0.7562]])
# └── 'x' --> <FastTreeValue 0x7fe7aac13b80>
#     └── 'c' --> tensor([[-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485]])

# %%
# %timeit t.a = new_value
# Out:
# 62.1 ns ± 0.0321 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489]]),
#     x: Batch(
#            c: tensor([[-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.5073, -1.0989, -0.8014],
#         [-0.7302, -0.5589,  0.4489]])

# %%
# %timeit b.a
# Out:
# 53.9 ns ± 0.104 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.3162,  0.3770,  0.4529],
#                [-1.7105,  0.2515, -0.5916]]),
#     x: Batch(
#            c: tensor([[-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 491 ns ± 0.226 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 850 ns ± 0.222 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.7 µs ± 41.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 137 µs ± 924 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 139 µs ± 446 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fe6e2ea5cd0>
# ├── 'a' --> tensor([[[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]],
# │
# │                   [[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]],
# │
# │                   [[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]],
# │
# │                   [[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]],
# │
# │                   [[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]],
# │
# │                   [[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]],
# │
# │                   [[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]],
# │
# │                   [[-0.5073, -1.0989, -0.8014],
# │                    [-0.7302, -0.5589,  0.4489]]])
# └── 'x' --> <FastTreeValue 0x7fe78416c460>
#     └── 'c' --> tensor([[[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                         [[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                         [[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                         [[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                         [[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                         [[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                         [[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                         [[-2.2146, -1.4381,  0.1359,  0.1692],
#                          [-1.0815, -0.9812,  0.4565,  1.2166],
#                          [-1.1077, -1.1897, -0.5812, -1.5485]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32 µs ± 17.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fe6ca3f3df0>
# ├── 'a' --> tensor([[-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489],
# │                   [-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489],
# │                   [-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489],
# │                   [-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489],
# │                   [-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489],
# │                   [-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489],
# │                   [-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489],
# │                   [-0.5073, -1.0989, -0.8014],
# │                   [-0.7302, -0.5589,  0.4489]])
# └── 'x' --> <FastTreeValue 0x7fe6e2e41fa0>
#     └── 'c' --> tensor([[-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485],
#                         [-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485],
#                         [-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485],
#                         [-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485],
#                         [-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485],
#                         [-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485],
#                         [-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485],
#                         [-2.2146, -1.4381,  0.1359,  0.1692],
#                         [-1.0815, -0.9812,  0.4565,  1.2166],
#                         [-1.1077, -1.1897, -0.5812, -1.5485]])

# %%
# %timeit t_cat(trees)
# Out:
# 29.7 µs ± 68.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.2 µs ± 44.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                       [[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                       [[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                       [[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                       [[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                       [[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                       [[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]],
#
#                       [[-2.2146, -1.4381,  0.1359,  0.1692],
#                        [-1.0815, -0.9812,  0.4565,  1.2166],
#                        [-1.1077, -1.1897, -0.5812, -1.5485]]]),
#        ),
#     a: tensor([[[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]],
#
#                [[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]],
#
#                [[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]],
#
#                [[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]],
#
#                [[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]],
#
#                [[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]],
#
#                [[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]],
#
#                [[-0.5073, -1.0989, -0.8014],
#                 [-0.7302, -0.5589,  0.4489]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 81.1 µs ± 196 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485],
#                       [-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485],
#                       [-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485],
#                       [-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485],
#                       [-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485],
#                       [-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485],
#                       [-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485],
#                       [-2.2146, -1.4381,  0.1359,  0.1692],
#                       [-1.0815, -0.9812,  0.4565,  1.2166],
#                       [-1.1077, -1.1897, -0.5812, -1.5485]]),
#        ),
#     a: tensor([[-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489],
#                [-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489],
#                [-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489],
#                [-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489],
#                [-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489],
#                [-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489],
#                [-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489],
#                [-0.5073, -1.0989, -0.8014],
#                [-0.7302, -0.5589,  0.4489]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 151 µs ± 742 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 324 µs ± 5.55 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
