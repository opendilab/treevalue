# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f062c964cd0>
# ├── 'a' --> tensor([[ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855]])
# └── 'x' --> <FastTreeValue 0x7f062c964910>
#     └── 'c' --> tensor([[ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329]])

# %%
t.a
# Out:
# tensor([[ 1.6975,  0.6199,  0.1697],
#         [-0.4004, -2.3131,  1.3855]])

# %%
# %timeit t.a
# Out:
# 75.7 ns ± 1.05 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f062c964cd0>
# ├── 'a' --> tensor([[ 0.9357,  1.7329, -0.0052],
# │                   [ 0.8376,  1.4258, -0.1918]])
# └── 'x' --> <FastTreeValue 0x7f062c964910>
#     └── 'c' --> tensor([[ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329]])

# %%
# %timeit t.a = new_value
# Out:
# 79.5 ns ± 1.09 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855]]),
#     x: Batch(
#            c: tensor([[ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.6975,  0.6199,  0.1697],
#         [-0.4004, -2.3131,  1.3855]])

# %%
# %timeit b.a
# Out:
# 69.6 ns ± 0.873 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.4374, -0.8280,  0.8035],
#                [ 1.0159, -0.7703,  0.5648]]),
#     x: Batch(
#            c: tensor([[ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 633 ns ± 13.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.83 µs ± 191 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.3 µs ± 233 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 302 µs ± 11.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 298 µs ± 14 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f0608404880>
# ├── 'a' --> tensor([[[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]],
# │
# │                   [[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]],
# │
# │                   [[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]],
# │
# │                   [[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]],
# │
# │                   [[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]],
# │
# │                   [[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]],
# │
# │                   [[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]],
# │
# │                   [[ 1.6975,  0.6199,  0.1697],
# │                    [-0.4004, -2.3131,  1.3855]]])
# └── 'x' --> <FastTreeValue 0x7f062c9648b0>
#     └── 'c' --> tensor([[[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                         [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                         [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                         [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                         [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                         [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                         [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                         [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                          [-0.9696, -0.5546,  0.9099,  1.2974],
#                          [ 1.2927, -0.2715,  2.0525, -0.7329]]])

# %%
# %timeit t_stack(trees)
# Out:
# 49.8 µs ± 1.25 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f053c003430>
# ├── 'a' --> tensor([[ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855],
# │                   [ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855],
# │                   [ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855],
# │                   [ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855],
# │                   [ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855],
# │                   [ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855],
# │                   [ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855],
# │                   [ 1.6975,  0.6199,  0.1697],
# │                   [-0.4004, -2.3131,  1.3855]])
# └── 'x' --> <FastTreeValue 0x7f053c003160>
#     └── 'c' --> tensor([[ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329],
#                         [ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329],
#                         [ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329],
#                         [ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329],
#                         [ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329],
#                         [ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329],
#                         [ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329],
#                         [ 1.6165, -1.3755, -0.2740,  0.9637],
#                         [-0.9696, -0.5546,  0.9099,  1.2974],
#                         [ 1.2927, -0.2715,  2.0525, -0.7329]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.8 µs ± 564 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 99.7 µs ± 1.19 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]],
#
#                [[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]],
#
#                [[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]],
#
#                [[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]],
#
#                [[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]],
#
#                [[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]],
#
#                [[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]],
#
#                [[ 1.6975,  0.6199,  0.1697],
#                 [-0.4004, -2.3131,  1.3855]]]),
#     x: Batch(
#            c: tensor([[[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                       [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                       [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                       [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                       [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                       [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                       [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]],
#
#                       [[ 1.6165, -1.3755, -0.2740,  0.9637],
#                        [-0.9696, -0.5546,  0.9099,  1.2974],
#                        [ 1.2927, -0.2715,  2.0525, -0.7329]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 113 µs ± 1.23 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855],
#                [ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855],
#                [ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855],
#                [ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855],
#                [ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855],
#                [ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855],
#                [ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855],
#                [ 1.6975,  0.6199,  0.1697],
#                [-0.4004, -2.3131,  1.3855]]),
#     x: Batch(
#            c: tensor([[ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329],
#                       [ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329],
#                       [ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329],
#                       [ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329],
#                       [ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329],
#                       [ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329],
#                       [ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329],
#                       [ 1.6165, -1.3755, -0.2740,  0.9637],
#                       [-0.9696, -0.5546,  0.9099,  1.2974],
#                       [ 1.2927, -0.2715,  2.0525, -0.7329]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 201 µs ± 3.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 710 µs ± 25.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
