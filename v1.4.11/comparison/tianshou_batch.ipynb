# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f7fb3c3b970>
# ├── 'a' --> tensor([[ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081]])
# └── 'x' --> <FastTreeValue 0x7f7fb3c3beb0>
#     └── 'c' --> tensor([[-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859]])

# %%
t.a
# Out:
# tensor([[ 0.1548,  0.3995, -0.1012],
#         [ 0.1734, -0.1087,  0.3081]])

# %%
# %timeit t.a
# Out:
# 60 ns ± 0.0662 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f7fb3c3b970>
# ├── 'a' --> tensor([[ 0.5464,  0.4177,  0.1307],
# │                   [ 2.6676, -0.3564,  1.3676]])
# └── 'x' --> <FastTreeValue 0x7f7fb3c3beb0>
#     └── 'c' --> tensor([[-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859]])

# %%
# %timeit t.a = new_value
# Out:
# 59.1 ns ± 0.0151 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081]]),
#     x: Batch(
#            c: tensor([[-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.1548,  0.3995, -0.1012],
#         [ 0.1734, -0.1087,  0.3081]])

# %%
# %timeit b.a
# Out:
# 54 ns ± 0.262 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.0156, -1.0689,  0.5433],
#                [ 0.4498,  1.7494,  1.2631]]),
#     x: Batch(
#            c: tensor([[-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 483 ns ± 0.142 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 851 ns ± 0.0936 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.5 µs ± 38.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 139 µs ± 747 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 786 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f7ee1338fd0>
# ├── 'a' --> tensor([[[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]],
# │
# │                   [[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]],
# │
# │                   [[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]],
# │
# │                   [[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]],
# │
# │                   [[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]],
# │
# │                   [[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]],
# │
# │                   [[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]],
# │
# │                   [[ 0.1548,  0.3995, -0.1012],
# │                    [ 0.1734, -0.1087,  0.3081]]])
# └── 'x' --> <FastTreeValue 0x7f7ed342a7c0>
#     └── 'c' --> tensor([[[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                         [[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                         [[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                         [[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                         [[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                         [[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                         [[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                         [[-0.9755,  1.9807,  0.8748,  0.4493],
#                          [ 0.2988,  0.9633, -0.3700,  0.6555],
#                          [-0.9643, -0.7303,  0.5187,  0.7859]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.8 µs ± 59.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f7ed342a850>
# ├── 'a' --> tensor([[ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081],
# │                   [ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081],
# │                   [ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081],
# │                   [ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081],
# │                   [ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081],
# │                   [ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081],
# │                   [ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081],
# │                   [ 0.1548,  0.3995, -0.1012],
# │                   [ 0.1734, -0.1087,  0.3081]])
# └── 'x' --> <FastTreeValue 0x7f7ed23cff40>
#     └── 'c' --> tensor([[-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859],
#                         [-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859],
#                         [-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859],
#                         [-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859],
#                         [-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859],
#                         [-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859],
#                         [-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859],
#                         [-0.9755,  1.9807,  0.8748,  0.4493],
#                         [ 0.2988,  0.9633, -0.3700,  0.6555],
#                         [-0.9643, -0.7303,  0.5187,  0.7859]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.6 µs ± 78.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.8 µs ± 66.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]],
#
#                [[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]],
#
#                [[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]],
#
#                [[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]],
#
#                [[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]],
#
#                [[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]],
#
#                [[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]],
#
#                [[ 0.1548,  0.3995, -0.1012],
#                 [ 0.1734, -0.1087,  0.3081]]]),
#     x: Batch(
#            c: tensor([[[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                       [[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                       [[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                       [[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                       [[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                       [[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                       [[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]],
#
#                       [[-0.9755,  1.9807,  0.8748,  0.4493],
#                        [ 0.2988,  0.9633, -0.3700,  0.6555],
#                        [-0.9643, -0.7303,  0.5187,  0.7859]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.7 µs ± 300 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081],
#                [ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081],
#                [ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081],
#                [ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081],
#                [ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081],
#                [ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081],
#                [ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081],
#                [ 0.1548,  0.3995, -0.1012],
#                [ 0.1734, -0.1087,  0.3081]]),
#     x: Batch(
#            c: tensor([[-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859],
#                       [-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859],
#                       [-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859],
#                       [-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859],
#                       [-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859],
#                       [-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859],
#                       [-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859],
#                       [-0.9755,  1.9807,  0.8748,  0.4493],
#                       [ 0.2988,  0.9633, -0.3700,  0.6555],
#                       [-0.9643, -0.7303,  0.5187,  0.7859]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 151 µs ± 334 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 334 µs ± 13 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
