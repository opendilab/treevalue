# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fcee810aeb0>
# ├── 'a' --> tensor([[ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743]])
# └── 'x' --> <FastTreeValue 0x7fcee810ad60>
#     └── 'c' --> tensor([[ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893]])

# %%
t.a
# Out:
# tensor([[ 1.9443,  1.7802, -0.0796],
#         [-0.8191, -0.0908, -0.9743]])

# %%
# %timeit t.a
# Out:
# 74.7 ns ± 0.0511 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fcee810aeb0>
# ├── 'a' --> tensor([[-0.7842,  1.9743,  0.0909],
# │                   [ 0.2083,  0.2050, -0.1499]])
# └── 'x' --> <FastTreeValue 0x7fcee810ad60>
#     └── 'c' --> tensor([[ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893]])

# %%
# %timeit t.a = new_value
# Out:
# 77.3 ns ± 0.0657 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743]]),
#     x: Batch(
#            c: tensor([[ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.9443,  1.7802, -0.0796],
#         [-0.8191, -0.0908, -0.9743]])

# %%
# %timeit b.a
# Out:
# 64.9 ns ± 0.108 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.5309, -0.2198, -0.5251],
#                [ 0.3280, -0.7300, -0.1559]]),
#     x: Batch(
#            c: tensor([[ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 543 ns ± 0.172 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 868 ns ± 0.693 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 37.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 146 µs ± 710 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 738 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fce17893d60>
# ├── 'a' --> tensor([[[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]],
# │
# │                   [[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]],
# │
# │                   [[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]],
# │
# │                   [[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]],
# │
# │                   [[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]],
# │
# │                   [[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]],
# │
# │                   [[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]],
# │
# │                   [[ 1.9443,  1.7802, -0.0796],
# │                    [-0.8191, -0.0908, -0.9743]]])
# └── 'x' --> <FastTreeValue 0x7fceea193a90>
#     └── 'c' --> tensor([[[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                         [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                         [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                         [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                         [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                         [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                         [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                         [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                          [ 0.4269,  1.4966, -1.3921,  1.7467],
#                          [ 0.8976, -0.3542, -0.7827, -1.3893]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 601 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fce17893eb0>
# ├── 'a' --> tensor([[ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743],
# │                   [ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743],
# │                   [ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743],
# │                   [ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743],
# │                   [ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743],
# │                   [ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743],
# │                   [ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743],
# │                   [ 1.9443,  1.7802, -0.0796],
# │                   [-0.8191, -0.0908, -0.9743]])
# └── 'x' --> <FastTreeValue 0x7fcee809d8b0>
#     └── 'c' --> tensor([[ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893],
#                         [ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893],
#                         [ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893],
#                         [ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893],
#                         [ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893],
#                         [ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893],
#                         [ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893],
#                         [ 0.4194,  0.5960,  0.2993, -1.3675],
#                         [ 0.4269,  1.4966, -1.3921,  1.7467],
#                         [ 0.8976, -0.3542, -0.7827, -1.3893]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.5 µs ± 56.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.1 µs ± 60 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                       [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                       [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                       [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                       [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                       [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                       [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]],
#
#                       [[ 0.4194,  0.5960,  0.2993, -1.3675],
#                        [ 0.4269,  1.4966, -1.3921,  1.7467],
#                        [ 0.8976, -0.3542, -0.7827, -1.3893]]]),
#        ),
#     a: tensor([[[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]],
#
#                [[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]],
#
#                [[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]],
#
#                [[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]],
#
#                [[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]],
#
#                [[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]],
#
#                [[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]],
#
#                [[ 1.9443,  1.7802, -0.0796],
#                 [-0.8191, -0.0908, -0.9743]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.5 µs ± 206 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893],
#                       [ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893],
#                       [ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893],
#                       [ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893],
#                       [ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893],
#                       [ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893],
#                       [ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893],
#                       [ 0.4194,  0.5960,  0.2993, -1.3675],
#                       [ 0.4269,  1.4966, -1.3921,  1.7467],
#                       [ 0.8976, -0.3542, -0.7827, -1.3893]]),
#        ),
#     a: tensor([[ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743],
#                [ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743],
#                [ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743],
#                [ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743],
#                [ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743],
#                [ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743],
#                [ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743],
#                [ 1.9443,  1.7802, -0.0796],
#                [-0.8191, -0.0908, -0.9743]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 223 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 347 µs ± 7.77 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
