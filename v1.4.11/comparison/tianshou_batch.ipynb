# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f3d20308df0>
# ├── 'a' --> tensor([[-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333]])
# └── 'x' --> <FastTreeValue 0x7f3d20308c70>
#     └── 'c' --> tensor([[ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113]])

# %%
t.a
# Out:
# tensor([[-0.2902,  1.0230, -1.4103],
#         [-0.6718, -0.2313,  0.3333]])

# %%
# %timeit t.a
# Out:
# 71.2 ns ± 0.0654 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f3d20308df0>
# ├── 'a' --> tensor([[-0.8603,  1.4949,  1.7349],
# │                   [-0.9699, -0.1600, -0.8846]])
# └── 'x' --> <FastTreeValue 0x7f3d20308c70>
#     └── 'c' --> tensor([[ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113]])

# %%
# %timeit t.a = new_value
# Out:
# 72.3 ns ± 0.112 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333]]),
#     x: Batch(
#            c: tensor([[ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2902,  1.0230, -1.4103],
#         [-0.6718, -0.2313,  0.3333]])

# %%
# %timeit b.a
# Out:
# 66.5 ns ± 0.093 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.3998, -0.3610,  1.5191],
#                [-0.0301,  1.1678, -0.1710]]),
#     x: Batch(
#            c: tensor([[ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 548 ns ± 7.18 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.11 µs ± 60.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 17.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 150 µs ± 1.26 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 151 µs ± 933 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f3d18142d90>
# ├── 'a' --> tensor([[[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]],
# │
# │                   [[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]],
# │
# │                   [[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]],
# │
# │                   [[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]],
# │
# │                   [[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]],
# │
# │                   [[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]],
# │
# │                   [[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]],
# │
# │                   [[-0.2902,  1.0230, -1.4103],
# │                    [-0.6718, -0.2313,  0.3333]]])
# └── 'x' --> <FastTreeValue 0x7f3d18142910>
#     └── 'c' --> tensor([[[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                         [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                         [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                         [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                         [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                         [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                         [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                         [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                          [-0.3957, -1.3752,  1.3042, -1.0254],
#                          [ 0.9955,  0.7514, -0.7870, -0.0113]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.6 µs ± 104 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f3c2f8cae80>
# ├── 'a' --> tensor([[-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333],
# │                   [-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333],
# │                   [-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333],
# │                   [-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333],
# │                   [-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333],
# │                   [-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333],
# │                   [-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333],
# │                   [-0.2902,  1.0230, -1.4103],
# │                   [-0.6718, -0.2313,  0.3333]])
# └── 'x' --> <FastTreeValue 0x7f3c2f8cae20>
#     └── 'c' --> tensor([[ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113],
#                         [ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113],
#                         [ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113],
#                         [ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113],
#                         [ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113],
#                         [ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113],
#                         [ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113],
#                         [ 1.6724,  0.0853,  0.8137,  0.1767],
#                         [-0.3957, -1.3752,  1.3042, -1.0254],
#                         [ 0.9955,  0.7514, -0.7870, -0.0113]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.5 µs ± 65 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.9 µs ± 97.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                       [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                       [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                       [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                       [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                       [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                       [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]],
#
#                       [[ 1.6724,  0.0853,  0.8137,  0.1767],
#                        [-0.3957, -1.3752,  1.3042, -1.0254],
#                        [ 0.9955,  0.7514, -0.7870, -0.0113]]]),
#        ),
#     a: tensor([[[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]],
#
#                [[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]],
#
#                [[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]],
#
#                [[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]],
#
#                [[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]],
#
#                [[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]],
#
#                [[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]],
#
#                [[-0.2902,  1.0230, -1.4103],
#                 [-0.6718, -0.2313,  0.3333]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.6 µs ± 97.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113],
#                       [ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113],
#                       [ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113],
#                       [ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113],
#                       [ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113],
#                       [ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113],
#                       [ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113],
#                       [ 1.6724,  0.0853,  0.8137,  0.1767],
#                       [-0.3957, -1.3752,  1.3042, -1.0254],
#                       [ 0.9955,  0.7514, -0.7870, -0.0113]]),
#        ),
#     a: tensor([[-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333],
#                [-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333],
#                [-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333],
#                [-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333],
#                [-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333],
#                [-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333],
#                [-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333],
#                [-0.2902,  1.0230, -1.4103],
#                [-0.6718, -0.2313,  0.3333]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 644 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 376 µs ± 5.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
