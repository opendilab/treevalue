# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fca60913e80>
# ├── 'a' --> tensor([[-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031]])
# └── 'x' --> <FastTreeValue 0x7fca5c87bdf0>
#     └── 'c' --> tensor([[ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018]])

# %%
t.a
# Out:
# tensor([[-1.3473,  0.5227,  0.2256],
#         [ 1.3356, -0.6625, -0.0031]])

# %%
# %timeit t.a
# Out:
# 83.5 ns ± 1.62 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fca60913e80>
# ├── 'a' --> tensor([[ 0.6439, -0.2325,  0.6591],
# │                   [ 0.7574,  0.1826,  0.4571]])
# └── 'x' --> <FastTreeValue 0x7fca5c87bdf0>
#     └── 'c' --> tensor([[ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018]])

# %%
# %timeit t.a = new_value
# Out:
# 88.3 ns ± 0.918 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031]]),
#     x: Batch(
#            c: tensor([[ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.3473,  0.5227,  0.2256],
#         [ 1.3356, -0.6625, -0.0031]])

# %%
# %timeit b.a
# Out:
# 74.7 ns ± 0.698 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.8842, -1.2744, -0.3244],
#                [-1.0508, -1.8523,  1.2913]]),
#     x: Batch(
#            c: tensor([[ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 630 ns ± 11.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.03 µs ± 7.51 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.3 µs ± 71.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 168 µs ± 769 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 172 µs ± 1.91 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc9800d8730>
# ├── 'a' --> tensor([[[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]],
# │
# │                   [[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]],
# │
# │                   [[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]],
# │
# │                   [[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]],
# │
# │                   [[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]],
# │
# │                   [[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]],
# │
# │                   [[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]],
# │
# │                   [[-1.3473,  0.5227,  0.2256],
# │                    [ 1.3356, -0.6625, -0.0031]]])
# └── 'x' --> <FastTreeValue 0x7fc9800d8c10>
#     └── 'c' --> tensor([[[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                         [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                         [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                         [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                         [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                         [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                         [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                         [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                          [ 2.5084, -0.5091, -1.3495,  0.0655],
#                          [-2.2577,  0.8985, -1.2597,  1.4018]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40.2 µs ± 331 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc9800d8d90>
# ├── 'a' --> tensor([[-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031],
# │                   [-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031],
# │                   [-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031],
# │                   [-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031],
# │                   [-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031],
# │                   [-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031],
# │                   [-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031],
# │                   [-1.3473,  0.5227,  0.2256],
# │                   [ 1.3356, -0.6625, -0.0031]])
# └── 'x' --> <FastTreeValue 0x7fc980148e20>
#     └── 'c' --> tensor([[ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018],
#                         [ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018],
#                         [ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018],
#                         [ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018],
#                         [ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018],
#                         [ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018],
#                         [ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018],
#                         [ 0.4232,  0.2431, -0.1906, -0.8429],
#                         [ 2.5084, -0.5091, -1.3495,  0.0655],
#                         [-2.2577,  0.8985, -1.2597,  1.4018]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.9 µs ± 200 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.1 µs ± 822 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]],
#
#                [[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]],
#
#                [[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]],
#
#                [[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]],
#
#                [[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]],
#
#                [[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]],
#
#                [[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]],
#
#                [[-1.3473,  0.5227,  0.2256],
#                 [ 1.3356, -0.6625, -0.0031]]]),
#     x: Batch(
#            c: tensor([[[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                       [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                       [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                       [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                       [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                       [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                       [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]],
#
#                       [[ 0.4232,  0.2431, -0.1906, -0.8429],
#                        [ 2.5084, -0.5091, -1.3495,  0.0655],
#                        [-2.2577,  0.8985, -1.2597,  1.4018]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 94.9 µs ± 1.29 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031],
#                [-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031],
#                [-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031],
#                [-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031],
#                [-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031],
#                [-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031],
#                [-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031],
#                [-1.3473,  0.5227,  0.2256],
#                [ 1.3356, -0.6625, -0.0031]]),
#     x: Batch(
#            c: tensor([[ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018],
#                       [ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018],
#                       [ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018],
#                       [ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018],
#                       [ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018],
#                       [ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018],
#                       [ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018],
#                       [ 0.4232,  0.2431, -0.1906, -0.8429],
#                       [ 2.5084, -0.5091, -1.3495,  0.0655],
#                       [-2.2577,  0.8985, -1.2597,  1.4018]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 170 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 390 µs ± 8.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
