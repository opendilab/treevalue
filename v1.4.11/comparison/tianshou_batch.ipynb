# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9026e53f70>
# ├── 'a' --> tensor([[-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012]])
# └── 'x' --> <FastTreeValue 0x7f9026e53c70>
#     └── 'c' --> tensor([[-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813]])

# %%
t.a
# Out:
# tensor([[-0.8983,  1.2968, -0.5388],
#         [-0.4750, -1.3317, -0.6012]])

# %%
# %timeit t.a
# Out:
# 86.2 ns ± 1.99 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9026e53f70>
# ├── 'a' --> tensor([[-1.0969, -0.8117,  0.4056],
# │                   [-1.7604, -2.1846,  0.1701]])
# └── 'x' --> <FastTreeValue 0x7f9026e53c70>
#     └── 'c' --> tensor([[-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813]])

# %%
# %timeit t.a = new_value
# Out:
# 80.5 ns ± 1.83 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012]]),
#     x: Batch(
#            c: tensor([[-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.8983,  1.2968, -0.5388],
#         [-0.4750, -1.3317, -0.6012]])

# %%
# %timeit b.a
# Out:
# 70.2 ns ± 0.909 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.2726,  0.3910, -1.2752],
#                [ 0.2487,  0.5495,  0.3545]]),
#     x: Batch(
#            c: tensor([[-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 647 ns ± 12.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.03 µs ± 26.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13 µs ± 159 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 269 µs ± 14.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 256 µs ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f8f46673d00>
# ├── 'a' --> tensor([[[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]],
# │
# │                   [[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]],
# │
# │                   [[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]],
# │
# │                   [[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]],
# │
# │                   [[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]],
# │
# │                   [[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]],
# │
# │                   [[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]],
# │
# │                   [[-0.8983,  1.2968, -0.5388],
# │                    [-0.4750, -1.3317, -0.6012]]])
# └── 'x' --> <FastTreeValue 0x7f8f46673f40>
#     └── 'c' --> tensor([[[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                         [[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                         [[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                         [[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                         [[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                         [[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                         [[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                         [[-0.3985, -0.6194,  1.3615, -0.2856],
#                          [-0.1964,  0.7922, -0.1684, -0.2313],
#                          [-1.4953,  0.6301,  0.7087, -1.0813]]])

# %%
# %timeit t_stack(trees)
# Out:
# 48.8 µs ± 594 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9024dc66d0>
# ├── 'a' --> tensor([[-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012],
# │                   [-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012],
# │                   [-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012],
# │                   [-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012],
# │                   [-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012],
# │                   [-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012],
# │                   [-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012],
# │                   [-0.8983,  1.2968, -0.5388],
# │                   [-0.4750, -1.3317, -0.6012]])
# └── 'x' --> <FastTreeValue 0x7f9024dc6520>
#     └── 'c' --> tensor([[-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813],
#                         [-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813],
#                         [-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813],
#                         [-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813],
#                         [-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813],
#                         [-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813],
#                         [-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813],
#                         [-0.3985, -0.6194,  1.3615, -0.2856],
#                         [-0.1964,  0.7922, -0.1684, -0.2313],
#                         [-1.4953,  0.6301,  0.7087, -1.0813]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.6 µs ± 1.11 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 94 µs ± 1.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                       [[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                       [[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                       [[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                       [[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                       [[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                       [[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]],
#
#                       [[-0.3985, -0.6194,  1.3615, -0.2856],
#                        [-0.1964,  0.7922, -0.1684, -0.2313],
#                        [-1.4953,  0.6301,  0.7087, -1.0813]]]),
#        ),
#     a: tensor([[[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]],
#
#                [[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]],
#
#                [[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]],
#
#                [[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]],
#
#                [[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]],
#
#                [[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]],
#
#                [[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]],
#
#                [[-0.8983,  1.2968, -0.5388],
#                 [-0.4750, -1.3317, -0.6012]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 108 µs ± 2.96 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813],
#                       [-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813],
#                       [-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813],
#                       [-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813],
#                       [-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813],
#                       [-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813],
#                       [-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813],
#                       [-0.3985, -0.6194,  1.3615, -0.2856],
#                       [-0.1964,  0.7922, -0.1684, -0.2313],
#                       [-1.4953,  0.6301,  0.7087, -1.0813]]),
#        ),
#     a: tensor([[-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012],
#                [-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012],
#                [-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012],
#                [-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012],
#                [-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012],
#                [-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012],
#                [-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012],
#                [-0.8983,  1.2968, -0.5388],
#                [-0.4750, -1.3317, -0.6012]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 194 µs ± 8.13 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 616 µs ± 28.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
