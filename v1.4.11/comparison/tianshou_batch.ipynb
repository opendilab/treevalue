# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f834c2fc1c0>
# ├── 'a' --> tensor([[ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411]])
# └── 'x' --> <FastTreeValue 0x7f834c2fc190>
#     └── 'c' --> tensor([[-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818]])

# %%
t.a
# Out:
# tensor([[ 0.6074, -0.0954, -0.0355],
#         [-0.8305,  0.3161,  0.5411]])

# %%
# %timeit t.a
# Out:
# 72 ns ± 0.0533 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f834c2fc1c0>
# ├── 'a' --> tensor([[-0.4756,  0.4856, -1.1483],
# │                   [-0.2845,  1.6225,  0.8750]])
# └── 'x' --> <FastTreeValue 0x7f834c2fc190>
#     └── 'c' --> tensor([[-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818]])

# %%
# %timeit t.a = new_value
# Out:
# 76.7 ns ± 0.0523 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411]]),
#     x: Batch(
#            c: tensor([[-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.6074, -0.0954, -0.0355],
#         [-0.8305,  0.3161,  0.5411]])

# %%
# %timeit b.a
# Out:
# 64.5 ns ± 0.162 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.4176, -0.0840, -2.0796],
#                [ 1.1679,  0.0814, -0.4291]]),
#     x: Batch(
#            c: tensor([[-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 538 ns ± 0.108 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 876 ns ± 6.25 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 41.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 843 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 931 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f826eb548b0>
# ├── 'a' --> tensor([[[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]],
# │
# │                   [[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]],
# │
# │                   [[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]],
# │
# │                   [[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]],
# │
# │                   [[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]],
# │
# │                   [[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]],
# │
# │                   [[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]],
# │
# │                   [[ 0.6074, -0.0954, -0.0355],
# │                    [-0.8305,  0.3161,  0.5411]]])
# └── 'x' --> <FastTreeValue 0x7f826eb54580>
#     └── 'c' --> tensor([[[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                         [[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                         [[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                         [[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                         [[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                         [[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                         [[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                         [[-1.4203,  1.0498, -1.9123,  1.0350],
#                          [-1.4240,  0.3639,  1.0898, -0.5938],
#                          [-2.2943,  0.4062,  0.3100, -1.2818]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.4 µs ± 77.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f826eb54b50>
# ├── 'a' --> tensor([[ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411],
# │                   [ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411],
# │                   [ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411],
# │                   [ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411],
# │                   [ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411],
# │                   [ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411],
# │                   [ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411],
# │                   [ 0.6074, -0.0954, -0.0355],
# │                   [-0.8305,  0.3161,  0.5411]])
# └── 'x' --> <FastTreeValue 0x7f826eb54700>
#     └── 'c' --> tensor([[-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818],
#                         [-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818],
#                         [-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818],
#                         [-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818],
#                         [-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818],
#                         [-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818],
#                         [-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818],
#                         [-1.4203,  1.0498, -1.9123,  1.0350],
#                         [-1.4240,  0.3639,  1.0898, -0.5938],
#                         [-2.2943,  0.4062,  0.3100, -1.2818]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.9 µs ± 76.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.3 µs ± 60 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]],
#
#                [[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]],
#
#                [[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]],
#
#                [[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]],
#
#                [[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]],
#
#                [[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]],
#
#                [[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]],
#
#                [[ 0.6074, -0.0954, -0.0355],
#                 [-0.8305,  0.3161,  0.5411]]]),
#     x: Batch(
#            c: tensor([[[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                       [[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                       [[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                       [[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                       [[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                       [[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                       [[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]],
#
#                       [[-1.4203,  1.0498, -1.9123,  1.0350],
#                        [-1.4240,  0.3639,  1.0898, -0.5938],
#                        [-2.2943,  0.4062,  0.3100, -1.2818]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.9 µs ± 521 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411],
#                [ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411],
#                [ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411],
#                [ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411],
#                [ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411],
#                [ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411],
#                [ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411],
#                [ 0.6074, -0.0954, -0.0355],
#                [-0.8305,  0.3161,  0.5411]]),
#     x: Batch(
#            c: tensor([[-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818],
#                       [-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818],
#                       [-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818],
#                       [-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818],
#                       [-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818],
#                       [-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818],
#                       [-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818],
#                       [-1.4203,  1.0498, -1.9123,  1.0350],
#                       [-1.4240,  0.3639,  1.0898, -0.5938],
#                       [-2.2943,  0.4062,  0.3100, -1.2818]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 371 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 348 µs ± 6.35 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
