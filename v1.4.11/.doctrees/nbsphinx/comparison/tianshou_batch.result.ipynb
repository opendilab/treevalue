# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f2ae7b92c70>
# ├── 'a' --> tensor([[ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580]])
# └── 'x' --> <FastTreeValue 0x7f2ae7b17610>
#     └── 'c' --> tensor([[ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541]])

# %%
t.a
# Out:
# tensor([[ 1.9341,  0.0216, -0.2810],
#         [-1.1783, -0.2332,  0.7580]])

# %%
# %timeit t.a
# Out:
# 76.8 ns ± 0.0902 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f2ae7b92c70>
# ├── 'a' --> tensor([[-0.6142, -0.2010,  0.2336],
# │                   [-0.7256, -1.0697,  1.3368]])
# └── 'x' --> <FastTreeValue 0x7f2ae7b17610>
#     └── 'c' --> tensor([[ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541]])

# %%
# %timeit t.a = new_value
# Out:
# 85.2 ns ± 0.0273 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580]]),
#     x: Batch(
#            c: tensor([[ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.9341,  0.0216, -0.2810],
#         [-1.1783, -0.2332,  0.7580]])

# %%
# %timeit b.a
# Out:
# 64.4 ns ± 0.143 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.9237, -1.9785,  0.2253],
#                [ 0.9189,  0.8782,  0.1902]]),
#     x: Batch(
#            c: tensor([[ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 539 ns ± 0.122 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 870 ns ± 1.05 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 59.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 655 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 148 µs ± 854 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f2a1fe0bf40>
# ├── 'a' --> tensor([[[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]],
# │
# │                   [[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]],
# │
# │                   [[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]],
# │
# │                   [[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]],
# │
# │                   [[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]],
# │
# │                   [[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]],
# │
# │                   [[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]],
# │
# │                   [[ 1.9341,  0.0216, -0.2810],
# │                    [-1.1783, -0.2332,  0.7580]]])
# └── 'x' --> <FastTreeValue 0x7f2ae4afc520>
#     └── 'c' --> tensor([[[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                         [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                         [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                         [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                         [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                         [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                         [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                         [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                          [ 0.4263,  1.3220, -0.7781,  0.3240],
#                          [-0.4045,  0.0979,  0.1629,  0.9541]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.3 µs ± 119 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f2a0737ed60>
# ├── 'a' --> tensor([[ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580],
# │                   [ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580],
# │                   [ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580],
# │                   [ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580],
# │                   [ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580],
# │                   [ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580],
# │                   [ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580],
# │                   [ 1.9341,  0.0216, -0.2810],
# │                   [-1.1783, -0.2332,  0.7580]])
# └── 'x' --> <FastTreeValue 0x7f2a1528b5e0>
#     └── 'c' --> tensor([[ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541],
#                         [ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541],
#                         [ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541],
#                         [ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541],
#                         [ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541],
#                         [ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541],
#                         [ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541],
#                         [ 0.3537,  1.6901,  0.9406, -1.5621],
#                         [ 0.4263,  1.3220, -0.7781,  0.3240],
#                         [-0.4045,  0.0979,  0.1629,  0.9541]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.1 µs ± 44.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.1 µs ± 66.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                       [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                       [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                       [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                       [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                       [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                       [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]],
#
#                       [[ 0.3537,  1.6901,  0.9406, -1.5621],
#                        [ 0.4263,  1.3220, -0.7781,  0.3240],
#                        [-0.4045,  0.0979,  0.1629,  0.9541]]]),
#        ),
#     a: tensor([[[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]],
#
#                [[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]],
#
#                [[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]],
#
#                [[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]],
#
#                [[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]],
#
#                [[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]],
#
#                [[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]],
#
#                [[ 1.9341,  0.0216, -0.2810],
#                 [-1.1783, -0.2332,  0.7580]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.9 µs ± 572 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541],
#                       [ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541],
#                       [ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541],
#                       [ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541],
#                       [ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541],
#                       [ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541],
#                       [ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541],
#                       [ 0.3537,  1.6901,  0.9406, -1.5621],
#                       [ 0.4263,  1.3220, -0.7781,  0.3240],
#                       [-0.4045,  0.0979,  0.1629,  0.9541]]),
#        ),
#     a: tensor([[ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580],
#                [ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580],
#                [ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580],
#                [ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580],
#                [ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580],
#                [ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580],
#                [ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580],
#                [ 1.9341,  0.0216, -0.2810],
#                [-1.1783, -0.2332,  0.7580]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 1.95 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 361 µs ± 6.71 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
