# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f75146baa60>
# ├── 'a' --> tensor([[ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840]])
# └── 'x' --> <FastTreeValue 0x7f75146c0640>
#     └── 'c' --> tensor([[-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270]])

# %%
t.a
# Out:
# tensor([[ 0.3338, -0.8056,  0.1283],
#         [ 0.5683, -0.6126, -0.4840]])

# %%
# %timeit t.a
# Out:
# 91.7 ns ± 0.485 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f75146baa60>
# ├── 'a' --> tensor([[ 1.0073,  0.5078, -1.0277],
# │                   [-1.4599, -1.6192,  0.3854]])
# └── 'x' --> <FastTreeValue 0x7f75146c0640>
#     └── 'c' --> tensor([[-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270]])

# %%
# %timeit t.a = new_value
# Out:
# 95.6 ns ± 1.08 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840]]),
#     x: Batch(
#            c: tensor([[-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.3338, -0.8056,  0.1283],
#         [ 0.5683, -0.6126, -0.4840]])

# %%
# %timeit b.a
# Out:
# 77.1 ns ± 0.17 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.1347, -0.7617,  1.3634],
#                [-0.5281, -0.2270, -0.2559]]),
#     x: Batch(
#            c: tensor([[-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 647 ns ± 5.27 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.04 µs ± 7.78 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.2 µs ± 182 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 165 µs ± 1.09 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 166 µs ± 2.47 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f7437f16dc0>
# ├── 'a' --> tensor([[[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]],
# │
# │                   [[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]],
# │
# │                   [[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]],
# │
# │                   [[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]],
# │
# │                   [[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]],
# │
# │                   [[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]],
# │
# │                   [[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]],
# │
# │                   [[ 0.3338, -0.8056,  0.1283],
# │                    [ 0.5683, -0.6126, -0.4840]]])
# └── 'x' --> <FastTreeValue 0x7f7437f16e20>
#     └── 'c' --> tensor([[[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                         [[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                         [[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                         [[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                         [[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                         [[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                         [[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                         [[-0.0847, -1.4123,  0.9874,  0.3653],
#                          [-1.6388, -0.6762,  1.7158,  0.7512],
#                          [-0.3127,  1.6198,  0.8973, -0.5270]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39 µs ± 220 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f7437f165b0>
# ├── 'a' --> tensor([[ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840],
# │                   [ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840],
# │                   [ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840],
# │                   [ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840],
# │                   [ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840],
# │                   [ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840],
# │                   [ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840],
# │                   [ 0.3338, -0.8056,  0.1283],
# │                   [ 0.5683, -0.6126, -0.4840]])
# └── 'x' --> <FastTreeValue 0x7f7437f16b20>
#     └── 'c' --> tensor([[-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270],
#                         [-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270],
#                         [-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270],
#                         [-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270],
#                         [-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270],
#                         [-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270],
#                         [-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270],
#                         [-0.0847, -1.4123,  0.9874,  0.3653],
#                         [-1.6388, -0.6762,  1.7158,  0.7512],
#                         [-0.3127,  1.6198,  0.8973, -0.5270]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.5 µs ± 182 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.7 µs ± 704 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]],
#
#                [[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]],
#
#                [[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]],
#
#                [[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]],
#
#                [[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]],
#
#                [[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]],
#
#                [[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]],
#
#                [[ 0.3338, -0.8056,  0.1283],
#                 [ 0.5683, -0.6126, -0.4840]]]),
#     x: Batch(
#            c: tensor([[[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                       [[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                       [[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                       [[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                       [[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                       [[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                       [[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]],
#
#                       [[-0.0847, -1.4123,  0.9874,  0.3653],
#                        [-1.6388, -0.6762,  1.7158,  0.7512],
#                        [-0.3127,  1.6198,  0.8973, -0.5270]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 97.1 µs ± 574 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840],
#                [ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840],
#                [ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840],
#                [ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840],
#                [ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840],
#                [ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840],
#                [ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840],
#                [ 0.3338, -0.8056,  0.1283],
#                [ 0.5683, -0.6126, -0.4840]]),
#     x: Batch(
#            c: tensor([[-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270],
#                       [-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270],
#                       [-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270],
#                       [-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270],
#                       [-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270],
#                       [-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270],
#                       [-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270],
#                       [-0.0847, -1.4123,  0.9874,  0.3653],
#                       [-1.6388, -0.6762,  1.7158,  0.7512],
#                       [-0.3127,  1.6198,  0.8973, -0.5270]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 713 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 420 µs ± 7.41 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
