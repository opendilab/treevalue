# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f23d01de9d0>
# ├── 'a' --> tensor([[ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029]])
# └── 'x' --> <FastTreeValue 0x7f23d01deb80>
#     └── 'c' --> tensor([[-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100]])

# %%
t.a
# Out:
# tensor([[ 0.8360, -0.5661, -0.8863],
#         [ 0.8542, -0.4269,  0.4029]])

# %%
# %timeit t.a
# Out:
# 80.3 ns ± 0.0511 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f23d01de9d0>
# ├── 'a' --> tensor([[-2.2939, -0.5133, -1.5335],
# │                   [ 2.7822, -1.4813,  1.6519]])
# └── 'x' --> <FastTreeValue 0x7f23d01deb80>
#     └── 'c' --> tensor([[-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100]])

# %%
# %timeit t.a = new_value
# Out:
# 83.9 ns ± 0.0844 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029]]),
#     x: Batch(
#            c: tensor([[-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8360, -0.5661, -0.8863],
#         [ 0.8542, -0.4269,  0.4029]])

# %%
# %timeit b.a
# Out:
# 66.5 ns ± 0.107 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.9169,  0.4251, -0.3642],
#                [-0.3259,  1.8397,  0.4612]]),
#     x: Batch(
#            c: tensor([[-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 542 ns ± 0.882 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 885 ns ± 0.66 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11 µs ± 25.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 1.95 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 153 µs ± 6.64 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f22df847fd0>
# ├── 'a' --> tensor([[[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]],
# │
# │                   [[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]],
# │
# │                   [[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]],
# │
# │                   [[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]],
# │
# │                   [[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]],
# │
# │                   [[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]],
# │
# │                   [[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]],
# │
# │                   [[ 0.8360, -0.5661, -0.8863],
# │                    [ 0.8542, -0.4269,  0.4029]]])
# └── 'x' --> <FastTreeValue 0x7f22df847790>
#     └── 'c' --> tensor([[[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                         [[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                         [[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                         [[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                         [[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                         [[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                         [[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                         [[-0.6455,  0.6271, -0.5613, -0.4665],
#                          [ 0.1783, -0.2042,  0.9114, -0.2242],
#                          [-1.3634, -1.1156,  0.0761, -0.2100]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.1 µs ± 136 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f22df847ee0>
# ├── 'a' --> tensor([[ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029],
# │                   [ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029],
# │                   [ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029],
# │                   [ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029],
# │                   [ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029],
# │                   [ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029],
# │                   [ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029],
# │                   [ 0.8360, -0.5661, -0.8863],
# │                   [ 0.8542, -0.4269,  0.4029]])
# └── 'x' --> <FastTreeValue 0x7f22df847cd0>
#     └── 'c' --> tensor([[-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100],
#                         [-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100],
#                         [-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100],
#                         [-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100],
#                         [-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100],
#                         [-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100],
#                         [-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100],
#                         [-0.6455,  0.6271, -0.5613, -0.4665],
#                         [ 0.1783, -0.2042,  0.9114, -0.2242],
#                         [-1.3634, -1.1156,  0.0761, -0.2100]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.6 µs ± 84.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.3 µs ± 116 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]],
#
#                [[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]],
#
#                [[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]],
#
#                [[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]],
#
#                [[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]],
#
#                [[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]],
#
#                [[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]],
#
#                [[ 0.8360, -0.5661, -0.8863],
#                 [ 0.8542, -0.4269,  0.4029]]]),
#     x: Batch(
#            c: tensor([[[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                       [[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                       [[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                       [[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                       [[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                       [[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                       [[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]],
#
#                       [[-0.6455,  0.6271, -0.5613, -0.4665],
#                        [ 0.1783, -0.2042,  0.9114, -0.2242],
#                        [-1.3634, -1.1156,  0.0761, -0.2100]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.6 µs ± 234 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029],
#                [ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029],
#                [ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029],
#                [ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029],
#                [ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029],
#                [ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029],
#                [ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029],
#                [ 0.8360, -0.5661, -0.8863],
#                [ 0.8542, -0.4269,  0.4029]]),
#     x: Batch(
#            c: tensor([[-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100],
#                       [-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100],
#                       [-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100],
#                       [-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100],
#                       [-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100],
#                       [-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100],
#                       [-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100],
#                       [-0.6455,  0.6271, -0.5613, -0.4665],
#                       [ 0.1783, -0.2042,  0.9114, -0.2242],
#                       [-1.3634, -1.1156,  0.0761, -0.2100]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 615 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 383 µs ± 11.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
