# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fe2684f2850>
# ├── 'a' --> tensor([[-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150]])
# └── 'x' --> <FastTreeValue 0x7fe2684d7b20>
#     └── 'c' --> tensor([[-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671]])

# %%
t.a
# Out:
# tensor([[-0.7295,  0.0858,  0.6173],
#         [ 0.7528,  1.4364,  1.1150]])

# %%
# %timeit t.a
# Out:
# 63.6 ns ± 0.0563 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fe2684f2850>
# ├── 'a' --> tensor([[ 1.1771, -0.2486,  0.9453],
# │                   [-0.3870,  0.4321,  1.3020]])
# └── 'x' --> <FastTreeValue 0x7fe2684d7b20>
#     └── 'c' --> tensor([[-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671]])

# %%
# %timeit t.a = new_value
# Out:
# 66.2 ns ± 0.0829 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150]]),
#     x: Batch(
#            c: tensor([[-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7295,  0.0858,  0.6173],
#         [ 0.7528,  1.4364,  1.1150]])

# %%
# %timeit b.a
# Out:
# 57.9 ns ± 0.0569 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0928,  0.8882, -1.6376],
#                [-0.7473, -0.5996, -0.8077]]),
#     x: Batch(
#            c: tensor([[-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 498 ns ± 0.61 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 828 ns ± 1.59 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 17.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 408 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 349 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fe26b57b4c0>
# ├── 'a' --> tensor([[[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]],
# │
# │                   [[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]],
# │
# │                   [[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]],
# │
# │                   [[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]],
# │
# │                   [[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]],
# │
# │                   [[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]],
# │
# │                   [[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]],
# │
# │                   [[-0.7295,  0.0858,  0.6173],
# │                    [ 0.7528,  1.4364,  1.1150]]])
# └── 'x' --> <FastTreeValue 0x7fe26b57b640>
#     └── 'c' --> tensor([[[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                         [[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                         [[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                         [[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                         [[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                         [[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                         [[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                         [[-0.4621,  1.2627, -0.2302, -0.2564],
#                          [ 2.2813, -1.3560, -0.0349,  0.3819],
#                          [ 0.5339, -1.5875,  0.0447,  0.6671]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 56.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fe2684e72b0>
# ├── 'a' --> tensor([[-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150],
# │                   [-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150],
# │                   [-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150],
# │                   [-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150],
# │                   [-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150],
# │                   [-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150],
# │                   [-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150],
# │                   [-0.7295,  0.0858,  0.6173],
# │                   [ 0.7528,  1.4364,  1.1150]])
# └── 'x' --> <FastTreeValue 0x7fe18b31b370>
#     └── 'c' --> tensor([[-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671],
#                         [-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671],
#                         [-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671],
#                         [-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671],
#                         [-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671],
#                         [-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671],
#                         [-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671],
#                         [-0.4621,  1.2627, -0.2302, -0.2564],
#                         [ 2.2813, -1.3560, -0.0349,  0.3819],
#                         [ 0.5339, -1.5875,  0.0447,  0.6671]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.4 µs ± 120 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.8 µs ± 160 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]],
#
#                [[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]],
#
#                [[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]],
#
#                [[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]],
#
#                [[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]],
#
#                [[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]],
#
#                [[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]],
#
#                [[-0.7295,  0.0858,  0.6173],
#                 [ 0.7528,  1.4364,  1.1150]]]),
#     x: Batch(
#            c: tensor([[[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                       [[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                       [[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                       [[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                       [[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                       [[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                       [[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]],
#
#                       [[-0.4621,  1.2627, -0.2302, -0.2564],
#                        [ 2.2813, -1.3560, -0.0349,  0.3819],
#                        [ 0.5339, -1.5875,  0.0447,  0.6671]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.4 µs ± 175 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150],
#                [-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150],
#                [-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150],
#                [-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150],
#                [-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150],
#                [-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150],
#                [-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150],
#                [-0.7295,  0.0858,  0.6173],
#                [ 0.7528,  1.4364,  1.1150]]),
#     x: Batch(
#            c: tensor([[-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671],
#                       [-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671],
#                       [-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671],
#                       [-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671],
#                       [-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671],
#                       [-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671],
#                       [-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671],
#                       [-0.4621,  1.2627, -0.2302, -0.2564],
#                       [ 2.2813, -1.3560, -0.0349,  0.3819],
#                       [ 0.5339, -1.5875,  0.0447,  0.6671]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 395 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 338 µs ± 1.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
