# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fd33032e760>
# ├── 'a' --> tensor([[-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681]])
# └── 'x' --> <FastTreeValue 0x7fd33032ed30>
#     └── 'c' --> tensor([[-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686]])

# %%
t.a
# Out:
# tensor([[-0.7406, -0.0918,  0.6092],
#         [-0.3348, -1.7574, -0.0681]])

# %%
# %timeit t.a
# Out:
# 88.8 ns ± 0.0787 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fd33032e760>
# ├── 'a' --> tensor([[ 1.7035,  0.3154, -0.6155],
# │                   [ 0.3794, -2.1430, -0.2829]])
# └── 'x' --> <FastTreeValue 0x7fd33032ed30>
#     └── 'c' --> tensor([[-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686]])

# %%
# %timeit t.a = new_value
# Out:
# 93.1 ns ± 0.258 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681]]),
#     x: Batch(
#            c: tensor([[-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7406, -0.0918,  0.6092],
#         [-0.3348, -1.7574, -0.0681]])

# %%
# %timeit b.a
# Out:
# 79 ns ± 0.0499 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.5540, -1.0987, -0.6495],
#                [ 1.0316,  0.4298, -0.6832]]),
#     x: Batch(
#            c: tensor([[-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 655 ns ± 1.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.05 µs ± 0.207 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.7 µs ± 112 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 175 µs ± 1.57 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 175 µs ± 1.74 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fd330317df0>
# ├── 'a' --> tensor([[[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]],
# │
# │                   [[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]],
# │
# │                   [[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]],
# │
# │                   [[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]],
# │
# │                   [[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]],
# │
# │                   [[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]],
# │
# │                   [[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]],
# │
# │                   [[-0.7406, -0.0918,  0.6092],
# │                    [-0.3348, -1.7574, -0.0681]]])
# └── 'x' --> <FastTreeValue 0x7fd24c2816d0>
#     └── 'c' --> tensor([[[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                         [[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                         [[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                         [[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                         [[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                         [[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                         [[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                         [[-0.8512, -0.4557,  0.8848,  0.3590],
#                          [-0.5797, -0.5089, -0.4830, -0.1878],
#                          [ 0.8764,  1.1452,  0.1165,  0.4686]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40.8 µs ± 107 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fd24c281340>
# ├── 'a' --> tensor([[-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681],
# │                   [-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681],
# │                   [-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681],
# │                   [-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681],
# │                   [-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681],
# │                   [-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681],
# │                   [-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681],
# │                   [-0.7406, -0.0918,  0.6092],
# │                   [-0.3348, -1.7574, -0.0681]])
# └── 'x' --> <FastTreeValue 0x7fd24c2e8f10>
#     └── 'c' --> tensor([[-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686],
#                         [-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686],
#                         [-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686],
#                         [-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686],
#                         [-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686],
#                         [-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686],
#                         [-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686],
#                         [-0.8512, -0.4557,  0.8848,  0.3590],
#                         [-0.5797, -0.5089, -0.4830, -0.1878],
#                         [ 0.8764,  1.1452,  0.1165,  0.4686]])

# %%
# %timeit t_cat(trees)
# Out:
# 39.1 µs ± 437 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.6 µs ± 293 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]],
#
#                [[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]],
#
#                [[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]],
#
#                [[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]],
#
#                [[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]],
#
#                [[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]],
#
#                [[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]],
#
#                [[-0.7406, -0.0918,  0.6092],
#                 [-0.3348, -1.7574, -0.0681]]]),
#     x: Batch(
#            c: tensor([[[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                       [[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                       [[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                       [[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                       [[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                       [[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                       [[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]],
#
#                       [[-0.8512, -0.4557,  0.8848,  0.3590],
#                        [-0.5797, -0.5089, -0.4830, -0.1878],
#                        [ 0.8764,  1.1452,  0.1165,  0.4686]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 138 µs ± 709 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681],
#                [-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681],
#                [-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681],
#                [-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681],
#                [-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681],
#                [-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681],
#                [-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681],
#                [-0.7406, -0.0918,  0.6092],
#                [-0.3348, -1.7574, -0.0681]]),
#     x: Batch(
#            c: tensor([[-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686],
#                       [-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686],
#                       [-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686],
#                       [-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686],
#                       [-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686],
#                       [-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686],
#                       [-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686],
#                       [-0.8512, -0.4557,  0.8848,  0.3590],
#                       [-0.5797, -0.5089, -0.4830, -0.1878],
#                       [ 0.8764,  1.1452,  0.1165,  0.4686]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 183 µs ± 4 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 447 µs ± 8.71 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
