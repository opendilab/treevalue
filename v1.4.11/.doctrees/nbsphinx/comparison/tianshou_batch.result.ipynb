# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9db7597160>
# ├── 'a' --> tensor([[ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038]])
# └── 'x' --> <FastTreeValue 0x7f9db75970a0>
#     └── 'c' --> tensor([[ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036]])

# %%
t.a
# Out:
# tensor([[ 0.4597, -1.8913,  1.2844],
#         [-0.0992, -0.1325,  1.0038]])

# %%
# %timeit t.a
# Out:
# 81.9 ns ± 0.832 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9db7597160>
# ├── 'a' --> tensor([[ 0.2929,  0.3660,  1.2555],
# │                   [ 0.4558, -1.5711, -1.6294]])
# └── 'x' --> <FastTreeValue 0x7f9db75970a0>
#     └── 'c' --> tensor([[ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036]])

# %%
# %timeit t.a = new_value
# Out:
# 82.9 ns ± 0.614 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038]]),
#     x: Batch(
#            c: tensor([[ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.4597, -1.8913,  1.2844],
#         [-0.0992, -0.1325,  1.0038]])

# %%
# %timeit b.a
# Out:
# 79.1 ns ± 0.747 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.1355,  0.4451,  1.8467],
#                [ 0.2874, -1.6495,  2.1917]]),
#     x: Batch(
#            c: tensor([[ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 665 ns ± 6.12 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.08 µs ± 17.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 14 µs ± 145 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 276 µs ± 13.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 280 µs ± 14.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f9ce4d267f0>
# ├── 'a' --> tensor([[[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]],
# │
# │                   [[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]],
# │
# │                   [[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]],
# │
# │                   [[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]],
# │
# │                   [[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]],
# │
# │                   [[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]],
# │
# │                   [[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]],
# │
# │                   [[ 0.4597, -1.8913,  1.2844],
# │                    [-0.0992, -0.1325,  1.0038]]])
# └── 'x' --> <FastTreeValue 0x7f9ce4d26d00>
#     └── 'c' --> tensor([[[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                         [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                         [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                         [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                         [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                         [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                         [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                         [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                          [ 0.3160,  0.3521,  0.0807,  0.7827],
#                          [-2.1529,  0.3167,  0.5835,  0.1036]]])

# %%
# %timeit t_stack(trees)
# Out:
# 49.7 µs ± 997 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9db75fabe0>
# ├── 'a' --> tensor([[ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038],
# │                   [ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038],
# │                   [ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038],
# │                   [ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038],
# │                   [ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038],
# │                   [ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038],
# │                   [ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038],
# │                   [ 0.4597, -1.8913,  1.2844],
# │                   [-0.0992, -0.1325,  1.0038]])
# └── 'x' --> <FastTreeValue 0x7f9cd71c7b20>
#     └── 'c' --> tensor([[ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036],
#                         [ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036],
#                         [ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036],
#                         [ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036],
#                         [ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036],
#                         [ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036],
#                         [ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036],
#                         [ 0.3676,  1.5595,  1.8056,  0.7761],
#                         [ 0.3160,  0.3521,  0.0807,  0.7827],
#                         [-2.1529,  0.3167,  0.5835,  0.1036]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.9 µs ± 2.27 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 107 µs ± 4.86 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]],
#
#                [[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]],
#
#                [[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]],
#
#                [[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]],
#
#                [[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]],
#
#                [[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]],
#
#                [[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]],
#
#                [[ 0.4597, -1.8913,  1.2844],
#                 [-0.0992, -0.1325,  1.0038]]]),
#     x: Batch(
#            c: tensor([[[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                       [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                       [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                       [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                       [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                       [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                       [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]],
#
#                       [[ 0.3676,  1.5595,  1.8056,  0.7761],
#                        [ 0.3160,  0.3521,  0.0807,  0.7827],
#                        [-2.1529,  0.3167,  0.5835,  0.1036]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 117 µs ± 4.48 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038],
#                [ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038],
#                [ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038],
#                [ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038],
#                [ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038],
#                [ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038],
#                [ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038],
#                [ 0.4597, -1.8913,  1.2844],
#                [-0.0992, -0.1325,  1.0038]]),
#     x: Batch(
#            c: tensor([[ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036],
#                       [ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036],
#                       [ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036],
#                       [ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036],
#                       [ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036],
#                       [ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036],
#                       [ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036],
#                       [ 0.3676,  1.5595,  1.8056,  0.7761],
#                       [ 0.3160,  0.3521,  0.0807,  0.7827],
#                       [-2.1529,  0.3167,  0.5835,  0.1036]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 205 µs ± 8.01 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 695 µs ± 42.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
