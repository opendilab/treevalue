# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fe2518048e0>
# ├── 'a' --> tensor([[ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180]])
# └── 'x' --> <FastTreeValue 0x7fe24701cbe0>
#     └── 'c' --> tensor([[ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814]])

# %%
t.a
# Out:
# tensor([[ 0.6480,  0.2867,  0.7589],
#         [ 1.0755,  0.2601, -0.3180]])

# %%
# %timeit t.a
# Out:
# 70.9 ns ± 0.0924 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fe2518048e0>
# ├── 'a' --> tensor([[-0.2565,  1.1143, -0.0102],
# │                   [ 2.6236, -1.1752, -1.1262]])
# └── 'x' --> <FastTreeValue 0x7fe24701cbe0>
#     └── 'c' --> tensor([[ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814]])

# %%
# %timeit t.a = new_value
# Out:
# 75.5 ns ± 0.106 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180]]),
#     x: Batch(
#            c: tensor([[ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.6480,  0.2867,  0.7589],
#         [ 1.0755,  0.2601, -0.3180]])

# %%
# %timeit b.a
# Out:
# 66.3 ns ± 0.122 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.5244, -0.2904,  1.6781],
#                [-0.1739,  0.0664, -0.7906]]),
#     x: Batch(
#            c: tensor([[ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 540 ns ± 1.02 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.17 µs ± 49.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11 µs ± 25.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 150 µs ± 2.25 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 149 µs ± 957 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fe32819ef70>
# ├── 'a' --> tensor([[[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]],
# │
# │                   [[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]],
# │
# │                   [[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]],
# │
# │                   [[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]],
# │
# │                   [[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]],
# │
# │                   [[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]],
# │
# │                   [[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]],
# │
# │                   [[ 0.6480,  0.2867,  0.7589],
# │                    [ 1.0755,  0.2601, -0.3180]]])
# └── 'x' --> <FastTreeValue 0x7fe32819ea00>
#     └── 'c' --> tensor([[[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                         [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                         [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                         [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                         [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                         [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                         [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                         [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                          [-0.3705,  0.7008,  1.3706,  1.9400],
#                          [ 0.7475, -2.3823,  1.7930, -0.6814]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 37.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fe3281a4370>
# ├── 'a' --> tensor([[ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180],
# │                   [ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180],
# │                   [ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180],
# │                   [ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180],
# │                   [ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180],
# │                   [ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180],
# │                   [ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180],
# │                   [ 0.6480,  0.2867,  0.7589],
# │                   [ 1.0755,  0.2601, -0.3180]])
# └── 'x' --> <FastTreeValue 0x7fe3281a4250>
#     └── 'c' --> tensor([[ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814],
#                         [ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814],
#                         [ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814],
#                         [ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814],
#                         [ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814],
#                         [ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814],
#                         [ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814],
#                         [ 2.8241, -0.7268,  0.5924,  0.1750],
#                         [-0.3705,  0.7008,  1.3706,  1.9400],
#                         [ 0.7475, -2.3823,  1.7930, -0.6814]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 69.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.4 µs ± 189 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                       [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                       [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                       [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                       [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                       [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                       [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]],
#
#                       [[ 2.8241, -0.7268,  0.5924,  0.1750],
#                        [-0.3705,  0.7008,  1.3706,  1.9400],
#                        [ 0.7475, -2.3823,  1.7930, -0.6814]]]),
#        ),
#     a: tensor([[[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]],
#
#                [[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]],
#
#                [[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]],
#
#                [[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]],
#
#                [[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]],
#
#                [[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]],
#
#                [[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]],
#
#                [[ 0.6480,  0.2867,  0.7589],
#                 [ 1.0755,  0.2601, -0.3180]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.8 µs ± 115 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814],
#                       [ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814],
#                       [ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814],
#                       [ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814],
#                       [ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814],
#                       [ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814],
#                       [ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814],
#                       [ 2.8241, -0.7268,  0.5924,  0.1750],
#                       [-0.3705,  0.7008,  1.3706,  1.9400],
#                       [ 0.7475, -2.3823,  1.7930, -0.6814]]),
#        ),
#     a: tensor([[ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180],
#                [ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180],
#                [ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180],
#                [ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180],
#                [ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180],
#                [ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180],
#                [ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180],
#                [ 0.6480,  0.2867,  0.7589],
#                [ 1.0755,  0.2601, -0.3180]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 568 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 382 µs ± 6.85 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
