# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f1712c3a2e0>
# ├── 'a' --> tensor([[ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730]])
# └── 'x' --> <FastTreeValue 0x7f1712c3afd0>
#     └── 'c' --> tensor([[-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690]])

# %%
t.a
# Out:
# tensor([[ 0.1729,  0.4353, -0.7749],
#         [ 1.3990, -0.5528,  0.5730]])

# %%
# %timeit t.a
# Out:
# 81.4 ns ± 0.0631 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f1712c3a2e0>
# ├── 'a' --> tensor([[-1.1065, -1.1155, -0.2095],
# │                   [ 0.1934, -1.3089,  1.6962]])
# └── 'x' --> <FastTreeValue 0x7f1712c3afd0>
#     └── 'c' --> tensor([[-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690]])

# %%
# %timeit t.a = new_value
# Out:
# 77.2 ns ± 0.243 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730]]),
#     x: Batch(
#            c: tensor([[-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.1729,  0.4353, -0.7749],
#         [ 1.3990, -0.5528,  0.5730]])

# %%
# %timeit b.a
# Out:
# 68 ns ± 0.123 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 2.3594, -0.3685,  0.2110],
#                [-1.1421, -0.8398,  0.9380]]),
#     x: Batch(
#            c: tensor([[-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 542 ns ± 0.247 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 928 ns ± 0.48 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 18.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 1.09 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 1.2 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f1632448c40>
# ├── 'a' --> tensor([[[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]],
# │
# │                   [[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]],
# │
# │                   [[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]],
# │
# │                   [[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]],
# │
# │                   [[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]],
# │
# │                   [[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]],
# │
# │                   [[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]],
# │
# │                   [[ 0.1729,  0.4353, -0.7749],
# │                    [ 1.3990, -0.5528,  0.5730]]])
# └── 'x' --> <FastTreeValue 0x7f1632448550>
#     └── 'c' --> tensor([[[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                         [[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                         [[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                         [[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                         [[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                         [[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                         [[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                         [[-0.1570,  0.6470, -0.4550, -0.4735],
#                          [ 1.4410, -0.6961,  1.1408, -0.2953],
#                          [-0.5242, -0.2678,  0.8594,  0.5690]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.2 µs ± 122 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f1632448ca0>
# ├── 'a' --> tensor([[ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730],
# │                   [ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730],
# │                   [ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730],
# │                   [ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730],
# │                   [ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730],
# │                   [ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730],
# │                   [ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730],
# │                   [ 0.1729,  0.4353, -0.7749],
# │                   [ 1.3990, -0.5528,  0.5730]])
# └── 'x' --> <FastTreeValue 0x7f1632448760>
#     └── 'c' --> tensor([[-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690],
#                         [-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690],
#                         [-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690],
#                         [-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690],
#                         [-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690],
#                         [-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690],
#                         [-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690],
#                         [-0.1570,  0.6470, -0.4550, -0.4735],
#                         [ 1.4410, -0.6961,  1.1408, -0.2953],
#                         [-0.5242, -0.2678,  0.8594,  0.5690]])

# %%
# %timeit t_cat(trees)
# Out:
# 31 µs ± 122 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.7 µs ± 65.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                       [[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                       [[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                       [[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                       [[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                       [[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                       [[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]],
#
#                       [[-0.1570,  0.6470, -0.4550, -0.4735],
#                        [ 1.4410, -0.6961,  1.1408, -0.2953],
#                        [-0.5242, -0.2678,  0.8594,  0.5690]]]),
#        ),
#     a: tensor([[[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]],
#
#                [[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]],
#
#                [[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]],
#
#                [[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]],
#
#                [[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]],
#
#                [[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]],
#
#                [[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]],
#
#                [[ 0.1729,  0.4353, -0.7749],
#                 [ 1.3990, -0.5528,  0.5730]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.7 µs ± 310 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690],
#                       [-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690],
#                       [-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690],
#                       [-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690],
#                       [-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690],
#                       [-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690],
#                       [-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690],
#                       [-0.1570,  0.6470, -0.4550, -0.4735],
#                       [ 1.4410, -0.6961,  1.1408, -0.2953],
#                       [-0.5242, -0.2678,  0.8594,  0.5690]]),
#        ),
#     a: tensor([[ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730],
#                [ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730],
#                [ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730],
#                [ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730],
#                [ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730],
#                [ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730],
#                [ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730],
#                [ 0.1729,  0.4353, -0.7749],
#                [ 1.3990, -0.5528,  0.5730]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 230 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 356 µs ± 10.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
