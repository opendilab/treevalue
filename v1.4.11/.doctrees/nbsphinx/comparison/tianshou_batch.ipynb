# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f06b653ae80>
# ├── 'a' --> tensor([[ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604]])
# └── 'x' --> <FastTreeValue 0x7f06c0ba3d90>
#     └── 'c' --> tensor([[-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685]])

# %%
t.a
# Out:
# tensor([[ 1.2872,  0.0766, -0.5873],
#         [ 1.6863, -0.4751,  0.2604]])

# %%
# %timeit t.a
# Out:
# 72.3 ns ± 0.029 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f06b653ae80>
# ├── 'a' --> tensor([[-0.4434,  1.4770, -0.8558],
# │                   [-0.3411,  0.0121, -0.9548]])
# └── 'x' --> <FastTreeValue 0x7f06c0ba3d90>
#     └── 'c' --> tensor([[-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685]])

# %%
# %timeit t.a = new_value
# Out:
# 64.4 ns ± 0.0463 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604]]),
#     x: Batch(
#            c: tensor([[-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.2872,  0.0766, -0.5873],
#         [ 1.6863, -0.4751,  0.2604]])

# %%
# %timeit b.a
# Out:
# 56.4 ns ± 0.132 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.2859,  0.6469,  0.5124],
#                [-0.3898,  1.2663,  0.5575]]),
#     x: Batch(
#            c: tensor([[-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 491 ns ± 0.115 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.74 µs ± 103 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 59.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 429 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 649 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f06a7d442e0>
# ├── 'a' --> tensor([[[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]],
# │
# │                   [[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]],
# │
# │                   [[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]],
# │
# │                   [[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]],
# │
# │                   [[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]],
# │
# │                   [[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]],
# │
# │                   [[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]],
# │
# │                   [[ 1.2872,  0.0766, -0.5873],
# │                    [ 1.6863, -0.4751,  0.2604]]])
# └── 'x' --> <FastTreeValue 0x7f06a7d44340>
#     └── 'c' --> tensor([[[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                         [[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                         [[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                         [[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                         [[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                         [[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                         [[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                         [[-0.2374,  0.6364,  0.4966, -0.1740],
#                          [-2.5466,  1.9171,  0.8585,  0.5708],
#                          [ 1.7927, -0.1525,  0.1949,  1.3685]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.3 µs ± 132 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f06a7d446d0>
# ├── 'a' --> tensor([[ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604],
# │                   [ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604],
# │                   [ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604],
# │                   [ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604],
# │                   [ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604],
# │                   [ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604],
# │                   [ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604],
# │                   [ 1.2872,  0.0766, -0.5873],
# │                   [ 1.6863, -0.4751,  0.2604]])
# └── 'x' --> <FastTreeValue 0x7f06a7d44b50>
#     └── 'c' --> tensor([[-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685],
#                         [-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685],
#                         [-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685],
#                         [-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685],
#                         [-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685],
#                         [-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685],
#                         [-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685],
#                         [-0.2374,  0.6364,  0.4966, -0.1740],
#                         [-2.5466,  1.9171,  0.8585,  0.5708],
#                         [ 1.7927, -0.1525,  0.1949,  1.3685]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.1 µs ± 102 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69.9 µs ± 342 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                       [[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                       [[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                       [[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                       [[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                       [[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                       [[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]],
#
#                       [[-0.2374,  0.6364,  0.4966, -0.1740],
#                        [-2.5466,  1.9171,  0.8585,  0.5708],
#                        [ 1.7927, -0.1525,  0.1949,  1.3685]]]),
#        ),
#     a: tensor([[[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]],
#
#                [[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]],
#
#                [[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]],
#
#                [[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]],
#
#                [[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]],
#
#                [[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]],
#
#                [[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]],
#
#                [[ 1.2872,  0.0766, -0.5873],
#                 [ 1.6863, -0.4751,  0.2604]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.6 µs ± 139 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685],
#                       [-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685],
#                       [-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685],
#                       [-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685],
#                       [-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685],
#                       [-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685],
#                       [-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685],
#                       [-0.2374,  0.6364,  0.4966, -0.1740],
#                       [-2.5466,  1.9171,  0.8585,  0.5708],
#                       [ 1.7927, -0.1525,  0.1949,  1.3685]]),
#        ),
#     a: tensor([[ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604],
#                [ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604],
#                [ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604],
#                [ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604],
#                [ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604],
#                [ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604],
#                [ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604],
#                [ 1.2872,  0.0766, -0.5873],
#                [ 1.6863, -0.4751,  0.2604]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 151 µs ± 512 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 360 µs ± 4.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
