# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f40ecaf7b20>
# ├── 'a' --> tensor([[-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018]])
# └── 'x' --> <FastTreeValue 0x7f40ecaf7af0>
#     └── 'c' --> tensor([[ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008]])

# %%
t.a
# Out:
# tensor([[-0.1845,  0.6124, -1.2290],
#         [-0.0842, -0.9023, -0.2018]])

# %%
# %timeit t.a
# Out:
# 63.5 ns ± 0.0784 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f40ecaf7b20>
# ├── 'a' --> tensor([[-0.9662, -0.5058,  0.3967],
# │                   [-1.6880, -0.6910,  0.8214]])
# └── 'x' --> <FastTreeValue 0x7f40ecaf7af0>
#     └── 'c' --> tensor([[ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008]])

# %%
# %timeit t.a = new_value
# Out:
# 67.4 ns ± 0.0517 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018]]),
#     x: Batch(
#            c: tensor([[ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.1845,  0.6124, -1.2290],
#         [-0.0842, -0.9023, -0.2018]])

# %%
# %timeit b.a
# Out:
# 58.2 ns ± 0.0562 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.1599, -0.0753,  0.5819],
#                [-1.2152, -1.5053,  0.7747]]),
#     x: Batch(
#            c: tensor([[ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 489 ns ± 0.0819 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 803 ns ± 0.0611 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 18.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 1.57 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 965 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f4026e71fd0>
# ├── 'a' --> tensor([[[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]],
# │
# │                   [[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]],
# │
# │                   [[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]],
# │
# │                   [[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]],
# │
# │                   [[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]],
# │
# │                   [[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]],
# │
# │                   [[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]],
# │
# │                   [[-0.1845,  0.6124, -1.2290],
# │                    [-0.0842, -0.9023, -0.2018]]])
# └── 'x' --> <FastTreeValue 0x7f400e877a30>
#     └── 'c' --> tensor([[[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                         [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                         [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                         [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                         [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                         [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                         [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                         [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                          [ 1.1383,  0.9718, -1.2163, -0.5486],
#                          [-0.8100, -1.9993, -1.7049,  0.6008]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.7 µs ± 57.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f401c73fca0>
# ├── 'a' --> tensor([[-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018],
# │                   [-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018],
# │                   [-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018],
# │                   [-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018],
# │                   [-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018],
# │                   [-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018],
# │                   [-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018],
# │                   [-0.1845,  0.6124, -1.2290],
# │                   [-0.0842, -0.9023, -0.2018]])
# └── 'x' --> <FastTreeValue 0x7f401c73f700>
#     └── 'c' --> tensor([[ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008],
#                         [ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008],
#                         [ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008],
#                         [ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008],
#                         [ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008],
#                         [ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008],
#                         [ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008],
#                         [ 0.3422,  0.8952,  0.2246, -1.8704],
#                         [ 1.1383,  0.9718, -1.2163, -0.5486],
#                         [-0.8100, -1.9993, -1.7049,  0.6008]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.7 µs ± 85.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.7 µs ± 56.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                       [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                       [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                       [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                       [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                       [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                       [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]],
#
#                       [[ 0.3422,  0.8952,  0.2246, -1.8704],
#                        [ 1.1383,  0.9718, -1.2163, -0.5486],
#                        [-0.8100, -1.9993, -1.7049,  0.6008]]]),
#        ),
#     a: tensor([[[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]],
#
#                [[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]],
#
#                [[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]],
#
#                [[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]],
#
#                [[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]],
#
#                [[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]],
#
#                [[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]],
#
#                [[-0.1845,  0.6124, -1.2290],
#                 [-0.0842, -0.9023, -0.2018]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 77.8 µs ± 146 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008],
#                       [ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008],
#                       [ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008],
#                       [ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008],
#                       [ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008],
#                       [ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008],
#                       [ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008],
#                       [ 0.3422,  0.8952,  0.2246, -1.8704],
#                       [ 1.1383,  0.9718, -1.2163, -0.5486],
#                       [-0.8100, -1.9993, -1.7049,  0.6008]]),
#        ),
#     a: tensor([[-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018],
#                [-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018],
#                [-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018],
#                [-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018],
#                [-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018],
#                [-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018],
#                [-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018],
#                [-0.1845,  0.6124, -1.2290],
#                [-0.0842, -0.9023, -0.2018]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 146 µs ± 235 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 349 µs ± 3.62 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
