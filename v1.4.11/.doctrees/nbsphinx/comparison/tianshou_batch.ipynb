# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f4ee03c45e0>
# ├── 'a' --> tensor([[-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170]])
# └── 'x' --> <FastTreeValue 0x7f4ee03c4430>
#     └── 'c' --> tensor([[-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600]])

# %%
t.a
# Out:
# tensor([[-0.2315, -1.7141,  0.9290],
#         [-1.7733, -0.8543, -1.1170]])

# %%
# %timeit t.a
# Out:
# 72 ns ± 0.0575 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f4ee03c45e0>
# ├── 'a' --> tensor([[ 0.9053, -1.7710, -0.5826],
# │                   [-0.4153,  0.1152, -1.7694]])
# └── 'x' --> <FastTreeValue 0x7f4ee03c4430>
#     └── 'c' --> tensor([[-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600]])

# %%
# %timeit t.a = new_value
# Out:
# 72.6 ns ± 0.271 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170]]),
#     x: Batch(
#            c: tensor([[-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2315, -1.7141,  0.9290],
#         [-1.7733, -0.8543, -1.1170]])

# %%
# %timeit b.a
# Out:
# 64.5 ns ± 0.197 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.6636, -0.1593, -0.6833],
#                [-1.3697,  2.4799, -0.4031]]),
#     x: Batch(
#            c: tensor([[-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 546 ns ± 0.534 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 863 ns ± 0.181 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 31.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 732 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 746 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f4ee035be80>
# ├── 'a' --> tensor([[[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]],
# │
# │                   [[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]],
# │
# │                   [[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]],
# │
# │                   [[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]],
# │
# │                   [[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]],
# │
# │                   [[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]],
# │
# │                   [[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]],
# │
# │                   [[-0.2315, -1.7141,  0.9290],
# │                    [-1.7733, -0.8543, -1.1170]]])
# └── 'x' --> <FastTreeValue 0x7f4ee03c4670>
#     └── 'c' --> tensor([[[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                         [[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                         [[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                         [[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                         [[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                         [[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                         [[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                         [[-1.0982, -0.3342,  0.4704,  0.9425],
#                          [ 0.6309,  0.6510,  0.2208, -1.2020],
#                          [ 1.4439,  0.4009, -1.1932, -1.1600]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 56.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f4e02c81d90>
# ├── 'a' --> tensor([[-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170],
# │                   [-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170],
# │                   [-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170],
# │                   [-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170],
# │                   [-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170],
# │                   [-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170],
# │                   [-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170],
# │                   [-0.2315, -1.7141,  0.9290],
# │                   [-1.7733, -0.8543, -1.1170]])
# └── 'x' --> <FastTreeValue 0x7f4e02c81b20>
#     └── 'c' --> tensor([[-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600],
#                         [-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600],
#                         [-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600],
#                         [-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600],
#                         [-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600],
#                         [-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600],
#                         [-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600],
#                         [-1.0982, -0.3342,  0.4704,  0.9425],
#                         [ 0.6309,  0.6510,  0.2208, -1.2020],
#                         [ 1.4439,  0.4009, -1.1932, -1.1600]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 37.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.5 µs ± 70.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                       [[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                       [[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                       [[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                       [[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                       [[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                       [[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]],
#
#                       [[-1.0982, -0.3342,  0.4704,  0.9425],
#                        [ 0.6309,  0.6510,  0.2208, -1.2020],
#                        [ 1.4439,  0.4009, -1.1932, -1.1600]]]),
#        ),
#     a: tensor([[[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]],
#
#                [[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]],
#
#                [[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]],
#
#                [[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]],
#
#                [[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]],
#
#                [[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]],
#
#                [[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]],
#
#                [[-0.2315, -1.7141,  0.9290],
#                 [-1.7733, -0.8543, -1.1170]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.9 µs ± 169 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600],
#                       [-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600],
#                       [-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600],
#                       [-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600],
#                       [-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600],
#                       [-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600],
#                       [-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600],
#                       [-1.0982, -0.3342,  0.4704,  0.9425],
#                       [ 0.6309,  0.6510,  0.2208, -1.2020],
#                       [ 1.4439,  0.4009, -1.1932, -1.1600]]),
#        ),
#     a: tensor([[-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170],
#                [-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170],
#                [-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170],
#                [-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170],
#                [-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170],
#                [-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170],
#                [-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170],
#                [-0.2315, -1.7141,  0.9290],
#                [-1.7733, -0.8543, -1.1170]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 153 µs ± 122 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 350 µs ± 6.41 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
