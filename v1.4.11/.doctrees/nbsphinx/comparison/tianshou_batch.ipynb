# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)
# Out:
# /home/runner/work/treevalue/treevalue/treevalue/tree/integration/torch.py:23: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   register_for_torch(TreeValue)
# /home/runner/work/treevalue/treevalue/treevalue/tree/integration/torch.py:24: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   register_for_torch(FastTreeValue)

# %%
t
# Out:
# <FastTreeValue 0x7fdad8d8da30>
# ├── 'a' --> tensor([[-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547]])
# └── 'x' --> <FastTreeValue 0x7fdad8d8dac0>
#     └── 'c' --> tensor([[ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122]])

# %%
t.a
# Out:
# tensor([[-0.7591,  0.4417,  0.3128],
#         [-0.6850,  1.2767,  0.7547]])

# %%
# %timeit t.a
# Out:
# 47.1 ns ± 0.565 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fdad8d8da30>
# ├── 'a' --> tensor([[ 0.4243, -0.4714,  1.8125],
# │                   [ 0.6216,  1.0652, -0.1832]])
# └── 'x' --> <FastTreeValue 0x7fdad8d8dac0>
#     └── 'c' --> tensor([[ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122]])

# %%
# %timeit t.a = new_value
# Out:
# 49.3 ns ± 0.0942 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547]]),
#     x: Batch(
#            c: tensor([[ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7591,  0.4417,  0.3128],
#         [-0.6850,  1.2767,  0.7547]])

# %%
# %timeit b.a
# Out:
# 41.3 ns ± 0.136 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.8735,  0.6284,  0.3326],
#                [ 0.0997,  0.4222, -1.0756]]),
#     x: Batch(
#            c: tensor([[ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 370 ns ± 0.748 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 6.66 µs ± 86.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 8.41 µs ± 34 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 129 µs ± 518 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 127 µs ± 179 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fd9e518bac0>
# ├── 'a' --> tensor([[[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]],
# │
# │                   [[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]],
# │
# │                   [[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]],
# │
# │                   [[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]],
# │
# │                   [[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]],
# │
# │                   [[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]],
# │
# │                   [[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]],
# │
# │                   [[-0.7591,  0.4417,  0.3128],
# │                    [-0.6850,  1.2767,  0.7547]]])
# └── 'x' --> <FastTreeValue 0x7fd9e518bb50>
#     └── 'c' --> tensor([[[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                         [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                         [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                         [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                         [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                         [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                         [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                         [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                          [-0.7838,  1.0896, -0.1878, -0.0109],
#                          [-1.4905,  0.4139, -1.5012,  1.2122]]])

# %%
# %timeit t_stack(trees)
# Out:
# 24 µs ± 294 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fd9e518b460>
# ├── 'a' --> tensor([[-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547],
# │                   [-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547],
# │                   [-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547],
# │                   [-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547],
# │                   [-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547],
# │                   [-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547],
# │                   [-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547],
# │                   [-0.7591,  0.4417,  0.3128],
# │                   [-0.6850,  1.2767,  0.7547]])
# └── 'x' --> <FastTreeValue 0x7fd9e518b7f0>
#     └── 'c' --> tensor([[ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122],
#                         [ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122],
#                         [ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122],
#                         [ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122],
#                         [ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122],
#                         [ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122],
#                         [ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122],
#                         [ 0.8963, -0.5537, -1.3833, -1.3042],
#                         [-0.7838,  1.0896, -0.1878, -0.0109],
#                         [-1.4905,  0.4139, -1.5012,  1.2122]])

# %%
# %timeit t_cat(trees)
# Out:
# 22.2 µs ± 208 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 51.3 µs ± 204 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]],
#
#                [[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]],
#
#                [[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]],
#
#                [[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]],
#
#                [[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]],
#
#                [[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]],
#
#                [[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]],
#
#                [[-0.7591,  0.4417,  0.3128],
#                 [-0.6850,  1.2767,  0.7547]]]),
#     x: Batch(
#            c: tensor([[[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                       [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                       [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                       [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                       [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                       [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                       [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]],
#
#                       [[ 0.8963, -0.5537, -1.3833, -1.3042],
#                        [-0.7838,  1.0896, -0.1878, -0.0109],
#                        [-1.4905,  0.4139, -1.5012,  1.2122]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 62.8 µs ± 372 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547],
#                [-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547],
#                [-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547],
#                [-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547],
#                [-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547],
#                [-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547],
#                [-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547],
#                [-0.7591,  0.4417,  0.3128],
#                [-0.6850,  1.2767,  0.7547]]),
#     x: Batch(
#            c: tensor([[ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122],
#                       [ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122],
#                       [ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122],
#                       [ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122],
#                       [ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122],
#                       [ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122],
#                       [ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122],
#                       [ 0.8963, -0.5537, -1.3833, -1.3042],
#                       [-0.7838,  1.0896, -0.1878, -0.0109],
#                       [-1.4905,  0.4139, -1.5012,  1.2122]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 119 µs ± 822 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 291 µs ± 10.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
