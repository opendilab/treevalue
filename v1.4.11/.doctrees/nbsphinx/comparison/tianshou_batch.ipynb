# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f6ac8257cd0>
# ├── 'a' --> tensor([[-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134]])
# └── 'x' --> <FastTreeValue 0x7f6ac8257910>
#     └── 'c' --> tensor([[ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406]])

# %%
t.a
# Out:
# tensor([[-0.2760, -0.1368,  0.3276],
#         [ 1.2058, -0.3772, -0.9134]])

# %%
# %timeit t.a
# Out:
# 86 ns ± 0.888 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f6ac8257cd0>
# ├── 'a' --> tensor([[ 0.1223,  1.0002,  0.5378],
# │                   [-0.2191, -0.3524, -1.9007]])
# └── 'x' --> <FastTreeValue 0x7f6ac8257910>
#     └── 'c' --> tensor([[ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406]])

# %%
# %timeit t.a = new_value
# Out:
# 91.3 ns ± 0.47 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134]]),
#     x: Batch(
#            c: tensor([[ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2760, -0.1368,  0.3276],
#         [ 1.2058, -0.3772, -0.9134]])

# %%
# %timeit b.a
# Out:
# 73.7 ns ± 1.26 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.0824, -0.2280, -0.1339],
#                [-1.3566,  2.4732, -1.1220]]),
#     x: Batch(
#            c: tensor([[ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 609 ns ± 7.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.02 µs ± 12.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.9 µs ± 143 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 162 µs ± 1.77 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 163 µs ± 2.14 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f69ebb3bf10>
# ├── 'a' --> tensor([[[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]],
# │
# │                   [[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]],
# │
# │                   [[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]],
# │
# │                   [[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]],
# │
# │                   [[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]],
# │
# │                   [[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]],
# │
# │                   [[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]],
# │
# │                   [[-0.2760, -0.1368,  0.3276],
# │                    [ 1.2058, -0.3772, -0.9134]]])
# └── 'x' --> <FastTreeValue 0x7f69ebb3beb0>
#     └── 'c' --> tensor([[[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                         [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                         [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                         [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                         [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                         [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                         [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                         [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                          [ 0.9483,  0.4802, -0.3334, -1.7319],
#                          [ 1.3300,  0.0585, -1.1194,  0.2406]]])

# %%
# %timeit t_stack(trees)
# Out:
# 37.4 µs ± 321 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f69ebb3b5e0>
# ├── 'a' --> tensor([[-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134],
# │                   [-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134],
# │                   [-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134],
# │                   [-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134],
# │                   [-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134],
# │                   [-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134],
# │                   [-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134],
# │                   [-0.2760, -0.1368,  0.3276],
# │                   [ 1.2058, -0.3772, -0.9134]])
# └── 'x' --> <FastTreeValue 0x7f69ebb3ba00>
#     └── 'c' --> tensor([[ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406],
#                         [ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406],
#                         [ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406],
#                         [ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406],
#                         [ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406],
#                         [ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406],
#                         [ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406],
#                         [ 0.1810,  1.2680,  0.6181, -2.3500],
#                         [ 0.9483,  0.4802, -0.3334, -1.7319],
#                         [ 1.3300,  0.0585, -1.1194,  0.2406]])

# %%
# %timeit t_cat(trees)
# Out:
# 35.5 µs ± 672 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 74.8 µs ± 1.52 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                       [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                       [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                       [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                       [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                       [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                       [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]],
#
#                       [[ 0.1810,  1.2680,  0.6181, -2.3500],
#                        [ 0.9483,  0.4802, -0.3334, -1.7319],
#                        [ 1.3300,  0.0585, -1.1194,  0.2406]]]),
#        ),
#     a: tensor([[[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]],
#
#                [[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]],
#
#                [[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]],
#
#                [[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]],
#
#                [[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]],
#
#                [[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]],
#
#                [[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]],
#
#                [[-0.2760, -0.1368,  0.3276],
#                 [ 1.2058, -0.3772, -0.9134]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 92.8 µs ± 853 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406],
#                       [ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406],
#                       [ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406],
#                       [ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406],
#                       [ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406],
#                       [ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406],
#                       [ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406],
#                       [ 0.1810,  1.2680,  0.6181, -2.3500],
#                       [ 0.9483,  0.4802, -0.3334, -1.7319],
#                       [ 1.3300,  0.0585, -1.1194,  0.2406]]),
#        ),
#     a: tensor([[-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134],
#                [-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134],
#                [-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134],
#                [-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134],
#                [-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134],
#                [-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134],
#                [-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134],
#                [-0.2760, -0.1368,  0.3276],
#                [ 1.2058, -0.3772, -0.9134]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 172 µs ± 1.83 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 404 µs ± 9.84 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
