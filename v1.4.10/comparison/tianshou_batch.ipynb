# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f53073fb400>
# ├── 'a' --> tensor([[ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117]])
# └── 'x' --> <FastTreeValue 0x7f53073fbaf0>
#     └── 'c' --> tensor([[ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000]])

# %%
t.a
# Out:
# tensor([[ 1.8109,  0.9329, -0.5649],
#         [ 1.1794, -0.8268, -0.7117]])

# %%
# %timeit t.a
# Out:
# 64.4 ns ± 0.0637 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f53073fb400>
# ├── 'a' --> tensor([[ 0.4586,  0.2295,  1.3920],
# │                   [-0.8380,  0.5893, -0.4397]])
# └── 'x' --> <FastTreeValue 0x7f53073fbaf0>
#     └── 'c' --> tensor([[ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000]])

# %%
# %timeit t.a = new_value
# Out:
# 61.5 ns ± 0.331 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117]]),
#     x: Batch(
#            c: tensor([[ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.8109,  0.9329, -0.5649],
#         [ 1.1794, -0.8268, -0.7117]])

# %%
# %timeit b.a
# Out:
# 54.2 ns ± 0.0823 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5839, -0.2819, -0.6887],
#                [ 0.3910, -0.0344,  0.2971]]),
#     x: Batch(
#            c: tensor([[ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 490 ns ± 0.207 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 920 ns ± 6.56 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.7 µs ± 36.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 139 µs ± 635 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 427 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f53073fb4f0>
# ├── 'a' --> tensor([[[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]],
# │
# │                   [[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]],
# │
# │                   [[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]],
# │
# │                   [[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]],
# │
# │                   [[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]],
# │
# │                   [[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]],
# │
# │                   [[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]],
# │
# │                   [[ 1.8109,  0.9329, -0.5649],
# │                    [ 1.1794, -0.8268, -0.7117]]])
# └── 'x' --> <FastTreeValue 0x7f5304381490>
#     └── 'c' --> tensor([[[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                         [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                         [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                         [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                         [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                         [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                         [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                         [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                          [-0.7723,  0.7716,  1.8424, -0.2690],
#                          [ 0.1857,  0.9921,  0.5953, -0.7000]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.8 µs ± 66.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5226bd1c40>
# ├── 'a' --> tensor([[ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117],
# │                   [ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117],
# │                   [ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117],
# │                   [ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117],
# │                   [ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117],
# │                   [ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117],
# │                   [ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117],
# │                   [ 1.8109,  0.9329, -0.5649],
# │                   [ 1.1794, -0.8268, -0.7117]])
# └── 'x' --> <FastTreeValue 0x7f5304381520>
#     └── 'c' --> tensor([[ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000],
#                         [ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000],
#                         [ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000],
#                         [ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000],
#                         [ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000],
#                         [ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000],
#                         [ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000],
#                         [ 1.5826,  2.1168, -1.1296, -0.4522],
#                         [-0.7723,  0.7716,  1.8424, -0.2690],
#                         [ 0.1857,  0.9921,  0.5953, -0.7000]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.9 µs ± 58.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69.6 µs ± 52.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                       [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                       [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                       [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                       [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                       [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                       [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]],
#
#                       [[ 1.5826,  2.1168, -1.1296, -0.4522],
#                        [-0.7723,  0.7716,  1.8424, -0.2690],
#                        [ 0.1857,  0.9921,  0.5953, -0.7000]]]),
#        ),
#     a: tensor([[[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]],
#
#                [[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]],
#
#                [[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]],
#
#                [[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]],
#
#                [[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]],
#
#                [[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]],
#
#                [[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]],
#
#                [[ 1.8109,  0.9329, -0.5649],
#                 [ 1.1794, -0.8268, -0.7117]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.5 µs ± 252 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000],
#                       [ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000],
#                       [ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000],
#                       [ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000],
#                       [ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000],
#                       [ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000],
#                       [ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000],
#                       [ 1.5826,  2.1168, -1.1296, -0.4522],
#                       [-0.7723,  0.7716,  1.8424, -0.2690],
#                       [ 0.1857,  0.9921,  0.5953, -0.7000]]),
#        ),
#     a: tensor([[ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117],
#                [ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117],
#                [ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117],
#                [ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117],
#                [ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117],
#                [ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117],
#                [ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117],
#                [ 1.8109,  0.9329, -0.5649],
#                [ 1.1794, -0.8268, -0.7117]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 152 µs ± 277 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 334 µs ± 7.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
