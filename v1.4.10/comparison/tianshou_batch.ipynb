# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5c4d13cac0>
# ├── 'a' --> tensor([[ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934]])
# └── 'x' --> <FastTreeValue 0x7f5c4d13c640>
#     └── 'c' --> tensor([[-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824]])

# %%
t.a
# Out:
# tensor([[ 1.1752,  0.4028, -0.2042],
#         [-1.6124,  0.0638, -2.4934]])

# %%
# %timeit t.a
# Out:
# 71.6 ns ± 0.0137 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5c4d13cac0>
# ├── 'a' --> tensor([[-0.9826, -0.5195, -2.4043],
# │                   [ 0.1779,  0.0659, -0.2051]])
# └── 'x' --> <FastTreeValue 0x7f5c4d13c640>
#     └── 'c' --> tensor([[-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824]])

# %%
# %timeit t.a = new_value
# Out:
# 69.9 ns ± 0.178 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934]]),
#     x: Batch(
#            c: tensor([[-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.1752,  0.4028, -0.2042],
#         [-1.6124,  0.0638, -2.4934]])

# %%
# %timeit b.a
# Out:
# 57.4 ns ± 0.0308 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.3950, -1.0655, -2.0609],
#                [-0.1953,  0.4966, -0.9159]]),
#     x: Batch(
#            c: tensor([[-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 479 ns ± 0.206 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 832 ns ± 2.85 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 34.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 140 µs ± 221 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 542 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5c4d13c940>
# ├── 'a' --> tensor([[[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]],
# │
# │                   [[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]],
# │
# │                   [[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]],
# │
# │                   [[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]],
# │
# │                   [[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]],
# │
# │                   [[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]],
# │
# │                   [[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]],
# │
# │                   [[ 1.1752,  0.4028, -0.2042],
# │                    [-1.6124,  0.0638, -2.4934]]])
# └── 'x' --> <FastTreeValue 0x7f5b6bdc5f40>
#     └── 'c' --> tensor([[[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                         [[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                         [[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                         [[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                         [[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                         [[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                         [[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                         [[-0.3699,  0.9907,  1.0763, -0.1672],
#                          [-0.7339, -0.0670, -1.6184, -0.7610],
#                          [ 0.3000,  0.0811,  0.0857, -0.0824]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.6 µs ± 40.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5c480a9940>
# ├── 'a' --> tensor([[ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934],
# │                   [ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934],
# │                   [ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934],
# │                   [ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934],
# │                   [ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934],
# │                   [ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934],
# │                   [ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934],
# │                   [ 1.1752,  0.4028, -0.2042],
# │                   [-1.6124,  0.0638, -2.4934]])
# └── 'x' --> <FastTreeValue 0x7f5c480a92b0>
#     └── 'c' --> tensor([[-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824],
#                         [-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824],
#                         [-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824],
#                         [-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824],
#                         [-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824],
#                         [-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824],
#                         [-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824],
#                         [-0.3699,  0.9907,  1.0763, -0.1672],
#                         [-0.7339, -0.0670, -1.6184, -0.7610],
#                         [ 0.3000,  0.0811,  0.0857, -0.0824]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.8 µs ± 75.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69.7 µs ± 106 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                       [[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                       [[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                       [[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                       [[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                       [[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                       [[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]],
#
#                       [[-0.3699,  0.9907,  1.0763, -0.1672],
#                        [-0.7339, -0.0670, -1.6184, -0.7610],
#                        [ 0.3000,  0.0811,  0.0857, -0.0824]]]),
#        ),
#     a: tensor([[[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]],
#
#                [[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]],
#
#                [[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]],
#
#                [[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]],
#
#                [[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]],
#
#                [[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]],
#
#                [[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]],
#
#                [[ 1.1752,  0.4028, -0.2042],
#                 [-1.6124,  0.0638, -2.4934]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.5 µs ± 109 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824],
#                       [-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824],
#                       [-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824],
#                       [-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824],
#                       [-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824],
#                       [-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824],
#                       [-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824],
#                       [-0.3699,  0.9907,  1.0763, -0.1672],
#                       [-0.7339, -0.0670, -1.6184, -0.7610],
#                       [ 0.3000,  0.0811,  0.0857, -0.0824]]),
#        ),
#     a: tensor([[ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934],
#                [ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934],
#                [ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934],
#                [ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934],
#                [ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934],
#                [ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934],
#                [ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934],
#                [ 1.1752,  0.4028, -0.2042],
#                [-1.6124,  0.0638, -2.4934]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 537 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 321 µs ± 3.35 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
