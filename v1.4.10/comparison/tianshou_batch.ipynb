# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f6bcc9985b0>
# ├── 'a' --> tensor([[-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010]])
# └── 'x' --> <FastTreeValue 0x7f6bcc9983d0>
#     └── 'c' --> tensor([[ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755]])

# %%
t.a
# Out:
# tensor([[-1.3355, -0.9136,  0.0264],
#         [ 0.2588,  1.7571,  0.3010]])

# %%
# %timeit t.a
# Out:
# 86.2 ns ± 0.0818 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f6bcc9985b0>
# ├── 'a' --> tensor([[ 1.2507, -0.3872,  1.4392],
# │                   [-0.5466,  1.2910,  1.1118]])
# └── 'x' --> <FastTreeValue 0x7f6bcc9983d0>
#     └── 'c' --> tensor([[ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755]])

# %%
# %timeit t.a = new_value
# Out:
# 92.6 ns ± 0.556 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010]]),
#     x: Batch(
#            c: tensor([[ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.3355, -0.9136,  0.0264],
#         [ 0.2588,  1.7571,  0.3010]])

# %%
# %timeit b.a
# Out:
# 75.9 ns ± 0.836 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5335, -1.5512, -1.8706],
#                [ 1.1311, -0.2220,  1.0065]]),
#     x: Batch(
#            c: tensor([[ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 652 ns ± 3.97 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1 µs ± 9.58 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12 µs ± 188 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 164 µs ± 1.68 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 169 µs ± 1.24 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f6afa10a460>
# ├── 'a' --> tensor([[[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]],
# │
# │                   [[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]],
# │
# │                   [[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]],
# │
# │                   [[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]],
# │
# │                   [[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]],
# │
# │                   [[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]],
# │
# │                   [[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]],
# │
# │                   [[-1.3355, -0.9136,  0.0264],
# │                    [ 0.2588,  1.7571,  0.3010]]])
# └── 'x' --> <FastTreeValue 0x7f6afa10afd0>
#     └── 'c' --> tensor([[[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                         [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                         [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                         [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                         [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                         [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                         [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                         [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                          [-0.6268,  0.8891, -1.1677, -0.5109],
#                          [-0.7673,  1.4450, -1.8508,  1.9755]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39 µs ± 280 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f6aec1fbd00>
# ├── 'a' --> tensor([[-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010],
# │                   [-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010],
# │                   [-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010],
# │                   [-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010],
# │                   [-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010],
# │                   [-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010],
# │                   [-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010],
# │                   [-1.3355, -0.9136,  0.0264],
# │                   [ 0.2588,  1.7571,  0.3010]])
# └── 'x' --> <FastTreeValue 0x7f6aeb1a1f40>
#     └── 'c' --> tensor([[ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755],
#                         [ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755],
#                         [ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755],
#                         [ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755],
#                         [ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755],
#                         [ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755],
#                         [ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755],
#                         [ 0.8142,  0.8115,  0.5382, -0.3286],
#                         [-0.6268,  0.8891, -1.1677, -0.5109],
#                         [-0.7673,  1.4450, -1.8508,  1.9755]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.8 µs ± 124 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 77.6 µs ± 365 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]],
#
#                [[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]],
#
#                [[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]],
#
#                [[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]],
#
#                [[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]],
#
#                [[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]],
#
#                [[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]],
#
#                [[-1.3355, -0.9136,  0.0264],
#                 [ 0.2588,  1.7571,  0.3010]]]),
#     x: Batch(
#            c: tensor([[[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                       [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                       [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                       [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                       [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                       [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                       [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]],
#
#                       [[ 0.8142,  0.8115,  0.5382, -0.3286],
#                        [-0.6268,  0.8891, -1.1677, -0.5109],
#                        [-0.7673,  1.4450, -1.8508,  1.9755]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98 µs ± 796 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010],
#                [-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010],
#                [-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010],
#                [-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010],
#                [-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010],
#                [-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010],
#                [-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010],
#                [-1.3355, -0.9136,  0.0264],
#                [ 0.2588,  1.7571,  0.3010]]),
#     x: Batch(
#            c: tensor([[ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755],
#                       [ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755],
#                       [ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755],
#                       [ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755],
#                       [ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755],
#                       [ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755],
#                       [ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755],
#                       [ 0.8142,  0.8115,  0.5382, -0.3286],
#                       [-0.6268,  0.8891, -1.1677, -0.5109],
#                       [-0.7673,  1.4450, -1.8508,  1.9755]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 173 µs ± 1.33 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 407 µs ± 6.85 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
