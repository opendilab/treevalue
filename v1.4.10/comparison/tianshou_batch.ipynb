# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5d20ce1fd0>
# ├── 'a' --> tensor([[-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733]])
# └── 'x' --> <FastTreeValue 0x7f5d251537f0>
#     └── 'c' --> tensor([[-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153]])

# %%
t.a
# Out:
# tensor([[-2.1703, -0.1531, -0.4250],
#         [-0.2856,  0.5065,  1.5733]])

# %%
# %timeit t.a
# Out:
# 62.6 ns ± 0.0705 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5d20ce1fd0>
# ├── 'a' --> tensor([[0.5632, 1.3711, 0.3211],
# │                   [1.0448, 2.0416, 1.6856]])
# └── 'x' --> <FastTreeValue 0x7f5d251537f0>
#     └── 'c' --> tensor([[-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153]])

# %%
# %timeit t.a = new_value
# Out:
# 68.2 ns ± 0.0346 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733]]),
#     x: Batch(
#            c: tensor([[-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-2.1703, -0.1531, -0.4250],
#         [-0.2856,  0.5065,  1.5733]])

# %%
# %timeit b.a
# Out:
# 59.4 ns ± 0.0328 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.3165,  0.9045, -1.0728],
#                [ 1.0896, -0.5719, -0.3588]]),
#     x: Batch(
#            c: tensor([[-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 496 ns ± 1.45 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 805 ns ± 0.45 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.8 µs ± 11.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 1.41 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 623 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5d20ce1e50>
# ├── 'a' --> tensor([[[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]],
# │
# │                   [[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]],
# │
# │                   [[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]],
# │
# │                   [[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]],
# │
# │                   [[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]],
# │
# │                   [[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]],
# │
# │                   [[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]],
# │
# │                   [[-2.1703, -0.1531, -0.4250],
# │                    [-0.2856,  0.5065,  1.5733]]])
# └── 'x' --> <FastTreeValue 0x7f5c46512130>
#     └── 'c' --> tensor([[[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                         [[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                         [[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                         [[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                         [[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                         [[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                         [[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                         [[-1.1561, -0.5670,  0.5701,  0.2685],
#                          [ 0.2542, -0.0818,  0.3117,  0.7809],
#                          [-0.9623,  0.7984,  0.8020, -0.6153]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.1 µs ± 40.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5c46512880>
# ├── 'a' --> tensor([[-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733],
# │                   [-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733],
# │                   [-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733],
# │                   [-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733],
# │                   [-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733],
# │                   [-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733],
# │                   [-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733],
# │                   [-2.1703, -0.1531, -0.4250],
# │                   [-0.2856,  0.5065,  1.5733]])
# └── 'x' --> <FastTreeValue 0x7f5c46512940>
#     └── 'c' --> tensor([[-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153],
#                         [-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153],
#                         [-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153],
#                         [-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153],
#                         [-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153],
#                         [-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153],
#                         [-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153],
#                         [-1.1561, -0.5670,  0.5701,  0.2685],
#                         [ 0.2542, -0.0818,  0.3117,  0.7809],
#                         [-0.9623,  0.7984,  0.8020, -0.6153]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.8 µs ± 51 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.3 µs ± 59 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                       [[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                       [[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                       [[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                       [[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                       [[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                       [[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]],
#
#                       [[-1.1561, -0.5670,  0.5701,  0.2685],
#                        [ 0.2542, -0.0818,  0.3117,  0.7809],
#                        [-0.9623,  0.7984,  0.8020, -0.6153]]]),
#        ),
#     a: tensor([[[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]],
#
#                [[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]],
#
#                [[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]],
#
#                [[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]],
#
#                [[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]],
#
#                [[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]],
#
#                [[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]],
#
#                [[-2.1703, -0.1531, -0.4250],
#                 [-0.2856,  0.5065,  1.5733]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.7 µs ± 231 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153],
#                       [-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153],
#                       [-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153],
#                       [-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153],
#                       [-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153],
#                       [-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153],
#                       [-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153],
#                       [-1.1561, -0.5670,  0.5701,  0.2685],
#                       [ 0.2542, -0.0818,  0.3117,  0.7809],
#                       [-0.9623,  0.7984,  0.8020, -0.6153]]),
#        ),
#     a: tensor([[-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733],
#                [-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733],
#                [-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733],
#                [-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733],
#                [-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733],
#                [-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733],
#                [-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733],
#                [-2.1703, -0.1531, -0.4250],
#                [-0.2856,  0.5065,  1.5733]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 147 µs ± 284 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 349 µs ± 4.26 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
