# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f4420420160>
# ├── 'a' --> tensor([[ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980]])
# └── 'x' --> <FastTreeValue 0x7f4420420100>
#     └── 'c' --> tensor([[-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404]])

# %%
t.a
# Out:
# tensor([[ 0.8074,  1.1259, -0.1408],
#         [ 0.8202, -1.3297, -0.7980]])

# %%
# %timeit t.a
# Out:
# 83.2 ns ± 0.983 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f4420420160>
# ├── 'a' --> tensor([[ 0.1229, -0.8421,  2.2906],
# │                   [-1.6655, -0.4089,  0.0042]])
# └── 'x' --> <FastTreeValue 0x7f4420420100>
#     └── 'c' --> tensor([[-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404]])

# %%
# %timeit t.a = new_value
# Out:
# 86.6 ns ± 1.19 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980]]),
#     x: Batch(
#            c: tensor([[-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8074,  1.1259, -0.1408],
#         [ 0.8202, -1.3297, -0.7980]])

# %%
# %timeit b.a
# Out:
# 79 ns ± 0.603 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.4721, -0.0820, -0.7605],
#                [-0.6233, -0.5213, -0.2716]]),
#     x: Batch(
#            c: tensor([[-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 648 ns ± 8.22 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.41 µs ± 96.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12 µs ± 225 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 173 µs ± 2.27 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 174 µs ± 2.77 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f4410222760>
# ├── 'a' --> tensor([[[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]],
# │
# │                   [[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]],
# │
# │                   [[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]],
# │
# │                   [[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]],
# │
# │                   [[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]],
# │
# │                   [[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]],
# │
# │                   [[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]],
# │
# │                   [[ 0.8074,  1.1259, -0.1408],
# │                    [ 0.8202, -1.3297, -0.7980]]])
# └── 'x' --> <FastTreeValue 0x7f4422487e20>
#     └── 'c' --> tensor([[[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                         [[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                         [[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                         [[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                         [[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                         [[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                         [[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                         [[-1.0020,  0.8657, -0.2188,  0.0068],
#                          [-0.5225,  0.7401, -0.1084,  0.2575],
#                          [-1.0963, -1.2200, -0.8131, -1.3404]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40.1 µs ± 626 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f4332a48e20>
# ├── 'a' --> tensor([[ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980],
# │                   [ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980],
# │                   [ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980],
# │                   [ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980],
# │                   [ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980],
# │                   [ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980],
# │                   [ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980],
# │                   [ 0.8074,  1.1259, -0.1408],
# │                   [ 0.8202, -1.3297, -0.7980]])
# └── 'x' --> <FastTreeValue 0x7f4332a48d90>
#     └── 'c' --> tensor([[-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404],
#                         [-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404],
#                         [-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404],
#                         [-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404],
#                         [-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404],
#                         [-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404],
#                         [-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404],
#                         [-1.0020,  0.8657, -0.2188,  0.0068],
#                         [-0.5225,  0.7401, -0.1084,  0.2575],
#                         [-1.0963, -1.2200, -0.8131, -1.3404]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.9 µs ± 231 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.8 µs ± 311 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]],
#
#                [[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]],
#
#                [[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]],
#
#                [[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]],
#
#                [[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]],
#
#                [[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]],
#
#                [[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]],
#
#                [[ 0.8074,  1.1259, -0.1408],
#                 [ 0.8202, -1.3297, -0.7980]]]),
#     x: Batch(
#            c: tensor([[[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                       [[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                       [[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                       [[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                       [[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                       [[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                       [[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]],
#
#                       [[-1.0020,  0.8657, -0.2188,  0.0068],
#                        [-0.5225,  0.7401, -0.1084,  0.2575],
#                        [-1.0963, -1.2200, -0.8131, -1.3404]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 95.1 µs ± 1.43 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980],
#                [ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980],
#                [ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980],
#                [ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980],
#                [ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980],
#                [ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980],
#                [ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980],
#                [ 0.8074,  1.1259, -0.1408],
#                [ 0.8202, -1.3297, -0.7980]]),
#     x: Batch(
#            c: tensor([[-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404],
#                       [-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404],
#                       [-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404],
#                       [-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404],
#                       [-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404],
#                       [-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404],
#                       [-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404],
#                       [-1.0020,  0.8657, -0.2188,  0.0068],
#                       [-0.5225,  0.7401, -0.1084,  0.2575],
#                       [-1.0963, -1.2200, -0.8131, -1.3404]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 176 µs ± 2.75 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 438 µs ± 9.93 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
