# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f79185318e0>
# ├── 'a' --> tensor([[ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366]])
# └── 'x' --> <FastTreeValue 0x7f7918531d90>
#     └── 'c' --> tensor([[-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004]])

# %%
t.a
# Out:
# tensor([[ 0.5294, -0.1036, -1.0342],
#         [-0.1658,  1.1573, -0.0366]])

# %%
# %timeit t.a
# Out:
# 80.8 ns ± 1.37 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f79185318e0>
# ├── 'a' --> tensor([[-0.2095, -1.4906,  0.9081],
# │                   [ 1.6157,  2.3076, -0.7727]])
# └── 'x' --> <FastTreeValue 0x7f7918531d90>
#     └── 'c' --> tensor([[-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004]])

# %%
# %timeit t.a = new_value
# Out:
# 83.2 ns ± 0.988 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366]]),
#     x: Batch(
#            c: tensor([[-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.5294, -0.1036, -1.0342],
#         [-0.1658,  1.1573, -0.0366]])

# %%
# %timeit b.a
# Out:
# 80.4 ns ± 1.88 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.5904,  0.1455, -0.3351],
#                [-2.6094, -0.1032,  0.8900]]),
#     x: Batch(
#            c: tensor([[-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 662 ns ± 8.28 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 10.4 µs ± 196 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.9 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 313 µs ± 8.61 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 306 µs ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f7827ba9f40>
# ├── 'a' --> tensor([[[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]],
# │
# │                   [[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]],
# │
# │                   [[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]],
# │
# │                   [[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]],
# │
# │                   [[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]],
# │
# │                   [[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]],
# │
# │                   [[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]],
# │
# │                   [[ 0.5294, -0.1036, -1.0342],
# │                    [-0.1658,  1.1573, -0.0366]]])
# └── 'x' --> <FastTreeValue 0x7f7827c70ee0>
#     └── 'c' --> tensor([[[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                         [[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                         [[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                         [[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                         [[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                         [[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                         [[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                         [[-1.0353,  0.9499,  2.6903,  0.1555],
#                          [-2.1018,  1.2754,  0.2693,  1.3419],
#                          [-0.0868, -0.0711,  1.3800, -0.7004]]])

# %%
# %timeit t_stack(trees)
# Out:
# 54.5 µs ± 1.18 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f7827b866a0>
# ├── 'a' --> tensor([[ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366],
# │                   [ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366],
# │                   [ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366],
# │                   [ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366],
# │                   [ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366],
# │                   [ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366],
# │                   [ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366],
# │                   [ 0.5294, -0.1036, -1.0342],
# │                   [-0.1658,  1.1573, -0.0366]])
# └── 'x' --> <FastTreeValue 0x7f7827b86310>
#     └── 'c' --> tensor([[-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004],
#                         [-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004],
#                         [-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004],
#                         [-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004],
#                         [-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004],
#                         [-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004],
#                         [-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004],
#                         [-1.0353,  0.9499,  2.6903,  0.1555],
#                         [-2.1018,  1.2754,  0.2693,  1.3419],
#                         [-0.0868, -0.0711,  1.3800, -0.7004]])

# %%
# %timeit t_cat(trees)
# Out:
# 49.3 µs ± 1.42 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 98.6 µs ± 2.82 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]],
#
#                [[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]],
#
#                [[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]],
#
#                [[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]],
#
#                [[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]],
#
#                [[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]],
#
#                [[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]],
#
#                [[ 0.5294, -0.1036, -1.0342],
#                 [-0.1658,  1.1573, -0.0366]]]),
#     x: Batch(
#            c: tensor([[[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                       [[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                       [[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                       [[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                       [[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                       [[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                       [[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]],
#
#                       [[-1.0353,  0.9499,  2.6903,  0.1555],
#                        [-2.1018,  1.2754,  0.2693,  1.3419],
#                        [-0.0868, -0.0711,  1.3800, -0.7004]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 117 µs ± 2.68 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366],
#                [ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366],
#                [ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366],
#                [ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366],
#                [ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366],
#                [ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366],
#                [ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366],
#                [ 0.5294, -0.1036, -1.0342],
#                [-0.1658,  1.1573, -0.0366]]),
#     x: Batch(
#            c: tensor([[-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004],
#                       [-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004],
#                       [-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004],
#                       [-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004],
#                       [-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004],
#                       [-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004],
#                       [-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004],
#                       [-1.0353,  0.9499,  2.6903,  0.1555],
#                       [-2.1018,  1.2754,  0.2693,  1.3419],
#                       [-0.0868, -0.0711,  1.3800, -0.7004]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 213 µs ± 5.69 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 725 µs ± 15.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
