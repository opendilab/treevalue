# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f4bc2024e20>
# ├── 'a' --> tensor([[-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093]])
# └── 'x' --> <FastTreeValue 0x7f4bc2024220>
#     └── 'c' --> tensor([[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]])

# %%
t.a
# Out:
# tensor([[-0.7360,  0.5613,  0.2154],
#         [-0.0049,  0.6907,  1.5093]])

# %%
# %timeit t.a
# Out:
# 69 ns ± 0.0577 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f4bc2024e20>
# ├── 'a' --> tensor([[-0.9904, -2.2047,  0.8329],
# │                   [-2.5825, -1.4807,  1.1005]])
# └── 'x' --> <FastTreeValue 0x7f4bc2024220>
#     └── 'c' --> tensor([[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]])

# %%
# %timeit t.a = new_value
# Out:
# 63.8 ns ± 0.0687 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093]]),
#     x: Batch(
#            c: tensor([[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7360,  0.5613,  0.2154],
#         [-0.0049,  0.6907,  1.5093]])

# %%
# %timeit b.a
# Out:
# 57.6 ns ± 0.0397 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.9603,  0.8647, -0.8443],
#                [-0.7902, -0.5969, -1.2506]]),
#     x: Batch(
#            c: tensor([[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 488 ns ± 0.057 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 823 ns ± 0.0911 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 34.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 136 µs ± 628 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 139 µs ± 502 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f4ae4100af0>
# ├── 'a' --> tensor([[[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]],
# │
# │                   [[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]],
# │
# │                   [[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]],
# │
# │                   [[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]],
# │
# │                   [[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]],
# │
# │                   [[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]],
# │
# │                   [[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]],
# │
# │                   [[-0.7360,  0.5613,  0.2154],
# │                    [-0.0049,  0.6907,  1.5093]]])
# └── 'x' --> <FastTreeValue 0x7f4ae4100e50>
#     └── 'c' --> tensor([[[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                         [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                         [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                         [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                         [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                         [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                         [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                         [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                          [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                          [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.7 µs ± 75.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f4ae412ffa0>
# ├── 'a' --> tensor([[-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093],
# │                   [-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093],
# │                   [-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093],
# │                   [-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093],
# │                   [-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093],
# │                   [-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093],
# │                   [-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093],
# │                   [-0.7360,  0.5613,  0.2154],
# │                   [-0.0049,  0.6907,  1.5093]])
# └── 'x' --> <FastTreeValue 0x7f4ae412f8e0>
#     └── 'c' --> tensor([[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                         [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                         [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                         [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                         [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                         [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                         [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                         [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                         [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                         [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.2 µs ± 76.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.2 µs ± 51.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                       [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                       [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                       [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                       [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                       [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                       [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]],
#
#                       [[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                        [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                        [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]]]),
#        ),
#     a: tensor([[[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]],
#
#                [[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]],
#
#                [[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]],
#
#                [[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]],
#
#                [[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]],
#
#                [[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]],
#
#                [[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]],
#
#                [[-0.7360,  0.5613,  0.2154],
#                 [-0.0049,  0.6907,  1.5093]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.6 µs ± 149 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                       [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                       [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                       [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                       [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                       [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                       [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01],
#                       [ 9.2962e-01,  1.3709e+00,  8.0896e-01,  6.0204e-01],
#                       [-1.2223e+00,  1.0894e+00, -8.7757e-04, -2.2311e-01],
#                       [-1.5115e+00,  2.9133e-01, -9.0832e-01,  4.4606e-01]]),
#        ),
#     a: tensor([[-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093],
#                [-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093],
#                [-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093],
#                [-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093],
#                [-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093],
#                [-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093],
#                [-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093],
#                [-0.7360,  0.5613,  0.2154],
#                [-0.0049,  0.6907,  1.5093]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 145 µs ± 222 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 310 µs ± 2.19 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
