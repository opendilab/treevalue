# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9fb8f055e0>
# ├── 'a' --> tensor([[-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980]])
# └── 'x' --> <FastTreeValue 0x7f9fbbf7a220>
#     └── 'c' --> tensor([[ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053]])

# %%
t.a
# Out:
# tensor([[-1.4623,  0.3884,  0.4574],
#         [-0.4205, -0.2848,  0.7980]])

# %%
# %timeit t.a
# Out:
# 72.2 ns ± 0.0282 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9fb8f055e0>
# ├── 'a' --> tensor([[-0.0212,  0.0645,  1.0863],
# │                   [ 0.5797,  0.1391,  0.1240]])
# └── 'x' --> <FastTreeValue 0x7f9fbbf7a220>
#     └── 'c' --> tensor([[ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053]])

# %%
# %timeit t.a = new_value
# Out:
# 74.5 ns ± 0.119 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980]]),
#     x: Batch(
#            c: tensor([[ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.4623,  0.3884,  0.4574],
#         [-0.4205, -0.2848,  0.7980]])

# %%
# %timeit b.a
# Out:
# 64.5 ns ± 0.115 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.1897, -1.3231,  0.9960],
#                [ 0.6986, -1.8805,  1.0065]]),
#     x: Batch(
#            c: tensor([[ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 541 ns ± 0.177 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 879 ns ± 0.563 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 13.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 653 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 987 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f9edb77a8e0>
# ├── 'a' --> tensor([[[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]],
# │
# │                   [[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]],
# │
# │                   [[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]],
# │
# │                   [[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]],
# │
# │                   [[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]],
# │
# │                   [[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]],
# │
# │                   [[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]],
# │
# │                   [[-1.4623,  0.3884,  0.4574],
# │                    [-0.4205, -0.2848,  0.7980]]])
# └── 'x' --> <FastTreeValue 0x7f9edb77adc0>
#     └── 'c' --> tensor([[[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                         [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                         [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                         [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                         [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                         [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                         [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                         [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                          [ 0.2749, -1.1937, -0.9623,  0.9825],
#                          [-1.0850, -0.1556,  0.3969, -0.0053]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 76.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9fb8f05280>
# ├── 'a' --> tensor([[-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980],
# │                   [-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980],
# │                   [-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980],
# │                   [-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980],
# │                   [-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980],
# │                   [-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980],
# │                   [-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980],
# │                   [-1.4623,  0.3884,  0.4574],
# │                   [-0.4205, -0.2848,  0.7980]])
# └── 'x' --> <FastTreeValue 0x7f9fb8f053a0>
#     └── 'c' --> tensor([[ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053],
#                         [ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053],
#                         [ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053],
#                         [ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053],
#                         [ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053],
#                         [ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053],
#                         [ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053],
#                         [ 0.4818, -0.5456,  0.3289, -0.5318],
#                         [ 0.2749, -1.1937, -0.9623,  0.9825],
#                         [-1.0850, -0.1556,  0.3969, -0.0053]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.7 µs ± 81 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.5 µs ± 54.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                       [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                       [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                       [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                       [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                       [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                       [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]],
#
#                       [[ 0.4818, -0.5456,  0.3289, -0.5318],
#                        [ 0.2749, -1.1937, -0.9623,  0.9825],
#                        [-1.0850, -0.1556,  0.3969, -0.0053]]]),
#        ),
#     a: tensor([[[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]],
#
#                [[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]],
#
#                [[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]],
#
#                [[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]],
#
#                [[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]],
#
#                [[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]],
#
#                [[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]],
#
#                [[-1.4623,  0.3884,  0.4574],
#                 [-0.4205, -0.2848,  0.7980]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.4 µs ± 873 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053],
#                       [ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053],
#                       [ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053],
#                       [ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053],
#                       [ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053],
#                       [ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053],
#                       [ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053],
#                       [ 0.4818, -0.5456,  0.3289, -0.5318],
#                       [ 0.2749, -1.1937, -0.9623,  0.9825],
#                       [-1.0850, -0.1556,  0.3969, -0.0053]]),
#        ),
#     a: tensor([[-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980],
#                [-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980],
#                [-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980],
#                [-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980],
#                [-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980],
#                [-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980],
#                [-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980],
#                [-1.4623,  0.3884,  0.4574],
#                [-0.4205, -0.2848,  0.7980]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 153 µs ± 339 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 345 µs ± 6.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
