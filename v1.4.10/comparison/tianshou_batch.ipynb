# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fe0f475bac0>
# ├── 'a' --> tensor([[ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281]])
# └── 'x' --> <FastTreeValue 0x7fe0f478a7f0>
#     └── 'c' --> tensor([[ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714]])

# %%
t.a
# Out:
# tensor([[ 2.4524,  0.9395,  0.7352],
#         [-1.1029, -1.7935, -0.1281]])

# %%
# %timeit t.a
# Out:
# 71.6 ns ± 0.0486 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fe0f475bac0>
# ├── 'a' --> tensor([[ 0.6195, -0.0627, -0.1277],
# │                   [-1.3225,  0.3285, -0.9750]])
# └── 'x' --> <FastTreeValue 0x7fe0f478a7f0>
#     └── 'c' --> tensor([[ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714]])

# %%
# %timeit t.a = new_value
# Out:
# 69.1 ns ± 0.0251 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281]]),
#     x: Batch(
#            c: tensor([[ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 2.4524,  0.9395,  0.7352],
#         [-1.1029, -1.7935, -0.1281]])

# %%
# %timeit b.a
# Out:
# 55.6 ns ± 0.075 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.3784,  0.2881,  1.2556],
#                [-0.2649,  0.1924,  0.7594]]),
#     x: Batch(
#            c: tensor([[ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 493 ns ± 0.148 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 831 ns ± 0.21 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.5 µs ± 20.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 138 µs ± 677 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 411 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fe025f4d100>
# ├── 'a' --> tensor([[[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]],
# │
# │                   [[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]],
# │
# │                   [[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]],
# │
# │                   [[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]],
# │
# │                   [[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]],
# │
# │                   [[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]],
# │
# │                   [[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]],
# │
# │                   [[ 2.4524,  0.9395,  0.7352],
# │                    [-1.1029, -1.7935, -0.1281]]])
# └── 'x' --> <FastTreeValue 0x7fe030b66c40>
#     └── 'c' --> tensor([[[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                         [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                         [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                         [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                         [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                         [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                         [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                         [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                          [-0.9624, -0.8791, -0.3862,  0.7579],
#                          [-0.0089, -0.0057, -0.9921,  1.2714]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32 µs ± 50.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fe016fbdf40>
# ├── 'a' --> tensor([[ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281],
# │                   [ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281],
# │                   [ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281],
# │                   [ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281],
# │                   [ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281],
# │                   [ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281],
# │                   [ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281],
# │                   [ 2.4524,  0.9395,  0.7352],
# │                   [-1.1029, -1.7935, -0.1281]])
# └── 'x' --> <FastTreeValue 0x7fe0f47c4490>
#     └── 'c' --> tensor([[ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714],
#                         [ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714],
#                         [ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714],
#                         [ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714],
#                         [ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714],
#                         [ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714],
#                         [ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714],
#                         [ 0.0279, -0.5315,  0.1540, -0.1378],
#                         [-0.9624, -0.8791, -0.3862,  0.7579],
#                         [-0.0089, -0.0057, -0.9921,  1.2714]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.3 µs ± 69.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.6 µs ± 53.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                       [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                       [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                       [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                       [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                       [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                       [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]],
#
#                       [[ 0.0279, -0.5315,  0.1540, -0.1378],
#                        [-0.9624, -0.8791, -0.3862,  0.7579],
#                        [-0.0089, -0.0057, -0.9921,  1.2714]]]),
#        ),
#     a: tensor([[[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]],
#
#                [[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]],
#
#                [[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]],
#
#                [[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]],
#
#                [[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]],
#
#                [[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]],
#
#                [[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]],
#
#                [[ 2.4524,  0.9395,  0.7352],
#                 [-1.1029, -1.7935, -0.1281]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.2 µs ± 131 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714],
#                       [ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714],
#                       [ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714],
#                       [ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714],
#                       [ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714],
#                       [ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714],
#                       [ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714],
#                       [ 0.0279, -0.5315,  0.1540, -0.1378],
#                       [-0.9624, -0.8791, -0.3862,  0.7579],
#                       [-0.0089, -0.0057, -0.9921,  1.2714]]),
#        ),
#     a: tensor([[ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281],
#                [ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281],
#                [ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281],
#                [ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281],
#                [ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281],
#                [ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281],
#                [ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281],
#                [ 2.4524,  0.9395,  0.7352],
#                [-1.1029, -1.7935, -0.1281]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 333 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 331 µs ± 6.46 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
