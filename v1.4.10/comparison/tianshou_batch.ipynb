# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f1a606b7a60>
# ├── 'a' --> tensor([[-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443]])
# └── 'x' --> <FastTreeValue 0x7f1a6273b130>
#     └── 'c' --> tensor([[ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493]])

# %%
t.a
# Out:
# tensor([[-0.0677, -0.3700, -0.0628],
#         [-0.0843,  0.2029, -0.7443]])

# %%
# %timeit t.a
# Out:
# 66.1 ns ± 0.0366 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f1a606b7a60>
# ├── 'a' --> tensor([[0.8234, 0.0301, 0.7780],
# │                   [1.1967, 0.1693, 0.0811]])
# └── 'x' --> <FastTreeValue 0x7f1a6273b130>
#     └── 'c' --> tensor([[ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493]])

# %%
# %timeit t.a = new_value
# Out:
# 75.7 ns ± 0.271 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443]]),
#     x: Batch(
#            c: tensor([[ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.0677, -0.3700, -0.0628],
#         [-0.0843,  0.2029, -0.7443]])

# %%
# %timeit b.a
# Out:
# 60.2 ns ± 0.0397 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.1920, -1.4172, -0.8104],
#                [-0.8757, -1.6940,  1.5205]]),
#     x: Batch(
#            c: tensor([[ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 497 ns ± 0.175 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 834 ns ± 0.687 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 16.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 947 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 617 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f19902bbbe0>
# ├── 'a' --> tensor([[[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]],
# │
# │                   [[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]],
# │
# │                   [[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]],
# │
# │                   [[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]],
# │
# │                   [[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]],
# │
# │                   [[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]],
# │
# │                   [[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]],
# │
# │                   [[-0.0677, -0.3700, -0.0628],
# │                    [-0.0843,  0.2029, -0.7443]]])
# └── 'x' --> <FastTreeValue 0x7f19902bb820>
#     └── 'c' --> tensor([[[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                         [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                         [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                         [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                         [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                         [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                         [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                         [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                          [ 0.4286, -0.4107,  1.2677, -0.1923],
#                          [-0.4576,  0.4126,  0.1691, -0.8493]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.1 µs ± 123 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f1a606b7af0>
# ├── 'a' --> tensor([[-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443],
# │                   [-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443],
# │                   [-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443],
# │                   [-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443],
# │                   [-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443],
# │                   [-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443],
# │                   [-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443],
# │                   [-0.0677, -0.3700, -0.0628],
# │                   [-0.0843,  0.2029, -0.7443]])
# └── 'x' --> <FastTreeValue 0x7f1a606b7df0>
#     └── 'c' --> tensor([[ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493],
#                         [ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493],
#                         [ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493],
#                         [ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493],
#                         [ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493],
#                         [ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493],
#                         [ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493],
#                         [ 1.9264,  1.4251, -0.0032, -0.2834],
#                         [ 0.4286, -0.4107,  1.2677, -0.1923],
#                         [-0.4576,  0.4126,  0.1691, -0.8493]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 117 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.4 µs ± 90.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]],
#
#                [[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]],
#
#                [[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]],
#
#                [[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]],
#
#                [[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]],
#
#                [[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]],
#
#                [[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]],
#
#                [[-0.0677, -0.3700, -0.0628],
#                 [-0.0843,  0.2029, -0.7443]]]),
#     x: Batch(
#            c: tensor([[[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                       [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                       [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                       [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                       [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                       [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                       [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]],
#
#                       [[ 1.9264,  1.4251, -0.0032, -0.2834],
#                        [ 0.4286, -0.4107,  1.2677, -0.1923],
#                        [-0.4576,  0.4126,  0.1691, -0.8493]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.1 µs ± 301 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443],
#                [-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443],
#                [-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443],
#                [-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443],
#                [-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443],
#                [-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443],
#                [-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443],
#                [-0.0677, -0.3700, -0.0628],
#                [-0.0843,  0.2029, -0.7443]]),
#     x: Batch(
#            c: tensor([[ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493],
#                       [ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493],
#                       [ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493],
#                       [ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493],
#                       [ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493],
#                       [ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493],
#                       [ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493],
#                       [ 1.9264,  1.4251, -0.0032, -0.2834],
#                       [ 0.4286, -0.4107,  1.2677, -0.1923],
#                       [-0.4576,  0.4126,  0.1691, -0.8493]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 493 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 348 µs ± 2.47 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
