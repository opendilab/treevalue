# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f2adf8baf10>
# ├── 'a' --> tensor([[ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588]])
# └── 'x' --> <FastTreeValue 0x7f2adf8ba850>
#     └── 'c' --> tensor([[ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839]])

# %%
t.a
# Out:
# tensor([[ 0.4978,  0.4987,  0.2608],
#         [ 0.9485, -0.4595, -0.8588]])

# %%
# %timeit t.a
# Out:
# 74.5 ns ± 2.63 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f2adf8baf10>
# ├── 'a' --> tensor([[-0.2794, -1.3758,  0.5071],
# │                   [ 1.0555, -0.9098, -0.3927]])
# └── 'x' --> <FastTreeValue 0x7f2adf8ba850>
#     └── 'c' --> tensor([[ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839]])

# %%
# %timeit t.a = new_value
# Out:
# 75.6 ns ± 0.939 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588]]),
#     x: Batch(
#            c: tensor([[ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.4978,  0.4987,  0.2608],
#         [ 0.9485, -0.4595, -0.8588]])

# %%
# %timeit b.a
# Out:
# 69 ns ± 1.59 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.1586,  0.0815,  0.1684],
#                [ 0.3129, -0.3493,  0.6823]]),
#     x: Batch(
#            c: tensor([[ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 632 ns ± 10.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.05 µs ± 15.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 14.4 µs ± 312 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 285 µs ± 25.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 273 µs ± 21.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f29ff095e80>
# ├── 'a' --> tensor([[[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]],
# │
# │                   [[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]],
# │
# │                   [[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]],
# │
# │                   [[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]],
# │
# │                   [[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]],
# │
# │                   [[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]],
# │
# │                   [[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]],
# │
# │                   [[ 0.4978,  0.4987,  0.2608],
# │                    [ 0.9485, -0.4595, -0.8588]]])
# └── 'x' --> <FastTreeValue 0x7f2a0cfac970>
#     └── 'c' --> tensor([[[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                         [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                         [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                         [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                         [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                         [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                         [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                         [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                          [ 0.4865,  1.4569, -0.6067,  0.3747],
#                          [ 1.8328,  0.5563, -1.0222,  0.0839]]])

# %%
# %timeit t_stack(trees)
# Out:
# 48.8 µs ± 1.23 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f29ff095c70>
# ├── 'a' --> tensor([[ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588],
# │                   [ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588],
# │                   [ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588],
# │                   [ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588],
# │                   [ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588],
# │                   [ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588],
# │                   [ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588],
# │                   [ 0.4978,  0.4987,  0.2608],
# │                   [ 0.9485, -0.4595, -0.8588]])
# └── 'x' --> <FastTreeValue 0x7f29ff5d3940>
#     └── 'c' --> tensor([[ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839],
#                         [ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839],
#                         [ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839],
#                         [ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839],
#                         [ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839],
#                         [ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839],
#                         [ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839],
#                         [ 1.3945, -0.7486, -0.1088, -0.0421],
#                         [ 0.4865,  1.4569, -0.6067,  0.3747],
#                         [ 1.8328,  0.5563, -1.0222,  0.0839]])

# %%
# %timeit t_cat(trees)
# Out:
# 45 µs ± 1.51 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 95.8 µs ± 3.42 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]],
#
#                [[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]],
#
#                [[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]],
#
#                [[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]],
#
#                [[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]],
#
#                [[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]],
#
#                [[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]],
#
#                [[ 0.4978,  0.4987,  0.2608],
#                 [ 0.9485, -0.4595, -0.8588]]]),
#     x: Batch(
#            c: tensor([[[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                       [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                       [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                       [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                       [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                       [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                       [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]],
#
#                       [[ 1.3945, -0.7486, -0.1088, -0.0421],
#                        [ 0.4865,  1.4569, -0.6067,  0.3747],
#                        [ 1.8328,  0.5563, -1.0222,  0.0839]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 110 µs ± 1.88 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588],
#                [ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588],
#                [ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588],
#                [ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588],
#                [ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588],
#                [ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588],
#                [ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588],
#                [ 0.4978,  0.4987,  0.2608],
#                [ 0.9485, -0.4595, -0.8588]]),
#     x: Batch(
#            c: tensor([[ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839],
#                       [ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839],
#                       [ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839],
#                       [ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839],
#                       [ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839],
#                       [ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839],
#                       [ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839],
#                       [ 1.3945, -0.7486, -0.1088, -0.0421],
#                       [ 0.4865,  1.4569, -0.6067,  0.3747],
#                       [ 1.8328,  0.5563, -1.0222,  0.0839]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 195 µs ± 2.31 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 663 µs ± 19.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
