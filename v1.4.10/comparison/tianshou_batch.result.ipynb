# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f3be0d5d6d0>
# ├── 'a' --> tensor([[-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945]])
# └── 'x' --> <FastTreeValue 0x7f3be0dc5250>
#     └── 'c' --> tensor([[ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611]])

# %%
t.a
# Out:
# tensor([[-1.0909, -2.2955,  0.3277],
#         [ 0.4093, -0.8759,  0.1945]])

# %%
# %timeit t.a
# Out:
# 72.1 ns ± 0.0514 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f3be0d5d6d0>
# ├── 'a' --> tensor([[-1.2150,  0.4920,  0.0477],
# │                   [-1.9641, -0.0056, -1.4387]])
# └── 'x' --> <FastTreeValue 0x7f3be0dc5250>
#     └── 'c' --> tensor([[ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611]])

# %%
# %timeit t.a = new_value
# Out:
# 74.7 ns ± 0.033 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945]]),
#     x: Batch(
#            c: tensor([[ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.0909, -2.2955,  0.3277],
#         [ 0.4093, -0.8759,  0.1945]])

# %%
# %timeit b.a
# Out:
# 66.4 ns ± 0.111 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.1109,  0.7277, -0.9439],
#                [ 1.4072, -2.8786,  0.5645]]),
#     x: Batch(
#            c: tensor([[ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 563 ns ± 5.02 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 872 ns ± 0.301 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 29.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 470 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 1.49 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f3b026409a0>
# ├── 'a' --> tensor([[[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]],
# │
# │                   [[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]],
# │
# │                   [[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]],
# │
# │                   [[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]],
# │
# │                   [[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]],
# │
# │                   [[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]],
# │
# │                   [[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]],
# │
# │                   [[-1.0909, -2.2955,  0.3277],
# │                    [ 0.4093, -0.8759,  0.1945]]])
# └── 'x' --> <FastTreeValue 0x7f3b02640f10>
#     └── 'c' --> tensor([[[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                         [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                         [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                         [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                         [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                         [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                         [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                         [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                          [-1.7733,  0.4880,  0.5361, -0.9939],
#                          [-1.3367, -0.4552,  0.8652,  0.9611]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 77.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f3b1b1e3d00>
# ├── 'a' --> tensor([[-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945],
# │                   [-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945],
# │                   [-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945],
# │                   [-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945],
# │                   [-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945],
# │                   [-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945],
# │                   [-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945],
# │                   [-1.0909, -2.2955,  0.3277],
# │                   [ 0.4093, -0.8759,  0.1945]])
# └── 'x' --> <FastTreeValue 0x7f3b1b14aa30>
#     └── 'c' --> tensor([[ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611],
#                         [ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611],
#                         [ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611],
#                         [ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611],
#                         [ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611],
#                         [ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611],
#                         [ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611],
#                         [ 0.5204, -0.3113, -1.2925,  1.8809],
#                         [-1.7733,  0.4880,  0.5361, -0.9939],
#                         [-1.3367, -0.4552,  0.8652,  0.9611]])

# %%
# %timeit t_cat(trees)
# Out:
# 32 µs ± 43.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.9 µs ± 79.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]],
#
#                [[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]],
#
#                [[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]],
#
#                [[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]],
#
#                [[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]],
#
#                [[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]],
#
#                [[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]],
#
#                [[-1.0909, -2.2955,  0.3277],
#                 [ 0.4093, -0.8759,  0.1945]]]),
#     x: Batch(
#            c: tensor([[[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                       [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                       [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                       [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                       [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                       [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                       [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]],
#
#                       [[ 0.5204, -0.3113, -1.2925,  1.8809],
#                        [-1.7733,  0.4880,  0.5361, -0.9939],
#                        [-1.3367, -0.4552,  0.8652,  0.9611]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.1 µs ± 268 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945],
#                [-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945],
#                [-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945],
#                [-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945],
#                [-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945],
#                [-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945],
#                [-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945],
#                [-1.0909, -2.2955,  0.3277],
#                [ 0.4093, -0.8759,  0.1945]]),
#     x: Batch(
#            c: tensor([[ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611],
#                       [ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611],
#                       [ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611],
#                       [ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611],
#                       [ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611],
#                       [ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611],
#                       [ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611],
#                       [ 0.5204, -0.3113, -1.2925,  1.8809],
#                       [-1.7733,  0.4880,  0.5361, -0.9939],
#                       [-1.3367, -0.4552,  0.8652,  0.9611]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 318 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 354 µs ± 3.88 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
