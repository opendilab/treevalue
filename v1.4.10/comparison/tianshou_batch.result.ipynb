# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f1628159eb0>
# ├── 'a' --> tensor([[ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168]])
# └── 'x' --> <FastTreeValue 0x7f1628159820>
#     └── 'c' --> tensor([[-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254]])

# %%
t.a
# Out:
# tensor([[ 0.1142, -0.2589, -0.4252],
#         [-0.2623,  0.3734, -0.1168]])

# %%
# %timeit t.a
# Out:
# 87.3 ns ± 0.877 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f1628159eb0>
# ├── 'a' --> tensor([[ 0.1179,  0.9960, -0.8846],
# │                   [-1.0237, -1.8458,  0.4337]])
# └── 'x' --> <FastTreeValue 0x7f1628159820>
#     └── 'c' --> tensor([[-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254]])

# %%
# %timeit t.a = new_value
# Out:
# 86.9 ns ± 0.412 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168]]),
#     x: Batch(
#            c: tensor([[-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.1142, -0.2589, -0.4252],
#         [-0.2623,  0.3734, -0.1168]])

# %%
# %timeit b.a
# Out:
# 79.5 ns ± 0.112 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.7248, -0.9219, -0.5587],
#                [ 1.2157,  1.7215,  0.6845]]),
#     x: Batch(
#            c: tensor([[-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 648 ns ± 1.53 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.06 µs ± 1.43 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.5 µs ± 21 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 175 µs ± 1.81 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 172 µs ± 886 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f15377cc310>
# ├── 'a' --> tensor([[[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]],
# │
# │                   [[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]],
# │
# │                   [[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]],
# │
# │                   [[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]],
# │
# │                   [[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]],
# │
# │                   [[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]],
# │
# │                   [[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]],
# │
# │                   [[ 0.1142, -0.2589, -0.4252],
# │                    [-0.2623,  0.3734, -0.1168]]])
# └── 'x' --> <FastTreeValue 0x7f15377cc2b0>
#     └── 'c' --> tensor([[[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                         [[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                         [[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                         [[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                         [[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                         [[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                         [[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                         [[-0.2667,  0.2489, -0.3105, -2.6740],
#                          [ 0.4065, -1.7053, -1.4974,  1.6546],
#                          [-0.8901,  0.7504,  2.0759, -0.6254]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40 µs ± 196 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f15fc204ac0>
# ├── 'a' --> tensor([[ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168],
# │                   [ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168],
# │                   [ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168],
# │                   [ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168],
# │                   [ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168],
# │                   [ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168],
# │                   [ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168],
# │                   [ 0.1142, -0.2589, -0.4252],
# │                   [-0.2623,  0.3734, -0.1168]])
# └── 'x' --> <FastTreeValue 0x7f15fc204670>
#     └── 'c' --> tensor([[-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254],
#                         [-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254],
#                         [-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254],
#                         [-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254],
#                         [-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254],
#                         [-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254],
#                         [-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254],
#                         [-0.2667,  0.2489, -0.3105, -2.6740],
#                         [ 0.4065, -1.7053, -1.4974,  1.6546],
#                         [-0.8901,  0.7504,  2.0759, -0.6254]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.8 µs ± 80.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.4 µs ± 43.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                       [[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                       [[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                       [[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                       [[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                       [[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                       [[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]],
#
#                       [[-0.2667,  0.2489, -0.3105, -2.6740],
#                        [ 0.4065, -1.7053, -1.4974,  1.6546],
#                        [-0.8901,  0.7504,  2.0759, -0.6254]]]),
#        ),
#     a: tensor([[[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]],
#
#                [[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]],
#
#                [[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]],
#
#                [[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]],
#
#                [[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]],
#
#                [[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]],
#
#                [[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]],
#
#                [[ 0.1142, -0.2589, -0.4252],
#                 [-0.2623,  0.3734, -0.1168]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.9 µs ± 162 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254],
#                       [-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254],
#                       [-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254],
#                       [-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254],
#                       [-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254],
#                       [-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254],
#                       [-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254],
#                       [-0.2667,  0.2489, -0.3105, -2.6740],
#                       [ 0.4065, -1.7053, -1.4974,  1.6546],
#                       [-0.8901,  0.7504,  2.0759, -0.6254]]),
#        ),
#     a: tensor([[ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168],
#                [ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168],
#                [ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168],
#                [ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168],
#                [ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168],
#                [ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168],
#                [ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168],
#                [ 0.1142, -0.2589, -0.4252],
#                [-0.2623,  0.3734, -0.1168]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 234 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 440 µs ± 6.07 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
