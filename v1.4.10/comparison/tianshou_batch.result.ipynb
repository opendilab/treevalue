# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7efff4f8fc10>
# ├── 'a' --> tensor([[-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500]])
# └── 'x' --> <FastTreeValue 0x7efff4f8ffa0>
#     └── 'c' --> tensor([[-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909]])

# %%
t.a
# Out:
# tensor([[-1.0381, -0.7378, -1.1237],
#         [ 0.2332,  0.6524, -0.5500]])

# %%
# %timeit t.a
# Out:
# 63.4 ns ± 0.0439 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7efff4f8fc10>
# ├── 'a' --> tensor([[-0.6169,  0.4636, -0.1035],
# │                   [ 2.2933, -0.5145, -1.1763]])
# └── 'x' --> <FastTreeValue 0x7efff4f8ffa0>
#     └── 'c' --> tensor([[-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909]])

# %%
# %timeit t.a = new_value
# Out:
# 67.1 ns ± 0.0599 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500]]),
#     x: Batch(
#            c: tensor([[-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.0381, -0.7378, -1.1237],
#         [ 0.2332,  0.6524, -0.5500]])

# %%
# %timeit b.a
# Out:
# 58.7 ns ± 0.0625 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.3042,  1.3018,  0.6605],
#                [ 0.5506,  1.7377, -0.3645]]),
#     x: Batch(
#            c: tensor([[-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 509 ns ± 6.68 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 801 ns ± 0.188 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 27.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 415 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 672 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7efff41ab250>
# ├── 'a' --> tensor([[[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]],
# │
# │                   [[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]],
# │
# │                   [[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]],
# │
# │                   [[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]],
# │
# │                   [[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]],
# │
# │                   [[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]],
# │
# │                   [[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]],
# │
# │                   [[-1.0381, -0.7378, -1.1237],
# │                    [ 0.2332,  0.6524, -0.5500]]])
# └── 'x' --> <FastTreeValue 0x7efff41abf10>
#     └── 'c' --> tensor([[[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                         [[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                         [[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                         [[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                         [[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                         [[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                         [[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                         [[-2.0044,  0.4490, -1.4723,  0.8834],
#                          [-0.6180, -1.2177, -1.1789,  1.5593],
#                          [ 0.9237, -0.4347, -0.0064, -0.5909]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.7 µs ± 126 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7eff2a7f4e50>
# ├── 'a' --> tensor([[-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500],
# │                   [-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500],
# │                   [-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500],
# │                   [-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500],
# │                   [-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500],
# │                   [-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500],
# │                   [-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500],
# │                   [-1.0381, -0.7378, -1.1237],
# │                   [ 0.2332,  0.6524, -0.5500]])
# └── 'x' --> <FastTreeValue 0x7efff4ff9e50>
#     └── 'c' --> tensor([[-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909],
#                         [-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909],
#                         [-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909],
#                         [-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909],
#                         [-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909],
#                         [-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909],
#                         [-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909],
#                         [-2.0044,  0.4490, -1.4723,  0.8834],
#                         [-0.6180, -1.2177, -1.1789,  1.5593],
#                         [ 0.9237, -0.4347, -0.0064, -0.5909]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.6 µs ± 63.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69 µs ± 145 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                       [[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                       [[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                       [[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                       [[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                       [[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                       [[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]],
#
#                       [[-2.0044,  0.4490, -1.4723,  0.8834],
#                        [-0.6180, -1.2177, -1.1789,  1.5593],
#                        [ 0.9237, -0.4347, -0.0064, -0.5909]]]),
#        ),
#     a: tensor([[[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]],
#
#                [[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]],
#
#                [[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]],
#
#                [[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]],
#
#                [[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]],
#
#                [[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]],
#
#                [[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]],
#
#                [[-1.0381, -0.7378, -1.1237],
#                 [ 0.2332,  0.6524, -0.5500]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.5 µs ± 484 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909],
#                       [-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909],
#                       [-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909],
#                       [-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909],
#                       [-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909],
#                       [-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909],
#                       [-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909],
#                       [-2.0044,  0.4490, -1.4723,  0.8834],
#                       [-0.6180, -1.2177, -1.1789,  1.5593],
#                       [ 0.9237, -0.4347, -0.0064, -0.5909]]),
#        ),
#     a: tensor([[-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500],
#                [-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500],
#                [-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500],
#                [-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500],
#                [-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500],
#                [-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500],
#                [-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500],
#                [-1.0381, -0.7378, -1.1237],
#                [ 0.2332,  0.6524, -0.5500]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 1.24 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 345 µs ± 4.35 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
