# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f51e039eaf0>
# ├── 'a' --> tensor([[-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115]])
# └── 'x' --> <FastTreeValue 0x7f51e039ea30>
#     └── 'c' --> tensor([[ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473]])

# %%
t.a
# Out:
# tensor([[-0.2857, -0.8137,  1.1601],
#         [ 0.1386,  2.4571, -0.4115]])

# %%
# %timeit t.a
# Out:
# 87.1 ns ± 0.137 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f51e039eaf0>
# ├── 'a' --> tensor([[-0.9710,  0.1058, -1.2731],
# │                   [-0.8568, -0.3308,  0.2664]])
# └── 'x' --> <FastTreeValue 0x7f51e039ea30>
#     └── 'c' --> tensor([[ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473]])

# %%
# %timeit t.a = new_value
# Out:
# 89.4 ns ± 0.248 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115]]),
#     x: Batch(
#            c: tensor([[ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2857, -0.8137,  1.1601],
#         [ 0.1386,  2.4571, -0.4115]])

# %%
# %timeit b.a
# Out:
# 79.7 ns ± 0.136 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5453,  0.1608,  0.4012],
#                [-0.0702,  0.5850,  0.2778]]),
#     x: Batch(
#            c: tensor([[ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 658 ns ± 1.05 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.04 µs ± 1.06 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.5 µs ± 27.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 176 µs ± 5.14 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 174 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f50efaafdf0>
# ├── 'a' --> tensor([[[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]],
# │
# │                   [[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]],
# │
# │                   [[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]],
# │
# │                   [[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]],
# │
# │                   [[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]],
# │
# │                   [[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]],
# │
# │                   [[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]],
# │
# │                   [[-0.2857, -0.8137,  1.1601],
# │                    [ 0.1386,  2.4571, -0.4115]]])
# └── 'x' --> <FastTreeValue 0x7f51d827ecd0>
#     └── 'c' --> tensor([[[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                         [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                         [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                         [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                         [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                         [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                         [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                         [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                          [ 0.0419, -0.4437, -0.0196,  0.5133],
#                          [-0.8551,  0.3599, -0.9827,  0.0473]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40.2 µs ± 904 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f50ef9cc670>
# ├── 'a' --> tensor([[-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115],
# │                   [-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115],
# │                   [-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115],
# │                   [-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115],
# │                   [-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115],
# │                   [-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115],
# │                   [-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115],
# │                   [-0.2857, -0.8137,  1.1601],
# │                   [ 0.1386,  2.4571, -0.4115]])
# └── 'x' --> <FastTreeValue 0x7f50ef9cca60>
#     └── 'c' --> tensor([[ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473],
#                         [ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473],
#                         [ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473],
#                         [ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473],
#                         [ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473],
#                         [ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473],
#                         [ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473],
#                         [ 0.9456, -0.0106,  0.9440,  0.6426],
#                         [ 0.0419, -0.4437, -0.0196,  0.5133],
#                         [-0.8551,  0.3599, -0.9827,  0.0473]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.1 µs ± 37.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.8 µs ± 478 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                       [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                       [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                       [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                       [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                       [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                       [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]],
#
#                       [[ 0.9456, -0.0106,  0.9440,  0.6426],
#                        [ 0.0419, -0.4437, -0.0196,  0.5133],
#                        [-0.8551,  0.3599, -0.9827,  0.0473]]]),
#        ),
#     a: tensor([[[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]],
#
#                [[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]],
#
#                [[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]],
#
#                [[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]],
#
#                [[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]],
#
#                [[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]],
#
#                [[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]],
#
#                [[-0.2857, -0.8137,  1.1601],
#                 [ 0.1386,  2.4571, -0.4115]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.1 µs ± 98.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473],
#                       [ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473],
#                       [ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473],
#                       [ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473],
#                       [ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473],
#                       [ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473],
#                       [ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473],
#                       [ 0.9456, -0.0106,  0.9440,  0.6426],
#                       [ 0.0419, -0.4437, -0.0196,  0.5133],
#                       [-0.8551,  0.3599, -0.9827,  0.0473]]),
#        ),
#     a: tensor([[-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115],
#                [-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115],
#                [-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115],
#                [-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115],
#                [-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115],
#                [-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115],
#                [-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115],
#                [-0.2857, -0.8137,  1.1601],
#                [ 0.1386,  2.4571, -0.4115]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 496 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 450 µs ± 12.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
