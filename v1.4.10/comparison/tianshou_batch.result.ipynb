# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fbe28b96820>
# ├── 'a' --> tensor([[-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533]])
# └── 'x' --> <FastTreeValue 0x7fbe28b967c0>
#     └── 'c' --> tensor([[-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430]])

# %%
t.a
# Out:
# tensor([[-0.0967, -0.1896,  0.0645],
#         [-1.3601, -0.3854,  0.1533]])

# %%
# %timeit t.a
# Out:
# 84 ns ± 0.556 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fbe28b96820>
# ├── 'a' --> tensor([[ 1.1727,  1.1585, -0.3162],
# │                   [-0.4090,  0.7281, -0.4564]])
# └── 'x' --> <FastTreeValue 0x7fbe28b967c0>
#     └── 'c' --> tensor([[-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430]])

# %%
# %timeit t.a = new_value
# Out:
# 89.4 ns ± 0.815 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533]]),
#     x: Batch(
#            c: tensor([[-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.0967, -0.1896,  0.0645],
#         [-1.3601, -0.3854,  0.1533]])

# %%
# %timeit b.a
# Out:
# 83.7 ns ± 1.06 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5201, -0.7456,  1.7103],
#                [ 1.6747,  0.4329,  0.0135]]),
#     x: Batch(
#            c: tensor([[-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 641 ns ± 9.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.06 µs ± 14.8 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.5 µs ± 205 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 297 µs ± 8.04 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 289 µs ± 9.32 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fbd3b20aeb0>
# ├── 'a' --> tensor([[[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]],
# │
# │                   [[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]],
# │
# │                   [[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]],
# │
# │                   [[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]],
# │
# │                   [[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]],
# │
# │                   [[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]],
# │
# │                   [[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]],
# │
# │                   [[-0.0967, -0.1896,  0.0645],
# │                    [-1.3601, -0.3854,  0.1533]]])
# └── 'x' --> <FastTreeValue 0x7fbd3b20a8b0>
#     └── 'c' --> tensor([[[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                         [[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                         [[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                         [[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                         [[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                         [[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                         [[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                         [[-0.7740,  0.9549, -0.3496,  1.7303],
#                          [ 0.5080,  1.2535,  0.4033, -1.1982],
#                          [-0.6617,  0.4355, -0.2051,  0.7430]]])

# %%
# %timeit t_stack(trees)
# Out:
# 51.4 µs ± 1.25 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fbd53ff5220>
# ├── 'a' --> tensor([[-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533],
# │                   [-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533],
# │                   [-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533],
# │                   [-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533],
# │                   [-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533],
# │                   [-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533],
# │                   [-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533],
# │                   [-0.0967, -0.1896,  0.0645],
# │                   [-1.3601, -0.3854,  0.1533]])
# └── 'x' --> <FastTreeValue 0x7fbe2ac07c40>
#     └── 'c' --> tensor([[-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430],
#                         [-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430],
#                         [-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430],
#                         [-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430],
#                         [-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430],
#                         [-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430],
#                         [-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430],
#                         [-0.7740,  0.9549, -0.3496,  1.7303],
#                         [ 0.5080,  1.2535,  0.4033, -1.1982],
#                         [-0.6617,  0.4355, -0.2051,  0.7430]])

# %%
# %timeit t_cat(trees)
# Out:
# 46.3 µs ± 1.21 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 99.1 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                       [[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                       [[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                       [[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                       [[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                       [[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                       [[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]],
#
#                       [[-0.7740,  0.9549, -0.3496,  1.7303],
#                        [ 0.5080,  1.2535,  0.4033, -1.1982],
#                        [-0.6617,  0.4355, -0.2051,  0.7430]]]),
#        ),
#     a: tensor([[[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]],
#
#                [[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]],
#
#                [[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]],
#
#                [[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]],
#
#                [[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]],
#
#                [[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]],
#
#                [[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]],
#
#                [[-0.0967, -0.1896,  0.0645],
#                 [-1.3601, -0.3854,  0.1533]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 164 µs ± 1.66 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430],
#                       [-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430],
#                       [-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430],
#                       [-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430],
#                       [-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430],
#                       [-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430],
#                       [-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430],
#                       [-0.7740,  0.9549, -0.3496,  1.7303],
#                       [ 0.5080,  1.2535,  0.4033, -1.1982],
#                       [-0.6617,  0.4355, -0.2051,  0.7430]]),
#        ),
#     a: tensor([[-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533],
#                [-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533],
#                [-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533],
#                [-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533],
#                [-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533],
#                [-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533],
#                [-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533],
#                [-0.0967, -0.1896,  0.0645],
#                [-1.3601, -0.3854,  0.1533]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 201 µs ± 3.44 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 717 µs ± 21.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
