# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7efd6d957220>
# ├── 'a' --> tensor([[-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556]])
# └── 'x' --> <FastTreeValue 0x7efd6d9572e0>
#     └── 'c' --> tensor([[-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323]])

# %%
t.a
# Out:
# tensor([[-1.2217,  0.6848,  0.1480],
#         [ 0.2665,  0.2663, -0.2556]])

# %%
# %timeit t.a
# Out:
# 75.6 ns ± 0.825 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7efd6d957220>
# ├── 'a' --> tensor([[ 0.3183,  1.3407, -0.6320],
# │                   [-0.2636,  0.3520,  1.0342]])
# └── 'x' --> <FastTreeValue 0x7efd6d9572e0>
#     └── 'c' --> tensor([[-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323]])

# %%
# %timeit t.a = new_value
# Out:
# 76.9 ns ± 0.928 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556]]),
#     x: Batch(
#            c: tensor([[-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.2217,  0.6848,  0.1480],
#         [ 0.2665,  0.2663, -0.2556]])

# %%
# %timeit b.a
# Out:
# 71.5 ns ± 0.292 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.2080,  0.2663, -1.1947],
#                [ 0.6182,  1.0380,  0.6474]]),
#     x: Batch(
#            c: tensor([[-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 663 ns ± 9.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.09 µs ± 13 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.9 µs ± 129 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 278 µs ± 8.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 262 µs ± 5.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7efc9b0c01f0>
# ├── 'a' --> tensor([[[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]],
# │
# │                   [[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]],
# │
# │                   [[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]],
# │
# │                   [[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]],
# │
# │                   [[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]],
# │
# │                   [[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]],
# │
# │                   [[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]],
# │
# │                   [[-1.2217,  0.6848,  0.1480],
# │                    [ 0.2665,  0.2663, -0.2556]]])
# └── 'x' --> <FastTreeValue 0x7efc9b0c00a0>
#     └── 'c' --> tensor([[[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                         [[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                         [[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                         [[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                         [[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                         [[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                         [[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                         [[-0.2618, -0.0297,  0.4799,  0.0334],
#                          [ 0.7383,  0.4461, -0.8931, -2.0499],
#                          [-0.5908, -1.6390,  0.6264, -0.2323]]])

# %%
# %timeit t_stack(trees)
# Out:
# 49.3 µs ± 497 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7efc9b0c02e0>
# ├── 'a' --> tensor([[-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556],
# │                   [-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556],
# │                   [-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556],
# │                   [-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556],
# │                   [-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556],
# │                   [-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556],
# │                   [-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556],
# │                   [-1.2217,  0.6848,  0.1480],
# │                   [ 0.2665,  0.2663, -0.2556]])
# └── 'x' --> <FastTreeValue 0x7efd6d9bab20>
#     └── 'c' --> tensor([[-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323],
#                         [-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323],
#                         [-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323],
#                         [-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323],
#                         [-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323],
#                         [-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323],
#                         [-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323],
#                         [-0.2618, -0.0297,  0.4799,  0.0334],
#                         [ 0.7383,  0.4461, -0.8931, -2.0499],
#                         [-0.5908, -1.6390,  0.6264, -0.2323]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.1 µs ± 548 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 95.1 µs ± 896 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]],
#
#                [[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]],
#
#                [[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]],
#
#                [[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]],
#
#                [[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]],
#
#                [[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]],
#
#                [[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]],
#
#                [[-1.2217,  0.6848,  0.1480],
#                 [ 0.2665,  0.2663, -0.2556]]]),
#     x: Batch(
#            c: tensor([[[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                       [[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                       [[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                       [[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                       [[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                       [[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                       [[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]],
#
#                       [[-0.2618, -0.0297,  0.4799,  0.0334],
#                        [ 0.7383,  0.4461, -0.8931, -2.0499],
#                        [-0.5908, -1.6390,  0.6264, -0.2323]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 115 µs ± 3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556],
#                [-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556],
#                [-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556],
#                [-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556],
#                [-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556],
#                [-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556],
#                [-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556],
#                [-1.2217,  0.6848,  0.1480],
#                [ 0.2665,  0.2663, -0.2556]]),
#     x: Batch(
#            c: tensor([[-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323],
#                       [-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323],
#                       [-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323],
#                       [-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323],
#                       [-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323],
#                       [-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323],
#                       [-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323],
#                       [-0.2618, -0.0297,  0.4799,  0.0334],
#                       [ 0.7383,  0.4461, -0.8931, -2.0499],
#                       [-0.5908, -1.6390,  0.6264, -0.2323]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 210 µs ± 3.33 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 626 µs ± 22.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
