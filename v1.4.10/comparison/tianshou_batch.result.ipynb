# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f84b83bedc0>
# ├── 'a' --> tensor([[ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016]])
# └── 'x' --> <FastTreeValue 0x7f84b83be130>
#     └── 'c' --> tensor([[-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943]])

# %%
t.a
# Out:
# tensor([[ 1.0712,  0.6685, -1.3745],
#         [-1.8662,  1.4138, -1.1016]])

# %%
# %timeit t.a
# Out:
# 85.3 ns ± 0.508 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f84b83bedc0>
# ├── 'a' --> tensor([[-0.3757,  0.0778,  2.3211],
# │                   [-0.2066, -0.5002,  0.5639]])
# └── 'x' --> <FastTreeValue 0x7f84b83be130>
#     └── 'c' --> tensor([[-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943]])

# %%
# %timeit t.a = new_value
# Out:
# 108 ns ± 1.15 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016]]),
#     x: Batch(
#            c: tensor([[-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.0712,  0.6685, -1.3745],
#         [-1.8662,  1.4138, -1.1016]])

# %%
# %timeit b.a
# Out:
# 75.6 ns ± 0.723 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0014,  1.2352,  1.2543],
#                [ 0.1903,  0.9607, -0.2697]]),
#     x: Batch(
#            c: tensor([[-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 611 ns ± 9.72 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 976 ns ± 17.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.8 µs ± 90 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 160 µs ± 1.55 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 166 µs ± 2.57 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f84b835c2e0>
# ├── 'a' --> tensor([[[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]],
# │
# │                   [[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]],
# │
# │                   [[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]],
# │
# │                   [[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]],
# │
# │                   [[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]],
# │
# │                   [[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]],
# │
# │                   [[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]],
# │
# │                   [[ 1.0712,  0.6685, -1.3745],
# │                    [-1.8662,  1.4138, -1.1016]]])
# └── 'x' --> <FastTreeValue 0x7f83dac80d00>
#     └── 'c' --> tensor([[[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                         [[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                         [[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                         [[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                         [[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                         [[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                         [[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                         [[-0.6300,  0.6373, -1.2535,  0.1447],
#                          [-0.1994, -1.2656, -0.6013,  0.5879],
#                          [ 1.2484, -0.4126, -0.9154, -1.5943]]])

# %%
# %timeit t_stack(trees)
# Out:
# 37.2 µs ± 848 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f84b83be400>
# ├── 'a' --> tensor([[ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016],
# │                   [ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016],
# │                   [ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016],
# │                   [ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016],
# │                   [ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016],
# │                   [ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016],
# │                   [ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016],
# │                   [ 1.0712,  0.6685, -1.3745],
# │                   [-1.8662,  1.4138, -1.1016]])
# └── 'x' --> <FastTreeValue 0x7f84b838c820>
#     └── 'c' --> tensor([[-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943],
#                         [-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943],
#                         [-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943],
#                         [-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943],
#                         [-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943],
#                         [-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943],
#                         [-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943],
#                         [-0.6300,  0.6373, -1.2535,  0.1447],
#                         [-0.1994, -1.2656, -0.6013,  0.5879],
#                         [ 1.2484, -0.4126, -0.9154, -1.5943]])

# %%
# %timeit t_cat(trees)
# Out:
# 35.4 µs ± 420 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 74 µs ± 744 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]],
#
#                [[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]],
#
#                [[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]],
#
#                [[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]],
#
#                [[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]],
#
#                [[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]],
#
#                [[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]],
#
#                [[ 1.0712,  0.6685, -1.3745],
#                 [-1.8662,  1.4138, -1.1016]]]),
#     x: Batch(
#            c: tensor([[[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                       [[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                       [[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                       [[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                       [[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                       [[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                       [[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]],
#
#                       [[-0.6300,  0.6373, -1.2535,  0.1447],
#                        [-0.1994, -1.2656, -0.6013,  0.5879],
#                        [ 1.2484, -0.4126, -0.9154, -1.5943]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 92.7 µs ± 817 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016],
#                [ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016],
#                [ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016],
#                [ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016],
#                [ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016],
#                [ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016],
#                [ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016],
#                [ 1.0712,  0.6685, -1.3745],
#                [-1.8662,  1.4138, -1.1016]]),
#     x: Batch(
#            c: tensor([[-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943],
#                       [-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943],
#                       [-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943],
#                       [-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943],
#                       [-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943],
#                       [-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943],
#                       [-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943],
#                       [-0.6300,  0.6373, -1.2535,  0.1447],
#                       [-0.1994, -1.2656, -0.6013,  0.5879],
#                       [ 1.2484, -0.4126, -0.9154, -1.5943]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 171 µs ± 2.16 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 396 µs ± 9.63 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
