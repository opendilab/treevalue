# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f647c77e490>
# ├── 'a' --> tensor([[-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742]])
# └── 'x' --> <FastTreeValue 0x7f647f7fa280>
#     └── 'c' --> tensor([[-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371]])

# %%
t.a
# Out:
# tensor([[-1.0471, -0.5540,  0.3702],
#         [ 0.9376, -0.1113,  0.0742]])

# %%
# %timeit t.a
# Out:
# 81.8 ns ± 2.2 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f647c77e490>
# ├── 'a' --> tensor([[ 1.7329, -0.5370, -0.6683],
# │                   [ 1.4462,  1.8061,  0.3157]])
# └── 'x' --> <FastTreeValue 0x7f647f7fa280>
#     └── 'c' --> tensor([[-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371]])

# %%
# %timeit t.a = new_value
# Out:
# 83 ns ± 2.22 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742]]),
#     x: Batch(
#            c: tensor([[-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.0471, -0.5540,  0.3702],
#         [ 0.9376, -0.1113,  0.0742]])

# %%
# %timeit b.a
# Out:
# 70.3 ns ± 1.48 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.8026, -0.1284, -1.6205],
#                [-0.2140, -0.4802,  1.6686]]),
#     x: Batch(
#            c: tensor([[-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 622 ns ± 8.54 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.05 µs ± 25.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.1 µs ± 331 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 281 µs ± 8.25 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 272 µs ± 9.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f63acefe730>
# ├── 'a' --> tensor([[[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]],
# │
# │                   [[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]],
# │
# │                   [[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]],
# │
# │                   [[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]],
# │
# │                   [[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]],
# │
# │                   [[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]],
# │
# │                   [[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]],
# │
# │                   [[-1.0471, -0.5540,  0.3702],
# │                    [ 0.9376, -0.1113,  0.0742]]])
# └── 'x' --> <FastTreeValue 0x7f63acefefd0>
#     └── 'c' --> tensor([[[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                         [[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                         [[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                         [[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                         [[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                         [[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                         [[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                         [[-2.3320, -2.0105,  1.0806, -1.1732],
#                          [ 1.6259,  0.5755, -0.4924, -0.4412],
#                          [-1.1403,  0.3080,  0.4132, -0.3371]]])

# %%
# %timeit t_stack(trees)
# Out:
# 47.6 µs ± 441 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f63acefe190>
# ├── 'a' --> tensor([[-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742],
# │                   [-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742],
# │                   [-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742],
# │                   [-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742],
# │                   [-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742],
# │                   [-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742],
# │                   [-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742],
# │                   [-1.0471, -0.5540,  0.3702],
# │                   [ 0.9376, -0.1113,  0.0742]])
# └── 'x' --> <FastTreeValue 0x7f639efd98b0>
#     └── 'c' --> tensor([[-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371],
#                         [-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371],
#                         [-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371],
#                         [-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371],
#                         [-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371],
#                         [-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371],
#                         [-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371],
#                         [-2.3320, -2.0105,  1.0806, -1.1732],
#                         [ 1.6259,  0.5755, -0.4924, -0.4412],
#                         [-1.1403,  0.3080,  0.4132, -0.3371]])

# %%
# %timeit t_cat(trees)
# Out:
# 43.1 µs ± 1.4 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 97.1 µs ± 1.98 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                       [[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                       [[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                       [[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                       [[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                       [[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                       [[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]],
#
#                       [[-2.3320, -2.0105,  1.0806, -1.1732],
#                        [ 1.6259,  0.5755, -0.4924, -0.4412],
#                        [-1.1403,  0.3080,  0.4132, -0.3371]]]),
#        ),
#     a: tensor([[[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]],
#
#                [[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]],
#
#                [[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]],
#
#                [[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]],
#
#                [[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]],
#
#                [[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]],
#
#                [[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]],
#
#                [[-1.0471, -0.5540,  0.3702],
#                 [ 0.9376, -0.1113,  0.0742]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 110 µs ± 2.33 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371],
#                       [-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371],
#                       [-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371],
#                       [-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371],
#                       [-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371],
#                       [-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371],
#                       [-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371],
#                       [-2.3320, -2.0105,  1.0806, -1.1732],
#                       [ 1.6259,  0.5755, -0.4924, -0.4412],
#                       [-1.1403,  0.3080,  0.4132, -0.3371]]),
#        ),
#     a: tensor([[-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742],
#                [-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742],
#                [-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742],
#                [-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742],
#                [-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742],
#                [-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742],
#                [-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742],
#                [-1.0471, -0.5540,  0.3702],
#                [ 0.9376, -0.1113,  0.0742]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 200 µs ± 5.68 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 659 µs ± 24.6 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
