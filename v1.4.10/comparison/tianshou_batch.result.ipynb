# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f59af592df0>
# ├── 'a' --> tensor([[-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010]])
# └── 'x' --> <FastTreeValue 0x7f59af592c10>
#     └── 'c' --> tensor([[-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899]])

# %%
t.a
# Out:
# tensor([[-0.2469, -0.0454,  0.7386],
#         [-1.3191, -0.2826, -0.4010]])

# %%
# %timeit t.a
# Out:
# 64.4 ns ± 0.0422 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f59af592df0>
# ├── 'a' --> tensor([[-1.2222,  0.9794,  2.1663],
# │                   [-0.5836,  1.7414,  0.2541]])
# └── 'x' --> <FastTreeValue 0x7f59af592c10>
#     └── 'c' --> tensor([[-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899]])

# %%
# %timeit t.a = new_value
# Out:
# 61.5 ns ± 0.0433 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010]]),
#     x: Batch(
#            c: tensor([[-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2469, -0.0454,  0.7386],
#         [-1.3191, -0.2826, -0.4010]])

# %%
# %timeit b.a
# Out:
# 58.3 ns ± 0.0155 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.2306,  1.4037, -0.4511],
#                [ 0.5644,  1.5431, -0.8329]]),
#     x: Batch(
#            c: tensor([[-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 485 ns ± 0.082 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 867 ns ± 4.85 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.7 µs ± 7.41 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 1.57 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 589 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f58ced94af0>
# ├── 'a' --> tensor([[[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]],
# │
# │                   [[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]],
# │
# │                   [[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]],
# │
# │                   [[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]],
# │
# │                   [[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]],
# │
# │                   [[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]],
# │
# │                   [[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]],
# │
# │                   [[-0.2469, -0.0454,  0.7386],
# │                    [-1.3191, -0.2826, -0.4010]]])
# └── 'x' --> <FastTreeValue 0x7f58ced94b20>
#     └── 'c' --> tensor([[[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                         [[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                         [[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                         [[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                         [[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                         [[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                         [[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                         [[-0.9359,  0.1275,  1.4792,  0.3138],
#                          [ 0.4353, -0.1419, -1.6264, -0.1023],
#                          [ 1.9519, -1.3939, -0.2297, -0.9899]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.9 µs ± 70.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f58e780b760>
# ├── 'a' --> tensor([[-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010],
# │                   [-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010],
# │                   [-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010],
# │                   [-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010],
# │                   [-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010],
# │                   [-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010],
# │                   [-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010],
# │                   [-0.2469, -0.0454,  0.7386],
# │                   [-1.3191, -0.2826, -0.4010]])
# └── 'x' --> <FastTreeValue 0x7f58cdd38f40>
#     └── 'c' --> tensor([[-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899],
#                         [-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899],
#                         [-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899],
#                         [-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899],
#                         [-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899],
#                         [-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899],
#                         [-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899],
#                         [-0.9359,  0.1275,  1.4792,  0.3138],
#                         [ 0.4353, -0.1419, -1.6264, -0.1023],
#                         [ 1.9519, -1.3939, -0.2297, -0.9899]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.7 µs ± 70.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 69.7 µs ± 42.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                       [[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                       [[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                       [[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                       [[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                       [[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                       [[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]],
#
#                       [[-0.9359,  0.1275,  1.4792,  0.3138],
#                        [ 0.4353, -0.1419, -1.6264, -0.1023],
#                        [ 1.9519, -1.3939, -0.2297, -0.9899]]]),
#        ),
#     a: tensor([[[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]],
#
#                [[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]],
#
#                [[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]],
#
#                [[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]],
#
#                [[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]],
#
#                [[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]],
#
#                [[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]],
#
#                [[-0.2469, -0.0454,  0.7386],
#                 [-1.3191, -0.2826, -0.4010]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 81.4 µs ± 341 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899],
#                       [-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899],
#                       [-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899],
#                       [-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899],
#                       [-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899],
#                       [-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899],
#                       [-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899],
#                       [-0.9359,  0.1275,  1.4792,  0.3138],
#                       [ 0.4353, -0.1419, -1.6264, -0.1023],
#                       [ 1.9519, -1.3939, -0.2297, -0.9899]]),
#        ),
#     a: tensor([[-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010],
#                [-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010],
#                [-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010],
#                [-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010],
#                [-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010],
#                [-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010],
#                [-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010],
#                [-0.2469, -0.0454,  0.7386],
#                [-1.3191, -0.2826, -0.4010]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 152 µs ± 379 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 335 µs ± 7.55 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
