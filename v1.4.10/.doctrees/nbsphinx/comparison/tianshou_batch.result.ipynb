# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fefbc8559d0>
# ├── 'a' --> tensor([[-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015]])
# └── 'x' --> <FastTreeValue 0x7fefc193a310>
#     └── 'c' --> tensor([[-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531]])

# %%
t.a
# Out:
# tensor([[-0.7762,  1.1774,  1.0172],
#         [-1.4848,  0.8297,  0.2015]])

# %%
# %timeit t.a
# Out:
# 66.8 ns ± 0.0691 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fefbc8559d0>
# ├── 'a' --> tensor([[-0.4062,  0.2409, -0.3850],
# │                   [-0.0714, -1.2697, -0.2042]])
# └── 'x' --> <FastTreeValue 0x7fefc193a310>
#     └── 'c' --> tensor([[-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531]])

# %%
# %timeit t.a = new_value
# Out:
# 70.6 ns ± 0.0136 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015]]),
#     x: Batch(
#            c: tensor([[-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7762,  1.1774,  1.0172],
#         [-1.4848,  0.8297,  0.2015]])

# %%
# %timeit b.a
# Out:
# 54.7 ns ± 0.0756 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.9800,  0.5608,  1.4834],
#                [ 0.0722, -0.8551, -0.2893]]),
#     x: Batch(
#            c: tensor([[-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 496 ns ± 0.175 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 842 ns ± 0.484 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.5 µs ± 38.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 139 µs ± 394 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 1.03 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7feeef071430>
# ├── 'a' --> tensor([[[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]],
# │
# │                   [[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]],
# │
# │                   [[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]],
# │
# │                   [[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]],
# │
# │                   [[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]],
# │
# │                   [[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]],
# │
# │                   [[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]],
# │
# │                   [[-0.7762,  1.1774,  1.0172],
# │                    [-1.4848,  0.8297,  0.2015]]])
# └── 'x' --> <FastTreeValue 0x7fefc18f8190>
#     └── 'c' --> tensor([[[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                         [[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                         [[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                         [[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                         [[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                         [[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                         [[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                         [[-0.0813, -1.0073,  0.2224,  1.6947],
#                          [ 0.9498, -0.4264, -1.2200,  1.1560],
#                          [ 0.3967, -1.0518,  0.5656, -1.5531]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32 µs ± 46.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7feef9c04c70>
# ├── 'a' --> tensor([[-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015],
# │                   [-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015],
# │                   [-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015],
# │                   [-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015],
# │                   [-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015],
# │                   [-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015],
# │                   [-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015],
# │                   [-0.7762,  1.1774,  1.0172],
# │                   [-1.4848,  0.8297,  0.2015]])
# └── 'x' --> <FastTreeValue 0x7fefbc8c4e20>
#     └── 'c' --> tensor([[-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531],
#                         [-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531],
#                         [-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531],
#                         [-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531],
#                         [-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531],
#                         [-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531],
#                         [-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531],
#                         [-0.0813, -1.0073,  0.2224,  1.6947],
#                         [ 0.9498, -0.4264, -1.2200,  1.1560],
#                         [ 0.3967, -1.0518,  0.5656, -1.5531]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.1 µs ± 91.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.7 µs ± 59.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                       [[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                       [[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                       [[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                       [[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                       [[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                       [[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]],
#
#                       [[-0.0813, -1.0073,  0.2224,  1.6947],
#                        [ 0.9498, -0.4264, -1.2200,  1.1560],
#                        [ 0.3967, -1.0518,  0.5656, -1.5531]]]),
#        ),
#     a: tensor([[[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]],
#
#                [[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]],
#
#                [[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]],
#
#                [[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]],
#
#                [[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]],
#
#                [[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]],
#
#                [[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]],
#
#                [[-0.7762,  1.1774,  1.0172],
#                 [-1.4848,  0.8297,  0.2015]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.1 µs ± 141 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531],
#                       [-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531],
#                       [-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531],
#                       [-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531],
#                       [-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531],
#                       [-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531],
#                       [-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531],
#                       [-0.0813, -1.0073,  0.2224,  1.6947],
#                       [ 0.9498, -0.4264, -1.2200,  1.1560],
#                       [ 0.3967, -1.0518,  0.5656, -1.5531]]),
#        ),
#     a: tensor([[-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015],
#                [-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015],
#                [-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015],
#                [-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015],
#                [-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015],
#                [-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015],
#                [-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015],
#                [-0.7762,  1.1774,  1.0172],
#                [-1.4848,  0.8297,  0.2015]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 393 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 327 µs ± 4.17 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
