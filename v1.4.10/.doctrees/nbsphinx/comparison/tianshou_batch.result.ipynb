# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f0e64124e20>
# ├── 'a' --> tensor([[ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622]])
# └── 'x' --> <FastTreeValue 0x7f0e64124700>
#     └── 'c' --> tensor([[-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209]])

# %%
t.a
# Out:
# tensor([[ 0.0048, -1.3324,  0.3060],
#         [-0.4558, -0.3247,  0.8622]])

# %%
# %timeit t.a
# Out:
# 69.4 ns ± 0.0193 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f0e64124e20>
# ├── 'a' --> tensor([[-2.2999, -0.3551, -0.5331],
# │                   [-0.0955,  0.1454,  0.1676]])
# └── 'x' --> <FastTreeValue 0x7f0e64124700>
#     └── 'c' --> tensor([[-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209]])

# %%
# %timeit t.a = new_value
# Out:
# 65 ns ± 0.0348 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622]]),
#     x: Batch(
#            c: tensor([[-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0048, -1.3324,  0.3060],
#         [-0.4558, -0.3247,  0.8622]])

# %%
# %timeit b.a
# Out:
# 56.7 ns ± 0.0197 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.4468,  0.4190,  0.3929],
#                [ 1.3089,  0.1088, -0.6683]]),
#     x: Batch(
#            c: tensor([[-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 483 ns ± 0.125 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 829 ns ± 0.232 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 37.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 137 µs ± 380 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 138 µs ± 2.06 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f0d879509a0>
# ├── 'a' --> tensor([[[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]],
# │
# │                   [[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]],
# │
# │                   [[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]],
# │
# │                   [[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]],
# │
# │                   [[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]],
# │
# │                   [[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]],
# │
# │                   [[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]],
# │
# │                   [[ 0.0048, -1.3324,  0.3060],
# │                    [-0.4558, -0.3247,  0.8622]]])
# └── 'x' --> <FastTreeValue 0x7f0e64119c70>
#     └── 'c' --> tensor([[[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                         [[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                         [[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                         [[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                         [[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                         [[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                         [[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                         [[-0.0676,  0.7722, -0.1086, -0.6988],
#                          [-0.2376, -1.7150,  0.5122,  0.4053],
#                          [-0.3278, -0.2699,  1.0629, -0.4209]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.2 µs ± 160 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f0e5c1d5e50>
# ├── 'a' --> tensor([[ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622],
# │                   [ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622],
# │                   [ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622],
# │                   [ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622],
# │                   [ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622],
# │                   [ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622],
# │                   [ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622],
# │                   [ 0.0048, -1.3324,  0.3060],
# │                   [-0.4558, -0.3247,  0.8622]])
# └── 'x' --> <FastTreeValue 0x7f0d87937fd0>
#     └── 'c' --> tensor([[-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209],
#                         [-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209],
#                         [-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209],
#                         [-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209],
#                         [-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209],
#                         [-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209],
#                         [-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209],
#                         [-0.0676,  0.7722, -0.1086, -0.6988],
#                         [-0.2376, -1.7150,  0.5122,  0.4053],
#                         [-0.3278, -0.2699,  1.0629, -0.4209]])

# %%
# %timeit t_cat(trees)
# Out:
# 31 µs ± 39 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.8 µs ± 145 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]],
#
#                [[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]],
#
#                [[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]],
#
#                [[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]],
#
#                [[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]],
#
#                [[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]],
#
#                [[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]],
#
#                [[ 0.0048, -1.3324,  0.3060],
#                 [-0.4558, -0.3247,  0.8622]]]),
#     x: Batch(
#            c: tensor([[[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                       [[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                       [[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                       [[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                       [[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                       [[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                       [[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]],
#
#                       [[-0.0676,  0.7722, -0.1086, -0.6988],
#                        [-0.2376, -1.7150,  0.5122,  0.4053],
#                        [-0.3278, -0.2699,  1.0629, -0.4209]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.2 µs ± 347 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622],
#                [ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622],
#                [ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622],
#                [ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622],
#                [ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622],
#                [ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622],
#                [ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622],
#                [ 0.0048, -1.3324,  0.3060],
#                [-0.4558, -0.3247,  0.8622]]),
#     x: Batch(
#            c: tensor([[-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209],
#                       [-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209],
#                       [-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209],
#                       [-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209],
#                       [-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209],
#                       [-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209],
#                       [-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209],
#                       [-0.0676,  0.7722, -0.1086, -0.6988],
#                       [-0.2376, -1.7150,  0.5122,  0.4053],
#                       [-0.3278, -0.2699,  1.0629, -0.4209]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 145 µs ± 873 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 319 µs ± 6.87 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
