# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fa5009c46d0>
# ├── 'a' --> tensor([[-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421]])
# └── 'x' --> <FastTreeValue 0x7fa5009c43d0>
#     └── 'c' --> tensor([[-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222]])

# %%
t.a
# Out:
# tensor([[-1.5625,  1.0823,  0.3785],
#         [-0.4753, -0.5690, -1.6421]])

# %%
# %timeit t.a
# Out:
# 82.7 ns ± 0.988 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fa5009c46d0>
# ├── 'a' --> tensor([[ 1.6512, -0.8359, -0.6669],
# │                   [ 0.4989,  1.3635, -1.0420]])
# └── 'x' --> <FastTreeValue 0x7fa5009c43d0>
#     └── 'c' --> tensor([[-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222]])

# %%
# %timeit t.a = new_value
# Out:
# 84.9 ns ± 0.37 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421]]),
#     x: Batch(
#            c: tensor([[-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.5625,  1.0823,  0.3785],
#         [-0.4753, -0.5690, -1.6421]])

# %%
# %timeit b.a
# Out:
# 71.4 ns ± 0.698 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.8580,  1.9188, -0.5537],
#                [ 0.2480, -0.5785,  1.2276]]),
#     x: Batch(
#            c: tensor([[-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 665 ns ± 8.45 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.1 µs ± 11.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.5 µs ± 129 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 268 µs ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 259 µs ± 15.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fa42326fdc0>
# ├── 'a' --> tensor([[[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]],
# │
# │                   [[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]],
# │
# │                   [[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]],
# │
# │                   [[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]],
# │
# │                   [[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]],
# │
# │                   [[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]],
# │
# │                   [[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]],
# │
# │                   [[-1.5625,  1.0823,  0.3785],
# │                    [-0.4753, -0.5690, -1.6421]]])
# └── 'x' --> <FastTreeValue 0x7fa4232eb1f0>
#     └── 'c' --> tensor([[[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                         [[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                         [[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                         [[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                         [[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                         [[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                         [[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                         [[-0.3898,  0.0255,  0.1787, -0.2578],
#                          [-0.6263,  0.2111,  0.3275, -2.2208],
#                          [-1.8876,  0.9940,  0.2528,  0.7222]]])

# %%
# %timeit t_stack(trees)
# Out:
# 50.4 µs ± 1.05 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fa4311d9a60>
# ├── 'a' --> tensor([[-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421],
# │                   [-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421],
# │                   [-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421],
# │                   [-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421],
# │                   [-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421],
# │                   [-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421],
# │                   [-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421],
# │                   [-1.5625,  1.0823,  0.3785],
# │                   [-0.4753, -0.5690, -1.6421]])
# └── 'x' --> <FastTreeValue 0x7fa4311d9c10>
#     └── 'c' --> tensor([[-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222],
#                         [-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222],
#                         [-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222],
#                         [-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222],
#                         [-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222],
#                         [-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222],
#                         [-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222],
#                         [-0.3898,  0.0255,  0.1787, -0.2578],
#                         [-0.6263,  0.2111,  0.3275, -2.2208],
#                         [-1.8876,  0.9940,  0.2528,  0.7222]])

# %%
# %timeit t_cat(trees)
# Out:
# 48.6 µs ± 2.64 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 102 µs ± 3.53 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                       [[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                       [[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                       [[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                       [[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                       [[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                       [[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]],
#
#                       [[-0.3898,  0.0255,  0.1787, -0.2578],
#                        [-0.6263,  0.2111,  0.3275, -2.2208],
#                        [-1.8876,  0.9940,  0.2528,  0.7222]]]),
#        ),
#     a: tensor([[[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]],
#
#                [[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]],
#
#                [[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]],
#
#                [[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]],
#
#                [[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]],
#
#                [[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]],
#
#                [[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]],
#
#                [[-1.5625,  1.0823,  0.3785],
#                 [-0.4753, -0.5690, -1.6421]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 113 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222],
#                       [-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222],
#                       [-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222],
#                       [-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222],
#                       [-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222],
#                       [-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222],
#                       [-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222],
#                       [-0.3898,  0.0255,  0.1787, -0.2578],
#                       [-0.6263,  0.2111,  0.3275, -2.2208],
#                       [-1.8876,  0.9940,  0.2528,  0.7222]]),
#        ),
#     a: tensor([[-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421],
#                [-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421],
#                [-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421],
#                [-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421],
#                [-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421],
#                [-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421],
#                [-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421],
#                [-1.5625,  1.0823,  0.3785],
#                [-0.4753, -0.5690, -1.6421]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 203 µs ± 3.28 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 710 µs ± 67.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
