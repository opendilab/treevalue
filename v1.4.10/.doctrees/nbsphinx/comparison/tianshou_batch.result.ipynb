# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5404433fa0>
# ├── 'a' --> tensor([[ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323]])
# └── 'x' --> <FastTreeValue 0x7f5404433df0>
#     └── 'c' --> tensor([[ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889]])

# %%
t.a
# Out:
# tensor([[ 0.8325,  1.9681,  0.1941],
#         [ 0.7107, -2.5797,  1.7323]])

# %%
# %timeit t.a
# Out:
# 63.8 ns ± 0.0415 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5404433fa0>
# ├── 'a' --> tensor([[-0.0932, -0.7981, -0.8055],
# │                   [-0.9986, -0.3373, -0.4836]])
# └── 'x' --> <FastTreeValue 0x7f5404433df0>
#     └── 'c' --> tensor([[ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889]])

# %%
# %timeit t.a = new_value
# Out:
# 66.2 ns ± 0.043 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323]]),
#     x: Batch(
#            c: tensor([[ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8325,  1.9681,  0.1941],
#         [ 0.7107, -2.5797,  1.7323]])

# %%
# %timeit b.a
# Out:
# 58.6 ns ± 0.0516 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.9504,  0.5102,  0.4904],
#                [-1.8867,  1.1201, -0.6109]]),
#     x: Batch(
#            c: tensor([[ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 495 ns ± 0.878 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 807 ns ± 3.64 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.6 µs ± 18.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 1.23 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 376 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5404433f40>
# ├── 'a' --> tensor([[[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]],
# │
# │                   [[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]],
# │
# │                   [[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]],
# │
# │                   [[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]],
# │
# │                   [[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]],
# │
# │                   [[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]],
# │
# │                   [[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]],
# │
# │                   [[ 0.8325,  1.9681,  0.1941],
# │                    [ 0.7107, -2.5797,  1.7323]]])
# └── 'x' --> <FastTreeValue 0x7f5334084790>
#     └── 'c' --> tensor([[[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                         [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                         [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                         [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                         [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                         [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                         [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                         [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                          [ 2.3555, -0.6586, -0.5265,  1.0197],
#                          [-0.1509, -1.3955,  0.6940, -0.6889]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 119 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5334084e50>
# ├── 'a' --> tensor([[ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323],
# │                   [ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323],
# │                   [ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323],
# │                   [ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323],
# │                   [ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323],
# │                   [ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323],
# │                   [ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323],
# │                   [ 0.8325,  1.9681,  0.1941],
# │                   [ 0.7107, -2.5797,  1.7323]])
# └── 'x' --> <FastTreeValue 0x7f5334084940>
#     └── 'c' --> tensor([[ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889],
#                         [ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889],
#                         [ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889],
#                         [ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889],
#                         [ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889],
#                         [ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889],
#                         [ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889],
#                         [ 1.4073, -0.5541, -0.0419,  0.2157],
#                         [ 2.3555, -0.6586, -0.5265,  1.0197],
#                         [-0.1509, -1.3955,  0.6940, -0.6889]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.8 µs ± 72.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68 µs ± 58.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                       [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                       [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                       [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                       [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                       [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                       [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]],
#
#                       [[ 1.4073, -0.5541, -0.0419,  0.2157],
#                        [ 2.3555, -0.6586, -0.5265,  1.0197],
#                        [-0.1509, -1.3955,  0.6940, -0.6889]]]),
#        ),
#     a: tensor([[[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]],
#
#                [[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]],
#
#                [[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]],
#
#                [[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]],
#
#                [[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]],
#
#                [[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]],
#
#                [[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]],
#
#                [[ 0.8325,  1.9681,  0.1941],
#                 [ 0.7107, -2.5797,  1.7323]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.7 µs ± 198 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889],
#                       [ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889],
#                       [ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889],
#                       [ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889],
#                       [ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889],
#                       [ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889],
#                       [ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889],
#                       [ 1.4073, -0.5541, -0.0419,  0.2157],
#                       [ 2.3555, -0.6586, -0.5265,  1.0197],
#                       [-0.1509, -1.3955,  0.6940, -0.6889]]),
#        ),
#     a: tensor([[ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323],
#                [ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323],
#                [ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323],
#                [ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323],
#                [ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323],
#                [ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323],
#                [ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323],
#                [ 0.8325,  1.9681,  0.1941],
#                [ 0.7107, -2.5797,  1.7323]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 146 µs ± 789 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 347 µs ± 1.77 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
