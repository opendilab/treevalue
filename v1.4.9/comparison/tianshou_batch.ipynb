# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb0501c5370>
# ├── 'a' --> tensor([[ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200]])
# └── 'x' --> <FastTreeValue 0x7fb0501be130>
#     └── 'c' --> tensor([[ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813]])

# %%
t.a
# Out:
# tensor([[ 0.0639, -1.2395, -1.1217],
#         [-0.2416,  0.7529, -0.3200]])

# %%
# %timeit t.a
# Out:
# 72.2 ns ± 0.115 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb0501c5370>
# ├── 'a' --> tensor([[ 1.4129, -1.1408,  0.6447],
# │                   [-1.5124,  0.8358,  1.4733]])
# └── 'x' --> <FastTreeValue 0x7fb0501be130>
#     └── 'c' --> tensor([[ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813]])

# %%
# %timeit t.a = new_value
# Out:
# 74.6 ns ± 0.163 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200]]),
#     x: Batch(
#            c: tensor([[ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0639, -1.2395, -1.1217],
#         [-0.2416,  0.7529, -0.3200]])

# %%
# %timeit b.a
# Out:
# 69.6 ns ± 0.0969 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.7035, -0.2272, -0.9670],
#                [ 1.3279,  0.1914, -1.2148]]),
#     x: Batch(
#            c: tensor([[ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 544 ns ± 0.335 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 868 ns ± 0.178 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 34.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 143 µs ± 751 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 589 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7faf72a61a60>
# ├── 'a' --> tensor([[[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]],
# │
# │                   [[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]],
# │
# │                   [[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]],
# │
# │                   [[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]],
# │
# │                   [[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]],
# │
# │                   [[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]],
# │
# │                   [[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]],
# │
# │                   [[ 0.0639, -1.2395, -1.1217],
# │                    [-0.2416,  0.7529, -0.3200]]])
# └── 'x' --> <FastTreeValue 0x7faf72a614f0>
#     └── 'c' --> tensor([[[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                         [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                         [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                         [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                         [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                         [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                         [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                         [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                          [-0.8336,  0.4658, -0.6174,  0.8707],
#                          [ 2.0822, -1.0534,  0.7577, -0.0813]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 83.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7faf809872e0>
# ├── 'a' --> tensor([[ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200],
# │                   [ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200],
# │                   [ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200],
# │                   [ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200],
# │                   [ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200],
# │                   [ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200],
# │                   [ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200],
# │                   [ 0.0639, -1.2395, -1.1217],
# │                   [-0.2416,  0.7529, -0.3200]])
# └── 'x' --> <FastTreeValue 0x7faf72ad3f10>
#     └── 'c' --> tensor([[ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813],
#                         [ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813],
#                         [ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813],
#                         [ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813],
#                         [ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813],
#                         [ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813],
#                         [ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813],
#                         [ 0.4350, -1.1292,  0.7903,  0.5790],
#                         [-0.8336,  0.4658, -0.6174,  0.8707],
#                         [ 2.0822, -1.0534,  0.7577, -0.0813]])

# %%
# %timeit t_cat(trees)
# Out:
# 31 µs ± 54.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.4 µs ± 89.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                       [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                       [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                       [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                       [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                       [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                       [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]],
#
#                       [[ 0.4350, -1.1292,  0.7903,  0.5790],
#                        [-0.8336,  0.4658, -0.6174,  0.8707],
#                        [ 2.0822, -1.0534,  0.7577, -0.0813]]]),
#        ),
#     a: tensor([[[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]],
#
#                [[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]],
#
#                [[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]],
#
#                [[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]],
#
#                [[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]],
#
#                [[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]],
#
#                [[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]],
#
#                [[ 0.0639, -1.2395, -1.1217],
#                 [-0.2416,  0.7529, -0.3200]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.3 µs ± 175 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813],
#                       [ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813],
#                       [ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813],
#                       [ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813],
#                       [ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813],
#                       [ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813],
#                       [ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813],
#                       [ 0.4350, -1.1292,  0.7903,  0.5790],
#                       [-0.8336,  0.4658, -0.6174,  0.8707],
#                       [ 2.0822, -1.0534,  0.7577, -0.0813]]),
#        ),
#     a: tensor([[ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200],
#                [ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200],
#                [ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200],
#                [ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200],
#                [ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200],
#                [ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200],
#                [ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200],
#                [ 0.0639, -1.2395, -1.1217],
#                [-0.2416,  0.7529, -0.3200]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 413 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 349 µs ± 7.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
