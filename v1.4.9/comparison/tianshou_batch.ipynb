# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f3ba5113d90>
# ├── 'a' --> tensor([[ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169]])
# └── 'x' --> <FastTreeValue 0x7f3ba5098400>
#     └── 'c' --> tensor([[-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034]])

# %%
t.a
# Out:
# tensor([[ 0.0971,  0.7965, -0.9601],
#         [ 1.1143, -0.3848,  2.4169]])

# %%
# %timeit t.a
# Out:
# 87 ns ± 0.472 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f3ba5113d90>
# ├── 'a' --> tensor([[-0.9334,  0.8163,  0.4536],
# │                   [-1.1208,  1.8251,  0.4718]])
# └── 'x' --> <FastTreeValue 0x7f3ba5098400>
#     └── 'c' --> tensor([[-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034]])

# %%
# %timeit t.a = new_value
# Out:
# 84.5 ns ± 0.386 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169]]),
#     x: Batch(
#            c: tensor([[-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0971,  0.7965, -0.9601],
#         [ 1.1143, -0.3848,  2.4169]])

# %%
# %timeit b.a
# Out:
# 74 ns ± 0.557 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.0467, -0.5971,  0.9150],
#                [-1.7351, -1.4567,  0.1183]]),
#     x: Batch(
#            c: tensor([[-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 669 ns ± 5.51 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.1 µs ± 12.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.8 µs ± 94.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 280 µs ± 14.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 261 µs ± 8.07 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f3ac48d45b0>
# ├── 'a' --> tensor([[[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]],
# │
# │                   [[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]],
# │
# │                   [[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]],
# │
# │                   [[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]],
# │
# │                   [[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]],
# │
# │                   [[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]],
# │
# │                   [[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]],
# │
# │                   [[ 0.0971,  0.7965, -0.9601],
# │                    [ 1.1143, -0.3848,  2.4169]]])
# └── 'x' --> <FastTreeValue 0x7f3ad27fc250>
#     └── 'c' --> tensor([[[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                         [[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                         [[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                         [[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                         [[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                         [[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                         [[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                         [[-0.6472,  0.8780,  1.3981,  1.7420],
#                          [ 0.6891,  0.1784, -0.9523, -0.3230],
#                          [-0.9347,  0.0295,  0.4378, -0.1034]]])

# %%
# %timeit t_stack(trees)
# Out:
# 48.6 µs ± 246 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f3ad27fcbb0>
# ├── 'a' --> tensor([[ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169],
# │                   [ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169],
# │                   [ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169],
# │                   [ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169],
# │                   [ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169],
# │                   [ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169],
# │                   [ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169],
# │                   [ 0.0971,  0.7965, -0.9601],
# │                   [ 1.1143, -0.3848,  2.4169]])
# └── 'x' --> <FastTreeValue 0x7f3ad27fc220>
#     └── 'c' --> tensor([[-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034],
#                         [-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034],
#                         [-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034],
#                         [-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034],
#                         [-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034],
#                         [-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034],
#                         [-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034],
#                         [-0.6472,  0.8780,  1.3981,  1.7420],
#                         [ 0.6891,  0.1784, -0.9523, -0.3230],
#                         [-0.9347,  0.0295,  0.4378, -0.1034]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.2 µs ± 1.35 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 102 µs ± 1.67 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                       [[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                       [[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                       [[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                       [[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                       [[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                       [[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]],
#
#                       [[-0.6472,  0.8780,  1.3981,  1.7420],
#                        [ 0.6891,  0.1784, -0.9523, -0.3230],
#                        [-0.9347,  0.0295,  0.4378, -0.1034]]]),
#        ),
#     a: tensor([[[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]],
#
#                [[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]],
#
#                [[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]],
#
#                [[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]],
#
#                [[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]],
#
#                [[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]],
#
#                [[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]],
#
#                [[ 0.0971,  0.7965, -0.9601],
#                 [ 1.1143, -0.3848,  2.4169]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 114 µs ± 1.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034],
#                       [-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034],
#                       [-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034],
#                       [-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034],
#                       [-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034],
#                       [-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034],
#                       [-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034],
#                       [-0.6472,  0.8780,  1.3981,  1.7420],
#                       [ 0.6891,  0.1784, -0.9523, -0.3230],
#                       [-0.9347,  0.0295,  0.4378, -0.1034]]),
#        ),
#     a: tensor([[ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169],
#                [ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169],
#                [ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169],
#                [ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169],
#                [ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169],
#                [ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169],
#                [ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169],
#                [ 0.0971,  0.7965, -0.9601],
#                [ 1.1143, -0.3848,  2.4169]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 208 µs ± 6.43 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 639 µs ± 13.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
