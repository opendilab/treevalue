# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f20fc775f40>
# ├── 'a' --> tensor([[-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627]])
# └── 'x' --> <FastTreeValue 0x7f20fc775e50>
#     └── 'c' --> tensor([[-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990]])

# %%
t.a
# Out:
# tensor([[-1.6341, -0.7247, -1.3606],
#         [-0.7418,  0.7221, -0.2627]])

# %%
# %timeit t.a
# Out:
# 63.6 ns ± 0.0476 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f20fc775f40>
# ├── 'a' --> tensor([[-0.5880,  0.3184,  0.1054],
# │                   [-0.2095, -0.5954,  1.9935]])
# └── 'x' --> <FastTreeValue 0x7f20fc775e50>
#     └── 'c' --> tensor([[-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990]])

# %%
# %timeit t.a = new_value
# Out:
# 66.1 ns ± 0.0593 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627]]),
#     x: Batch(
#            c: tensor([[-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.6341, -0.7247, -1.3606],
#         [-0.7418,  0.7221, -0.2627]])

# %%
# %timeit b.a
# Out:
# 59 ns ± 0.0613 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.1836,  0.3430, -0.3185],
#                [ 1.7369,  0.6922, -0.0406]]),
#     x: Batch(
#            c: tensor([[-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 500 ns ± 0.142 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 808 ns ± 0.722 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 13.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 852 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 517 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f202e377670>
# ├── 'a' --> tensor([[[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]],
# │
# │                   [[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]],
# │
# │                   [[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]],
# │
# │                   [[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]],
# │
# │                   [[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]],
# │
# │                   [[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]],
# │
# │                   [[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]],
# │
# │                   [[-1.6341, -0.7247, -1.3606],
# │                    [-0.7418,  0.7221, -0.2627]]])
# └── 'x' --> <FastTreeValue 0x7f202e377c70>
#     └── 'c' --> tensor([[[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                         [[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                         [[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                         [[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                         [[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                         [[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                         [[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                         [[-0.9844, -0.7891,  0.5008,  0.4371],
#                          [ 0.1670, -0.2466,  0.2056,  0.8016],
#                          [-0.7788,  1.2567, -1.1857, -0.7990]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.3 µs ± 34.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f202053cd60>
# ├── 'a' --> tensor([[-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627],
# │                   [-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627],
# │                   [-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627],
# │                   [-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627],
# │                   [-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627],
# │                   [-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627],
# │                   [-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627],
# │                   [-1.6341, -0.7247, -1.3606],
# │                   [-0.7418,  0.7221, -0.2627]])
# └── 'x' --> <FastTreeValue 0x7f202053cee0>
#     └── 'c' --> tensor([[-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990],
#                         [-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990],
#                         [-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990],
#                         [-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990],
#                         [-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990],
#                         [-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990],
#                         [-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990],
#                         [-0.9844, -0.7891,  0.5008,  0.4371],
#                         [ 0.1670, -0.2466,  0.2056,  0.8016],
#                         [-0.7788,  1.2567, -1.1857, -0.7990]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.9 µs ± 80.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.7 µs ± 74.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]],
#
#                [[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]],
#
#                [[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]],
#
#                [[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]],
#
#                [[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]],
#
#                [[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]],
#
#                [[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]],
#
#                [[-1.6341, -0.7247, -1.3606],
#                 [-0.7418,  0.7221, -0.2627]]]),
#     x: Batch(
#            c: tensor([[[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                       [[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                       [[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                       [[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                       [[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                       [[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                       [[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]],
#
#                       [[-0.9844, -0.7891,  0.5008,  0.4371],
#                        [ 0.1670, -0.2466,  0.2056,  0.8016],
#                        [-0.7788,  1.2567, -1.1857, -0.7990]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80 µs ± 99.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627],
#                [-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627],
#                [-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627],
#                [-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627],
#                [-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627],
#                [-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627],
#                [-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627],
#                [-1.6341, -0.7247, -1.3606],
#                [-0.7418,  0.7221, -0.2627]]),
#     x: Batch(
#            c: tensor([[-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990],
#                       [-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990],
#                       [-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990],
#                       [-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990],
#                       [-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990],
#                       [-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990],
#                       [-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990],
#                       [-0.9844, -0.7891,  0.5008,  0.4371],
#                       [ 0.1670, -0.2466,  0.2056,  0.8016],
#                       [-0.7788,  1.2567, -1.1857, -0.7990]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 147 µs ± 1.32 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 349 µs ± 3.87 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
