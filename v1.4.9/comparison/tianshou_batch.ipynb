# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f840ce600d0>
# ├── 'a' --> tensor([[-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456]])
# └── 'x' --> <FastTreeValue 0x7f83e42e4700>
#     └── 'c' --> tensor([[-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381]])

# %%
t.a
# Out:
# tensor([[-0.1693, -1.2411,  1.1083],
#         [ 0.2348, -0.9138, -0.7456]])

# %%
# %timeit t.a
# Out:
# 87.9 ns ± 0.15 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f840ce600d0>
# ├── 'a' --> tensor([[ 0.1111,  0.4499,  0.7983],
# │                   [-0.5553, -1.1614,  0.0419]])
# └── 'x' --> <FastTreeValue 0x7f83e42e4700>
#     └── 'c' --> tensor([[-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381]])

# %%
# %timeit t.a = new_value
# Out:
# 89.3 ns ± 0.0849 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456]]),
#     x: Batch(
#            c: tensor([[-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.1693, -1.2411,  1.1083],
#         [ 0.2348, -0.9138, -0.7456]])

# %%
# %timeit b.a
# Out:
# 87.8 ns ± 0.3 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.9594, -0.2901,  0.1590],
#                [ 0.4468, -0.5524,  1.1407]]),
#     x: Batch(
#            c: tensor([[-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 672 ns ± 0.399 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.73 µs ± 19.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13 µs ± 27 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 175 µs ± 618 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 177 µs ± 1.62 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f840ce9da00>
# ├── 'a' --> tensor([[[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]],
# │
# │                   [[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]],
# │
# │                   [[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]],
# │
# │                   [[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]],
# │
# │                   [[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]],
# │
# │                   [[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]],
# │
# │                   [[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]],
# │
# │                   [[-0.1693, -1.2411,  1.1083],
# │                    [ 0.2348, -0.9138, -0.7456]]])
# └── 'x' --> <FastTreeValue 0x7f8336bcfcd0>
#     └── 'c' --> tensor([[[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                         [[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                         [[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                         [[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                         [[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                         [[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                         [[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                         [[-0.4604, -0.3749,  1.0360,  1.4542],
#                          [-0.0803, -1.6011, -0.9438, -0.0784],
#                          [-0.3663, -0.8563,  1.7624, -0.0381]]])

# %%
# %timeit t_stack(trees)
# Out:
# 40 µs ± 161 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f83362b52b0>
# ├── 'a' --> tensor([[-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456],
# │                   [-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456],
# │                   [-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456],
# │                   [-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456],
# │                   [-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456],
# │                   [-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456],
# │                   [-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456],
# │                   [-0.1693, -1.2411,  1.1083],
# │                   [ 0.2348, -0.9138, -0.7456]])
# └── 'x' --> <FastTreeValue 0x7f83e4202fd0>
#     └── 'c' --> tensor([[-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381],
#                         [-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381],
#                         [-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381],
#                         [-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381],
#                         [-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381],
#                         [-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381],
#                         [-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381],
#                         [-0.4604, -0.3749,  1.0360,  1.4542],
#                         [-0.0803, -1.6011, -0.9438, -0.0784],
#                         [-0.3663, -0.8563,  1.7624, -0.0381]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.9 µs ± 1.32 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.6 µs ± 93.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]],
#
#                [[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]],
#
#                [[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]],
#
#                [[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]],
#
#                [[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]],
#
#                [[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]],
#
#                [[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]],
#
#                [[-0.1693, -1.2411,  1.1083],
#                 [ 0.2348, -0.9138, -0.7456]]]),
#     x: Batch(
#            c: tensor([[[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                       [[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                       [[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                       [[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                       [[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                       [[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                       [[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]],
#
#                       [[-0.4604, -0.3749,  1.0360,  1.4542],
#                        [-0.0803, -1.6011, -0.9438, -0.0784],
#                        [-0.3663, -0.8563,  1.7624, -0.0381]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 99 µs ± 145 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456],
#                [-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456],
#                [-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456],
#                [-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456],
#                [-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456],
#                [-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456],
#                [-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456],
#                [-0.1693, -1.2411,  1.1083],
#                [ 0.2348, -0.9138, -0.7456]]),
#     x: Batch(
#            c: tensor([[-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381],
#                       [-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381],
#                       [-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381],
#                       [-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381],
#                       [-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381],
#                       [-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381],
#                       [-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381],
#                       [-0.4604, -0.3749,  1.0360,  1.4542],
#                       [-0.0803, -1.6011, -0.9438, -0.0784],
#                       [-0.3663, -0.8563,  1.7624, -0.0381]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 180 µs ± 122 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 455 µs ± 5.87 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
