# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f829452f820>
# ├── 'a' --> tensor([[ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348]])
# └── 'x' --> <FastTreeValue 0x7f829452f850>
#     └── 'c' --> tensor([[-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784]])

# %%
t.a
# Out:
# tensor([[ 0.1805,  1.1714, -0.9523],
#         [-1.4842,  0.3359, -0.7348]])

# %%
# %timeit t.a
# Out:
# 74.2 ns ± 0.0663 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f829452f820>
# ├── 'a' --> tensor([[-1.4475, -2.6678, -0.1099],
# │                   [ 0.7613, -0.1951, -1.8982]])
# └── 'x' --> <FastTreeValue 0x7f829452f850>
#     └── 'c' --> tensor([[-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784]])

# %%
# %timeit t.a = new_value
# Out:
# 81.1 ns ± 0.0602 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348]]),
#     x: Batch(
#            c: tensor([[-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.1805,  1.1714, -0.9523],
#         [-1.4842,  0.3359, -0.7348]])

# %%
# %timeit b.a
# Out:
# 60.9 ns ± 0.0666 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 2.2066,  0.1196, -0.0818],
#                [ 0.2221,  1.9354,  0.0524]]),
#     x: Batch(
#            c: tensor([[-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 494 ns ± 0.294 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 814 ns ± 5.67 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 8.64 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 313 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 226 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f81b9662af0>
# ├── 'a' --> tensor([[[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]],
# │
# │                   [[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]],
# │
# │                   [[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]],
# │
# │                   [[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]],
# │
# │                   [[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]],
# │
# │                   [[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]],
# │
# │                   [[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]],
# │
# │                   [[ 0.1805,  1.1714, -0.9523],
# │                    [-1.4842,  0.3359, -0.7348]]])
# └── 'x' --> <FastTreeValue 0x7f81b9662e20>
#     └── 'c' --> tensor([[[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                         [[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                         [[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                         [[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                         [[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                         [[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                         [[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                         [[-1.8396, -1.6364, -2.4151, -0.4126],
#                          [ 0.4257,  0.8001, -1.4069, -0.4998],
#                          [-0.5037,  0.1638, -1.9532, -0.2784]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.6 µs ± 111 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f81b9662e50>
# ├── 'a' --> tensor([[ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348],
# │                   [ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348],
# │                   [ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348],
# │                   [ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348],
# │                   [ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348],
# │                   [ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348],
# │                   [ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348],
# │                   [ 0.1805,  1.1714, -0.9523],
# │                   [-1.4842,  0.3359, -0.7348]])
# └── 'x' --> <FastTreeValue 0x7f81b9662be0>
#     └── 'c' --> tensor([[-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784],
#                         [-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784],
#                         [-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784],
#                         [-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784],
#                         [-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784],
#                         [-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784],
#                         [-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784],
#                         [-1.8396, -1.6364, -2.4151, -0.4126],
#                         [ 0.4257,  0.8001, -1.4069, -0.4998],
#                         [-0.5037,  0.1638, -1.9532, -0.2784]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.2 µs ± 66.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.7 µs ± 160 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]],
#
#                [[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]],
#
#                [[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]],
#
#                [[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]],
#
#                [[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]],
#
#                [[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]],
#
#                [[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]],
#
#                [[ 0.1805,  1.1714, -0.9523],
#                 [-1.4842,  0.3359, -0.7348]]]),
#     x: Batch(
#            c: tensor([[[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                       [[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                       [[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                       [[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                       [[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                       [[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                       [[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]],
#
#                       [[-1.8396, -1.6364, -2.4151, -0.4126],
#                        [ 0.4257,  0.8001, -1.4069, -0.4998],
#                        [-0.5037,  0.1638, -1.9532, -0.2784]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.7 µs ± 412 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348],
#                [ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348],
#                [ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348],
#                [ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348],
#                [ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348],
#                [ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348],
#                [ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348],
#                [ 0.1805,  1.1714, -0.9523],
#                [-1.4842,  0.3359, -0.7348]]),
#     x: Batch(
#            c: tensor([[-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784],
#                       [-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784],
#                       [-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784],
#                       [-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784],
#                       [-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784],
#                       [-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784],
#                       [-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784],
#                       [-1.8396, -1.6364, -2.4151, -0.4126],
#                       [ 0.4257,  0.8001, -1.4069, -0.4998],
#                       [-0.5037,  0.1638, -1.9532, -0.2784]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 148 µs ± 517 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 340 µs ± 638 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
