# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc198efe4f0>
# ├── 'a' --> tensor([[ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147]])
# └── 'x' --> <FastTreeValue 0x7fc198efe3d0>
#     └── 'c' --> tensor([[-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902]])

# %%
t.a
# Out:
# tensor([[ 2.8583,  1.4751,  1.2363],
#         [ 0.5493,  2.4923, -1.0147]])

# %%
# %timeit t.a
# Out:
# 72.1 ns ± 0.0716 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc198efe4f0>
# ├── 'a' --> tensor([[-0.3363, -0.6269, -0.1244],
# │                   [-0.3546,  0.0058,  0.3195]])
# └── 'x' --> <FastTreeValue 0x7fc198efe3d0>
#     └── 'c' --> tensor([[-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902]])

# %%
# %timeit t.a = new_value
# Out:
# 72 ns ± 0.128 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147]]),
#     x: Batch(
#            c: tensor([[-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 2.8583,  1.4751,  1.2363],
#         [ 0.5493,  2.4923, -1.0147]])

# %%
# %timeit b.a
# Out:
# 68.2 ns ± 0.0282 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.4837,  0.2889, -0.9938],
#                [ 0.0222,  0.2293,  0.5903]]),
#     x: Batch(
#            c: tensor([[-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 544 ns ± 0.0761 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 890 ns ± 0.758 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 33.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 143 µs ± 922 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 1.16 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc198efe310>
# ├── 'a' --> tensor([[[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]],
# │
# │                   [[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]],
# │
# │                   [[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]],
# │
# │                   [[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]],
# │
# │                   [[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]],
# │
# │                   [[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]],
# │
# │                   [[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]],
# │
# │                   [[ 2.8583,  1.4751,  1.2363],
# │                    [ 0.5493,  2.4923, -1.0147]]])
# └── 'x' --> <FastTreeValue 0x7fc198efe250>
#     └── 'c' --> tensor([[[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                         [[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                         [[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                         [[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                         [[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                         [[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                         [[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                         [[-0.2253, -0.0021,  0.6268,  0.0760],
#                          [ 0.2849,  0.9354,  1.7893,  1.6510],
#                          [-0.8473,  1.2995, -0.5616, -0.2902]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.3 µs ± 87.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc0bb7d1b80>
# ├── 'a' --> tensor([[ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147],
# │                   [ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147],
# │                   [ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147],
# │                   [ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147],
# │                   [ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147],
# │                   [ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147],
# │                   [ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147],
# │                   [ 2.8583,  1.4751,  1.2363],
# │                   [ 0.5493,  2.4923, -1.0147]])
# └── 'x' --> <FastTreeValue 0x7fc0bb7d1d00>
#     └── 'c' --> tensor([[-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902],
#                         [-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902],
#                         [-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902],
#                         [-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902],
#                         [-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902],
#                         [-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902],
#                         [-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902],
#                         [-0.2253, -0.0021,  0.6268,  0.0760],
#                         [ 0.2849,  0.9354,  1.7893,  1.6510],
#                         [-0.8473,  1.2995, -0.5616, -0.2902]])

# %%
# %timeit t_cat(trees)
# Out:
# 32 µs ± 113 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.4 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]],
#
#                [[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]],
#
#                [[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]],
#
#                [[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]],
#
#                [[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]],
#
#                [[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]],
#
#                [[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]],
#
#                [[ 2.8583,  1.4751,  1.2363],
#                 [ 0.5493,  2.4923, -1.0147]]]),
#     x: Batch(
#            c: tensor([[[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                       [[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                       [[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                       [[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                       [[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                       [[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                       [[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]],
#
#                       [[-0.2253, -0.0021,  0.6268,  0.0760],
#                        [ 0.2849,  0.9354,  1.7893,  1.6510],
#                        [-0.8473,  1.2995, -0.5616, -0.2902]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.5 µs ± 150 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147],
#                [ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147],
#                [ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147],
#                [ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147],
#                [ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147],
#                [ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147],
#                [ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147],
#                [ 2.8583,  1.4751,  1.2363],
#                [ 0.5493,  2.4923, -1.0147]]),
#     x: Batch(
#            c: tensor([[-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902],
#                       [-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902],
#                       [-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902],
#                       [-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902],
#                       [-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902],
#                       [-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902],
#                       [-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902],
#                       [-0.2253, -0.0021,  0.6268,  0.0760],
#                       [ 0.2849,  0.9354,  1.7893,  1.6510],
#                       [-0.8473,  1.2995, -0.5616, -0.2902]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 153 µs ± 441 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 346 µs ± 5.98 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
