# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb7056bc2e0>
# ├── 'a' --> tensor([[-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674]])
# └── 'x' --> <FastTreeValue 0x7fb7056bc880>
#     └── 'c' --> tensor([[-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229]])

# %%
t.a
# Out:
# tensor([[-0.2277, -0.6311,  1.3338],
#         [ 1.1571,  1.0818,  1.1674]])

# %%
# %timeit t.a
# Out:
# 85.5 ns ± 0.915 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb7056bc2e0>
# ├── 'a' --> tensor([[-0.6692,  0.2632,  1.6643],
# │                   [ 0.4711,  0.2812, -1.0354]])
# └── 'x' --> <FastTreeValue 0x7fb7056bc880>
#     └── 'c' --> tensor([[-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229]])

# %%
# %timeit t.a = new_value
# Out:
# 87.1 ns ± 0.486 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674]]),
#     x: Batch(
#            c: tensor([[-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2277, -0.6311,  1.3338],
#         [ 1.1571,  1.0818,  1.1674]])

# %%
# %timeit b.a
# Out:
# 74.5 ns ± 1.32 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.8009,  1.1480,  1.0953],
#                [-0.4912, -0.1539,  0.1379]]),
#     x: Batch(
#            c: tensor([[-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 618 ns ± 24.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 909 ns ± 17.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.6 µs ± 432 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 156 µs ± 2.72 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 156 µs ± 4.22 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fb624e53fa0>
# ├── 'a' --> tensor([[[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]],
# │
# │                   [[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]],
# │
# │                   [[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]],
# │
# │                   [[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]],
# │
# │                   [[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]],
# │
# │                   [[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]],
# │
# │                   [[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]],
# │
# │                   [[-0.2277, -0.6311,  1.3338],
# │                    [ 1.1571,  1.0818,  1.1674]]])
# └── 'x' --> <FastTreeValue 0x7fb6251dc670>
#     └── 'c' --> tensor([[[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                         [[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                         [[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                         [[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                         [[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                         [[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                         [[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                         [[-1.2075,  1.8667,  1.5095,  0.3370],
#                          [-0.9203, -0.8555, -0.3854,  0.9157],
#                          [-1.0094, -0.5842,  0.0205,  0.7229]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 652 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fb632d8fd30>
# ├── 'a' --> tensor([[-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674],
# │                   [-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674],
# │                   [-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674],
# │                   [-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674],
# │                   [-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674],
# │                   [-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674],
# │                   [-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674],
# │                   [-0.2277, -0.6311,  1.3338],
# │                   [ 1.1571,  1.0818,  1.1674]])
# └── 'x' --> <FastTreeValue 0x7fb70063ae50>
#     └── 'c' --> tensor([[-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229],
#                         [-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229],
#                         [-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229],
#                         [-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229],
#                         [-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229],
#                         [-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229],
#                         [-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229],
#                         [-1.2075,  1.8667,  1.5095,  0.3370],
#                         [-0.9203, -0.8555, -0.3854,  0.9157],
#                         [-1.0094, -0.5842,  0.0205,  0.7229]])

# %%
# %timeit t_cat(trees)
# Out:
# 33.6 µs ± 749 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 73.6 µs ± 2.61 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                       [[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                       [[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                       [[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                       [[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                       [[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                       [[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]],
#
#                       [[-1.2075,  1.8667,  1.5095,  0.3370],
#                        [-0.9203, -0.8555, -0.3854,  0.9157],
#                        [-1.0094, -0.5842,  0.0205,  0.7229]]]),
#        ),
#     a: tensor([[[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]],
#
#                [[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]],
#
#                [[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]],
#
#                [[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]],
#
#                [[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]],
#
#                [[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]],
#
#                [[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]],
#
#                [[-0.2277, -0.6311,  1.3338],
#                 [ 1.1571,  1.0818,  1.1674]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 93.5 µs ± 1.56 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229],
#                       [-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229],
#                       [-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229],
#                       [-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229],
#                       [-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229],
#                       [-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229],
#                       [-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229],
#                       [-1.2075,  1.8667,  1.5095,  0.3370],
#                       [-0.9203, -0.8555, -0.3854,  0.9157],
#                       [-1.0094, -0.5842,  0.0205,  0.7229]]),
#        ),
#     a: tensor([[-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674],
#                [-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674],
#                [-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674],
#                [-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674],
#                [-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674],
#                [-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674],
#                [-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674],
#                [-0.2277, -0.6311,  1.3338],
#                [ 1.1571,  1.0818,  1.1674]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 158 µs ± 4.31 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 396 µs ± 11.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
