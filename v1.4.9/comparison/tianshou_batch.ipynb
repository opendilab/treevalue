# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f82a8818d90>
# ├── 'a' --> tensor([[-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518]])
# └── 'x' --> <FastTreeValue 0x7f82a8818eb0>
#     └── 'c' --> tensor([[-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938]])

# %%
t.a
# Out:
# tensor([[-1.2124, -0.4745, -1.2731],
#         [-1.9713,  1.5994, -1.2518]])

# %%
# %timeit t.a
# Out:
# 72.9 ns ± 0.165 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f82a8818d90>
# ├── 'a' --> tensor([[ 1.6691,  1.1889, -1.3074],
# │                   [ 1.7389, -0.9633, -0.7140]])
# └── 'x' --> <FastTreeValue 0x7f82a8818eb0>
#     └── 'c' --> tensor([[-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938]])

# %%
# %timeit t.a = new_value
# Out:
# 69.2 ns ± 0.0363 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518]]),
#     x: Batch(
#            c: tensor([[-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.2124, -0.4745, -1.2731],
#         [-1.9713,  1.5994, -1.2518]])

# %%
# %timeit b.a
# Out:
# 54.6 ns ± 0.0309 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.0098, -0.2179, -1.2210],
#                [ 1.4148, -0.4234, -1.6411]]),
#     x: Batch(
#            c: tensor([[-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 489 ns ± 1.25 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.62 µs ± 109 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 33.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 140 µs ± 1.16 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 710 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f82a8887d00>
# ├── 'a' --> tensor([[[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]],
# │
# │                   [[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]],
# │
# │                   [[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]],
# │
# │                   [[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]],
# │
# │                   [[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]],
# │
# │                   [[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]],
# │
# │                   [[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]],
# │
# │                   [[-1.2124, -0.4745, -1.2731],
# │                    [-1.9713,  1.5994, -1.2518]]])
# └── 'x' --> <FastTreeValue 0x7f81b8eb3400>
#     └── 'c' --> tensor([[[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                         [[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                         [[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                         [[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                         [[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                         [[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                         [[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                         [[-0.2089,  0.1456,  0.6261,  0.0919],
#                          [ 0.4149,  1.4439, -0.7959,  0.5935],
#                          [ 1.4661,  1.1303, -0.3212,  0.3938]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 159 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f81d1e04910>
# ├── 'a' --> tensor([[-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518],
# │                   [-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518],
# │                   [-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518],
# │                   [-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518],
# │                   [-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518],
# │                   [-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518],
# │                   [-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518],
# │                   [-1.2124, -0.4745, -1.2731],
# │                   [-1.9713,  1.5994, -1.2518]])
# └── 'x' --> <FastTreeValue 0x7f81c763ae80>
#     └── 'c' --> tensor([[-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938],
#                         [-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938],
#                         [-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938],
#                         [-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938],
#                         [-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938],
#                         [-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938],
#                         [-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938],
#                         [-0.2089,  0.1456,  0.6261,  0.0919],
#                         [ 0.4149,  1.4439, -0.7959,  0.5935],
#                         [ 1.4661,  1.1303, -0.3212,  0.3938]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.4 µs ± 82.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.5 µs ± 73.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]],
#
#                [[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]],
#
#                [[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]],
#
#                [[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]],
#
#                [[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]],
#
#                [[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]],
#
#                [[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]],
#
#                [[-1.2124, -0.4745, -1.2731],
#                 [-1.9713,  1.5994, -1.2518]]]),
#     x: Batch(
#            c: tensor([[[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                       [[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                       [[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                       [[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                       [[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                       [[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                       [[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]],
#
#                       [[-0.2089,  0.1456,  0.6261,  0.0919],
#                        [ 0.4149,  1.4439, -0.7959,  0.5935],
#                        [ 1.4661,  1.1303, -0.3212,  0.3938]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.4 µs ± 322 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518],
#                [-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518],
#                [-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518],
#                [-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518],
#                [-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518],
#                [-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518],
#                [-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518],
#                [-1.2124, -0.4745, -1.2731],
#                [-1.9713,  1.5994, -1.2518]]),
#     x: Batch(
#            c: tensor([[-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938],
#                       [-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938],
#                       [-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938],
#                       [-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938],
#                       [-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938],
#                       [-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938],
#                       [-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938],
#                       [-0.2089,  0.1456,  0.6261,  0.0919],
#                       [ 0.4149,  1.4439, -0.7959,  0.5935],
#                       [ 1.4661,  1.1303, -0.3212,  0.3938]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 228 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 358 µs ± 5.81 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
