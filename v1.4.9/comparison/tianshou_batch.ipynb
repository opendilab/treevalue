# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9dacfc4550>
# ├── 'a' --> tensor([[-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671]])
# └── 'x' --> <FastTreeValue 0x7f9cef6d2d30>
#     └── 'c' --> tensor([[ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826]])

# %%
t.a
# Out:
# tensor([[-1.0921,  1.7420,  0.1157],
#         [ 0.1787, -0.5899, -1.3671]])

# %%
# %timeit t.a
# Out:
# 59.4 ns ± 0.0559 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9dacfc4550>
# ├── 'a' --> tensor([[ 1.1158, -0.6153, -0.2999],
# │                   [-0.3528,  1.0693, -0.0262]])
# └── 'x' --> <FastTreeValue 0x7f9cef6d2d30>
#     └── 'c' --> tensor([[ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826]])

# %%
# %timeit t.a = new_value
# Out:
# 61.7 ns ± 0.0287 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671]]),
#     x: Batch(
#            c: tensor([[ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.0921,  1.7420,  0.1157],
#         [ 0.1787, -0.5899, -1.3671]])

# %%
# %timeit b.a
# Out:
# 54.7 ns ± 0.0623 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.9630, -0.7880, -0.5218],
#                [ 2.4321, -0.7071, -0.9091]]),
#     x: Batch(
#            c: tensor([[ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 484 ns ± 0.45 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 850 ns ± 1.54 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.8 µs ± 25.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 139 µs ± 762 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 513 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f9cd68ee700>
# ├── 'a' --> tensor([[[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]],
# │
# │                   [[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]],
# │
# │                   [[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]],
# │
# │                   [[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]],
# │
# │                   [[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]],
# │
# │                   [[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]],
# │
# │                   [[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]],
# │
# │                   [[-1.0921,  1.7420,  0.1157],
# │                    [ 0.1787, -0.5899, -1.3671]]])
# └── 'x' --> <FastTreeValue 0x7f9dacfc47f0>
#     └── 'c' --> tensor([[[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                         [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                         [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                         [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                         [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                         [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                         [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                         [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                          [ 0.7201, -0.9107, -0.1143,  1.0589],
#                          [-0.3217,  1.9665, -0.3618,  0.4826]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.5 µs ± 140 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9db403c2b0>
# ├── 'a' --> tensor([[-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671],
# │                   [-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671],
# │                   [-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671],
# │                   [-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671],
# │                   [-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671],
# │                   [-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671],
# │                   [-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671],
# │                   [-1.0921,  1.7420,  0.1157],
# │                   [ 0.1787, -0.5899, -1.3671]])
# └── 'x' --> <FastTreeValue 0x7f9cef426820>
#     └── 'c' --> tensor([[ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826],
#                         [ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826],
#                         [ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826],
#                         [ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826],
#                         [ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826],
#                         [ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826],
#                         [ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826],
#                         [ 0.5493,  0.3698,  0.2008, -1.1419],
#                         [ 0.7201, -0.9107, -0.1143,  1.0589],
#                         [-0.3217,  1.9665, -0.3618,  0.4826]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.3 µs ± 62.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 70 µs ± 86.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]],
#
#                [[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]],
#
#                [[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]],
#
#                [[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]],
#
#                [[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]],
#
#                [[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]],
#
#                [[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]],
#
#                [[-1.0921,  1.7420,  0.1157],
#                 [ 0.1787, -0.5899, -1.3671]]]),
#     x: Batch(
#            c: tensor([[[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                       [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                       [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                       [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                       [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                       [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                       [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]],
#
#                       [[ 0.5493,  0.3698,  0.2008, -1.1419],
#                        [ 0.7201, -0.9107, -0.1143,  1.0589],
#                        [-0.3217,  1.9665, -0.3618,  0.4826]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.3 µs ± 269 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671],
#                [-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671],
#                [-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671],
#                [-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671],
#                [-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671],
#                [-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671],
#                [-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671],
#                [-1.0921,  1.7420,  0.1157],
#                [ 0.1787, -0.5899, -1.3671]]),
#     x: Batch(
#            c: tensor([[ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826],
#                       [ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826],
#                       [ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826],
#                       [ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826],
#                       [ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826],
#                       [ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826],
#                       [ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826],
#                       [ 0.5493,  0.3698,  0.2008, -1.1419],
#                       [ 0.7201, -0.9107, -0.1143,  1.0589],
#                       [-0.3217,  1.9665, -0.3618,  0.4826]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 537 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 339 µs ± 17.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
