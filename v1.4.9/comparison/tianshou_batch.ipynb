# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fafbbc90490>
# ├── 'a' --> tensor([[-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256]])
# └── 'x' --> <FastTreeValue 0x7fafbbc90310>
#     └── 'c' --> tensor([[-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892]])

# %%
t.a
# Out:
# tensor([[-1.2249, -0.2282, -0.1180],
#         [ 2.4746,  0.9928, -0.1256]])

# %%
# %timeit t.a
# Out:
# 64.7 ns ± 0.0525 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fafbbc90490>
# ├── 'a' --> tensor([[-0.0728, -1.5156, -0.1947],
# │                   [ 1.5389, -0.4492,  1.4219]])
# └── 'x' --> <FastTreeValue 0x7fafbbc90310>
#     └── 'c' --> tensor([[-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892]])

# %%
# %timeit t.a = new_value
# Out:
# 61.1 ns ± 0.0207 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256]]),
#     x: Batch(
#            c: tensor([[-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.2249, -0.2282, -0.1180],
#         [ 2.4746,  0.9928, -0.1256]])

# %%
# %timeit b.a
# Out:
# 51.4 ns ± 0.0316 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.3855,  0.5660,  1.9850],
#                [ 1.2469,  0.0987,  1.0214]]),
#     x: Batch(
#            c: tensor([[-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 480 ns ± 0.113 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 830 ns ± 0.539 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 35 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 139 µs ± 1.26 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 744 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fafb8c0cfd0>
# ├── 'a' --> tensor([[[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]],
# │
# │                   [[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]],
# │
# │                   [[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]],
# │
# │                   [[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]],
# │
# │                   [[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]],
# │
# │                   [[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]],
# │
# │                   [[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]],
# │
# │                   [[-1.2249, -0.2282, -0.1180],
# │                    [ 2.4746,  0.9928, -0.1256]]])
# └── 'x' --> <FastTreeValue 0x7fafb8ba2e20>
#     └── 'c' --> tensor([[[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                         [[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                         [[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                         [[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                         [[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                         [[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                         [[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                         [[-0.8683,  0.1123,  0.1465,  0.9690],
#                          [ 0.3273,  0.5886,  0.9590, -0.3153],
#                          [-0.7889,  0.4892,  0.4503,  0.1892]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.5 µs ± 100 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7faedd3dbf40>
# ├── 'a' --> tensor([[-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256],
# │                   [-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256],
# │                   [-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256],
# │                   [-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256],
# │                   [-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256],
# │                   [-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256],
# │                   [-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256],
# │                   [-1.2249, -0.2282, -0.1180],
# │                   [ 2.4746,  0.9928, -0.1256]])
# └── 'x' --> <FastTreeValue 0x7faef3d5f160>
#     └── 'c' --> tensor([[-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892],
#                         [-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892],
#                         [-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892],
#                         [-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892],
#                         [-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892],
#                         [-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892],
#                         [-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892],
#                         [-0.8683,  0.1123,  0.1465,  0.9690],
#                         [ 0.3273,  0.5886,  0.9590, -0.3153],
#                         [-0.7889,  0.4892,  0.4503,  0.1892]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.6 µs ± 87 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.8 µs ± 79.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                       [[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                       [[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                       [[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                       [[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                       [[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                       [[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]],
#
#                       [[-0.8683,  0.1123,  0.1465,  0.9690],
#                        [ 0.3273,  0.5886,  0.9590, -0.3153],
#                        [-0.7889,  0.4892,  0.4503,  0.1892]]]),
#        ),
#     a: tensor([[[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]],
#
#                [[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]],
#
#                [[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]],
#
#                [[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]],
#
#                [[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]],
#
#                [[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]],
#
#                [[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]],
#
#                [[-1.2249, -0.2282, -0.1180],
#                 [ 2.4746,  0.9928, -0.1256]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.8 µs ± 265 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892],
#                       [-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892],
#                       [-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892],
#                       [-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892],
#                       [-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892],
#                       [-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892],
#                       [-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892],
#                       [-0.8683,  0.1123,  0.1465,  0.9690],
#                       [ 0.3273,  0.5886,  0.9590, -0.3153],
#                       [-0.7889,  0.4892,  0.4503,  0.1892]]),
#        ),
#     a: tensor([[-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256],
#                [-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256],
#                [-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256],
#                [-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256],
#                [-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256],
#                [-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256],
#                [-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256],
#                [-1.2249, -0.2282, -0.1180],
#                [ 2.4746,  0.9928, -0.1256]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 147 µs ± 301 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 324 µs ± 1.87 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
