# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc4343f07c0>
# ├── 'a' --> tensor([[-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266]])
# └── 'x' --> <FastTreeValue 0x7fc4343f09d0>
#     └── 'c' --> tensor([[ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395]])

# %%
t.a
# Out:
# tensor([[-0.6458, -0.5966,  0.4236],
#         [-0.7259, -0.7237, -0.4266]])

# %%
# %timeit t.a
# Out:
# 83.2 ns ± 1.43 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc4343f07c0>
# ├── 'a' --> tensor([[ 0.0165,  0.6419,  0.5560],
# │                   [ 0.6404, -1.4287,  1.5773]])
# └── 'x' --> <FastTreeValue 0x7fc4343f09d0>
#     └── 'c' --> tensor([[ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395]])

# %%
# %timeit t.a = new_value
# Out:
# 83.9 ns ± 1.13 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266]]),
#     x: Batch(
#            c: tensor([[ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.6458, -0.5966,  0.4236],
#         [-0.7259, -0.7237, -0.4266]])

# %%
# %timeit b.a
# Out:
# 74.9 ns ± 1.35 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.6553,  0.8331,  0.0588],
#                [ 0.4051,  1.1194,  1.3981]]),
#     x: Batch(
#            c: tensor([[ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 658 ns ± 14.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 10 µs ± 213 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.7 µs ± 229 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 313 µs ± 9.33 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 303 µs ± 13.3 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc343a06070>
# ├── 'a' --> tensor([[[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]],
# │
# │                   [[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]],
# │
# │                   [[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]],
# │
# │                   [[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]],
# │
# │                   [[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]],
# │
# │                   [[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]],
# │
# │                   [[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]],
# │
# │                   [[-0.6458, -0.5966,  0.4236],
# │                    [-0.7259, -0.7237, -0.4266]]])
# └── 'x' --> <FastTreeValue 0x7fc343a061f0>
#     └── 'c' --> tensor([[[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                         [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                         [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                         [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                         [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                         [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                         [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                         [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                          [ 0.1082, -1.3604, -1.2271, -0.6794],
#                          [-0.3190, -1.2577, -0.0144,  1.7395]]])

# %%
# %timeit t_stack(trees)
# Out:
# 50 µs ± 1.7 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc343a06670>
# ├── 'a' --> tensor([[-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266],
# │                   [-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266],
# │                   [-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266],
# │                   [-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266],
# │                   [-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266],
# │                   [-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266],
# │                   [-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266],
# │                   [-0.6458, -0.5966,  0.4236],
# │                   [-0.7259, -0.7237, -0.4266]])
# └── 'x' --> <FastTreeValue 0x7fc343a06130>
#     └── 'c' --> tensor([[ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395],
#                         [ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395],
#                         [ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395],
#                         [ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395],
#                         [ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395],
#                         [ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395],
#                         [ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395],
#                         [ 1.6131, -2.2754, -1.2517,  0.6802],
#                         [ 0.1082, -1.3604, -1.2271, -0.6794],
#                         [-0.3190, -1.2577, -0.0144,  1.7395]])

# %%
# %timeit t_cat(trees)
# Out:
# 45.2 µs ± 824 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 104 µs ± 2.18 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                       [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                       [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                       [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                       [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                       [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                       [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]],
#
#                       [[ 1.6131, -2.2754, -1.2517,  0.6802],
#                        [ 0.1082, -1.3604, -1.2271, -0.6794],
#                        [-0.3190, -1.2577, -0.0144,  1.7395]]]),
#        ),
#     a: tensor([[[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]],
#
#                [[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]],
#
#                [[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]],
#
#                [[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]],
#
#                [[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]],
#
#                [[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]],
#
#                [[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]],
#
#                [[-0.6458, -0.5966,  0.4236],
#                 [-0.7259, -0.7237, -0.4266]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 112 µs ± 4.6 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395],
#                       [ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395],
#                       [ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395],
#                       [ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395],
#                       [ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395],
#                       [ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395],
#                       [ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395],
#                       [ 1.6131, -2.2754, -1.2517,  0.6802],
#                       [ 0.1082, -1.3604, -1.2271, -0.6794],
#                       [-0.3190, -1.2577, -0.0144,  1.7395]]),
#        ),
#     a: tensor([[-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266],
#                [-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266],
#                [-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266],
#                [-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266],
#                [-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266],
#                [-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266],
#                [-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266],
#                [-0.6458, -0.5966,  0.4236],
#                [-0.7259, -0.7237, -0.4266]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 195 µs ± 2.89 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 652 µs ± 25 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
