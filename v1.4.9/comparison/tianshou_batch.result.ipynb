# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fdd09a62df0>
# ├── 'a' --> tensor([[ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131]])
# └── 'x' --> <FastTreeValue 0x7fdd09a62bb0>
#     └── 'c' --> tensor([[-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586]])

# %%
t.a
# Out:
# tensor([[ 1.2478,  0.2741, -1.0767],
#         [ 0.0179, -0.0067, -1.9131]])

# %%
# %timeit t.a
# Out:
# 62.9 ns ± 0.0798 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fdd09a62df0>
# ├── 'a' --> tensor([[-0.5593,  0.8031, -0.1126],
# │                   [-1.4360, -2.9471,  0.8153]])
# └── 'x' --> <FastTreeValue 0x7fdd09a62bb0>
#     └── 'c' --> tensor([[-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586]])

# %%
# %timeit t.a = new_value
# Out:
# 69.4 ns ± 0.0506 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131]]),
#     x: Batch(
#            c: tensor([[-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.2478,  0.2741, -1.0767],
#         [ 0.0179, -0.0067, -1.9131]])

# %%
# %timeit b.a
# Out:
# 59.4 ns ± 0.0378 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.7780, -0.5350, -0.9460],
#                [-0.0704,  1.1328, -1.1583]]),
#     x: Batch(
#            c: tensor([[-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 496 ns ± 0.0339 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 813 ns ± 0.248 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 34 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 143 µs ± 547 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 667 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fdc38ca2760>
# ├── 'a' --> tensor([[[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]],
# │
# │                   [[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]],
# │
# │                   [[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]],
# │
# │                   [[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]],
# │
# │                   [[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]],
# │
# │                   [[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]],
# │
# │                   [[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]],
# │
# │                   [[ 1.2478,  0.2741, -1.0767],
# │                    [ 0.0179, -0.0067, -1.9131]]])
# └── 'x' --> <FastTreeValue 0x7fdd09ac2f10>
#     └── 'c' --> tensor([[[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                         [[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                         [[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                         [[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                         [[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                         [[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                         [[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                         [[-1.1259, -2.7068,  2.2372,  0.7570],
#                          [-0.0307, -0.2814, -0.1282,  1.0457],
#                          [-0.4827,  1.3990,  0.3906, -0.1586]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.9 µs ± 67.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fdc2bb52490>
# ├── 'a' --> tensor([[ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131],
# │                   [ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131],
# │                   [ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131],
# │                   [ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131],
# │                   [ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131],
# │                   [ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131],
# │                   [ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131],
# │                   [ 1.2478,  0.2741, -1.0767],
# │                   [ 0.0179, -0.0067, -1.9131]])
# └── 'x' --> <FastTreeValue 0x7fdc2bb52400>
#     └── 'c' --> tensor([[-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586],
#                         [-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586],
#                         [-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586],
#                         [-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586],
#                         [-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586],
#                         [-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586],
#                         [-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586],
#                         [-1.1259, -2.7068,  2.2372,  0.7570],
#                         [-0.0307, -0.2814, -0.1282,  1.0457],
#                         [-0.4827,  1.3990,  0.3906, -0.1586]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.9 µs ± 62.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67 µs ± 40.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                       [[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                       [[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                       [[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                       [[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                       [[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                       [[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]],
#
#                       [[-1.1259, -2.7068,  2.2372,  0.7570],
#                        [-0.0307, -0.2814, -0.1282,  1.0457],
#                        [-0.4827,  1.3990,  0.3906, -0.1586]]]),
#        ),
#     a: tensor([[[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]],
#
#                [[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]],
#
#                [[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]],
#
#                [[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]],
#
#                [[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]],
#
#                [[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]],
#
#                [[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]],
#
#                [[ 1.2478,  0.2741, -1.0767],
#                 [ 0.0179, -0.0067, -1.9131]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.5 µs ± 243 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586],
#                       [-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586],
#                       [-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586],
#                       [-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586],
#                       [-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586],
#                       [-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586],
#                       [-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586],
#                       [-1.1259, -2.7068,  2.2372,  0.7570],
#                       [-0.0307, -0.2814, -0.1282,  1.0457],
#                       [-0.4827,  1.3990,  0.3906, -0.1586]]),
#        ),
#     a: tensor([[ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131],
#                [ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131],
#                [ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131],
#                [ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131],
#                [ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131],
#                [ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131],
#                [ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131],
#                [ 1.2478,  0.2741, -1.0767],
#                [ 0.0179, -0.0067, -1.9131]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 146 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 333 µs ± 500 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
