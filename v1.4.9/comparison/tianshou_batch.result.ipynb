# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f995c6ad820>
# ├── 'a' --> tensor([[-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620]])
# └── 'x' --> <FastTreeValue 0x7f995c6adeb0>
#     └── 'c' --> tensor([[ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212]])

# %%
t.a
# Out:
# tensor([[-0.0909, -1.3664,  0.2224],
#         [-0.5330,  0.3378,  0.1620]])

# %%
# %timeit t.a
# Out:
# 74.2 ns ± 0.18 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f995c6ad820>
# ├── 'a' --> tensor([[ 0.1856, -0.3989, -0.3771],
# │                   [ 0.3414,  0.6212,  1.0660]])
# └── 'x' --> <FastTreeValue 0x7f995c6adeb0>
#     └── 'c' --> tensor([[ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212]])

# %%
# %timeit t.a = new_value
# Out:
# 74.7 ns ± 0.146 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620]]),
#     x: Batch(
#            c: tensor([[ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.0909, -1.3664,  0.2224],
#         [-0.5330,  0.3378,  0.1620]])

# %%
# %timeit b.a
# Out:
# 69.7 ns ± 0.0684 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.2132, -0.8335, -0.2575],
#                [ 1.0753, -1.2932, -0.4610]]),
#     x: Batch(
#            c: tensor([[ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 554 ns ± 0.92 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 889 ns ± 0.824 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 17.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 152 µs ± 971 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 151 µs ± 1.44 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f995c6add90>
# ├── 'a' --> tensor([[[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]],
# │
# │                   [[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]],
# │
# │                   [[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]],
# │
# │                   [[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]],
# │
# │                   [[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]],
# │
# │                   [[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]],
# │
# │                   [[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]],
# │
# │                   [[-0.0909, -1.3664,  0.2224],
# │                    [-0.5330,  0.3378,  0.1620]]])
# └── 'x' --> <FastTreeValue 0x7f995c6adcd0>
#     └── 'c' --> tensor([[[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                         [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                         [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                         [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                         [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                         [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                         [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                         [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                          [ 1.9002,  0.1509,  1.6149,  0.2998],
#                          [ 0.2035, -1.2814,  0.2195, -0.4212]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.9 µs ± 104 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f986ed07340>
# ├── 'a' --> tensor([[-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620],
# │                   [-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620],
# │                   [-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620],
# │                   [-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620],
# │                   [-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620],
# │                   [-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620],
# │                   [-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620],
# │                   [-0.0909, -1.3664,  0.2224],
# │                   [-0.5330,  0.3378,  0.1620]])
# └── 'x' --> <FastTreeValue 0x7f986ed07880>
#     └── 'c' --> tensor([[ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212],
#                         [ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212],
#                         [ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212],
#                         [ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212],
#                         [ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212],
#                         [ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212],
#                         [ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212],
#                         [ 0.6799, -0.6034, -0.5100,  0.6008],
#                         [ 1.9002,  0.1509,  1.6149,  0.2998],
#                         [ 0.2035, -1.2814,  0.2195, -0.4212]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.9 µs ± 99.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.5 µs ± 45 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                       [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                       [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                       [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                       [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                       [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                       [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]],
#
#                       [[ 0.6799, -0.6034, -0.5100,  0.6008],
#                        [ 1.9002,  0.1509,  1.6149,  0.2998],
#                        [ 0.2035, -1.2814,  0.2195, -0.4212]]]),
#        ),
#     a: tensor([[[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]],
#
#                [[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]],
#
#                [[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]],
#
#                [[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]],
#
#                [[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]],
#
#                [[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]],
#
#                [[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]],
#
#                [[-0.0909, -1.3664,  0.2224],
#                 [-0.5330,  0.3378,  0.1620]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 85.1 µs ± 164 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212],
#                       [ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212],
#                       [ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212],
#                       [ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212],
#                       [ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212],
#                       [ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212],
#                       [ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212],
#                       [ 0.6799, -0.6034, -0.5100,  0.6008],
#                       [ 1.9002,  0.1509,  1.6149,  0.2998],
#                       [ 0.2035, -1.2814,  0.2195, -0.4212]]),
#        ),
#     a: tensor([[-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620],
#                [-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620],
#                [-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620],
#                [-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620],
#                [-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620],
#                [-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620],
#                [-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620],
#                [-0.0909, -1.3664,  0.2224],
#                [-0.5330,  0.3378,  0.1620]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 406 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 378 µs ± 10.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
