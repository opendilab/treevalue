# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc4409b2c10>
# ├── 'a' --> tensor([[ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381]])
# └── 'x' --> <FastTreeValue 0x7fc4409b26d0>
#     └── 'c' --> tensor([[ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739]])

# %%
t.a
# Out:
# tensor([[ 0.2363,  1.1786, -0.2301],
#         [ 0.5549, -0.0558, -0.4381]])

# %%
# %timeit t.a
# Out:
# 60.1 ns ± 0.0398 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc4409b2c10>
# ├── 'a' --> tensor([[ 0.6646, -1.6940,  0.1733],
# │                   [ 0.9858, -1.6711, -0.3650]])
# └── 'x' --> <FastTreeValue 0x7fc4409b26d0>
#     └── 'c' --> tensor([[ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739]])

# %%
# %timeit t.a = new_value
# Out:
# 59 ns ± 0.0601 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381]]),
#     x: Batch(
#            c: tensor([[ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.2363,  1.1786, -0.2301],
#         [ 0.5549, -0.0558, -0.4381]])

# %%
# %timeit b.a
# Out:
# 55.8 ns ± 0.0425 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.9885, -1.0693, -1.8033],
#                [ 1.2642,  0.8512, -0.1159]]),
#     x: Batch(
#            c: tensor([[ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 481 ns ± 0.189 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 996 ns ± 0.611 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 41.5 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 139 µs ± 1.4 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 1.05 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc4409b25e0>
# ├── 'a' --> tensor([[[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]],
# │
# │                   [[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]],
# │
# │                   [[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]],
# │
# │                   [[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]],
# │
# │                   [[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]],
# │
# │                   [[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]],
# │
# │                   [[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]],
# │
# │                   [[ 0.2363,  1.1786, -0.2301],
# │                    [ 0.5549, -0.0558, -0.4381]]])
# └── 'x' --> <FastTreeValue 0x7fc440996b50>
#     └── 'c' --> tensor([[[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                         [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                         [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                         [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                         [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                         [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                         [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                         [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                          [ 0.5771,  0.6858, -1.6819, -2.3071],
#                          [ 0.6159,  0.4710, -0.7772, -1.8739]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.6 µs ± 44 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc363c24eb0>
# ├── 'a' --> tensor([[ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381],
# │                   [ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381],
# │                   [ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381],
# │                   [ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381],
# │                   [ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381],
# │                   [ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381],
# │                   [ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381],
# │                   [ 0.2363,  1.1786, -0.2301],
# │                   [ 0.5549, -0.0558, -0.4381]])
# └── 'x' --> <FastTreeValue 0x7fc3637a9220>
#     └── 'c' --> tensor([[ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739],
#                         [ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739],
#                         [ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739],
#                         [ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739],
#                         [ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739],
#                         [ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739],
#                         [ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739],
#                         [ 0.7530, -0.6170, -0.1573,  2.6721],
#                         [ 0.5771,  0.6858, -1.6819, -2.3071],
#                         [ 0.6159,  0.4710, -0.7772, -1.8739]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.6 µs ± 105 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 70.2 µs ± 74.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]],
#
#                [[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]],
#
#                [[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]],
#
#                [[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]],
#
#                [[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]],
#
#                [[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]],
#
#                [[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]],
#
#                [[ 0.2363,  1.1786, -0.2301],
#                 [ 0.5549, -0.0558, -0.4381]]]),
#     x: Batch(
#            c: tensor([[[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                       [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                       [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                       [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                       [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                       [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                       [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]],
#
#                       [[ 0.7530, -0.6170, -0.1573,  2.6721],
#                        [ 0.5771,  0.6858, -1.6819, -2.3071],
#                        [ 0.6159,  0.4710, -0.7772, -1.8739]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.3 µs ± 193 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381],
#                [ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381],
#                [ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381],
#                [ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381],
#                [ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381],
#                [ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381],
#                [ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381],
#                [ 0.2363,  1.1786, -0.2301],
#                [ 0.5549, -0.0558, -0.4381]]),
#     x: Batch(
#            c: tensor([[ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739],
#                       [ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739],
#                       [ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739],
#                       [ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739],
#                       [ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739],
#                       [ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739],
#                       [ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739],
#                       [ 0.7530, -0.6170, -0.1573,  2.6721],
#                       [ 0.5771,  0.6858, -1.6819, -2.3071],
#                       [ 0.6159,  0.4710, -0.7772, -1.8739]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 146 µs ± 647 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 328 µs ± 679 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
