# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f48041c0430>
# ├── 'a' --> tensor([[-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827]])
# └── 'x' --> <FastTreeValue 0x7f48085b1af0>
#     └── 'c' --> tensor([[-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755]])

# %%
t.a
# Out:
# tensor([[-0.2956, -0.0268, -1.1199],
#         [-0.0915, -1.4693, -1.3827]])

# %%
# %timeit t.a
# Out:
# 88.6 ns ± 0.393 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f48041c0430>
# ├── 'a' --> tensor([[ 0.6170, -1.6233, -0.9258],
# │                   [ 0.6422,  0.9661, -0.3826]])
# └── 'x' --> <FastTreeValue 0x7f48085b1af0>
#     └── 'c' --> tensor([[-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755]])

# %%
# %timeit t.a = new_value
# Out:
# 96.6 ns ± 0.169 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827]]),
#     x: Batch(
#            c: tensor([[-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2956, -0.0268, -1.1199],
#         [-0.0915, -1.4693, -1.3827]])

# %%
# %timeit b.a
# Out:
# 81.6 ns ± 0.602 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0776,  0.1292,  0.8960],
#                [-0.4754,  0.3319,  0.5267]]),
#     x: Batch(
#            c: tensor([[-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 648 ns ± 2.68 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.07 µs ± 1.35 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.4 µs ± 89.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 174 µs ± 1.34 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 172 µs ± 890 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f4727a64df0>
# ├── 'a' --> tensor([[[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]],
# │
# │                   [[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]],
# │
# │                   [[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]],
# │
# │                   [[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]],
# │
# │                   [[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]],
# │
# │                   [[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]],
# │
# │                   [[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]],
# │
# │                   [[-0.2956, -0.0268, -1.1199],
# │                    [-0.0915, -1.4693, -1.3827]]])
# └── 'x' --> <FastTreeValue 0x7f4727a644c0>
#     └── 'c' --> tensor([[[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                         [[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                         [[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                         [[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                         [[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                         [[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                         [[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                         [[-0.3643, -0.1308, -0.1339, -2.7844],
#                          [-1.2030, -0.2666,  0.6920, -0.3156],
#                          [-1.1032, -1.2814, -0.1864, -0.3755]]])

# %%
# %timeit t_stack(trees)
# Out:
# 39.8 µs ± 78.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f4727a647f0>
# ├── 'a' --> tensor([[-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827],
# │                   [-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827],
# │                   [-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827],
# │                   [-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827],
# │                   [-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827],
# │                   [-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827],
# │                   [-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827],
# │                   [-0.2956, -0.0268, -1.1199],
# │                   [-0.0915, -1.4693, -1.3827]])
# └── 'x' --> <FastTreeValue 0x7f4727a64820>
#     └── 'c' --> tensor([[-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755],
#                         [-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755],
#                         [-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755],
#                         [-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755],
#                         [-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755],
#                         [-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755],
#                         [-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755],
#                         [-0.3643, -0.1308, -0.1339, -2.7844],
#                         [-1.2030, -0.2666,  0.6920, -0.3156],
#                         [-1.1032, -1.2814, -0.1864, -0.3755]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.3 µs ± 97.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 79.7 µs ± 246 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]],
#
#                [[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]],
#
#                [[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]],
#
#                [[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]],
#
#                [[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]],
#
#                [[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]],
#
#                [[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]],
#
#                [[-0.2956, -0.0268, -1.1199],
#                 [-0.0915, -1.4693, -1.3827]]]),
#     x: Batch(
#            c: tensor([[[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                       [[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                       [[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                       [[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                       [[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                       [[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                       [[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]],
#
#                       [[-0.3643, -0.1308, -0.1339, -2.7844],
#                        [-1.2030, -0.2666,  0.6920, -0.3156],
#                        [-1.1032, -1.2814, -0.1864, -0.3755]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 97.5 µs ± 1.77 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827],
#                [-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827],
#                [-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827],
#                [-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827],
#                [-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827],
#                [-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827],
#                [-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827],
#                [-0.2956, -0.0268, -1.1199],
#                [-0.0915, -1.4693, -1.3827]]),
#     x: Batch(
#            c: tensor([[-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755],
#                       [-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755],
#                       [-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755],
#                       [-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755],
#                       [-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755],
#                       [-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755],
#                       [-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755],
#                       [-0.3643, -0.1308, -0.1339, -2.7844],
#                       [-1.2030, -0.2666,  0.6920, -0.3156],
#                       [-1.1032, -1.2814, -0.1864, -0.3755]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 173 µs ± 1.3 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 399 µs ± 5.55 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
