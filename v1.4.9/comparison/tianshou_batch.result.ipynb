# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5c38b7a880>
# ├── 'a' --> tensor([[-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650]])
# └── 'x' --> <FastTreeValue 0x7f5c38b7a580>
#     └── 'c' --> tensor([[-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407]])

# %%
t.a
# Out:
# tensor([[-0.0035,  0.3781,  0.7497],
#         [-0.9561,  1.1244,  1.3650]])

# %%
# %timeit t.a
# Out:
# 74.4 ns ± 0.0758 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5c38b7a880>
# ├── 'a' --> tensor([[ 1.5717,  0.5944, -1.4531],
# │                   [ 1.1345,  1.0239, -0.4440]])
# └── 'x' --> <FastTreeValue 0x7f5c38b7a580>
#     └── 'c' --> tensor([[-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407]])

# %%
# %timeit t.a = new_value
# Out:
# 74.5 ns ± 0.033 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650]]),
#     x: Batch(
#            c: tensor([[-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.0035,  0.3781,  0.7497],
#         [-0.9561,  1.1244,  1.3650]])

# %%
# %timeit b.a
# Out:
# 68.2 ns ± 0.0604 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.5809,  0.8541, -0.8960],
#                [-1.0868, -0.5568, -0.4133]]),
#     x: Batch(
#            c: tensor([[-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 544 ns ± 0.158 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 870 ns ± 1.03 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 15.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 822 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 1.11 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5b588d0a00>
# ├── 'a' --> tensor([[[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]],
# │
# │                   [[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]],
# │
# │                   [[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]],
# │
# │                   [[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]],
# │
# │                   [[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]],
# │
# │                   [[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]],
# │
# │                   [[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]],
# │
# │                   [[-0.0035,  0.3781,  0.7497],
# │                    [-0.9561,  1.1244,  1.3650]]])
# └── 'x' --> <FastTreeValue 0x7f5b58395d90>
#     └── 'c' --> tensor([[[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                         [[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                         [[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                         [[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                         [[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                         [[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                         [[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                         [[-2.0307,  1.8054, -1.0529, -0.0950],
#                          [-0.5562, -1.6391, -0.5223, -0.3581],
#                          [ 0.0707, -1.3562,  0.2824,  0.3407]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.9 µs ± 106 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5b583b9f40>
# ├── 'a' --> tensor([[-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650],
# │                   [-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650],
# │                   [-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650],
# │                   [-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650],
# │                   [-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650],
# │                   [-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650],
# │                   [-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650],
# │                   [-0.0035,  0.3781,  0.7497],
# │                   [-0.9561,  1.1244,  1.3650]])
# └── 'x' --> <FastTreeValue 0x7f5b58395880>
#     └── 'c' --> tensor([[-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407],
#                         [-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407],
#                         [-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407],
#                         [-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407],
#                         [-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407],
#                         [-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407],
#                         [-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407],
#                         [-2.0307,  1.8054, -1.0529, -0.0950],
#                         [-0.5562, -1.6391, -0.5223, -0.3581],
#                         [ 0.0707, -1.3562,  0.2824,  0.3407]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.5 µs ± 65.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.2 µs ± 82.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                       [[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                       [[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                       [[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                       [[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                       [[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                       [[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]],
#
#                       [[-2.0307,  1.8054, -1.0529, -0.0950],
#                        [-0.5562, -1.6391, -0.5223, -0.3581],
#                        [ 0.0707, -1.3562,  0.2824,  0.3407]]]),
#        ),
#     a: tensor([[[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]],
#
#                [[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]],
#
#                [[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]],
#
#                [[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]],
#
#                [[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]],
#
#                [[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]],
#
#                [[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]],
#
#                [[-0.0035,  0.3781,  0.7497],
#                 [-0.9561,  1.1244,  1.3650]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.3 µs ± 235 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407],
#                       [-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407],
#                       [-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407],
#                       [-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407],
#                       [-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407],
#                       [-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407],
#                       [-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407],
#                       [-2.0307,  1.8054, -1.0529, -0.0950],
#                       [-0.5562, -1.6391, -0.5223, -0.3581],
#                       [ 0.0707, -1.3562,  0.2824,  0.3407]]),
#        ),
#     a: tensor([[-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650],
#                [-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650],
#                [-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650],
#                [-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650],
#                [-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650],
#                [-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650],
#                [-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650],
#                [-0.0035,  0.3781,  0.7497],
#                [-0.9561,  1.1244,  1.3650]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 156 µs ± 221 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 354 µs ± 5.81 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
