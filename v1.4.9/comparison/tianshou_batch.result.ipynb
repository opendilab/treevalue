# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7ff54ed92e80>
# ├── 'a' --> tensor([[ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467]])
# └── 'x' --> <FastTreeValue 0x7ff54ed172e0>
#     └── 'c' --> tensor([[ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824]])

# %%
t.a
# Out:
# tensor([[ 0.8439, -1.1235, -0.3175],
#         [-1.2080, -1.7119, -1.4467]])

# %%
# %timeit t.a
# Out:
# 91 ns ± 1.2 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7ff54ed92e80>
# ├── 'a' --> tensor([[0.6485, 0.2948, 1.6077],
# │                   [0.6419, 0.3462, 1.1177]])
# └── 'x' --> <FastTreeValue 0x7ff54ed172e0>
#     └── 'c' --> tensor([[ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824]])

# %%
# %timeit t.a = new_value
# Out:
# 111 ns ± 0.804 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467]]),
#     x: Batch(
#            c: tensor([[ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8439, -1.1235, -0.3175],
#         [-1.2080, -1.7119, -1.4467]])

# %%
# %timeit b.a
# Out:
# 79.5 ns ± 1.15 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.4359, -0.4401,  2.1981],
#                [ 0.3575,  0.0495, -0.9931]]),
#     x: Batch(
#            c: tensor([[ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 626 ns ± 8.59 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.03 µs ± 11.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.7 µs ± 97.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 168 µs ± 2.84 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 164 µs ± 2.18 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7ff46e582df0>
# ├── 'a' --> tensor([[[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]],
# │
# │                   [[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]],
# │
# │                   [[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]],
# │
# │                   [[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]],
# │
# │                   [[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]],
# │
# │                   [[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]],
# │
# │                   [[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]],
# │
# │                   [[ 0.8439, -1.1235, -0.3175],
# │                    [-1.2080, -1.7119, -1.4467]]])
# └── 'x' --> <FastTreeValue 0x7ff46e582dc0>
#     └── 'c' --> tensor([[[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                         [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                         [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                         [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                         [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                         [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                         [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                         [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                          [ 0.1392, -0.6508,  0.1743, -0.4098],
#                          [ 0.1473,  0.2678,  0.2204, -0.1824]]])

# %%
# %timeit t_stack(trees)
# Out:
# 37.2 µs ± 625 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7ff46e582340>
# ├── 'a' --> tensor([[ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467],
# │                   [ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467],
# │                   [ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467],
# │                   [ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467],
# │                   [ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467],
# │                   [ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467],
# │                   [ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467],
# │                   [ 0.8439, -1.1235, -0.3175],
# │                   [-1.2080, -1.7119, -1.4467]])
# └── 'x' --> <FastTreeValue 0x7ff46e5825e0>
#     └── 'c' --> tensor([[ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824],
#                         [ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824],
#                         [ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824],
#                         [ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824],
#                         [ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824],
#                         [ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824],
#                         [ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824],
#                         [ 0.7773,  0.1732,  0.2433, -0.9701],
#                         [ 0.1392, -0.6508,  0.1743, -0.4098],
#                         [ 0.1473,  0.2678,  0.2204, -0.1824]])

# %%
# %timeit t_cat(trees)
# Out:
# 34.5 µs ± 270 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 72.8 µs ± 1.25 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]],
#
#                [[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]],
#
#                [[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]],
#
#                [[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]],
#
#                [[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]],
#
#                [[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]],
#
#                [[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]],
#
#                [[ 0.8439, -1.1235, -0.3175],
#                 [-1.2080, -1.7119, -1.4467]]]),
#     x: Batch(
#            c: tensor([[[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                       [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                       [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                       [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                       [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                       [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                       [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]],
#
#                       [[ 0.7773,  0.1732,  0.2433, -0.9701],
#                        [ 0.1392, -0.6508,  0.1743, -0.4098],
#                        [ 0.1473,  0.2678,  0.2204, -0.1824]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 92.5 µs ± 832 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467],
#                [ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467],
#                [ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467],
#                [ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467],
#                [ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467],
#                [ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467],
#                [ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467],
#                [ 0.8439, -1.1235, -0.3175],
#                [-1.2080, -1.7119, -1.4467]]),
#     x: Batch(
#            c: tensor([[ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824],
#                       [ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824],
#                       [ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824],
#                       [ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824],
#                       [ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824],
#                       [ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824],
#                       [ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824],
#                       [ 0.7773,  0.1732,  0.2433, -0.9701],
#                       [ 0.1392, -0.6508,  0.1743, -0.4098],
#                       [ 0.1473,  0.2678,  0.2204, -0.1824]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 173 µs ± 2 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 406 µs ± 8.14 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
