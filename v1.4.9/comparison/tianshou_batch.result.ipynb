# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fa8541dcbb0>
# ├── 'a' --> tensor([[-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577]])
# └── 'x' --> <FastTreeValue 0x7fa8541a20a0>
#     └── 'c' --> tensor([[ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941]])

# %%
t.a
# Out:
# tensor([[-0.4742, -1.0812,  0.3301],
#         [ 0.6152,  0.7604,  2.2577]])

# %%
# %timeit t.a
# Out:
# 88.4 ns ± 0.133 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fa8541dcbb0>
# ├── 'a' --> tensor([[-0.6395,  2.2801,  1.6400],
# │                   [-0.6731, -0.4484,  0.4975]])
# └── 'x' --> <FastTreeValue 0x7fa8541a20a0>
#     └── 'c' --> tensor([[ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941]])

# %%
# %timeit t.a = new_value
# Out:
# 94 ns ± 1.52 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577]]),
#     x: Batch(
#            c: tensor([[ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.4742, -1.0812,  0.3301],
#         [ 0.6152,  0.7604,  2.2577]])

# %%
# %timeit b.a
# Out:
# 83.5 ns ± 1.25 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.2750, -0.2157, -0.1672],
#                [-1.0493, -0.1908, -0.6668]]),
#     x: Batch(
#            c: tensor([[ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 659 ns ± 3.84 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.05 µs ± 2.59 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.4 µs ± 39.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 190 µs ± 7.33 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 176 µs ± 1.23 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fa770132610>
# ├── 'a' --> tensor([[[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]],
# │
# │                   [[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]],
# │
# │                   [[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]],
# │
# │                   [[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]],
# │
# │                   [[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]],
# │
# │                   [[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]],
# │
# │                   [[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]],
# │
# │                   [[-0.4742, -1.0812,  0.3301],
# │                    [ 0.6152,  0.7604,  2.2577]]])
# └── 'x' --> <FastTreeValue 0x7fa770132700>
#     └── 'c' --> tensor([[[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                         [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                         [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                         [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                         [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                         [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                         [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                         [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                          [-0.2644,  0.3024, -0.7233, -0.5715],
#                          [ 0.8484, -0.2733, -0.5785,  1.4941]]])

# %%
# %timeit t_stack(trees)
# Out:
# 61.9 µs ± 426 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fa8541e19a0>
# ├── 'a' --> tensor([[-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577],
# │                   [-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577],
# │                   [-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577],
# │                   [-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577],
# │                   [-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577],
# │                   [-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577],
# │                   [-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577],
# │                   [-0.4742, -1.0812,  0.3301],
# │                   [ 0.6152,  0.7604,  2.2577]])
# └── 'x' --> <FastTreeValue 0x7fa77019e670>
#     └── 'c' --> tensor([[ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941],
#                         [ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941],
#                         [ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941],
#                         [ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941],
#                         [ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941],
#                         [ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941],
#                         [ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941],
#                         [ 1.1007,  0.3630, -1.5211,  0.9929],
#                         [-0.2644,  0.3024, -0.7233, -0.5715],
#                         [ 0.8484, -0.2733, -0.5785,  1.4941]])

# %%
# %timeit t_cat(trees)
# Out:
# 37.8 µs ± 183 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.8 µs ± 231 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]],
#
#                [[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]],
#
#                [[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]],
#
#                [[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]],
#
#                [[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]],
#
#                [[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]],
#
#                [[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]],
#
#                [[-0.4742, -1.0812,  0.3301],
#                 [ 0.6152,  0.7604,  2.2577]]]),
#     x: Batch(
#            c: tensor([[[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                       [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                       [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                       [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                       [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                       [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                       [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]],
#
#                       [[ 1.1007,  0.3630, -1.5211,  0.9929],
#                        [-0.2644,  0.3024, -0.7233, -0.5715],
#                        [ 0.8484, -0.2733, -0.5785,  1.4941]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.5 µs ± 313 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577],
#                [-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577],
#                [-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577],
#                [-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577],
#                [-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577],
#                [-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577],
#                [-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577],
#                [-0.4742, -1.0812,  0.3301],
#                [ 0.6152,  0.7604,  2.2577]]),
#     x: Batch(
#            c: tensor([[ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941],
#                       [ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941],
#                       [ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941],
#                       [ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941],
#                       [ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941],
#                       [ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941],
#                       [ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941],
#                       [ 1.1007,  0.3630, -1.5211,  0.9929],
#                       [-0.2644,  0.3024, -0.7233, -0.5715],
#                       [ 0.8484, -0.2733, -0.5785,  1.4941]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 179 µs ± 173 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 454 µs ± 7.04 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
