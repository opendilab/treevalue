# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f9b36b92d90>
# ├── 'a' --> tensor([[-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927]])
# └── 'x' --> <FastTreeValue 0x7f9b36b92bb0>
#     └── 'c' --> tensor([[ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114]])

# %%
t.a
# Out:
# tensor([[-0.1898, -0.3202,  0.0371],
#         [ 0.9171,  0.8698, -0.4927]])

# %%
# %timeit t.a
# Out:
# 74.2 ns ± 0.0993 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f9b36b92d90>
# ├── 'a' --> tensor([[ 1.0728, -0.1586, -0.5403],
# │                   [ 0.1228, -0.7831,  0.0206]])
# └── 'x' --> <FastTreeValue 0x7f9b36b92bb0>
#     └── 'c' --> tensor([[ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114]])

# %%
# %timeit t.a = new_value
# Out:
# 76.9 ns ± 0.0556 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927]]),
#     x: Batch(
#            c: tensor([[ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.1898, -0.3202,  0.0371],
#         [ 0.9171,  0.8698, -0.4927]])

# %%
# %timeit b.a
# Out:
# 64.5 ns ± 0.119 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.5481,  1.8394, -1.9871],
#                [ 1.7590, -1.0871,  0.5286]]),
#     x: Batch(
#            c: tensor([[ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 542 ns ± 0.0431 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 858 ns ± 0.534 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 33.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 845 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 147 µs ± 749 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f9b34afd430>
# ├── 'a' --> tensor([[[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]],
# │
# │                   [[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]],
# │
# │                   [[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]],
# │
# │                   [[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]],
# │
# │                   [[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]],
# │
# │                   [[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]],
# │
# │                   [[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]],
# │
# │                   [[-0.1898, -0.3202,  0.0371],
# │                    [ 0.9171,  0.8698, -0.4927]]])
# └── 'x' --> <FastTreeValue 0x7f9b34b056d0>
#     └── 'c' --> tensor([[[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                         [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                         [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                         [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                         [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                         [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                         [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                         [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                          [ 1.1653,  0.4592,  0.0243,  1.7704],
#                          [ 0.8243, -0.0514, -0.6810, -1.6114]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.7 µs ± 67.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f9a56382df0>
# ├── 'a' --> tensor([[-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927],
# │                   [-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927],
# │                   [-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927],
# │                   [-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927],
# │                   [-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927],
# │                   [-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927],
# │                   [-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927],
# │                   [-0.1898, -0.3202,  0.0371],
# │                   [ 0.9171,  0.8698, -0.4927]])
# └── 'x' --> <FastTreeValue 0x7f9a56382940>
#     └── 'c' --> tensor([[ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114],
#                         [ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114],
#                         [ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114],
#                         [ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114],
#                         [ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114],
#                         [ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114],
#                         [ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114],
#                         [ 0.2721, -1.1402, -0.0501,  0.1734],
#                         [ 1.1653,  0.4592,  0.0243,  1.7704],
#                         [ 0.8243, -0.0514, -0.6810, -1.6114]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.9 µs ± 50.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.8 µs ± 76.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]],
#
#                [[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]],
#
#                [[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]],
#
#                [[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]],
#
#                [[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]],
#
#                [[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]],
#
#                [[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]],
#
#                [[-0.1898, -0.3202,  0.0371],
#                 [ 0.9171,  0.8698, -0.4927]]]),
#     x: Batch(
#            c: tensor([[[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                       [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                       [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                       [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                       [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                       [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                       [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]],
#
#                       [[ 0.2721, -1.1402, -0.0501,  0.1734],
#                        [ 1.1653,  0.4592,  0.0243,  1.7704],
#                        [ 0.8243, -0.0514, -0.6810, -1.6114]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.4 µs ± 305 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927],
#                [-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927],
#                [-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927],
#                [-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927],
#                [-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927],
#                [-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927],
#                [-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927],
#                [-0.1898, -0.3202,  0.0371],
#                [ 0.9171,  0.8698, -0.4927]]),
#     x: Batch(
#            c: tensor([[ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114],
#                       [ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114],
#                       [ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114],
#                       [ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114],
#                       [ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114],
#                       [ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114],
#                       [ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114],
#                       [ 0.2721, -1.1402, -0.0501,  0.1734],
#                       [ 1.1653,  0.4592,  0.0243,  1.7704],
#                       [ 0.8243, -0.0514, -0.6810, -1.6114]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 1.15 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 358 µs ± 5.95 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
