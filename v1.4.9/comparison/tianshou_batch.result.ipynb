# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb32816e3d0>
# ├── 'a' --> tensor([[ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692]])
# └── 'x' --> <FastTreeValue 0x7fb328168400>
#     └── 'c' --> tensor([[-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684]])

# %%
t.a
# Out:
# tensor([[ 1.2783, -0.5849, -0.4628],
#         [-0.6087, -0.3553,  1.1692]])

# %%
# %timeit t.a
# Out:
# 64.6 ns ± 0.129 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb32816e3d0>
# ├── 'a' --> tensor([[-0.7942,  1.2242, -0.2050],
# │                   [-0.5945, -1.0038, -0.0319]])
# └── 'x' --> <FastTreeValue 0x7fb328168400>
#     └── 'c' --> tensor([[-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684]])

# %%
# %timeit t.a = new_value
# Out:
# 67.9 ns ± 0.0163 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692]]),
#     x: Batch(
#            c: tensor([[-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.2783, -0.5849, -0.4628],
#         [-0.6087, -0.3553,  1.1692]])

# %%
# %timeit b.a
# Out:
# 59.9 ns ± 0.0294 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.9459, -0.4451, -1.8352],
#                [-0.6153, -0.0248, -0.0393]]),
#     x: Batch(
#            c: tensor([[-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 497 ns ± 0.213 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 818 ns ± 0.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.8 µs ± 10.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 383 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 140 µs ± 472 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fb24af05ac0>
# ├── 'a' --> tensor([[[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]],
# │
# │                   [[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]],
# │
# │                   [[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]],
# │
# │                   [[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]],
# │
# │                   [[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]],
# │
# │                   [[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]],
# │
# │                   [[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]],
# │
# │                   [[ 1.2783, -0.5849, -0.4628],
# │                    [-0.6087, -0.3553,  1.1692]]])
# └── 'x' --> <FastTreeValue 0x7fb328136b50>
#     └── 'c' --> tensor([[[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                         [[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                         [[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                         [[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                         [[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                         [[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                         [[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                         [[-0.6378, -0.7657, -1.3418, -0.7613],
#                          [-1.1882,  0.1599,  0.6757,  1.1649],
#                          [-0.0033,  0.2518,  0.3221, -0.0684]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 54.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fb328157850>
# ├── 'a' --> tensor([[ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692],
# │                   [ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692],
# │                   [ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692],
# │                   [ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692],
# │                   [ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692],
# │                   [ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692],
# │                   [ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692],
# │                   [ 1.2783, -0.5849, -0.4628],
# │                   [-0.6087, -0.3553,  1.1692]])
# └── 'x' --> <FastTreeValue 0x7fb328157d30>
#     └── 'c' --> tensor([[-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684],
#                         [-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684],
#                         [-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684],
#                         [-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684],
#                         [-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684],
#                         [-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684],
#                         [-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684],
#                         [-0.6378, -0.7657, -1.3418, -0.7613],
#                         [-1.1882,  0.1599,  0.6757,  1.1649],
#                         [-0.0033,  0.2518,  0.3221, -0.0684]])

# %%
# %timeit t_cat(trees)
# Out:
# 31 µs ± 73.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.4 µs ± 76 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                       [[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                       [[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                       [[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                       [[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                       [[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                       [[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]],
#
#                       [[-0.6378, -0.7657, -1.3418, -0.7613],
#                        [-1.1882,  0.1599,  0.6757,  1.1649],
#                        [-0.0033,  0.2518,  0.3221, -0.0684]]]),
#        ),
#     a: tensor([[[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]],
#
#                [[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]],
#
#                [[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]],
#
#                [[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]],
#
#                [[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]],
#
#                [[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]],
#
#                [[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]],
#
#                [[ 1.2783, -0.5849, -0.4628],
#                 [-0.6087, -0.3553,  1.1692]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.6 µs ± 341 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684],
#                       [-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684],
#                       [-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684],
#                       [-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684],
#                       [-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684],
#                       [-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684],
#                       [-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684],
#                       [-0.6378, -0.7657, -1.3418, -0.7613],
#                       [-1.1882,  0.1599,  0.6757,  1.1649],
#                       [-0.0033,  0.2518,  0.3221, -0.0684]]),
#        ),
#     a: tensor([[ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692],
#                [ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692],
#                [ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692],
#                [ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692],
#                [ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692],
#                [ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692],
#                [ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692],
#                [ 1.2783, -0.5849, -0.4628],
#                [-0.6087, -0.3553,  1.1692]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 866 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 343 µs ± 5.98 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
