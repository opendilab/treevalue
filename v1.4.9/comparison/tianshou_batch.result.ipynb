# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f76b6c3a7f0>
# ├── 'a' --> tensor([[ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598]])
# └── 'x' --> <FastTreeValue 0x7f76b6c3a670>
#     └── 'c' --> tensor([[-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645]])

# %%
t.a
# Out:
# tensor([[ 0.5619, -0.7177, -1.3256],
#         [ 1.3629, -0.3701,  2.3598]])

# %%
# %timeit t.a
# Out:
# 75 ns ± 0.0952 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f76b6c3a7f0>
# ├── 'a' --> tensor([[ 0.5320, -1.4223,  0.3883],
# │                   [ 1.1122,  0.6189,  0.9038]])
# └── 'x' --> <FastTreeValue 0x7f76b6c3a670>
#     └── 'c' --> tensor([[-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645]])

# %%
# %timeit t.a = new_value
# Out:
# 74 ns ± 0.0155 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598]]),
#     x: Batch(
#            c: tensor([[-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.5619, -0.7177, -1.3256],
#         [ 1.3629, -0.3701,  2.3598]])

# %%
# %timeit b.a
# Out:
# 57.8 ns ± 0.025 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.7347,  1.7840, -0.8165],
#                [ 0.3403,  1.0676,  1.4430]]),
#     x: Batch(
#            c: tensor([[-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 497 ns ± 1.89 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 861 ns ± 0.521 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.5 µs ± 31.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 138 µs ± 808 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 451 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f75e4346eb0>
# ├── 'a' --> tensor([[[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]],
# │
# │                   [[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]],
# │
# │                   [[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]],
# │
# │                   [[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]],
# │
# │                   [[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]],
# │
# │                   [[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]],
# │
# │                   [[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]],
# │
# │                   [[ 0.5619, -0.7177, -1.3256],
# │                    [ 1.3629, -0.3701,  2.3598]]])
# └── 'x' --> <FastTreeValue 0x7f75e4346d00>
#     └── 'c' --> tensor([[[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                         [[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                         [[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                         [[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                         [[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                         [[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                         [[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                         [[-1.2325,  2.0640,  1.4409, -0.1027],
#                          [ 1.3134, -0.9141,  0.4605,  0.3210],
#                          [-0.5744,  0.4653,  0.5253, -1.8645]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.3 µs ± 53.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f75eeecaf40>
# ├── 'a' --> tensor([[ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598],
# │                   [ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598],
# │                   [ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598],
# │                   [ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598],
# │                   [ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598],
# │                   [ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598],
# │                   [ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598],
# │                   [ 0.5619, -0.7177, -1.3256],
# │                   [ 1.3629, -0.3701,  2.3598]])
# └── 'x' --> <FastTreeValue 0x7f76b4bc26a0>
#     └── 'c' --> tensor([[-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645],
#                         [-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645],
#                         [-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645],
#                         [-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645],
#                         [-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645],
#                         [-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645],
#                         [-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645],
#                         [-1.2325,  2.0640,  1.4409, -0.1027],
#                         [ 1.3134, -0.9141,  0.4605,  0.3210],
#                         [-0.5744,  0.4653,  0.5253, -1.8645]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 91.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.9 µs ± 85.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]],
#
#                [[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]],
#
#                [[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]],
#
#                [[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]],
#
#                [[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]],
#
#                [[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]],
#
#                [[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]],
#
#                [[ 0.5619, -0.7177, -1.3256],
#                 [ 1.3629, -0.3701,  2.3598]]]),
#     x: Batch(
#            c: tensor([[[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                       [[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                       [[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                       [[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                       [[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                       [[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                       [[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]],
#
#                       [[-1.2325,  2.0640,  1.4409, -0.1027],
#                        [ 1.3134, -0.9141,  0.4605,  0.3210],
#                        [-0.5744,  0.4653,  0.5253, -1.8645]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 81.2 µs ± 139 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598],
#                [ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598],
#                [ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598],
#                [ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598],
#                [ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598],
#                [ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598],
#                [ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598],
#                [ 0.5619, -0.7177, -1.3256],
#                [ 1.3629, -0.3701,  2.3598]]),
#     x: Batch(
#            c: tensor([[-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645],
#                       [-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645],
#                       [-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645],
#                       [-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645],
#                       [-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645],
#                       [-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645],
#                       [-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645],
#                       [-1.2325,  2.0640,  1.4409, -0.1027],
#                       [ 1.3134, -0.9141,  0.4605,  0.3210],
#                       [-0.5744,  0.4653,  0.5253, -1.8645]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 655 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 329 µs ± 4.82 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
