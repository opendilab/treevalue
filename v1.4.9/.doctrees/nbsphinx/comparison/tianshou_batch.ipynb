# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fbb700980a0>
# ├── 'a' --> tensor([[-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673]])
# └── 'x' --> <FastTreeValue 0x7fbb70098100>
#     └── 'c' --> tensor([[-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456]])

# %%
t.a
# Out:
# tensor([[-0.8691, -0.6444, -0.1947],
#         [-0.4621,  0.1073, -0.1673]])

# %%
# %timeit t.a
# Out:
# 104 ns ± 0.701 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fbb700980a0>
# ├── 'a' --> tensor([[ 1.6692,  1.7595,  1.1978],
# │                   [-0.7196,  2.1896, -0.1220]])
# └── 'x' --> <FastTreeValue 0x7fbb70098100>
#     └── 'c' --> tensor([[-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456]])

# %%
# %timeit t.a = new_value
# Out:
# 111 ns ± 0.467 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673]]),
#     x: Batch(
#            c: tensor([[-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.8691, -0.6444, -0.1947],
#         [-0.4621,  0.1073, -0.1673]])

# %%
# %timeit b.a
# Out:
# 89.2 ns ± 0.727 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.1152,  0.2850, -0.5504],
#                [-0.1626, -2.0072, -1.5025]]),
#     x: Batch(
#            c: tensor([[-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 654 ns ± 2.75 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.04 µs ± 9.04 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.8 µs ± 50.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 169 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 168 µs ± 1.39 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fba9c0abca0>
# ├── 'a' --> tensor([[[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]],
# │
# │                   [[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]],
# │
# │                   [[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]],
# │
# │                   [[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]],
# │
# │                   [[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]],
# │
# │                   [[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]],
# │
# │                   [[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]],
# │
# │                   [[-0.8691, -0.6444, -0.1947],
# │                    [-0.4621,  0.1073, -0.1673]]])
# └── 'x' --> <FastTreeValue 0x7fba9c053f40>
#     └── 'c' --> tensor([[[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                         [[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                         [[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                         [[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                         [[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                         [[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                         [[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                         [[-1.4334,  0.4805,  0.0126,  0.7170],
#                          [ 0.0875, -2.6497, -0.8223,  0.4800],
#                          [ 0.2991, -0.7852, -1.4994, -0.3456]]])

# %%
# %timeit t_stack(trees)
# Out:
# 38.5 µs ± 671 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fba9c0ab880>
# ├── 'a' --> tensor([[-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673],
# │                   [-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673],
# │                   [-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673],
# │                   [-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673],
# │                   [-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673],
# │                   [-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673],
# │                   [-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673],
# │                   [-0.8691, -0.6444, -0.1947],
# │                   [-0.4621,  0.1073, -0.1673]])
# └── 'x' --> <FastTreeValue 0x7fba9c120e20>
#     └── 'c' --> tensor([[-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456],
#                         [-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456],
#                         [-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456],
#                         [-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456],
#                         [-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456],
#                         [-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456],
#                         [-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456],
#                         [-1.4334,  0.4805,  0.0126,  0.7170],
#                         [ 0.0875, -2.6497, -0.8223,  0.4800],
#                         [ 0.2991, -0.7852, -1.4994, -0.3456]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.7 µs ± 405 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 78.8 µs ± 615 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]],
#
#                [[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]],
#
#                [[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]],
#
#                [[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]],
#
#                [[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]],
#
#                [[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]],
#
#                [[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]],
#
#                [[-0.8691, -0.6444, -0.1947],
#                 [-0.4621,  0.1073, -0.1673]]]),
#     x: Batch(
#            c: tensor([[[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                       [[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                       [[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                       [[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                       [[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                       [[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                       [[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]],
#
#                       [[-1.4334,  0.4805,  0.0126,  0.7170],
#                        [ 0.0875, -2.6497, -0.8223,  0.4800],
#                        [ 0.2991, -0.7852, -1.4994, -0.3456]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 96.8 µs ± 532 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673],
#                [-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673],
#                [-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673],
#                [-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673],
#                [-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673],
#                [-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673],
#                [-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673],
#                [-0.8691, -0.6444, -0.1947],
#                [-0.4621,  0.1073, -0.1673]]),
#     x: Batch(
#            c: tensor([[-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456],
#                       [-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456],
#                       [-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456],
#                       [-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456],
#                       [-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456],
#                       [-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456],
#                       [-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456],
#                       [-1.4334,  0.4805,  0.0126,  0.7170],
#                       [ 0.0875, -2.6497, -0.8223,  0.4800],
#                       [ 0.2991, -0.7852, -1.4994, -0.3456]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 179 µs ± 583 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 410 µs ± 7.33 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
