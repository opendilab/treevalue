# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f52ebd58160>
# ├── 'a' --> tensor([[ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102]])
# └── 'x' --> <FastTreeValue 0x7f52ebd585e0>
#     └── 'c' --> tensor([[-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472]])

# %%
t.a
# Out:
# tensor([[ 2.2528,  0.6125, -0.7782],
#         [ 1.4371,  0.3689,  0.7102]])

# %%
# %timeit t.a
# Out:
# 77.6 ns ± 0.654 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f52ebd58160>
# ├── 'a' --> tensor([[-0.8167,  1.1796, -0.8421],
# │                   [-0.7309, -1.6376,  0.0807]])
# └── 'x' --> <FastTreeValue 0x7f52ebd585e0>
#     └── 'c' --> tensor([[-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472]])

# %%
# %timeit t.a = new_value
# Out:
# 83.6 ns ± 0.8 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102]]),
#     x: Batch(
#            c: tensor([[-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 2.2528,  0.6125, -0.7782],
#         [ 1.4371,  0.3689,  0.7102]])

# %%
# %timeit b.a
# Out:
# 72.6 ns ± 0.524 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 2.4187,  1.0888,  0.5108],
#                [-0.4905, -0.8666, -1.5605]]),
#     x: Batch(
#            c: tensor([[-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 658 ns ± 3.17 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.1 µs ± 6.08 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 14.4 µs ± 124 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 296 µs ± 18.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 281 µs ± 23.9 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f52e8d3c2b0>
# ├── 'a' --> tensor([[[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]],
# │
# │                   [[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]],
# │
# │                   [[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]],
# │
# │                   [[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]],
# │
# │                   [[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]],
# │
# │                   [[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]],
# │
# │                   [[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]],
# │
# │                   [[ 2.2528,  0.6125, -0.7782],
# │                    [ 1.4371,  0.3689,  0.7102]]])
# └── 'x' --> <FastTreeValue 0x7f522410fe20>
#     └── 'c' --> tensor([[[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                         [[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                         [[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                         [[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                         [[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                         [[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                         [[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                         [[-1.3356, -0.2131, -0.2318, -0.8285],
#                          [ 0.5538, -1.0726,  0.2692, -1.2117],
#                          [-0.9919, -0.6567, -1.1095,  0.3472]]])

# %%
# %timeit t_stack(trees)
# Out:
# 54.9 µs ± 2.04 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f520b65e220>
# ├── 'a' --> tensor([[ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102],
# │                   [ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102],
# │                   [ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102],
# │                   [ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102],
# │                   [ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102],
# │                   [ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102],
# │                   [ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102],
# │                   [ 2.2528,  0.6125, -0.7782],
# │                   [ 1.4371,  0.3689,  0.7102]])
# └── 'x' --> <FastTreeValue 0x7f5248f39490>
#     └── 'c' --> tensor([[-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472],
#                         [-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472],
#                         [-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472],
#                         [-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472],
#                         [-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472],
#                         [-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472],
#                         [-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472],
#                         [-1.3356, -0.2131, -0.2318, -0.8285],
#                         [ 0.5538, -1.0726,  0.2692, -1.2117],
#                         [-0.9919, -0.6567, -1.1095,  0.3472]])

# %%
# %timeit t_cat(trees)
# Out:
# 51.2 µs ± 3.58 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 103 µs ± 4.11 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]],
#
#                [[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]],
#
#                [[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]],
#
#                [[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]],
#
#                [[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]],
#
#                [[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]],
#
#                [[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]],
#
#                [[ 2.2528,  0.6125, -0.7782],
#                 [ 1.4371,  0.3689,  0.7102]]]),
#     x: Batch(
#            c: tensor([[[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                       [[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                       [[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                       [[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                       [[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                       [[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                       [[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]],
#
#                       [[-1.3356, -0.2131, -0.2318, -0.8285],
#                        [ 0.5538, -1.0726,  0.2692, -1.2117],
#                        [-0.9919, -0.6567, -1.1095,  0.3472]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 119 µs ± 3.06 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102],
#                [ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102],
#                [ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102],
#                [ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102],
#                [ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102],
#                [ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102],
#                [ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102],
#                [ 2.2528,  0.6125, -0.7782],
#                [ 1.4371,  0.3689,  0.7102]]),
#     x: Batch(
#            c: tensor([[-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472],
#                       [-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472],
#                       [-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472],
#                       [-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472],
#                       [-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472],
#                       [-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472],
#                       [-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472],
#                       [-1.3356, -0.2131, -0.2318, -0.8285],
#                       [ 0.5538, -1.0726,  0.2692, -1.2117],
#                       [-0.9919, -0.6567, -1.1095,  0.3472]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 204 µs ± 6.18 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 626 µs ± 24.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
