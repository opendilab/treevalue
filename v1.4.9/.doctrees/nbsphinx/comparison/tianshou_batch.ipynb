# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5b88a7b0d0>
# ├── 'a' --> tensor([[-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857]])
# └── 'x' --> <FastTreeValue 0x7f5b88a7b250>
#     └── 'c' --> tensor([[-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038]])

# %%
t.a
# Out:
# tensor([[-0.7756,  1.0817,  0.3484],
#         [ 0.0912,  0.1874, -0.0857]])

# %%
# %timeit t.a
# Out:
# 72.4 ns ± 0.069 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5b88a7b0d0>
# ├── 'a' --> tensor([[ 0.8658, -1.5412, -0.4335],
# │                   [-0.8093,  1.7554, -1.1460]])
# └── 'x' --> <FastTreeValue 0x7f5b88a7b250>
#     └── 'c' --> tensor([[-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038]])

# %%
# %timeit t.a = new_value
# Out:
# 74.6 ns ± 0.0585 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857]]),
#     x: Batch(
#            c: tensor([[-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7756,  1.0817,  0.3484],
#         [ 0.0912,  0.1874, -0.0857]])

# %%
# %timeit b.a
# Out:
# 69.2 ns ± 0.135 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.5187,  1.6517,  0.2069],
#                [-0.4694, -1.9469, -1.7957]]),
#     x: Batch(
#            c: tensor([[-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 545 ns ± 0.0969 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 890 ns ± 0.68 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 30.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 1.04 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 145 µs ± 1.26 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5aac376d60>
# ├── 'a' --> tensor([[[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]],
# │
# │                   [[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]],
# │
# │                   [[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]],
# │
# │                   [[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]],
# │
# │                   [[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]],
# │
# │                   [[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]],
# │
# │                   [[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]],
# │
# │                   [[-0.7756,  1.0817,  0.3484],
# │                    [ 0.0912,  0.1874, -0.0857]]])
# └── 'x' --> <FastTreeValue 0x7f5aba22bfa0>
#     └── 'c' --> tensor([[[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                         [[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                         [[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                         [[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                         [[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                         [[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                         [[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                         [[-0.2892,  1.3914,  0.6051, -0.3843],
#                          [-1.3379, -0.5239, -0.0051, -0.1954],
#                          [ 0.5647,  0.9956,  0.3587,  0.2038]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.9 µs ± 70.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5aac3058e0>
# ├── 'a' --> tensor([[-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857],
# │                   [-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857],
# │                   [-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857],
# │                   [-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857],
# │                   [-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857],
# │                   [-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857],
# │                   [-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857],
# │                   [-0.7756,  1.0817,  0.3484],
# │                   [ 0.0912,  0.1874, -0.0857]])
# └── 'x' --> <FastTreeValue 0x7f5ac6b3fe50>
#     └── 'c' --> tensor([[-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038],
#                         [-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038],
#                         [-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038],
#                         [-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038],
#                         [-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038],
#                         [-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038],
#                         [-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038],
#                         [-0.2892,  1.3914,  0.6051, -0.3843],
#                         [-1.3379, -0.5239, -0.0051, -0.1954],
#                         [ 0.5647,  0.9956,  0.3587,  0.2038]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 108 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.6 µs ± 67.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                       [[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                       [[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                       [[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                       [[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                       [[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                       [[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]],
#
#                       [[-0.2892,  1.3914,  0.6051, -0.3843],
#                        [-1.3379, -0.5239, -0.0051, -0.1954],
#                        [ 0.5647,  0.9956,  0.3587,  0.2038]]]),
#        ),
#     a: tensor([[[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]],
#
#                [[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]],
#
#                [[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]],
#
#                [[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]],
#
#                [[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]],
#
#                [[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]],
#
#                [[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]],
#
#                [[-0.7756,  1.0817,  0.3484],
#                 [ 0.0912,  0.1874, -0.0857]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.8 µs ± 133 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038],
#                       [-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038],
#                       [-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038],
#                       [-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038],
#                       [-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038],
#                       [-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038],
#                       [-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038],
#                       [-0.2892,  1.3914,  0.6051, -0.3843],
#                       [-1.3379, -0.5239, -0.0051, -0.1954],
#                       [ 0.5647,  0.9956,  0.3587,  0.2038]]),
#        ),
#     a: tensor([[-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857],
#                [-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857],
#                [-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857],
#                [-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857],
#                [-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857],
#                [-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857],
#                [-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857],
#                [-0.7756,  1.0817,  0.3484],
#                [ 0.0912,  0.1874, -0.0857]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 304 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 356 µs ± 7.96 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
