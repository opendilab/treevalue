# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fe96b2eea00>
# ├── 'a' --> tensor([[-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104]])
# └── 'x' --> <FastTreeValue 0x7fe960a7a940>
#     └── 'c' --> tensor([[-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607]])

# %%
t.a
# Out:
# tensor([[-0.3564, -0.1906, -0.9502],
#         [-0.6790, -0.7819,  0.9104]])

# %%
# %timeit t.a
# Out:
# 86.7 ns ± 0.443 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fe96b2eea00>
# ├── 'a' --> tensor([[-0.0053, -0.7707, -1.8488],
# │                   [ 1.0400,  0.5690,  1.7829]])
# └── 'x' --> <FastTreeValue 0x7fe960a7a940>
#     └── 'c' --> tensor([[-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607]])

# %%
# %timeit t.a = new_value
# Out:
# 89.1 ns ± 1.15 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104]]),
#     x: Batch(
#            c: tensor([[-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.3564, -0.1906, -0.9502],
#         [-0.6790, -0.7819,  0.9104]])

# %%
# %timeit b.a
# Out:
# 77.5 ns ± 0.921 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.0244,  1.0302,  0.7168],
#                [-0.7481,  0.0794, -0.1237]]),
#     x: Batch(
#            c: tensor([[-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 645 ns ± 12 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 9.38 µs ± 152 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12.3 µs ± 352 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 171 µs ± 2.27 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 171 µs ± 1.52 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fe9523c4580>
# ├── 'a' --> tensor([[[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]],
# │
# │                   [[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]],
# │
# │                   [[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]],
# │
# │                   [[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]],
# │
# │                   [[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]],
# │
# │                   [[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]],
# │
# │                   [[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]],
# │
# │                   [[-0.3564, -0.1906, -0.9502],
# │                    [-0.6790, -0.7819,  0.9104]]])
# └── 'x' --> <FastTreeValue 0x7fe9522aff40>
#     └── 'c' --> tensor([[[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                         [[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                         [[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                         [[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                         [[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                         [[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                         [[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                         [[-0.2713,  0.8691, -1.2446, -0.1072],
#                          [ 0.6114,  0.7280,  0.7055,  0.0657],
#                          [ 0.5914, -0.3034, -0.2372, -1.1607]]])

# %%
# %timeit t_stack(trees)
# Out:
# 38.2 µs ± 470 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fe96c61f850>
# ├── 'a' --> tensor([[-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104],
# │                   [-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104],
# │                   [-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104],
# │                   [-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104],
# │                   [-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104],
# │                   [-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104],
# │                   [-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104],
# │                   [-0.3564, -0.1906, -0.9502],
# │                   [-0.6790, -0.7819,  0.9104]])
# └── 'x' --> <FastTreeValue 0x7fe96c61f0d0>
#     └── 'c' --> tensor([[-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607],
#                         [-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607],
#                         [-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607],
#                         [-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607],
#                         [-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607],
#                         [-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607],
#                         [-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607],
#                         [-0.2713,  0.8691, -1.2446, -0.1072],
#                         [ 0.6114,  0.7280,  0.7055,  0.0657],
#                         [ 0.5914, -0.3034, -0.2372, -1.1607]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.3 µs ± 185 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 76.1 µs ± 548 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]],
#
#                [[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]],
#
#                [[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]],
#
#                [[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]],
#
#                [[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]],
#
#                [[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]],
#
#                [[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]],
#
#                [[-0.3564, -0.1906, -0.9502],
#                 [-0.6790, -0.7819,  0.9104]]]),
#     x: Batch(
#            c: tensor([[[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                       [[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                       [[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                       [[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                       [[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                       [[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                       [[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]],
#
#                       [[-0.2713,  0.8691, -1.2446, -0.1072],
#                        [ 0.6114,  0.7280,  0.7055,  0.0657],
#                        [ 0.5914, -0.3034, -0.2372, -1.1607]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 98.3 µs ± 836 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104],
#                [-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104],
#                [-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104],
#                [-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104],
#                [-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104],
#                [-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104],
#                [-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104],
#                [-0.3564, -0.1906, -0.9502],
#                [-0.6790, -0.7819,  0.9104]]),
#     x: Batch(
#            c: tensor([[-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607],
#                       [-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607],
#                       [-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607],
#                       [-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607],
#                       [-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607],
#                       [-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607],
#                       [-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607],
#                       [-0.2713,  0.8691, -1.2446, -0.1072],
#                       [ 0.6114,  0.7280,  0.7055,  0.0657],
#                       [ 0.5914, -0.3034, -0.2372, -1.1607]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 178 µs ± 1.41 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 443 µs ± 8.84 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
