# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5350ef9ca0>
# ├── 'a' --> tensor([[ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075]])
# └── 'x' --> <FastTreeValue 0x7f5350ef9dc0>
#     └── 'c' --> tensor([[-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680]])

# %%
t.a
# Out:
# tensor([[ 1.2986,  0.6295,  0.1456],
#         [-0.2346, -1.4261,  0.0075]])

# %%
# %timeit t.a
# Out:
# 63.9 ns ± 0.0605 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5350ef9ca0>
# ├── 'a' --> tensor([[-0.1159, -0.8025,  0.0718],
# │                   [ 1.4440,  0.3878, -1.2103]])
# └── 'x' --> <FastTreeValue 0x7f5350ef9dc0>
#     └── 'c' --> tensor([[-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680]])

# %%
# %timeit t.a = new_value
# Out:
# 68.3 ns ± 0.0341 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075]]),
#     x: Batch(
#            c: tensor([[-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.2986,  0.6295,  0.1456],
#         [-0.2346, -1.4261,  0.0075]])

# %%
# %timeit b.a
# Out:
# 58.4 ns ± 0.0846 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.7065, -1.1422,  0.5988],
#                [ 0.2010, -1.6334,  0.4863]]),
#     x: Batch(
#            c: tensor([[-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 488 ns ± 0.135 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 810 ns ± 1.06 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.9 µs ± 36.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 145 µs ± 325 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 975 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5350ea3760>
# ├── 'a' --> tensor([[[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]],
# │
# │                   [[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]],
# │
# │                   [[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]],
# │
# │                   [[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]],
# │
# │                   [[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]],
# │
# │                   [[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]],
# │
# │                   [[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]],
# │
# │                   [[ 1.2986,  0.6295,  0.1456],
# │                    [-0.2346, -1.4261,  0.0075]]])
# └── 'x' --> <FastTreeValue 0x7f52746c2e20>
#     └── 'c' --> tensor([[[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                         [[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                         [[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                         [[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                         [[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                         [[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                         [[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                         [[-1.6582, -0.2189,  0.6896, -0.5367],
#                          [ 0.4442,  0.1250,  0.3993,  0.9457],
#                          [ 0.0084,  0.7474,  0.2958,  0.0680]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 105 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5274690df0>
# ├── 'a' --> tensor([[ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075],
# │                   [ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075],
# │                   [ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075],
# │                   [ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075],
# │                   [ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075],
# │                   [ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075],
# │                   [ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075],
# │                   [ 1.2986,  0.6295,  0.1456],
# │                   [-0.2346, -1.4261,  0.0075]])
# └── 'x' --> <FastTreeValue 0x7f53533137f0>
#     └── 'c' --> tensor([[-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680],
#                         [-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680],
#                         [-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680],
#                         [-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680],
#                         [-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680],
#                         [-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680],
#                         [-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680],
#                         [-1.6582, -0.2189,  0.6896, -0.5367],
#                         [ 0.4442,  0.1250,  0.3993,  0.9457],
#                         [ 0.0084,  0.7474,  0.2958,  0.0680]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.8 µs ± 55.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 66.7 µs ± 112 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]],
#
#                [[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]],
#
#                [[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]],
#
#                [[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]],
#
#                [[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]],
#
#                [[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]],
#
#                [[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]],
#
#                [[ 1.2986,  0.6295,  0.1456],
#                 [-0.2346, -1.4261,  0.0075]]]),
#     x: Batch(
#            c: tensor([[[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                       [[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                       [[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                       [[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                       [[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                       [[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                       [[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]],
#
#                       [[-1.6582, -0.2189,  0.6896, -0.5367],
#                        [ 0.4442,  0.1250,  0.3993,  0.9457],
#                        [ 0.0084,  0.7474,  0.2958,  0.0680]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.4 µs ± 362 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075],
#                [ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075],
#                [ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075],
#                [ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075],
#                [ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075],
#                [ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075],
#                [ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075],
#                [ 1.2986,  0.6295,  0.1456],
#                [-0.2346, -1.4261,  0.0075]]),
#     x: Batch(
#            c: tensor([[-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680],
#                       [-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680],
#                       [-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680],
#                       [-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680],
#                       [-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680],
#                       [-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680],
#                       [-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680],
#                       [-1.6582, -0.2189,  0.6896, -0.5367],
#                       [ 0.4442,  0.1250,  0.3993,  0.9457],
#                       [ 0.0084,  0.7474,  0.2958,  0.0680]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 172 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 334 µs ± 4.73 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
