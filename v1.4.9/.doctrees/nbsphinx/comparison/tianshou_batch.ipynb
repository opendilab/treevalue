# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f7220057be0>
# ├── 'a' --> tensor([[-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079]])
# └── 'x' --> <FastTreeValue 0x7f7225101ac0>
#     └── 'c' --> tensor([[-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147]])

# %%
t.a
# Out:
# tensor([[-0.4738,  1.2382,  0.8992],
#         [ 0.2503, -0.2515,  0.8079]])

# %%
# %timeit t.a
# Out:
# 65.3 ns ± 0.039 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f7220057be0>
# ├── 'a' --> tensor([[ 0.0514, -0.2053,  0.4784],
# │                   [ 0.5799,  0.0352,  1.2409]])
# └── 'x' --> <FastTreeValue 0x7f7225101ac0>
#     └── 'c' --> tensor([[-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147]])

# %%
# %timeit t.a = new_value
# Out:
# 63.3 ns ± 0.0355 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079]]),
#     x: Batch(
#            c: tensor([[-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.4738,  1.2382,  0.8992],
#         [ 0.2503, -0.2515,  0.8079]])

# %%
# %timeit b.a
# Out:
# 58.2 ns ± 0.0845 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.8596, -0.9105,  0.0618],
#                [ 0.8199,  1.4508,  0.1312]]),
#     x: Batch(
#            c: tensor([[-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 487 ns ± 0.289 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 828 ns ± 4.48 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.3 µs ± 20.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 140 µs ± 579 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 141 µs ± 287 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f7220069220>
# ├── 'a' --> tensor([[[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]],
# │
# │                   [[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]],
# │
# │                   [[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]],
# │
# │                   [[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]],
# │
# │                   [[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]],
# │
# │                   [[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]],
# │
# │                   [[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]],
# │
# │                   [[-0.4738,  1.2382,  0.8992],
# │                    [ 0.2503, -0.2515,  0.8079]]])
# └── 'x' --> <FastTreeValue 0x7f72200692b0>
#     └── 'c' --> tensor([[[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                         [[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                         [[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                         [[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                         [[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                         [[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                         [[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                         [[-0.2526, -0.2172, -0.7834, -0.7718],
#                          [-0.4261,  0.7291,  1.1549,  0.2194],
#                          [-0.2149, -0.6474, -0.7576, -0.3147]]])

# %%
# %timeit t_stack(trees)
# Out:
# 32.8 µs ± 129 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f7152cac1f0>
# ├── 'a' --> tensor([[-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079],
# │                   [-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079],
# │                   [-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079],
# │                   [-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079],
# │                   [-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079],
# │                   [-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079],
# │                   [-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079],
# │                   [-0.4738,  1.2382,  0.8992],
# │                   [ 0.2503, -0.2515,  0.8079]])
# └── 'x' --> <FastTreeValue 0x7f7152cac280>
#     └── 'c' --> tensor([[-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147],
#                         [-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147],
#                         [-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147],
#                         [-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147],
#                         [-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147],
#                         [-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147],
#                         [-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147],
#                         [-0.2526, -0.2172, -0.7834, -0.7718],
#                         [-0.4261,  0.7291,  1.1549,  0.2194],
#                         [-0.2149, -0.6474, -0.7576, -0.3147]])

# %%
# %timeit t_cat(trees)
# Out:
# 30.8 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 70.2 µs ± 53.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]],
#
#                [[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]],
#
#                [[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]],
#
#                [[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]],
#
#                [[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]],
#
#                [[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]],
#
#                [[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]],
#
#                [[-0.4738,  1.2382,  0.8992],
#                 [ 0.2503, -0.2515,  0.8079]]]),
#     x: Batch(
#            c: tensor([[[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                       [[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                       [[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                       [[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                       [[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                       [[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                       [[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]],
#
#                       [[-0.2526, -0.2172, -0.7834, -0.7718],
#                        [-0.4261,  0.7291,  1.1549,  0.2194],
#                        [-0.2149, -0.6474, -0.7576, -0.3147]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80 µs ± 356 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079],
#                [-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079],
#                [-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079],
#                [-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079],
#                [-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079],
#                [-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079],
#                [-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079],
#                [-0.4738,  1.2382,  0.8992],
#                [ 0.2503, -0.2515,  0.8079]]),
#     x: Batch(
#            c: tensor([[-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147],
#                       [-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147],
#                       [-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147],
#                       [-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147],
#                       [-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147],
#                       [-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147],
#                       [-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147],
#                       [-0.2526, -0.2172, -0.7834, -0.7718],
#                       [-0.4261,  0.7291,  1.1549,  0.2194],
#                       [-0.2149, -0.6474, -0.7576, -0.3147]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 236 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 320 µs ± 1.83 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
