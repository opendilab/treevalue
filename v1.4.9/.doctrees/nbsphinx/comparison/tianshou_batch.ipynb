# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f51bc89a6d0>
# ├── 'a' --> tensor([[-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565]])
# └── 'x' --> <FastTreeValue 0x7f51bc89a6a0>
#     └── 'c' --> tensor([[ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935]])

# %%
t.a
# Out:
# tensor([[-1.0336, -1.1901, -0.5806],
#         [-0.3897, -0.0062, -0.0565]])

# %%
# %timeit t.a
# Out:
# 76.6 ns ± 1.51 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f51bc89a6d0>
# ├── 'a' --> tensor([[ 1.5548, -0.4540, -1.1731],
# │                   [ 0.9374,  0.6252,  0.4588]])
# └── 'x' --> <FastTreeValue 0x7f51bc89a6a0>
#     └── 'c' --> tensor([[ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935]])

# %%
# %timeit t.a = new_value
# Out:
# 83.4 ns ± 1.12 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565]]),
#     x: Batch(
#            c: tensor([[ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-1.0336, -1.1901, -0.5806],
#         [-0.3897, -0.0062, -0.0565]])

# %%
# %timeit b.a
# Out:
# 76.5 ns ± 0.819 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.1992,  1.3604, -2.2250],
#                [-0.1252,  0.9611,  1.1982]]),
#     x: Batch(
#            c: tensor([[ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 677 ns ± 13.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.05 µs ± 16.3 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 13.7 µs ± 235 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 273 µs ± 7.62 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 259 µs ± 6.54 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f50e018dd60>
# ├── 'a' --> tensor([[[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]],
# │
# │                   [[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]],
# │
# │                   [[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]],
# │
# │                   [[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]],
# │
# │                   [[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]],
# │
# │                   [[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]],
# │
# │                   [[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]],
# │
# │                   [[-1.0336, -1.1901, -0.5806],
# │                    [-0.3897, -0.0062, -0.0565]]])
# └── 'x' --> <FastTreeValue 0x7f50e018de20>
#     └── 'c' --> tensor([[[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                         [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                         [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                         [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                         [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                         [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                         [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                         [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                          [ 1.2576, -0.4542, -0.6135,  0.4689],
#                          [-0.6507,  1.7854,  0.3108, -0.0935]]])

# %%
# %timeit t_stack(trees)
# Out:
# 46.8 µs ± 589 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f51bc89a5e0>
# ├── 'a' --> tensor([[-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565],
# │                   [-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565],
# │                   [-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565],
# │                   [-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565],
# │                   [-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565],
# │                   [-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565],
# │                   [-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565],
# │                   [-1.0336, -1.1901, -0.5806],
# │                   [-0.3897, -0.0062, -0.0565]])
# └── 'x' --> <FastTreeValue 0x7f51bc89a340>
#     └── 'c' --> tensor([[ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935],
#                         [ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935],
#                         [ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935],
#                         [ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935],
#                         [ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935],
#                         [ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935],
#                         [ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935],
#                         [ 0.4851, -0.7076, -0.1159,  1.4086],
#                         [ 1.2576, -0.4542, -0.6135,  0.4689],
#                         [-0.6507,  1.7854,  0.3108, -0.0935]])

# %%
# %timeit t_cat(trees)
# Out:
# 42.7 µs ± 637 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 95.9 µs ± 1.17 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]],
#
#                [[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]],
#
#                [[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]],
#
#                [[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]],
#
#                [[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]],
#
#                [[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]],
#
#                [[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]],
#
#                [[-1.0336, -1.1901, -0.5806],
#                 [-0.3897, -0.0062, -0.0565]]]),
#     x: Batch(
#            c: tensor([[[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                       [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                       [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                       [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                       [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                       [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                       [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]],
#
#                       [[ 0.4851, -0.7076, -0.1159,  1.4086],
#                        [ 1.2576, -0.4542, -0.6135,  0.4689],
#                        [-0.6507,  1.7854,  0.3108, -0.0935]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 112 µs ± 1.58 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565],
#                [-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565],
#                [-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565],
#                [-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565],
#                [-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565],
#                [-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565],
#                [-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565],
#                [-1.0336, -1.1901, -0.5806],
#                [-0.3897, -0.0062, -0.0565]]),
#     x: Batch(
#            c: tensor([[ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935],
#                       [ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935],
#                       [ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935],
#                       [ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935],
#                       [ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935],
#                       [ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935],
#                       [ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935],
#                       [ 0.4851, -0.7076, -0.1159,  1.4086],
#                       [ 1.2576, -0.4542, -0.6135,  0.4689],
#                       [-0.6507,  1.7854,  0.3108, -0.0935]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 199 µs ± 5.82 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 623 µs ± 16.8 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
