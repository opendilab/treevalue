# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7faa5cbd80a0>
# ├── 'a' --> tensor([[ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070]])
# └── 'x' --> <FastTreeValue 0x7faa5cbd85e0>
#     └── 'c' --> tensor([[ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779]])

# %%
t.a
# Out:
# tensor([[ 1.3449,  1.6207,  0.7699],
#         [-1.9216,  1.0365, -1.9070]])

# %%
# %timeit t.a
# Out:
# 84.3 ns ± 0.814 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7faa5cbd80a0>
# ├── 'a' --> tensor([[ 0.1622, -0.7175,  0.1122],
# │                   [ 0.6128,  1.0814, -1.9317]])
# └── 'x' --> <FastTreeValue 0x7faa5cbd85e0>
#     └── 'c' --> tensor([[ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779]])

# %%
# %timeit t.a = new_value
# Out:
# 88.9 ns ± 0.233 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070]]),
#     x: Batch(
#            c: tensor([[ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 1.3449,  1.6207,  0.7699],
#         [-1.9216,  1.0365, -1.9070]])

# %%
# %timeit b.a
# Out:
# 80.6 ns ± 0.938 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.3644, -0.2836, -1.0777],
#                [-1.6039, -0.5658, -0.3601]]),
#     x: Batch(
#            c: tensor([[ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 631 ns ± 4.03 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 1.01 µs ± 9.56 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 12 µs ± 107 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 165 µs ± 1.78 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 166 µs ± 555 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fa98a34a220>
# ├── 'a' --> tensor([[[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]],
# │
# │                   [[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]],
# │
# │                   [[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]],
# │
# │                   [[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]],
# │
# │                   [[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]],
# │
# │                   [[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]],
# │
# │                   [[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]],
# │
# │                   [[ 1.3449,  1.6207,  0.7699],
# │                    [-1.9216,  1.0365, -1.9070]]])
# └── 'x' --> <FastTreeValue 0x7fa97c7cb700>
#     └── 'c' --> tensor([[[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                         [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                         [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                         [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                         [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                         [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                         [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                         [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                          [-1.1773, -0.4147,  1.6012, -1.8310],
#                          [-0.8204,  0.3620,  1.0838, -0.4779]]])

# %%
# %timeit t_stack(trees)
# Out:
# 38.3 µs ± 173 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7faa5cc39e20>
# ├── 'a' --> tensor([[ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070],
# │                   [ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070],
# │                   [ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070],
# │                   [ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070],
# │                   [ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070],
# │                   [ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070],
# │                   [ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070],
# │                   [ 1.3449,  1.6207,  0.7699],
# │                   [-1.9216,  1.0365, -1.9070]])
# └── 'x' --> <FastTreeValue 0x7fa98a34a640>
#     └── 'c' --> tensor([[ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779],
#                         [ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779],
#                         [ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779],
#                         [ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779],
#                         [ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779],
#                         [ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779],
#                         [ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779],
#                         [ 1.3392, -0.4452, -1.8944, -0.0140],
#                         [-1.1773, -0.4147,  1.6012, -1.8310],
#                         [-0.8204,  0.3620,  1.0838, -0.4779]])

# %%
# %timeit t_cat(trees)
# Out:
# 36.1 µs ± 371 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 75.5 µs ± 681 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]],
#
#                [[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]],
#
#                [[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]],
#
#                [[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]],
#
#                [[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]],
#
#                [[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]],
#
#                [[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]],
#
#                [[ 1.3449,  1.6207,  0.7699],
#                 [-1.9216,  1.0365, -1.9070]]]),
#     x: Batch(
#            c: tensor([[[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                       [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                       [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                       [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                       [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                       [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                       [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]],
#
#                       [[ 1.3392, -0.4452, -1.8944, -0.0140],
#                        [-1.1773, -0.4147,  1.6012, -1.8310],
#                        [-0.8204,  0.3620,  1.0838, -0.4779]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 95.2 µs ± 689 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070],
#                [ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070],
#                [ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070],
#                [ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070],
#                [ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070],
#                [ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070],
#                [ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070],
#                [ 1.3449,  1.6207,  0.7699],
#                [-1.9216,  1.0365, -1.9070]]),
#     x: Batch(
#            c: tensor([[ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779],
#                       [ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779],
#                       [ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779],
#                       [ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779],
#                       [ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779],
#                       [ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779],
#                       [ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779],
#                       [ 1.3392, -0.4452, -1.8944, -0.0140],
#                       [-1.1773, -0.4147,  1.6012, -1.8310],
#                       [-0.8204,  0.3620,  1.0838, -0.4779]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 174 µs ± 1.86 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 408 µs ± 8.26 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
