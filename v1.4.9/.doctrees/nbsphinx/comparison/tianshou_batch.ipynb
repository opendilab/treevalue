# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f0b44f3d4f0>
# ├── 'a' --> tensor([[ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375]])
# └── 'x' --> <FastTreeValue 0x7f0b44f3d400>
#     └── 'c' --> tensor([[ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405]])

# %%
t.a
# Out:
# tensor([[ 0.0039, -0.2592,  0.9200],
#         [ 0.3825, -0.7133,  0.2375]])

# %%
# %timeit t.a
# Out:
# 72.8 ns ± 0.0932 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f0b44f3d4f0>
# ├── 'a' --> tensor([[ 0.1639, -0.3158,  1.9617],
# │                   [ 0.8976,  0.6974,  0.6350]])
# └── 'x' --> <FastTreeValue 0x7f0b44f3d400>
#     └── 'c' --> tensor([[ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405]])

# %%
# %timeit t.a = new_value
# Out:
# 88.6 ns ± 0.0504 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375]]),
#     x: Batch(
#            c: tensor([[ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.0039, -0.2592,  0.9200],
#         [ 0.3825, -0.7133,  0.2375]])

# %%
# %timeit b.a
# Out:
# 65.2 ns ± 0.121 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.2908, -1.2111, -0.5731],
#                [ 0.3964,  0.0879,  0.1779]]),
#     x: Batch(
#            c: tensor([[ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 544 ns ± 0.133 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 879 ns ± 0.942 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11 µs ± 12.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 148 µs ± 2.12 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 148 µs ± 891 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f0a687cc940>
# ├── 'a' --> tensor([[[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]],
# │
# │                   [[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]],
# │
# │                   [[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]],
# │
# │                   [[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]],
# │
# │                   [[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]],
# │
# │                   [[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]],
# │
# │                   [[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]],
# │
# │                   [[ 0.0039, -0.2592,  0.9200],
# │                    [ 0.3825, -0.7133,  0.2375]]])
# └── 'x' --> <FastTreeValue 0x7f0a687cc2b0>
#     └── 'c' --> tensor([[[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                         [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                         [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                         [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                         [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                         [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                         [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                         [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                          [ 0.6961, -0.4644, -0.2192, -0.1233],
#                          [ 1.0977,  0.8891, -2.1298,  0.9405]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 118 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f0b48f580a0>
# ├── 'a' --> tensor([[ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375],
# │                   [ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375],
# │                   [ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375],
# │                   [ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375],
# │                   [ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375],
# │                   [ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375],
# │                   [ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375],
# │                   [ 0.0039, -0.2592,  0.9200],
# │                   [ 0.3825, -0.7133,  0.2375]])
# └── 'x' --> <FastTreeValue 0x7f0a68837d60>
#     └── 'c' --> tensor([[ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405],
#                         [ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405],
#                         [ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405],
#                         [ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405],
#                         [ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405],
#                         [ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405],
#                         [ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405],
#                         [ 0.4680,  0.1480, -0.1257, -0.9223],
#                         [ 0.6961, -0.4644, -0.2192, -0.1233],
#                         [ 1.0977,  0.8891, -2.1298,  0.9405]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.5 µs ± 39.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.2 µs ± 34.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]],
#
#                [[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]],
#
#                [[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]],
#
#                [[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]],
#
#                [[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]],
#
#                [[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]],
#
#                [[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]],
#
#                [[ 0.0039, -0.2592,  0.9200],
#                 [ 0.3825, -0.7133,  0.2375]]]),
#     x: Batch(
#            c: tensor([[[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                       [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                       [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                       [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                       [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                       [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                       [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]],
#
#                       [[ 0.4680,  0.1480, -0.1257, -0.9223],
#                        [ 0.6961, -0.4644, -0.2192, -0.1233],
#                        [ 1.0977,  0.8891, -2.1298,  0.9405]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.2 µs ± 235 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375],
#                [ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375],
#                [ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375],
#                [ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375],
#                [ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375],
#                [ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375],
#                [ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375],
#                [ 0.0039, -0.2592,  0.9200],
#                [ 0.3825, -0.7133,  0.2375]]),
#     x: Batch(
#            c: tensor([[ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405],
#                       [ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405],
#                       [ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405],
#                       [ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405],
#                       [ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405],
#                       [ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405],
#                       [ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405],
#                       [ 0.4680,  0.1480, -0.1257, -0.9223],
#                       [ 0.6961, -0.4644, -0.2192, -0.1233],
#                       [ 1.0977,  0.8891, -2.1298,  0.9405]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 151 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 352 µs ± 5.5 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
