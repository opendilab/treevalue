# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7faaa4062520>
# ├── 'a' --> tensor([[-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164]])
# └── 'x' --> <FastTreeValue 0x7faaa4062880>
#     └── 'c' --> tensor([[ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714]])

# %%
t.a
# Out:
# tensor([[-0.5299,  0.9485,  0.3038],
#         [ 1.8866,  0.2931,  0.5164]])

# %%
# %timeit t.a
# Out:
# 71.2 ns ± 0.101 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7faaa4062520>
# ├── 'a' --> tensor([[ 1.5410, -0.6584, -1.0230],
# │                   [ 0.6332, -0.9858, -0.1994]])
# └── 'x' --> <FastTreeValue 0x7faaa4062880>
#     └── 'c' --> tensor([[ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714]])

# %%
# %timeit t.a = new_value
# Out:
# 72.3 ns ± 0.0981 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164]]),
#     x: Batch(
#            c: tensor([[ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.5299,  0.9485,  0.3038],
#         [ 1.8866,  0.2931,  0.5164]])

# %%
# %timeit b.a
# Out:
# 66.6 ns ± 0.114 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.0991, -1.5384,  0.2118],
#                [ 1.2224,  0.8649, -0.0631]]),
#     x: Batch(
#            c: tensor([[ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 554 ns ± 9.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.14 µs ± 20.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.1 µs ± 22.7 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 147 µs ± 580 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 149 µs ± 2.59 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fa9b473c520>
# ├── 'a' --> tensor([[[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]],
# │
# │                   [[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]],
# │
# │                   [[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]],
# │
# │                   [[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]],
# │
# │                   [[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]],
# │
# │                   [[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]],
# │
# │                   [[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]],
# │
# │                   [[-0.5299,  0.9485,  0.3038],
# │                    [ 1.8866,  0.2931,  0.5164]]])
# └── 'x' --> <FastTreeValue 0x7fa9cd4e7f40>
#     └── 'c' --> tensor([[[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                         [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                         [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                         [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                         [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                         [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                         [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                         [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                          [-0.6770, -0.7569, -0.4340, -1.4582],
#                          [-0.4429,  0.2504, -3.5457,  0.2714]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.3 µs ± 60.8 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fa9b46c7610>
# ├── 'a' --> tensor([[-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164],
# │                   [-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164],
# │                   [-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164],
# │                   [-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164],
# │                   [-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164],
# │                   [-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164],
# │                   [-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164],
# │                   [-0.5299,  0.9485,  0.3038],
# │                   [ 1.8866,  0.2931,  0.5164]])
# └── 'x' --> <FastTreeValue 0x7fa9b46c78b0>
#     └── 'c' --> tensor([[ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714],
#                         [ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714],
#                         [ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714],
#                         [ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714],
#                         [ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714],
#                         [ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714],
#                         [ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714],
#                         [ 1.5753, -0.5468,  0.0813,  0.0209],
#                         [-0.6770, -0.7569, -0.4340, -1.4582],
#                         [-0.4429,  0.2504, -3.5457,  0.2714]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.1 µs ± 158 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.2 µs ± 111 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                       [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                       [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                       [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                       [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                       [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                       [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]],
#
#                       [[ 1.5753, -0.5468,  0.0813,  0.0209],
#                        [-0.6770, -0.7569, -0.4340, -1.4582],
#                        [-0.4429,  0.2504, -3.5457,  0.2714]]]),
#        ),
#     a: tensor([[[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]],
#
#                [[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]],
#
#                [[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]],
#
#                [[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]],
#
#                [[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]],
#
#                [[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]],
#
#                [[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]],
#
#                [[-0.5299,  0.9485,  0.3038],
#                 [ 1.8866,  0.2931,  0.5164]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 83.4 µs ± 193 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714],
#                       [ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714],
#                       [ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714],
#                       [ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714],
#                       [ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714],
#                       [ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714],
#                       [ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714],
#                       [ 1.5753, -0.5468,  0.0813,  0.0209],
#                       [-0.6770, -0.7569, -0.4340, -1.4582],
#                       [-0.4429,  0.2504, -3.5457,  0.2714]]),
#        ),
#     a: tensor([[-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164],
#                [-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164],
#                [-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164],
#                [-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164],
#                [-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164],
#                [-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164],
#                [-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164],
#                [-0.5299,  0.9485,  0.3038],
#                [ 1.8866,  0.2931,  0.5164]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 152 µs ± 294 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 379 µs ± 7.73 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
