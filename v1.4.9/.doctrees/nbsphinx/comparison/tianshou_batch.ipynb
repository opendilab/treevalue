# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5d34db0c70>
# ├── 'a' --> tensor([[-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309]])
# └── 'x' --> <FastTreeValue 0x7f5d34db0df0>
#     └── 'c' --> tensor([[ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560]])

# %%
t.a
# Out:
# tensor([[-0.7054,  0.5642, -0.4477],
#         [ 0.2626, -0.6154,  0.3309]])

# %%
# %timeit t.a
# Out:
# 70.9 ns ± 0.111 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5d34db0c70>
# ├── 'a' --> tensor([[ 0.4616, -1.2337, -0.0153],
# │                   [-1.3556,  1.1220, -1.6815]])
# └── 'x' --> <FastTreeValue 0x7f5d34db0df0>
#     └── 'c' --> tensor([[ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560]])

# %%
# %timeit t.a = new_value
# Out:
# 72 ns ± 0.065 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309]]),
#     x: Batch(
#            c: tensor([[ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.7054,  0.5642, -0.4477],
#         [ 0.2626, -0.6154,  0.3309]])

# %%
# %timeit b.a
# Out:
# 66.2 ns ± 0.139 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.8793, -1.1364,  1.1235],
#                [-0.2550, -1.2102,  0.0600]]),
#     x: Batch(
#            c: tensor([[ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 545 ns ± 0.792 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 8.12 µs ± 23.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 13.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 150 µs ± 1.1 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 154 µs ± 7.25 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5d10221e50>
# ├── 'a' --> tensor([[[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]],
# │
# │                   [[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]],
# │
# │                   [[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]],
# │
# │                   [[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]],
# │
# │                   [[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]],
# │
# │                   [[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]],
# │
# │                   [[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]],
# │
# │                   [[-0.7054,  0.5642, -0.4477],
# │                    [ 0.2626, -0.6154,  0.3309]]])
# └── 'x' --> <FastTreeValue 0x7f5d10221a00>
#     └── 'c' --> tensor([[[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                         [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                         [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                         [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                         [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                         [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                         [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                         [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                          [-0.4083, -1.9370,  0.1315,  0.3702],
#                          [ 0.1689, -0.0775,  0.0704, -0.9560]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.5 µs ± 98.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5d10203fa0>
# ├── 'a' --> tensor([[-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309],
# │                   [-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309],
# │                   [-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309],
# │                   [-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309],
# │                   [-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309],
# │                   [-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309],
# │                   [-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309],
# │                   [-0.7054,  0.5642, -0.4477],
# │                   [ 0.2626, -0.6154,  0.3309]])
# └── 'x' --> <FastTreeValue 0x7f5d34e08df0>
#     └── 'c' --> tensor([[ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560],
#                         [ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560],
#                         [ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560],
#                         [ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560],
#                         [ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560],
#                         [ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560],
#                         [ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560],
#                         [ 0.7754,  0.8626,  1.1882, -1.2503],
#                         [-0.4083, -1.9370,  0.1315,  0.3702],
#                         [ 0.1689, -0.0775,  0.0704, -0.9560]])

# %%
# %timeit t_cat(trees)
# Out:
# 32.4 µs ± 55.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67 µs ± 210 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]],
#
#                [[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]],
#
#                [[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]],
#
#                [[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]],
#
#                [[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]],
#
#                [[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]],
#
#                [[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]],
#
#                [[-0.7054,  0.5642, -0.4477],
#                 [ 0.2626, -0.6154,  0.3309]]]),
#     x: Batch(
#            c: tensor([[[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                       [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                       [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                       [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                       [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                       [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                       [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]],
#
#                       [[ 0.7754,  0.8626,  1.1882, -1.2503],
#                        [-0.4083, -1.9370,  0.1315,  0.3702],
#                        [ 0.1689, -0.0775,  0.0704, -0.9560]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84.1 µs ± 332 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309],
#                [-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309],
#                [-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309],
#                [-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309],
#                [-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309],
#                [-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309],
#                [-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309],
#                [-0.7054,  0.5642, -0.4477],
#                [ 0.2626, -0.6154,  0.3309]]),
#     x: Batch(
#            c: tensor([[ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560],
#                       [ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560],
#                       [ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560],
#                       [ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560],
#                       [ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560],
#                       [ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560],
#                       [ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560],
#                       [ 0.7754,  0.8626,  1.1882, -1.2503],
#                       [-0.4083, -1.9370,  0.1315,  0.3702],
#                       [ 0.1689, -0.0775,  0.0704, -0.9560]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 154 µs ± 277 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 380 µs ± 6.91 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
