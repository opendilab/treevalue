# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fa9f0f7c550>
# ├── 'a' --> tensor([[-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839]])
# └── 'x' --> <FastTreeValue 0x7fa9f0f7c340>
#     └── 'c' --> tensor([[ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561]])

# %%
t.a
# Out:
# tensor([[-0.5494, -2.1986,  0.9218],
#         [ 0.0132,  0.5585, -0.3839]])

# %%
# %timeit t.a
# Out:
# 59.1 ns ± 0.431 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fa9f0f7c550>
# ├── 'a' --> tensor([[-1.7424,  0.4191,  0.9657],
# │                   [ 0.6635,  0.8618, -1.6873]])
# └── 'x' --> <FastTreeValue 0x7fa9f0f7c340>
#     └── 'c' --> tensor([[ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561]])

# %%
# %timeit t.a = new_value
# Out:
# 60.9 ns ± 0.0342 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839]]),
#     x: Batch(
#            c: tensor([[ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.5494, -2.1986,  0.9218],
#         [ 0.0132,  0.5585, -0.3839]])

# %%
# %timeit b.a
# Out:
# 59.8 ns ± 0.0635 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-1.0320,  2.0815, -0.3613],
#                [ 1.2571,  0.4279, -0.6874]]),
#     x: Batch(
#            c: tensor([[ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 487 ns ± 0.081 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 887 ns ± 5.37 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 33 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 135 µs ± 750 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 139 µs ± 826 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fa915853df0>
# ├── 'a' --> tensor([[[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]],
# │
# │                   [[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]],
# │
# │                   [[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]],
# │
# │                   [[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]],
# │
# │                   [[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]],
# │
# │                   [[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]],
# │
# │                   [[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]],
# │
# │                   [[-0.5494, -2.1986,  0.9218],
# │                    [ 0.0132,  0.5585, -0.3839]]])
# └── 'x' --> <FastTreeValue 0x7fa9f5ffa7f0>
#     └── 'c' --> tensor([[[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                         [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                         [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                         [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                         [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                         [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                         [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                         [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                          [ 0.5951, -2.4501, -0.1148,  0.5612],
#                          [ 0.0850,  0.4995,  2.2770,  0.6561]]])

# %%
# %timeit t_stack(trees)
# Out:
# 31.9 µs ± 94.1 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fa9157e1a30>
# ├── 'a' --> tensor([[-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839],
# │                   [-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839],
# │                   [-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839],
# │                   [-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839],
# │                   [-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839],
# │                   [-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839],
# │                   [-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839],
# │                   [-0.5494, -2.1986,  0.9218],
# │                   [ 0.0132,  0.5585, -0.3839]])
# └── 'x' --> <FastTreeValue 0x7fa9157e1550>
#     └── 'c' --> tensor([[ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561],
#                         [ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561],
#                         [ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561],
#                         [ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561],
#                         [ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561],
#                         [ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561],
#                         [ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561],
#                         [ 0.3194,  1.4381, -1.1096, -1.4040],
#                         [ 0.5951, -2.4501, -0.1148,  0.5612],
#                         [ 0.0850,  0.4995,  2.2770,  0.6561]])

# %%
# %timeit t_cat(trees)
# Out:
# 30 µs ± 24.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.3 µs ± 110 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                       [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                       [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                       [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                       [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                       [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                       [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]],
#
#                       [[ 0.3194,  1.4381, -1.1096, -1.4040],
#                        [ 0.5951, -2.4501, -0.1148,  0.5612],
#                        [ 0.0850,  0.4995,  2.2770,  0.6561]]]),
#        ),
#     a: tensor([[[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]],
#
#                [[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]],
#
#                [[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]],
#
#                [[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]],
#
#                [[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]],
#
#                [[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]],
#
#                [[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]],
#
#                [[-0.5494, -2.1986,  0.9218],
#                 [ 0.0132,  0.5585, -0.3839]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 80.7 µs ± 287 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561],
#                       [ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561],
#                       [ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561],
#                       [ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561],
#                       [ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561],
#                       [ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561],
#                       [ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561],
#                       [ 0.3194,  1.4381, -1.1096, -1.4040],
#                       [ 0.5951, -2.4501, -0.1148,  0.5612],
#                       [ 0.0850,  0.4995,  2.2770,  0.6561]]),
#        ),
#     a: tensor([[-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839],
#                [-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839],
#                [-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839],
#                [-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839],
#                [-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839],
#                [-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839],
#                [-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839],
#                [-0.5494, -2.1986,  0.9218],
#                [ 0.0132,  0.5585, -0.3839]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 151 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 325 µs ± 4.55 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
