# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb500875f40>
# ├── 'a' --> tensor([[ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534]])
# └── 'x' --> <FastTreeValue 0x7fb500875eb0>
#     └── 'c' --> tensor([[-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090]])

# %%
t.a
# Out:
# tensor([[ 0.8286, -1.2206,  1.3583],
#         [-0.0657,  0.9789, -0.4534]])

# %%
# %timeit t.a
# Out:
# 76 ns ± 0.117 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb500875f40>
# ├── 'a' --> tensor([[ 0.2203,  0.8077,  0.3048],
# │                   [-0.7838,  0.6946,  1.2427]])
# └── 'x' --> <FastTreeValue 0x7fb500875eb0>
#     └── 'c' --> tensor([[-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090]])

# %%
# %timeit t.a = new_value
# Out:
# 71.1 ns ± 0.234 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534]]),
#     x: Batch(
#            c: tensor([[-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.8286, -1.2206,  1.3583],
#         [-0.0657,  0.9789, -0.4534]])

# %%
# %timeit b.a
# Out:
# 59.6 ns ± 0.0871 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-2.5140, -0.1336, -0.2640],
#                [ 0.4835,  0.0648,  0.3194]]),
#     x: Batch(
#            c: tensor([[-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 496 ns ± 1.08 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 801 ns ± 0.0484 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.6 µs ± 76.8 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 147 µs ± 375 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 146 µs ± 1.46 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fb4324bc520>
# ├── 'a' --> tensor([[[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]],
# │
# │                   [[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]],
# │
# │                   [[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]],
# │
# │                   [[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]],
# │
# │                   [[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]],
# │
# │                   [[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]],
# │
# │                   [[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]],
# │
# │                   [[ 0.8286, -1.2206,  1.3583],
# │                    [-0.0657,  0.9789, -0.4534]]])
# └── 'x' --> <FastTreeValue 0x7fb4f01bde50>
#     └── 'c' --> tensor([[[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                         [[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                         [[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                         [[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                         [[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                         [[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                         [[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                         [[-1.3503, -0.2253,  0.2948,  0.4805],
#                          [ 0.4437,  0.0830,  0.9372,  1.3733],
#                          [-0.0842, -0.9576, -1.6271,  1.2090]]])

# %%
# %timeit t_stack(trees)
# Out:
# 34.1 µs ± 60.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fb4324bcc40>
# ├── 'a' --> tensor([[ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534],
# │                   [ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534],
# │                   [ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534],
# │                   [ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534],
# │                   [ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534],
# │                   [ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534],
# │                   [ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534],
# │                   [ 0.8286, -1.2206,  1.3583],
# │                   [-0.0657,  0.9789, -0.4534]])
# └── 'x' --> <FastTreeValue 0x7fb4324bca00>
#     └── 'c' --> tensor([[-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090],
#                         [-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090],
#                         [-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090],
#                         [-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090],
#                         [-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090],
#                         [-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090],
#                         [-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090],
#                         [-1.3503, -0.2253,  0.2948,  0.4805],
#                         [ 0.4437,  0.0830,  0.9372,  1.3733],
#                         [-0.0842, -0.9576, -1.6271,  1.2090]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.9 µs ± 162 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.4 µs ± 43.4 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]],
#
#                [[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]],
#
#                [[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]],
#
#                [[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]],
#
#                [[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]],
#
#                [[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]],
#
#                [[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]],
#
#                [[ 0.8286, -1.2206,  1.3583],
#                 [-0.0657,  0.9789, -0.4534]]]),
#     x: Batch(
#            c: tensor([[[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                       [[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                       [[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                       [[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                       [[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                       [[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                       [[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]],
#
#                       [[-1.3503, -0.2253,  0.2948,  0.4805],
#                        [ 0.4437,  0.0830,  0.9372,  1.3733],
#                        [-0.0842, -0.9576, -1.6271,  1.2090]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.6 µs ± 123 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534],
#                [ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534],
#                [ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534],
#                [ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534],
#                [ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534],
#                [ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534],
#                [ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534],
#                [ 0.8286, -1.2206,  1.3583],
#                [-0.0657,  0.9789, -0.4534]]),
#     x: Batch(
#            c: tensor([[-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090],
#                       [-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090],
#                       [-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090],
#                       [-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090],
#                       [-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090],
#                       [-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090],
#                       [-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090],
#                       [-1.3503, -0.2253,  0.2948,  0.4805],
#                       [ 0.4437,  0.0830,  0.9372,  1.3733],
#                       [-0.0842, -0.9576, -1.6271,  1.2090]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 148 µs ± 1.54 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 348 µs ± 1.07 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
