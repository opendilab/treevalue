# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f78bc5b1400>
# ├── 'a' --> tensor([[ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275]])
# └── 'x' --> <FastTreeValue 0x7f78bc5b1580>
#     └── 'c' --> tensor([[ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892]])

# %%
t.a
# Out:
# tensor([[ 2.1692, -0.5852, -1.6962],
#         [-0.2530,  1.1380, -2.0275]])

# %%
# %timeit t.a
# Out:
# 63.4 ns ± 0.034 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f78bc5b1400>
# ├── 'a' --> tensor([[ 1.1195, -0.2944,  0.8666],
# │                   [-0.7989,  1.5574, -1.1739]])
# └── 'x' --> <FastTreeValue 0x7f78bc5b1580>
#     └── 'c' --> tensor([[ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892]])

# %%
# %timeit t.a = new_value
# Out:
# 71.1 ns ± 0.056 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275]]),
#     x: Batch(
#            c: tensor([[ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 2.1692, -0.5852, -1.6962],
#         [-0.2530,  1.1380, -2.0275]])

# %%
# %timeit b.a
# Out:
# 59 ns ± 0.0591 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.6814,  2.3147,  0.4036],
#                [-0.8245, -0.0111, -2.0401]]),
#     x: Batch(
#            c: tensor([[ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 508 ns ± 0.21 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 824 ns ± 1.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 9.55 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 143 µs ± 515 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 143 µs ± 1.18 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f78bc5b16a0>
# ├── 'a' --> tensor([[[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]],
# │
# │                   [[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]],
# │
# │                   [[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]],
# │
# │                   [[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]],
# │
# │                   [[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]],
# │
# │                   [[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]],
# │
# │                   [[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]],
# │
# │                   [[ 2.1692, -0.5852, -1.6962],
# │                    [-0.2530,  1.1380, -2.0275]]])
# └── 'x' --> <FastTreeValue 0x7f78bc5b1700>
#     └── 'c' --> tensor([[[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                         [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                         [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                         [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                         [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                         [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                         [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                         [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                          [ 1.1218,  0.5192, -0.5309, -0.9625],
#                          [-1.1639,  0.2208, -0.9147,  0.2892]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.7 µs ± 88.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f77ec1f6d90>
# ├── 'a' --> tensor([[ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275],
# │                   [ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275],
# │                   [ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275],
# │                   [ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275],
# │                   [ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275],
# │                   [ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275],
# │                   [ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275],
# │                   [ 2.1692, -0.5852, -1.6962],
# │                   [-0.2530,  1.1380, -2.0275]])
# └── 'x' --> <FastTreeValue 0x7f77ec1f6e50>
#     └── 'c' --> tensor([[ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892],
#                         [ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892],
#                         [ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892],
#                         [ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892],
#                         [ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892],
#                         [ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892],
#                         [ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892],
#                         [ 2.0570,  0.8749,  0.0921,  0.9920],
#                         [ 1.1218,  0.5192, -0.5309, -0.9625],
#                         [-1.1639,  0.2208, -0.9147,  0.2892]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.3 µs ± 72.3 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.5 µs ± 84.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                       [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                       [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                       [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                       [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                       [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                       [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]],
#
#                       [[ 2.0570,  0.8749,  0.0921,  0.9920],
#                        [ 1.1218,  0.5192, -0.5309, -0.9625],
#                        [-1.1639,  0.2208, -0.9147,  0.2892]]]),
#        ),
#     a: tensor([[[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]],
#
#                [[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]],
#
#                [[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]],
#
#                [[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]],
#
#                [[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]],
#
#                [[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]],
#
#                [[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]],
#
#                [[ 2.1692, -0.5852, -1.6962],
#                 [-0.2530,  1.1380, -2.0275]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 78.5 µs ± 386 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892],
#                       [ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892],
#                       [ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892],
#                       [ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892],
#                       [ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892],
#                       [ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892],
#                       [ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892],
#                       [ 2.0570,  0.8749,  0.0921,  0.9920],
#                       [ 1.1218,  0.5192, -0.5309, -0.9625],
#                       [-1.1639,  0.2208, -0.9147,  0.2892]]),
#        ),
#     a: tensor([[ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275],
#                [ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275],
#                [ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275],
#                [ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275],
#                [ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275],
#                [ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275],
#                [ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275],
#                [ 2.1692, -0.5852, -1.6962],
#                [-0.2530,  1.1380, -2.0275]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 151 µs ± 406 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 347 µs ± 4.11 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
