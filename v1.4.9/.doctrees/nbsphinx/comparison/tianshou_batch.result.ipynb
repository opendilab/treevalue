# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fef90a97910>
# ├── 'a' --> tensor([[ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249]])
# └── 'x' --> <FastTreeValue 0x7fef90a978b0>
#     └── 'c' --> tensor([[-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828]])

# %%
t.a
# Out:
# tensor([[ 2.6202, -1.8144,  0.3302],
#         [ 0.8890, -0.0934, -0.6249]])

# %%
# %timeit t.a
# Out:
# 67.5 ns ± 0.0792 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fef90a97910>
# ├── 'a' --> tensor([[ 0.7908, -0.8349,  0.7486],
# │                   [ 0.9375,  0.6695, -0.0587]])
# └── 'x' --> <FastTreeValue 0x7fef90a978b0>
#     └── 'c' --> tensor([[-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828]])

# %%
# %timeit t.a = new_value
# Out:
# 63.1 ns ± 0.0433 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249]]),
#     x: Batch(
#            c: tensor([[-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 2.6202, -1.8144,  0.3302],
#         [ 0.8890, -0.0934, -0.6249]])

# %%
# %timeit b.a
# Out:
# 53.6 ns ± 0.095 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.1049,  1.2688,  0.3463],
#                [-0.4103,  0.3779,  0.5549]]),
#     x: Batch(
#            c: tensor([[-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 491 ns ± 0.88 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 840 ns ± 0.582 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 46.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 690 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 722 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7feea2149a30>
# ├── 'a' --> tensor([[[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]],
# │
# │                   [[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]],
# │
# │                   [[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]],
# │
# │                   [[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]],
# │
# │                   [[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]],
# │
# │                   [[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]],
# │
# │                   [[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]],
# │
# │                   [[ 2.6202, -1.8144,  0.3302],
# │                    [ 0.8890, -0.0934, -0.6249]]])
# └── 'x' --> <FastTreeValue 0x7fef90aaed00>
#     └── 'c' --> tensor([[[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                         [[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                         [[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                         [[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                         [[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                         [[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                         [[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                         [[-0.1902,  1.8934, -2.1412, -0.9223],
#                          [-0.2366, -0.3746, -1.1031, -2.0069],
#                          [ 1.0283, -0.6302, -0.3412,  1.2828]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 68.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7feea22c42b0>
# ├── 'a' --> tensor([[ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249],
# │                   [ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249],
# │                   [ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249],
# │                   [ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249],
# │                   [ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249],
# │                   [ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249],
# │                   [ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249],
# │                   [ 2.6202, -1.8144,  0.3302],
# │                   [ 0.8890, -0.0934, -0.6249]])
# └── 'x' --> <FastTreeValue 0x7feea27b15b0>
#     └── 'c' --> tensor([[-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828],
#                         [-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828],
#                         [-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828],
#                         [-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828],
#                         [-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828],
#                         [-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828],
#                         [-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828],
#                         [-0.1902,  1.8934, -2.1412, -0.9223],
#                         [-0.2366, -0.3746, -1.1031, -2.0069],
#                         [ 1.0283, -0.6302, -0.3412,  1.2828]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.1 µs ± 159 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68.7 µs ± 202 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]],
#
#                [[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]],
#
#                [[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]],
#
#                [[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]],
#
#                [[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]],
#
#                [[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]],
#
#                [[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]],
#
#                [[ 2.6202, -1.8144,  0.3302],
#                 [ 0.8890, -0.0934, -0.6249]]]),
#     x: Batch(
#            c: tensor([[[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                       [[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                       [[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                       [[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                       [[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                       [[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                       [[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]],
#
#                       [[-0.1902,  1.8934, -2.1412, -0.9223],
#                        [-0.2366, -0.3746, -1.1031, -2.0069],
#                        [ 1.0283, -0.6302, -0.3412,  1.2828]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 95.7 µs ± 294 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249],
#                [ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249],
#                [ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249],
#                [ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249],
#                [ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249],
#                [ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249],
#                [ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249],
#                [ 2.6202, -1.8144,  0.3302],
#                [ 0.8890, -0.0934, -0.6249]]),
#     x: Batch(
#            c: tensor([[-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828],
#                       [-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828],
#                       [-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828],
#                       [-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828],
#                       [-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828],
#                       [-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828],
#                       [-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828],
#                       [-0.1902,  1.8934, -2.1412, -0.9223],
#                       [-0.2366, -0.3746, -1.1031, -2.0069],
#                       [ 1.0283, -0.6302, -0.3412,  1.2828]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 149 µs ± 413 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 359 µs ± 3.99 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
