# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fad6c6d9760>
# ├── 'a' --> tensor([[ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461]])
# └── 'x' --> <FastTreeValue 0x7faca9d92c70>
#     └── 'c' --> tensor([[ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153]])

# %%
t.a
# Out:
# tensor([[ 0.7212, -0.5366, -0.2504],
#         [-0.5876, -1.0783, -0.4461]])

# %%
# %timeit t.a
# Out:
# 78.7 ns ± 0.11 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fad6c6d9760>
# ├── 'a' --> tensor([[ 0.0997,  1.4272, -1.1090],
# │                   [-0.3684, -1.0997,  0.7845]])
# └── 'x' --> <FastTreeValue 0x7faca9d92c70>
#     └── 'c' --> tensor([[ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153]])

# %%
# %timeit t.a = new_value
# Out:
# 87.2 ns ± 0.0399 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461]]),
#     x: Batch(
#            c: tensor([[ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.7212, -0.5366, -0.2504],
#         [-0.5876, -1.0783, -0.4461]])

# %%
# %timeit b.a
# Out:
# 68.1 ns ± 0.0438 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[-0.7196, -0.2167, -1.1822],
#                [ 0.5196,  0.1763, -0.1469]]),
#     x: Batch(
#            c: tensor([[ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 543 ns ± 0.0768 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 889 ns ± 0.341 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.2 µs ± 37.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 141 µs ± 1.18 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 144 µs ± 1.01 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fac90f999a0>
# ├── 'a' --> tensor([[[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]],
# │
# │                   [[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]],
# │
# │                   [[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]],
# │
# │                   [[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]],
# │
# │                   [[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]],
# │
# │                   [[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]],
# │
# │                   [[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]],
# │
# │                   [[ 0.7212, -0.5366, -0.2504],
# │                    [-0.5876, -1.0783, -0.4461]]])
# └── 'x' --> <FastTreeValue 0x7fac9eeb8d30>
#     └── 'c' --> tensor([[[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                         [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                         [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                         [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                         [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                         [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                         [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                         [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                          [ 0.5192,  1.1235, -0.3833, -0.2880],
#                          [-0.7102,  0.3791, -1.2177, -0.6153]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 217 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fac9eeb8e50>
# ├── 'a' --> tensor([[ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461],
# │                   [ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461],
# │                   [ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461],
# │                   [ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461],
# │                   [ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461],
# │                   [ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461],
# │                   [ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461],
# │                   [ 0.7212, -0.5366, -0.2504],
# │                   [-0.5876, -1.0783, -0.4461]])
# └── 'x' --> <FastTreeValue 0x7fac9eeb8be0>
#     └── 'c' --> tensor([[ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153],
#                         [ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153],
#                         [ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153],
#                         [ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153],
#                         [ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153],
#                         [ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153],
#                         [ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153],
#                         [ 0.3065,  0.0983,  2.4008, -2.3028],
#                         [ 0.5192,  1.1235, -0.3833, -0.2880],
#                         [-0.7102,  0.3791, -1.2177, -0.6153]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.6 µs ± 95 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.9 µs ± 31.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]],
#
#                [[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]],
#
#                [[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]],
#
#                [[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]],
#
#                [[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]],
#
#                [[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]],
#
#                [[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]],
#
#                [[ 0.7212, -0.5366, -0.2504],
#                 [-0.5876, -1.0783, -0.4461]]]),
#     x: Batch(
#            c: tensor([[[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                       [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                       [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                       [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                       [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                       [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                       [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]],
#
#                       [[ 0.3065,  0.0983,  2.4008, -2.3028],
#                        [ 0.5192,  1.1235, -0.3833, -0.2880],
#                        [-0.7102,  0.3791, -1.2177, -0.6153]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 84 µs ± 190 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461],
#                [ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461],
#                [ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461],
#                [ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461],
#                [ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461],
#                [ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461],
#                [ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461],
#                [ 0.7212, -0.5366, -0.2504],
#                [-0.5876, -1.0783, -0.4461]]),
#     x: Batch(
#            c: tensor([[ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153],
#                       [ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153],
#                       [ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153],
#                       [ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153],
#                       [ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153],
#                       [ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153],
#                       [ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153],
#                       [ 0.3065,  0.0983,  2.4008, -2.3028],
#                       [ 0.5192,  1.1235, -0.3833, -0.2880],
#                       [-0.7102,  0.3791, -1.2177, -0.6153]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 155 µs ± 431 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 354 µs ± 6.12 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
