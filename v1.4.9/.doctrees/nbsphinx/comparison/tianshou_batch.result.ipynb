# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fb532ff7fa0>
# ├── 'a' --> tensor([[-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893]])
# └── 'x' --> <FastTreeValue 0x7fb532ff7e50>
#     └── 'c' --> tensor([[ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442]])

# %%
t.a
# Out:
# tensor([[-0.1933,  0.8390, -0.9897],
#         [ 1.3075,  0.4517,  0.5893]])

# %%
# %timeit t.a
# Out:
# 64.7 ns ± 0.0548 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fb532ff7fa0>
# ├── 'a' --> tensor([[ 1.0158, -0.3076,  0.4634],
# │                   [ 0.1649, -0.1010, -0.7617]])
# └── 'x' --> <FastTreeValue 0x7fb532ff7e50>
#     └── 'c' --> tensor([[ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442]])

# %%
# %timeit t.a = new_value
# Out:
# 68.2 ns ± 0.0114 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893]]),
#     x: Batch(
#            c: tensor([[ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.1933,  0.8390, -0.9897],
#         [ 1.3075,  0.4517,  0.5893]])

# %%
# %timeit b.a
# Out:
# 57.5 ns ± 0.0332 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.0545, -0.0814, -1.8260],
#                [ 1.1886, -0.4560,  0.1352]]),
#     x: Batch(
#            c: tensor([[ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 487 ns ± 0.156 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 854 ns ± 0.264 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 31.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 138 µs ± 157 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 139 µs ± 444 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fb4550b4d90>
# ├── 'a' --> tensor([[[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]],
# │
# │                   [[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]],
# │
# │                   [[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]],
# │
# │                   [[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]],
# │
# │                   [[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]],
# │
# │                   [[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]],
# │
# │                   [[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]],
# │
# │                   [[-0.1933,  0.8390, -0.9897],
# │                    [ 1.3075,  0.4517,  0.5893]]])
# └── 'x' --> <FastTreeValue 0x7fb4550b4e20>
#     └── 'c' --> tensor([[[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                         [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                         [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                         [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                         [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                         [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                         [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                         [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                          [ 0.3403, -1.4044,  1.2080, -0.5636],
#                          [-0.1962,  0.6570, -2.5632, -0.2442]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.8 µs ± 41.5 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fb530145850>
# ├── 'a' --> tensor([[-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893],
# │                   [-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893],
# │                   [-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893],
# │                   [-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893],
# │                   [-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893],
# │                   [-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893],
# │                   [-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893],
# │                   [-0.1933,  0.8390, -0.9897],
# │                   [ 1.3075,  0.4517,  0.5893]])
# └── 'x' --> <FastTreeValue 0x7fb50c02dbb0>
#     └── 'c' --> tensor([[ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442],
#                         [ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442],
#                         [ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442],
#                         [ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442],
#                         [ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442],
#                         [ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442],
#                         [ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442],
#                         [ 0.0316,  0.2203, -0.9165,  0.1493],
#                         [ 0.3403, -1.4044,  1.2080, -0.5636],
#                         [-0.1962,  0.6570, -2.5632, -0.2442]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.7 µs ± 60.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 67.7 µs ± 80.7 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     a: tensor([[[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]],
#
#                [[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]],
#
#                [[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]],
#
#                [[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]],
#
#                [[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]],
#
#                [[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]],
#
#                [[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]],
#
#                [[-0.1933,  0.8390, -0.9897],
#                 [ 1.3075,  0.4517,  0.5893]]]),
#     x: Batch(
#            c: tensor([[[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                       [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                       [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                       [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                       [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                       [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                       [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]],
#
#                       [[ 0.0316,  0.2203, -0.9165,  0.1493],
#                        [ 0.3403, -1.4044,  1.2080, -0.5636],
#                        [-0.1962,  0.6570, -2.5632, -0.2442]]]),
#        ),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.5 µs ± 130 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     a: tensor([[-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893],
#                [-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893],
#                [-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893],
#                [-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893],
#                [-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893],
#                [-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893],
#                [-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893],
#                [-0.1933,  0.8390, -0.9897],
#                [ 1.3075,  0.4517,  0.5893]]),
#     x: Batch(
#            c: tensor([[ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442],
#                       [ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442],
#                       [ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442],
#                       [ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442],
#                       [ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442],
#                       [ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442],
#                       [ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442],
#                       [ 0.0316,  0.2203, -0.9165,  0.1493],
#                       [ 0.3403, -1.4044,  1.2080, -0.5636],
#                       [-0.1962,  0.6570, -2.5632, -0.2442]]),
#        ),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 392 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 319 µs ± 2.92 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
