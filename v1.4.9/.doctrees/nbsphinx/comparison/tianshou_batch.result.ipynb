# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7fc50098b130>
# ├── 'a' --> tensor([[-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078]])
# └── 'x' --> <FastTreeValue 0x7fc500977c70>
#     └── 'c' --> tensor([[-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205]])

# %%
t.a
# Out:
# tensor([[-0.2918, -1.5877, -2.6573],
#         [-0.1598,  0.0632,  1.2078]])

# %%
# %timeit t.a
# Out:
# 58.9 ns ± 0.0837 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7fc50098b130>
# ├── 'a' --> tensor([[ 1.0416, -0.3494,  0.9990],
# │                   [ 0.3242,  0.2933,  0.2608]])
# └── 'x' --> <FastTreeValue 0x7fc500977c70>
#     └── 'c' --> tensor([[-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205]])

# %%
# %timeit t.a = new_value
# Out:
# 61.2 ns ± 0.0577 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078]]),
#     x: Batch(
#            c: tensor([[-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[-0.2918, -1.5877, -2.6573],
#         [-0.1598,  0.0632,  1.2078]])

# %%
# %timeit b.a
# Out:
# 55.1 ns ± 0.0294 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 1.5162, -1.4652,  0.8117],
#                [-0.0460, -0.9863, -1.2807]]),
#     x: Batch(
#            c: tensor([[-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 478 ns ± 0.103 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 828 ns ± 0.864 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 11.4 µs ± 23.9 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 142 µs ± 955 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 382 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7fc430407c70>
# ├── 'a' --> tensor([[[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]],
# │
# │                   [[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]],
# │
# │                   [[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]],
# │
# │                   [[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]],
# │
# │                   [[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]],
# │
# │                   [[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]],
# │
# │                   [[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]],
# │
# │                   [[-0.2918, -1.5877, -2.6573],
# │                    [-0.1598,  0.0632,  1.2078]]])
# └── 'x' --> <FastTreeValue 0x7fc4303901c0>
#     └── 'c' --> tensor([[[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                         [[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                         [[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                         [[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                         [[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                         [[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                         [[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                         [[-0.0095, -0.1351,  0.6596, -0.7481],
#                          [ 0.6861,  0.8270,  0.3637,  0.6517],
#                          [ 0.1541, -1.0590, -2.3928, -1.1205]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33.5 µs ± 96.9 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7fc43db1c280>
# ├── 'a' --> tensor([[-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078],
# │                   [-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078],
# │                   [-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078],
# │                   [-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078],
# │                   [-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078],
# │                   [-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078],
# │                   [-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078],
# │                   [-0.2918, -1.5877, -2.6573],
# │                   [-0.1598,  0.0632,  1.2078]])
# └── 'x' --> <FastTreeValue 0x7fc4303c9f10>
#     └── 'c' --> tensor([[-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205],
#                         [-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205],
#                         [-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205],
#                         [-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205],
#                         [-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205],
#                         [-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205],
#                         [-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205],
#                         [-0.0095, -0.1351,  0.6596, -0.7481],
#                         [ 0.6861,  0.8270,  0.3637,  0.6517],
#                         [ 0.1541, -1.0590, -2.3928, -1.1205]])

# %%
# %timeit t_cat(trees)
# Out:
# 31.3 µs ± 66.2 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 65.3 µs ± 103 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                       [[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                       [[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                       [[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                       [[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                       [[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                       [[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]],
#
#                       [[-0.0095, -0.1351,  0.6596, -0.7481],
#                        [ 0.6861,  0.8270,  0.3637,  0.6517],
#                        [ 0.1541, -1.0590, -2.3928, -1.1205]]]),
#        ),
#     a: tensor([[[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]],
#
#                [[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]],
#
#                [[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]],
#
#                [[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]],
#
#                [[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]],
#
#                [[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]],
#
#                [[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]],
#
#                [[-0.2918, -1.5877, -2.6573],
#                 [-0.1598,  0.0632,  1.2078]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.3 µs ± 166 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205],
#                       [-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205],
#                       [-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205],
#                       [-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205],
#                       [-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205],
#                       [-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205],
#                       [-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205],
#                       [-0.0095, -0.1351,  0.6596, -0.7481],
#                       [ 0.6861,  0.8270,  0.3637,  0.6517],
#                       [ 0.1541, -1.0590, -2.3928, -1.1205]]),
#        ),
#     a: tensor([[-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078],
#                [-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078],
#                [-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078],
#                [-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078],
#                [-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078],
#                [-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078],
#                [-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078],
#                [-0.2918, -1.5877, -2.6573],
#                [-0.1598,  0.0632,  1.2078]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 354 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 323 µs ± 2.27 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
