# %% [markdown]
# # Comparison Between TreeValue and Tianshou Batch

# %% [markdown]
# In this section, we will take a look at the feature and performance of the [Tianshou Batch](https://github.com/thu-ml/tianshou) library, which is developed by Tsinghua Machine Learning Group.

# %% [markdown]
# Before starting the comparison, let us define some thing.

# %%
import torch 

_TREE_DATA_1 = {'a': 1, 'b': 2, 'x': {'c': 3, 'd': 4}}
_TREE_DATA_2 = {
    'a': torch.randn(2, 3), 
    'x': {
        'c': torch.randn(3, 4)
    },
}
_TREE_DATA_3 = {
    'obs': torch.randn(4, 84, 84),
    'action': torch.randint(0, 6, size=(1,)),
    'reward': torch.rand(1),
}

# %% [markdown]
# ## Read and Write Operation

# %% [markdown]
# Reading and writing are the two most common operations in the tree data structure based on the data model (TreeValue and Tianshou Batch both belong to this type), so this section will compare the reading and writing performance of these two libraries.

# %% [markdown]
# ### TreeValue's Get and Set

# %%
from treevalue import FastTreeValue

t = FastTreeValue(_TREE_DATA_2)

# %%
t
# Out:
# <FastTreeValue 0x7f5dd8a72a90>
# ├── 'a' --> tensor([[ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357]])
# └── 'x' --> <FastTreeValue 0x7f5dd8a72c10>
#     └── 'c' --> tensor([[ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016]])

# %%
t.a
# Out:
# tensor([[ 0.2517, -0.1784, -0.8919],
#         [ 1.2621,  0.0110,  0.3357]])

# %%
# %timeit t.a
# Out:
# 63.7 ns ± 0.409 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
t.a = new_value

t
# Out:
# <FastTreeValue 0x7f5dd8a72a90>
# ├── 'a' --> tensor([[ 1.8395, -2.7391,  0.4131],
# │                   [-1.0869, -1.3059, -1.4247]])
# └── 'x' --> <FastTreeValue 0x7f5dd8a72c10>
#     └── 'c' --> tensor([[ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016]])

# %%
# %timeit t.a = new_value
# Out:
# 69.9 ns ± 0.0371 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Get and Set

# %%
from tianshou.data import Batch

b = Batch(**_TREE_DATA_2)

# %%
b
# Out:
# Batch(
#     a: tensor([[ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357]]),
#     x: Batch(
#            c: tensor([[ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016]]),
#        ),
# )

# %%
b.a
# Out:
# tensor([[ 0.2517, -0.1784, -0.8919],
#         [ 1.2621,  0.0110,  0.3357]])

# %%
# %timeit b.a
# Out:
# 58.9 ns ± 0.0507 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
new_value = torch.randn(2, 3)
b.a = new_value

b
# Out:
# Batch(
#     a: tensor([[ 0.4465,  1.8448, -0.7256],
#                [ 1.5833, -1.4910, -0.7042]]),
#     x: Batch(
#            c: tensor([[ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016]]),
#        ),
# )

# %%
# %timeit b.a = new_value
# Out:
# 488 ns ± 0.0668 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### TreeValue's Initialization

# %%
# %timeit FastTreeValue(_TREE_DATA_1)
# Out:
# 850 ns ± 6.69 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ### Tianshou Batch's Initialization

# %%
# %timeit Batch(**_TREE_DATA_1)
# Out:
# 10.7 µs ± 19.2 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## Deep Copy Operation

# %%
import copy

# %% [markdown]
# ### Deep Copy of TreeValue

# %%
t3 = FastTreeValue(_TREE_DATA_3)
# %timeit copy.deepcopy(t3)
# Out:
# 144 µs ± 1.36 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Deep Copy of Tianshou Batch

# %%
b3 = Batch(**_TREE_DATA_3)
# %timeit copy.deepcopy(b3)
# Out:
# 142 µs ± 647 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Stack, Concat and Split Operation

# %% [markdown]
# ### Performance of TreeValue

# %%
trees = [FastTreeValue(_TREE_DATA_2) for _ in range(8)]

# %%
t_stack = FastTreeValue.func(subside=True)(torch.stack)

t_stack(trees)
# Out:
# <FastTreeValue 0x7f5dd8a72850>
# ├── 'a' --> tensor([[[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]],
# │
# │                   [[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]],
# │
# │                   [[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]],
# │
# │                   [[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]],
# │
# │                   [[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]],
# │
# │                   [[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]],
# │
# │                   [[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]],
# │
# │                   [[ 0.2517, -0.1784, -0.8919],
# │                    [ 1.2621,  0.0110,  0.3357]]])
# └── 'x' --> <FastTreeValue 0x7f5dd8a72d00>
#     └── 'c' --> tensor([[[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                         [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                         [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                         [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                         [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                         [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                         [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                         [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                          [-0.2265, -0.1483,  3.0062,  1.2603],
#                          [-0.5943, -0.3281, -0.7946,  0.5016]]])

# %%
# %timeit t_stack(trees)
# Out:
# 33 µs ± 95 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_cat = FastTreeValue.func(subside=True)(torch.cat)

t_cat(trees)
# Out:
# <FastTreeValue 0x7f5d09687940>
# ├── 'a' --> tensor([[ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357],
# │                   [ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357],
# │                   [ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357],
# │                   [ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357],
# │                   [ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357],
# │                   [ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357],
# │                   [ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357],
# │                   [ 0.2517, -0.1784, -0.8919],
# │                   [ 1.2621,  0.0110,  0.3357]])
# └── 'x' --> <FastTreeValue 0x7f5dd8a72ac0>
#     └── 'c' --> tensor([[ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016],
#                         [ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016],
#                         [ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016],
#                         [ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016],
#                         [ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016],
#                         [ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016],
#                         [ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016],
#                         [ 1.8303, -0.7548,  1.5602,  0.5168],
#                         [-0.2265, -0.1483,  3.0062,  1.2603],
#                         [-0.5943, -0.3281, -0.7946,  0.5016]])

# %%
# %timeit t_cat(trees)
# Out:
# 31 µs ± 67.6 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
t_split = FastTreeValue.func(rise=True)(torch.split)
tree = FastTreeValue({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1),
})

# %timeit t_split(tree, 1)
# Out:
# 68 µs ± 69 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ### Performance of Tianshou Batch

# %%
batches = [Batch(**_TREE_DATA_2) for _ in range(8)]

Batch.stack(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                       [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                       [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                       [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                       [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                       [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                       [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]],
#
#                       [[ 1.8303, -0.7548,  1.5602,  0.5168],
#                        [-0.2265, -0.1483,  3.0062,  1.2603],
#                        [-0.5943, -0.3281, -0.7946,  0.5016]]]),
#        ),
#     a: tensor([[[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]],
#
#                [[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]],
#
#                [[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]],
#
#                [[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]],
#
#                [[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]],
#
#                [[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]],
#
#                [[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]],
#
#                [[ 0.2517, -0.1784, -0.8919],
#                 [ 1.2621,  0.0110,  0.3357]]]),
# )

# %%
# %timeit Batch.stack(batches)
# Out:
# 79.2 µs ± 406 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
Batch.cat(batches)
# Out:
# Batch(
#     x: Batch(
#            c: tensor([[ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016],
#                       [ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016],
#                       [ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016],
#                       [ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016],
#                       [ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016],
#                       [ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016],
#                       [ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016],
#                       [ 1.8303, -0.7548,  1.5602,  0.5168],
#                       [-0.2265, -0.1483,  3.0062,  1.2603],
#                       [-0.5943, -0.3281, -0.7946,  0.5016]]),
#        ),
#     a: tensor([[ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357],
#                [ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357],
#                [ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357],
#                [ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357],
#                [ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357],
#                [ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357],
#                [ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357],
#                [ 0.2517, -0.1784, -0.8919],
#                [ 1.2621,  0.0110,  0.3357]]),
# )

# %%
# %timeit Batch.cat(batches)
# Out:
# 150 µs ± 403 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
batch = Batch({
    'obs': torch.randn(8, 4, 84, 84),
    'action': torch.randint(0, 6, size=(8, 1,)),
    'reward': torch.rand(8, 1)}
)

# %timeit list(Batch.split(batch, 1, shuffle=False, merge_last=True))
# Out:
# 344 µs ± 2.29 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
